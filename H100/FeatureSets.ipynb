# %%
# define the environment path 
import os
local_cobrakbase_path = os.path.join("C:", "Users", 'Andrew Freiburger',"Documents","Argonne","cobrakbase")
os.environ["HOME"] = local_cobrakbase_path

# import the KBase
import cobrakbase
with open("/Users/afreiburger/Documents/kbase_token.txt") as token_file:
# with open("C:/Users/Andrew Freiburger/Documents/Argonne/kbase_token.txt") as token_file:
    kbase_api = cobrakbase.KBaseAPI(token_file.readline())


featureSets = kbase_api.list_objects(190263, object_type="KBaseCollections.FeatureSet", include_metadata=False)
print(featureSets[0])
obj = kbase_api.get_from_ws(featureSets[0][1], 190263)

for k,v in obj.data.items():
    if isinstance(v, str):  continue
    print(k, end="\t")
    try:
        print(len(v))
    except Exception as e:
        # print(e)
        continue
    print()

print(obj.data['data'])
from pandas import DataFrame
df = DataFrame(data=obj.data['data'])#, ignoreIndex=True)
display(df)
print(dir(obj))
# models = [kbase_api.get_from_ws(featSet[1], 190263) for featSet in featureSets]
# Out:
# [603, 'GH1-Streptococcus-thermophilus-ATCC-19258-MAF-2.gbff_genome.RAST_HMMER_dbCAN_Search.FeatureSet', 'KBaseCollections.FeatureSet-2.0', '2024-09-03T15:31:41+0000', 1, 'freiburgermsu', 190263, 'freiburgermsu:narrative_1724954244921', '66e59a1a63ecafba24de947dac0b8820', 173, None]
# element_ordering	2
#
# elements	2
#
# exclude_dict	0
#
# data_keys	3
#
# info	data	16
#
# provenance	1
#
# path	1
#
# orig_wsid	epoch	refs	1
#
# copied	copy_source_inaccessible	{'description': 'HMMER_dbCAN_Search filtered', 'element_ordering': ['KJODLM_09470', 'KJODLM_06495'], 'elements': {'KJODLM_06495': ['190263/362/1'], 'KJODLM_09470': ['190263/362/1']}, 'exclude_dict': set(), 'data_keys': {'description': <class 'str'>, 'element_ordering': <class 'list'>, 'elements': <class 'dict'>}, 'info': <cobrakbase.kbase_object_info.KBaseObjectInfo object at 0x13cc19940>, 'data': {...}, 'provenance': [{'service': 'kb_hmmer', 'method': 'HMMER_dbCAN_Search', 'method_params': [{'model_cov_perc': 35, 'model_group': 'dbCAN', 'heatmap': '1', 'save_ANY_featureSets': '1', 'input_dbCAN_cellulosome_ids': ['ALL'], 'maxaccepts': 1000, 'input_dbCAN_PL_ids': ['ALL'], 'output_filtered_name': 'Streptococcus-thermophilus-ATCC-19258-MAF-2.gbff_genome.RAST_HMMER_dbCAN_Search.FeatureSet', 'e_value': 1e-15, 'vertical': '1', 'save_ALL_featureSets': '1', 'input_dbCAN_CBM_ids': ['ALL'], 'input_dbCAN_AA_ids': ['ALL'], 'show_target_block_headers': '1', 'input_dbCAN_CE_ids': ['ALL'], 'low_val': '1', 'bitscore': 100, 'show_blanks': '0', 'input_many_refs': ['190263/362/1'], 'input_dbCAN_GH_ids': ['ALL'], 'coalesce_output': '0', 'input_dbCAN_GT_ids': ['ALL'], 'genome_disp_name_config': 'obj_name', 'workspace_name': 'freiburgermsu:narrative_1724954244921'}], 'input_ws_objects': ['190263/362/1'], 'resolved_ws_objects': ['190263/362/1'], 'intermediate_incoming': [], 'intermediate_outgoing': [], 'external_data': [], 'subactions': [], 'custom': {}}], 'path': ['190263/603/1'], 'creator': 'freiburgermsu', 'orig_wsid': 190263, 'created': '2024-09-03T15:31:40+0000', 'epoch': 1725377500651, 'refs': ['190263/362/1'], 'copied': None, 'copy_source_inaccessible': 0}
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[20], line 29
#      27 print(obj.data['data'])
#      28 from pandas import DataFrame
# ---> 29 df = DataFrame(data=obj.data['data'])#, ignoreIndex=True)
#      30 display(df)
#      31 print(dir(obj))
#
# File /Users/afreiburger/test/lib/python3.12/site-packages/pandas/core/frame.py:778, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     772     mgr = self._init_mgr(
#     773         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     774     )
#     776 elif isinstance(data, dict):
#     777     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 778     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     779 elif isinstance(data, ma.MaskedArray):
#     780     from numpy.ma import mrecords
#
# File /Users/afreiburger/test/lib/python3.12/site-packages/pandas/core/internals/construction.py:503, in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     499     else:
#     500         # dtype check to exclude e.g. range objects, scalars
#     501         arrays = [x.copy() if hasattr(x, "dtype") else x for x in arrays]
# --> 503 return arrays_to_mgr(arrays, columns, index, dtype=dtype, typ=typ, consolidate=copy)
#
# File /Users/afreiburger/test/lib/python3.12/site-packages/pandas/core/internals/construction.py:114, in arrays_to_mgr(arrays, columns, index, dtype, verify_integrity, typ, consolidate)
#     111 if verify_integrity:
#     112     # figure out the index, if necessary
#     113     if index is None:
# --> 114         index = _extract_index(arrays)
#     115     else:
#     116         index = ensure_index(index)
#
# File /Users/afreiburger/test/lib/python3.12/site-packages/pandas/core/internals/construction.py:677, in _extract_index(data)
#     675 lengths = list(set(raw_lengths))
#     676 if len(lengths) > 1:
# --> 677     raise ValueError("All arrays must be of the same length")
#     679 if have_dicts:
#     680     raise ValueError(
#     681         "Mixing dicts with non-Series may lead to ambiguous ordering."
#     682     )
#
# ValueError: All arrays must be of the same length

# %% [markdown]
# # Evaluate the KBase App outputs

# %%
from pandas import read_csv
from glob import glob

dfs = []
for file in glob("HMMER_output_TAB/*"):
    dfs.append(read_csv(file, sep="\t"))

# %%
display(dfs[:5])
# Out:
# [   #                                                                                   --- full sequence --- -------------- this domain -------------   hmm coord   ali coord   env coord
#  0   # target name               accession   tlen q...
#  1   #       ------------------- ---------- ----- -...
#  2   190263/400/1.f:EIBLKL_08285 -            659 G...
#  3   190263/412/1.f:OOIBGL_06550 -            649 G...
#  4   190263/412/1.f:OOIBGL_08215 -            579 G...
#  5   190263/396/1.f:KAAOMA_00970 -            708 G...
#  6   190263/396/1.f:KAAOMA_01800 -            744 G...
#  7   190263/396/1.f:KAAOMA_01805 -            641 G...
#  8   190263/412/1.f:OOIBGL_15685 -            682 G...
#  9                                                   #
#  10                       # Program:         hmmsearch
#  11                # Version:         3.3.2 (Nov 2020)
#  12                          # Pipeline mode:   SEARCH
#  13  # Query file:      /kb/module/work/tmp/output....
#  14  # Target file:     /kb/module/work/tmp/output....
#  15  # Option settings: /kb/module/hmmer/bin/hmmsea...
#  16  # Current dir:     /kb/module/work/tmp/output....
#  17        # Date:            Tue Sep  3 18:46:40 2024
#  18                                             # [ok]                                                                                                                                    ,
#      #                                                                                   --- full sequence --- -------------- this domain -------------   hmm coord   ali coord   env coord
#  0    # target name               accession   tlen q...
#  1    #       ------------------- ---------- ----- -...
#  2    190263/420/1.f:GMHOLO_07820 -            726 G...
#  3    190263/527/1.f:HGADJN_08165 -            762 G...
#  4    190263/474/1.f:AMDJJA_01315 -            757 G...
#  ..                                                 ...
#  314  # Target file:     /kb/module/work/tmp/output....
#  315  # Option settings: /kb/module/hmmer/bin/hmmsea...
#  316  # Current dir:     /kb/module/work/tmp/output....
#  317        # Date:            Tue Sep  3 18:47:50 2024
#  318                                             # [ok]
#
#  [319 rows x 1 columns],
#      #                                                                                   --- full sequence --- -------------- this domain -------------   hmm coord   ali coord   env coord
#  0    # target name               accession   tlen q...
#  1    #       ------------------- ---------- ----- -...
#  2    190263/415/1.f:OLCEDN_02815 -            356 G...
#  3    190263/382/1.f:JACGKO_02680 -            369 G...
#  4    190263/436/1.f:KEEIED_06605 -            369 G...
#  ..                                                 ...
#  161  # Target file:     /kb/module/work/tmp/output....
#  162  # Option settings: /kb/module/hmmer/bin/hmmsea...
#  163  # Current dir:     /kb/module/work/tmp/output....
#  164        # Date:            Tue Sep  3 18:58:16 2024
#  165                                             # [ok]
#
#  [166 rows x 1 columns],
#     #                                                                                   --- full sequence --- -------------- this domain -------------   hmm coord   ali coord   env coord
#  0   # target name               accession   tlen q...
#  1   #       ------------------- ---------- ----- -...
#  2   190263/541/1.f:IDEEIE_07980 -           1260 G...
#  3   190263/541/1.f:IDEEIE_14815 -           1077 G...
#  4   190263/557/1.f:DOLMEB_10775 -           1301 G...
#  5   190263/495/1.f:ANKNCD_12120 -            861 G...
#  6   190263/512/1.f:JBCLGH_09280 -           1271 G...
#  7   190263/541/1.f:IDEEIE_07975 -            890 G...
#  8   190263/520/1.f:GGDGDE_09070 -            428 G...
#  9   190263/409/1.f:AJJCMD_02925 -           1874 G...
#  10  190263/375/1.f:CNGHJF_13215 -           1579 G...
#  11  190263/541/1.f:IDEEIE_06680 -           1245 G...
#  12  190263/409/1.f:AJJCMD_02060 -           1931 G...
#  13  190263/368/1.f:HPMDBE_22655 -            556 G...
#  14  190263/537/1.f:AHPNMI_06065 -           1425 G...
#  15  190263/439/1.f:KGLJGB_01045 -           1870 G...
#  16  190263/399/1.f:CDLIDF_01995 -            451 G...
#  17  190263/399/1.f:CDLIDF_07875 -            504 G...
#  18  190263/365/1.f:JJMMAK_15870 -            534 G...
#  19  190263/405/1.f:EHKDKA_10015 -            508 G...
#  20  190263/409/1.f:AJJCMD_17230 -           1869 G...
#  21  190263/366/1.f:DBJPFP_08230 -            565 G...
#  22  190263/391/1.f:NONBJF_03015 -            504 G...
#  23  190263/545/1.f:NCJBIN_03375 -            504 G...
#  24  190263/388/1.f:FDDJJK_03140 -            504 G...
#  25  190263/534/1.f:OHCFJE_08650 -            504 G...
#  26  190263/580/1.f:JCPJNN_28105 -            457 G...
#  27  190263/405/1.f:EHKDKA_09690 -            511 G...
#  28  190263/405/1.f:EHKDKA_09695 -            469 G...
#  29  190263/438/1.f:IKAFOJ_03820 -            236 G...
#  30  190263/366/1.f:DBJPFP_07120 -            486 G...
#  31  190263/438/1.f:IKAFOJ_03815 -            149 G...
#  32  190263/366/1.f:DBJPFP_12270 -           1049 G...
#  33                                                  #
#  34                       # Program:         hmmsearch
#  35                # Version:         3.3.2 (Nov 2020)
#  36                          # Pipeline mode:   SEARCH
#  37  # Query file:      /kb/module/work/tmp/output....
#  38  # Target file:     /kb/module/work/tmp/output....
#  39  # Option settings: /kb/module/hmmer/bin/hmmsea...
#  40  # Current dir:     /kb/module/work/tmp/output....
#  41        # Date:            Tue Sep  3 18:56:12 2024
#  42                                             # [ok]                                                                                                                                    ,
#      #                                                                                   --- full sequence --- -------------- this domain -------------   hmm coord   ali coord   env coord
#  0    # target name               accession   tlen q...
#  1    #       ------------------- ---------- ----- -...
#  2    190263/495/1.f:ANKNCD_08725 -           1674 G...
#  3    190263/423/1.f:PDNKFB_06835 -           1368 G...
#  4    190263/474/1.f:AMDJJA_00550 -           1708 G...
#  ..                                                 ...
#  415  # Target file:     /kb/module/work/tmp/output....
#  416  # Option settings: /kb/module/hmmer/bin/hmmsea...
#  417  # Current dir:     /kb/module/work/tmp/output....
#  418        # Date:            Tue Sep  3 18:48:17 2024
#  419                                             # [ok]
#
#  [420 rows x 1 columns]]
