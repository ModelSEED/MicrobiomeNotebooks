# %% [markdown]
# # parse and condense all of the App outputs into a single succinct CSV for annotation integration

# %%
from pandas import DataFrame, concat
from glob import glob

dfs = []
for hits in glob("HMMER_output_TAB/*.txt"):
    file = open(hits, 'r')
    lines = file.readlines()
    newLines = []
    for line in lines:
        if any(x in line for x in ["---", "[ok]", ': ', "#\n"]):   continue
        if line.strip() == '#': continue
        newLines.append(line.replace("description of target", "KBaseObj").replace(" name", ''))
    columns = [x.strip() for x in newLines[0].split()][1:]
    rows = [[x.strip() for x in line.split()] for line in newLines[1:]]
    dfs.append(DataFrame(rows, columns=columns))


totDF = concat(dfs)
totDF.to_csv("CAZY_H100_hits.csv")
display(totDF)
# Out:
#                          target accession tlen       query accession qlen  \
# 0   190263/400/1.f:EIBLKL_08285         -  659  GH5_20.hmm         -  344
# 1   190263/412/1.f:OOIBGL_06550         -  649  GH5_20.hmm         -  344
# 2   190263/412/1.f:OOIBGL_08215         -  579  GH5_20.hmm         -  344
# 3   190263/396/1.f:KAAOMA_00970         -  708  GH5_20.hmm         -  344
# 4   190263/396/1.f:KAAOMA_01800         -  744  GH5_20.hmm         -  344
# ..                          ...       ...  ...         ...       ...  ...
# 37  190263/562/1.f:KJGNCK_06255         -  346   GH5_2.hmm         -  237
# 38  190263/475/1.f:MCKEEP_04335         -  346   GH5_2.hmm         -  237
# 39  190263/396/1.f:KAAOMA_19800         -  936   GH5_2.hmm         -  237
# 40  190263/460/1.f:IHFGKI_14410         -  464   GH5_2.hmm         -  237
# 41  190263/412/1.f:OOIBGL_00395         -  410   GH5_2.hmm         -  237
#
#     E-value  score bias  #  ...  score bias from   to from   to from   to  \
# 0   2.3e-34  123.6  3.2  1  ...  119.5  3.2    3  250  275  536  273  596
# 1   3.7e-33  119.6  3.1  1  ...  117.7  3.3    3  249  265  525  263  536
# 2   1.8e-30  110.8  0.4  1  ...  110.1  0.4    3  336   66  422   64  429
# 3   2.1e-26   97.4  1.5  1  ...   94.9  1.5    3  306   59  377   57  413
# 4   1.1e-21   81.9  0.5  1  ...   80.4  0.5    3  265   58  348   56  361
# ..      ...    ...  ... ..  ...    ...  ...  ...  ...  ...  ...  ...  ...
# 37  1.6e-13   55.2  0.0  1  ...   54.7  0.0   56  185   92  246   57  307
# 38  2.3e-13   54.6  0.1  1  ...   54.2  0.1   56  184   92  240   55  306
# 39    5e-13   53.5  0.7  1  ...   52.8  0.7    3  220  549  768  547  781
# 40  1.4e-12   52.1  0.6  1  ...   51.5  0.6   61  235  133  334   83  336
# 41  1.6e-12   51.9  0.0  1  ...   51.1  0.0   23  213  110  343   86  365
#
#      acc        KBaseObj
# 0   0.85  [190263/400/1]
# 1   0.83  [190263/412/1]
# 2   0.79  [190263/412/1]
# 3   0.73  [190263/396/1]
# 4   0.77  [190263/396/1]
# ..   ...             ...
# 37  0.74  [190263/562/1]
# 38  0.77  [190263/475/1]
# 39  0.76  [190263/396/1]
# 40  0.82  [190263/460/1]
# 41  0.75  [190263/412/1]
#
# [44860 rows x 23 columns]

# %%
totDF.columns
# Out:
# Index(['target', 'accession', 'tlen', 'query', 'accession', 'qlen', 'E-value',
#        'score', 'bias', '#', 'of', 'c-Evalue', 'i-Evalue', 'score', 'bias',
#        'from', 'to', 'from', 'to', 'from', 'to', 'acc', 'KBaseObj'],
#       dtype='object')

# %% [markdown]
# # Process the CAZY HTML output into a CSV

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(open("KBase HMMER Custom Model Profile.html", "r").read() , 'lxml-xml')

# %% [markdown]
# ## parse the labels

# %%
# organism labels
horizontal_rows = soup.find_all(class_="horz-text")
organisms = []
for content in horizontal_rows:
    label = content.find("nobr")
    if label is None:  continue
    organisms.append(label.text.replace(".gbff_genome.RAST", ''))
print(organisms)

# feature labels
vertical_cols = soup.find_all(class_="vertical-text")
features = []
for content in vertical_cols:
    label = content.find("nobr")
    if label is None:  continue
    features.append(label.text.replace("\n", ''))
print(features)
# Out:
# ['Acidaminococcus-fermentans-DSM-20731-MAF-2', 'Acidaminococcus-sp-D21-MAF-2', 'Adlercreutzia-equolifaciens-DSM-19450', 'Akkermansia-muciniphila-ATCC-BAA-835-MAF-2', 'Alistipes-finegoldii-DSM-17242', 'Alistipes-ihumii-AP11-MAF-2', 'Alistipes-indistinctus-YIT-12060-DSM-22520-MAF-2', 'Alistipes-onderdonkii-DSM-19147-MAF-2', 'Alistipes-putredinis-DSM-17216-MAF-2', 'Alistipes-senegalensis-JC50-DSM-25460-MAF-2', 'Alistipes-shahii-WAL-8301-DSM-19121-MAF-2', 'Anaerofustis-stercorihominis-DSM-17244', 'Anaerostipes-caccae-DSM-14662-MAF-2', 'Anaerotruncus-colihominis-DSM-17241-MAF-2', 'Bacteroides-caccae-ATCC-43185-MAF-2', 'Bacteroides-cellulosilyticus-DSM-14838-MAF-2', 'Bacteroides-coprocola-DSM-17136-MAF-2', 'Bacteroides-coprophilus-DSM-18228-MAF-2', 'Bacteroides-dorei-5-1-36-MAF-2', 'Bacteroides-dorei-DSM-17855-MAF-2', 'Bacteroides-eggerthii-DSM-20697-MAF-2', 'Bacteroides-finegoldii-DSM-17565-MAF-2', 'Bacteroides-fragilis-3-1-12-MAF-2', 'Bacteroides-intestinalis-DSM-17393-MAF-2', 'Bacteroides-ovatus-ATCC-8483-MAF-2', 'Bacteroides-pectinophilus-ATCC-43243-MAF-2', 'Bacteroides-plebeius-DSM-17135-MAF-2', 'Bacteroides-rodentium-DSM-26882-MAF-2', 'Bacteroides-sp-1-1-6-MAF-2', 'Bacteroides-sp-2-1-16-MAF-2', 'Bacteroides-sp-2-1-22-MAF-2', 'Bacteroides-sp-3-1-19-MAF-2', 'Bacteroides-sp-9-1-42FAA-MAF-2', 'Bacteroides-sp-D2-MAF-2', 'Bacteroides-stercoris-ATCC-43183-MAF-2', 'Bacteroides-thetaiotaomicron-VPI-5482-MAF-2', 'Bacteroides-uniformis-ATCC-8492-MAF-2', 'Bacteroides-vulgatus-ATCC-8482', 'Bacteroides-xylanisolvens-DSMZ-18836-MAF-2', 'Bifidobacterium-breve-DSM-20213-MAF-2', 'Bifidobacterium-catenulatum-DSM-16992-MAF-2', 'Bifidobacterium-pseudocatenulatum-DSM-20438-MAF-2', 'Bilophila-wadsworthia-ATCC-49260-MAF-3', 'Blautia-hansenii-DSM-20583-MAF-2', 'Blautia-hydrogenotrophica-DSM-10507-MAF-2', 'Blautia-sp-KLE-1732-HM-1032-MAF-2', 'Blautia-wexlerae-DSM-19850-MAF-2', 'Bryantella-formatexigens-DSM-14469-MAF-2', 'Burkholderiales-bacterium-1-1-47-MAF-2', 'Butyricimonas-virosa-DSM-23226-MAF-2', 'Butyrivibrio-crossotus-DSM-2876-MAF-2', 'Catenibacterium-mitsuokai-DSM-15897-MAF-2', 'Clostridiales-bacterium-VE202-03', 'Clostridiales-bacterium-VE202-14-MAF-2', 'Clostridiales-bacterium-VE202-27-MAF-3', 'Clostridium-asparagiforme-DSM-15981-MAF-2', 'Clostridium-bartlettii-DSM-16795-MAF-2', 'Clostridium-bolteae-ATCC-BAA-613-MAF-2', 'Clostridium-hathewayi-DSM-13479-MAF-2', 'Clostridium-hylemonae-DSM-15053-MAF-2', 'Clostridium-leptum-DSM-753-MAF-2', 'Clostridium-methylpentosum-DSM-5476', 'Clostridium-nexile-DSM-1787-MAF-2', 'Clostridium-saccharolyticum-WM1-MAF-2', 'Clostridium-scindens-ATCC-35704-MAF-2', 'Clostridium-sp-ATCC-29733-VPI-C48-50-MAF-2', 'Clostridium-sp-L2-50-MAF-3', 'Clostridium-sp-M62-1-MAF-2', 'Clostridium-spiroforme-DSM-1552-MAF-2', 'Clostridium-sporogenes-ATCC-15579-MAF-2', 'Collinsella-aerofaciens-ATCC-25986-MAF-2', 'Collinsella-stercoris-DSM-13279-MAF-2', 'Coprococcus-comes-ATCC-27758-MAF-2', 'Coprococcus-eutactus-ATCC-27759-MAF-2', 'Desulfovibrio-piger-ATCC-29098-MAF-2', 'Dorea-formicigenerans-ATCC-27755-MAF-2', 'Dorea-longicatena-DSM-13814-MAF-2', 'Eggerthella-lenta-DSM-2243-MAF-2', 'Ethanoligens-harbinense-YUAN-3', 'Eubacterium-biforme-DSM-3989-MAF-2', 'Eubacterium-dolichum-DSM-3991', 'Eubacterium-eligens-ATCC-27750-MAF-2', 'Eubacterium-hallii-DSM-3353-MAF-2', 'Eubacterium-rectale-ATCC-33656-MAF-3', 'Eubacterium-siraeum-DSM-15702-MAF-2', 'Eubacterium-ventriosum-ATCC-27560-MAF-2', 'Faecalibacterium-prausnitzii-A2-165-MAF-2', 'Granulicatella-adiacens-ATCC-49175-MAF-2', 'Holdemania-filiformis-DSM-12042-MAF-2', 'Intestinimonas-butyriciproducens-DSM-26588-MAF-2', 'Lactobacillus-ruminis-ATCC-25644-MAF-2', 'Megasphaera-DSMZ-102144-MAF-2', 'Mitsuokella-multacida-DSM-20544-MAF-2', 'Odoribacter-splanchnicus-DSM-20712-MAF-2', 'Olsenella-uli-DSM-7084-MAF-2', 'Oscillibacter-sp-KLE-1728-MAF-2', 'Parabacteroides-distasonis-ATCC-8503-MAF-2', 'Parabacteroides-johnsonii-DSM-18315-MAF-2', 'Parabacteroides-merdae-ATCC-43184-MAF-2', 'Parabacteroides-sp-D13 ...
# ['GH1', 'GH2', 'GH3', 'GH4', 'GH5', 'GH5_1', 'GH5_2', 'GH5_4', 'GH5_5', 'GH5_7', 'GH5_8', 'GH5_9', 'GH5_10', 'GH5_13', 'GH5_14', 'GH5_18', 'GH5_19', 'GH5_20', 'GH5_21', 'GH5_22', 'GH5_25', 'GH5_26', 'GH5_27', 'GH5_28', 'GH5_29', 'GH5_36', 'GH5_37', 'GH5_38', 'GH5_39', 'GH5_44', 'GH5_45', 'GH5_46', 'GH5_47', 'GH5_50', 'GH5_52', 'GH5_54', 'GH5_55', 'GH5_56', 'GH8', 'GH9', 'GH10', 'GH11', 'GH13', 'GH13_1', 'GH13_2', 'GH13_3', 'GH13_4', 'GH13_5', 'GH13_6', 'GH13_7', 'GH13_8', 'GH13_9', 'GH13_10', 'GH13_11', 'GH13_12', 'GH13_13', 'GH13_14', 'GH13_15', 'GH13_16', 'GH13_17', 'GH13_18', 'GH13_19', 'GH13_20', 'GH13_21', 'GH13_23', 'GH13_24', 'GH13_27', 'GH13_28', 'GH13_29', 'GH13_30', 'GH13_31', 'GH13_32', 'GH13_33', 'GH13_35', 'GH13_36', 'GH13_37', 'GH13_38', 'GH13_39', 'GH13_40', 'GH13_41', 'GH13_42', 'GH14', 'GH15', 'GH16', 'GH16_3', 'GH16_4', 'GH16_5', 'GH16_6', 'GH16_7', 'GH16_8', 'GH16_11', 'GH16_12', 'GH16_13', 'GH16_14', 'GH16_16', 'GH16_21', 'GH16_24', 'GH16_25', 'GH16_26', 'GH18', 'GH20', 'GH23', 'GH24', 'GH25', 'GH26', 'GH27', 'GH28', 'GH29', 'GH30', 'GH30_1', 'GH30_2', 'GH30_3', 'GH30_4', 'GH30_5', 'GH30_6', 'GH30_7', 'GH30_8', 'GH30_9', 'GH31', 'GH32', 'GH33', 'GH35', 'GH36', 'GH37', 'GH38', 'GH39', 'GH42', 'GH43', 'GH43_1', 'GH43_2', 'GH43_3', 'GH43_4', 'GH43_5', 'GH43_6', 'GH43_7', 'GH43_8', 'GH43_9', 'GH43_10', 'GH43_11', 'GH43_12', 'GH43_13', 'GH43_14', 'GH43_15', 'GH43_16', 'GH43_17', 'GH43_18', 'GH43_19', 'GH43_20', 'GH43_21', 'GH43_22', 'GH43_23', 'GH43_24', 'GH43_26', 'GH43_27', 'GH43_28', 'GH43_29', 'GH43_30', 'GH43_31', 'GH43_32', 'GH43_33', 'GH43_34', 'GH43_35', 'GH43_36', 'GH43_37', 'GH44', 'GH46', 'GH48', 'GH49', 'GH50', 'GH51', 'GH52', 'GH53', 'GH55', 'GH57', 'GH59', 'GH63', 'GH64', 'GH65', 'GH66', 'GH67', 'GH68', 'GH73', 'GH74', 'GH76', 'GH77', 'GH78', 'GH79', 'GH81', 'GH84', 'GH85', 'GH86', 'GH88', 'GH89', 'GH91', 'GH92', 'GH93', 'GH94', 'GH95', 'GH97', 'GH98', 'GH99', 'GH101', 'GH102', 'GH103', 'GH105', 'GH106', 'GH108', 'GH109', 'GH110', 'GH112', 'GH113', 'GH115', 'GH116', 'GH117', 'GH120', 'GH121', 'GH123', 'GH124', 'GH125', 'GH127', 'GH128', 'GH129', 'GH130', 'GH133', 'GH136', 'GH137', 'GH138', 'GH139', 'GH140', 'GH141', 'GH142', 'GH143', 'GH144', 'GH146', 'GH147', 'GH148', 'GH151', 'GH154', 'GH156', 'GH158', 'GH159', 'GH161', 'GH163', 'GH164', 'GH165', 'GH166', 'GH170', 'GH171', 'GT1', 'GT2_Glycos_transf_2', 'GT2_Glyco_tranf_2_3', 'GT2_Glyco_tranf_2_5', 'GT3', 'GT4', 'GT5', 'GT6', 'GT8', 'GT9', 'GT10', 'GT11', 'GT14', 'GT17', 'GT19', 'GT20', 'GT22', 'GT23', 'GT25', 'GT26', 'GT28', 'GT30', 'GT35', 'GT39', 'GT51', 'GT56', 'GT66', 'GT80', 'GT83', 'GT84', 'GT100', 'GT101', 'GT104', 'GT107', 'GT108', 'GT111', 'GT113', 'CBM4', 'CBM6', 'CBM9', 'CBM22', 'CBM23', 'CBM27', 'CBM32', 'CBM34', 'CBM35', 'CBM35inCE17', 'CBM37', 'CBM38', 'CBM40', 'CBM51', 'CBM57', 'CBM58', 'CBM61', 'CBM62', 'CBM65', 'CBM66', 'CBM67', 'CBM70', 'CBM74', 'CBM75', 'CBM76', 'CBM77', 'CBM78', 'CBM79', 'CBM80', 'CBM82', 'CBM83', 'CBM86', 'CE1', 'CE2', 'CE3', 'CE4', 'CE6', 'CE7', 'CE8', 'CE9', 'CE11', 'CE12', 'CE15', 'CE17', 'CE19', 'PL1', 'PL1_2', 'PL1_5', 'PL1_7', 'PL6', 'PL6_1', 'PL6_2', 'PL7', 'PL7_1', 'PL8', 'PL8_1', 'PL8_2', 'PL8_3', 'PL9', 'PL9_1', 'PL9_2', 'PL9_3', 'PL10', 'PL10_1', 'PL10_2', 'PL10_3', 'PL11', 'PL11_1', 'PL11_2', 'PL12', 'PL12_1', 'PL12_2', 'PL12_3', 'PL13', 'PL15', 'PL15_2', 'PL17', 'PL17_1', 'PL17_2', 'PL21', 'PL21_1', 'PL22', 'PL26', 'PL27', 'PL29', 'PL30', 'PL33', 'PL33_1', 'PL33_2', 'PL35', 'PL37', 'PL38', 'PL40', 'PL42', 'AA1', 'AA1_2', 'AA1_3', 'AA3', 'AA4', 'AA7']

# %% [markdown]
# ## parse the # hits from each cell

# %%
rows = soup.find_all("tr")
elements = {}
for rowIndex, row in enumerate(rows):
    if rowIndex < 2:  continue
    label = row.find("nobr")
    if label is None:   break
    print(rowIndex)
    label = label.text.replace(".gbff_genome.RAST", '')
    elements[label] = []
    first = True
    # print(row is None)
    for td in row.find_all("td"):
        if first:  first = False  ;  continue
        hits = td.get("title")
        # print(hits)
        if hits is None:  hits = '0'
        elements[label].append(hits)
    print(len(elements[label]))

# %% [markdown]
# # DataFrame creation

# %%
test = ["0", "0", "2"]
# test.remove("0")
testSet = set(test)
testSet.remove("0")
print(testSet)
# Out:
# {'2'}

# %%
from pandas import DataFrame
from re import search

df = DataFrame(elements, index=features).T
display(df)
df.to_csv("CAZY_hits.csv")

# create a condensed CSV version
from json import dump
miniElements = {}
for org, hits in elements.items():
    hitsSet = set(hits)
    hitsSet.remove("0")
    miniElements[org] = list(hitsSet)
dump(miniElements, open("nonZeroHits.json", 'w'), indent=3)

df = DataFrame({org: [search(r"(\d+)(?= hit)", hit).group() if "hit" in hit else "0" for hit in hits]
                for org, hits in elements.items()}, index=features).T
display(df)
df.to_csv("CAZY_hits_numerical.csv")
# Out:
#                                                                                            GH1  \
# Acidaminococcus-fermentans-DSM-20731-MAF-2                                                   0
# Acidaminococcus-sp-D21-MAF-2                                                                 0
# Adlercreutzia-equolifaciens-DSM-19450                                                        0
# Akkermansia-muciniphila-ATCC-BAA-835-MAF-2                                                   0
# Alistipes-finegoldii-DSM-17242                                                               0
# ...                                                                                        ...
# Solobacterium-moorei-DSM-22971-MAF-2                                                         0
# Streptococcus-thermophilus-ATCC-19258-MAF-2                   2 hits KJODLM_06495 KJODLM_09470
# Subdoligranulum-sp-4-3-54A2FAA-MAF-2             3 hits OLPOLE_00795 OLPOLE_04110 OLPOLE_14585
# Subdoligranulum-variabile-DSM-15176-MAF-2    6 hits LNLACP_00150 LNLACP_03700 LNLACP_06940 ...
# Veillonella-dispar-ATCC-17748-MAF-2                                                          0
#
#                                                                                            GH2  \
# Acidaminococcus-fermentans-DSM-20731-MAF-2                                                   0
# Acidaminococcus-sp-D21-MAF-2                                                                 0
# Adlercreutzia-equolifaciens-DSM-19450                                       1 hit JACNIE_08440
# Akkermansia-muciniphila-ATCC-BAA-835-MAF-2   6 hits IKGMED_01545 IKGMED_02795 IKGMED_04255 ...
# Alistipes-finegoldii-DSM-17242               8 hits LHJMMB_01735 LHJMMB_06230 LHJMMB_06925 ...
# ...                                                                                        ...
# Solobacterium-moorei-DSM-22971-MAF-2                          2 hits DIOFOH_06630 DIOFOH_12040
# Streptococcus-thermophilus-ATCC-19258-MAF-2                                 1 hit KJODLM_08190
# Subdoligranulum-sp-4-3-54A2FAA-MAF-2         8 hits OLPOLE_00785 OLPOLE_03040 OLPOLE_03865 ...
# Subdoligranulum-variabile-DSM-15176-MAF-2    7 hits LNLACP_00140 LNLACP_00175 LNLACP_05300 ...
# Veillonella-dispar-ATCC-17748-MAF-2                                                          0
#
#                                                                                            GH3  \
# Acidaminococcus-fermentans-DSM-20731-MAF-2                                  1 hit KEEIED_07475
# Acidaminococcus-sp-D21-MAF-2                                                                 0
# Adlercreutzia-equolifaciens-DSM-19450                                       1 hit JACNIE_10280
# Akkermansia-muciniphila-ATCC-BAA-835-MAF-2                                  1 hit IKGMED_10865
# Alistipes-finegoldii-DSM-17242               7 hits LHJMMB_00385 LHJMMB_05295 LHJMMB_05310 ...
# ...                                                                                        ...
# Solobacterium-moorei-DSM-22971-MAF-2                                                         0
# Streptococcus-thermophilus-ATCC-19258-MAF-2                                 1 hit KJODLM_05575
# Subdoligranulum-sp-4-3-54A2FAA-MAF-2         8 hits OLPOLE_03035 OLPOLE_05475 OLPOLE_07015 ...
# Subdoligranulum-variabile-DSM-15176-MAF-2    11 hits LNLACP_00120 LNLACP_00955 LNLACP_05665...
# Veillonella-dispar-ATCC-17748-MAF-2                                         1 hit NBPJEL_09595
#
#                                                                           GH4  \
# Acidaminococcus-fermentans-DSM-20731-MAF-2                                  0
# Acidaminococcus-sp-D21-MAF-2                                                0
# Adlercreutzia-equolifaciens-DSM-19450                                       0
# Akkermansia-muciniphila-ATCC-BAA-835-MAF-2                                  0
# Alistipes-finegoldii-DSM-17242                                              0
# ...                                                                       ...
# Solobacterium-moorei-DSM-22971-MAF-2         2 hits DIOFOH_07270 DIOFOH_12710
# Streptococcus-thermophilus-ATCC-19258-MAF-2                                 0
# Subdoligranulum-sp-4-3-54A2FAA-MAF-2         2 hits OLPOLE_04370 OLPOLE_13485
# Subdoligranulum-variabile-DSM-15176-MAF-2    2 hits LNLACP_07710 LNLACP_09015
# Veillonella-dispar-ATCC-17748-MAF-2                                         0
#
#                                                                           GH5  \
# Acidaminococcus-fermentans-DSM-20731-MAF-2                                  0
# Acidaminococcus-sp-D21-MAF-2                                                0
# Adlercreutzia-equolifaciens-DSM-19450                      1 hit JACNIE_02790
# Akkermansia-muciniphila-ATCC-BAA-835-MAF-2                                  0
# Alistipes-finegoldii-DSM-17242               2 hits LHJMMB_05365 LHJMMB_07895
# ...                                                                       ...
# Solobacterium-moorei-DSM-22971-MAF-2                                        0
# Streptococcus-thermophilus-ATCC-19258-MAF-2                                 0
# Subdoligranulum-sp-4-3-54A2FAA-MAF-2                                        0
# Subdoligranulum-variabile-DSM-15176-MAF-2                                   0
# Veillonella-dispar-ATCC-17748-MAF-2                                         0
#
#                                             GH5_1               GH5_2 GH5_4  \
# Acidaminococcus-fermentans-DSM-20731-MAF-2      0                   0     0
# Acidaminococcus-sp-D21-MAF-2                    0                   0     0
# Adlercreutzia-equolifaciens-DSM-19450           0  1 hit JACNIE_02790     0
# Akkermansia-muciniphila-ATCC-BAA-835-MAF-2      0                   0     0
# Alistipes-finegoldii-DSM-17242                  0  1 hit LHJMMB_07895     0
# ...                                           ...                 ...   ...
# Solobacterium-moorei-DSM-22971-MAF-2            0                   0     0
# Streptococcus-thermophilus-ATCC-19258-MAF-2     0                   0     0
# Subdoligranulum-sp-4-3-54A2FAA-MAF-2            0                   0     0
# Subdoligranulum-variabile-DSM-15176-MAF-2       0                   0     0
# Veillonella-dispar-ATCC-17748-MAF-2             0                   0     0
#
#                                             GH5_5 GH5_7  ... PL37  \
# Acidaminococcus-fermentans-DSM-20731-MAF-2      0     0  ...    0
# Acidaminococcus-sp-D21-MAF-2                    0     0  ...    0
# Adlercreutzia-equolifaciens-DSM-19450           0     0  ...    0
# Akkermansia-muciniphila-ATCC-BAA-835-MAF-2      0     0  ...    0
# Alistipes-finegoldii-DSM-17242                  0     0  ...    0
# ...                                           ...   ...  ...  ...
# Solobacterium-moorei-DSM-22971-MAF-2            0     0  ...    0
# Streptococcus-thermophilus-ATCC-19258-MAF-2     0     0  ...    0
# Subdoligranulum-sp-4-3-54A2FAA-MAF-2            0     0  ...    0
# Subdoligranulum-variabile-DSM-15176-MAF-2       0     0  ...    0
# Veillonella-dispar-ATCC-17748-MAF-2             0     0  ...    0
#
#                                                            PL38 PL40 PL42  \
# Acidaminococcus-fermentans-DSM-20731-MAF-2                    0    0    0
# Acidaminococcus-sp-D21-MAF-2                                  0    0    0
# Adlercreutzia-equolifaciens-DSM-19450                         0    0    0
# Akkermansia-muciniphila-ATCC-BAA-835-MAF-2   1 hit IKGMED_04025    0    0
# Alistipes-finegoldii-DSM-17242                                0    0    0
# ...                                                         ...  ...  ...
# Solobacterium-moorei-DSM-22971-MAF-2                          0    0    0
# Streptococcus-thermophilus-ATCC-19258-MAF-2                   0    0    0
# Subdoligranulum-sp-4-3-54A2FAA-MAF-2                          0    0    0
# Subdoligranulum-variabile-DSM-15176-MAF-2                     0    0    0
# Veillonella-dispar-ATCC-17748-MAF-2                           0    0    0
#
#                                                             AA1  \
# Acidaminococcus-fermentans-DSM-20731-MAF-2                    0
# Acidaminococcus-sp-D21-MAF-2                                  0
# Adlercreutzia-equolifaciens-DSM-19450                         0
# Akkermansia-muciniphila-ATCC-BAA-835-MAF-2   1 hit IKGMED_09535
# Alistipes-finegoldii-DSM-17242                                0
# ...                                                         ...
# Solobacterium-moorei-DSM-22971-MAF-2                          0
# Streptococcus-thermophilus-ATCC-19258-MAF-2                   0
# Subdoligranulum-sp-4-3-54A2FAA-MAF-2                          0
# Subdoligranulum-variabile-DSM-15176-MAF-2                     0
# Veillonella-dispar-ATCC-17748-MAF-2                           0
#
#                                                           AA1_2  \
# Acidaminococcus-fermentans-DSM-20731-MAF-2                    0
# Acidaminococcus-sp-D21-MAF-2                                  0
# Adlercreutzia-equolifaciens-DSM-19450                         0
# Akkermansia-muciniphila-ATCC-BAA-835-MAF-2   1 hit IKGMED_09535
# Alistipes-finegoldii-DSM-17242                                0
# ...                                                         ...
# Solobacterium-moorei-DSM-22971-MAF-2                          0
# Streptococcus-thermophilus-ATCC-19258-MAF-2                   0
# Subdoligranulum-sp-4-3-54A2FAA-MAF-2                          0
# Subdoligranulum-variabile-DSM-15176-MAF-2                     0
# Veillonella-dispar-ATCC-17748-MAF-2                           0
#
#                                                           AA1_3 AA3  \
# Acidaminococcus-fermentans-DSM-20731-MAF-2                    0   0
# Acidaminococcus-sp-D21-MAF-2                                  0   0
# Adlercreutzia-equolifaciens-DSM-19450                         0   0
# Akkermansia-muciniphila-ATCC-BAA-835-MAF-2   1 hit IKGMED_09535   0
# Alistipes-finegoldii-DSM-17242                                0   0
# ...                                                         ...  ..
# Solobacterium-moorei-DSM-22971-MAF-2                          0   0
# Streptococcus-thermophilus-ATCC-19258-MAF-2                   0   0
# Subdoligranulum-sp-4-3-54A2FAA-MAF-2                          0   0
# Subdoligranulum-variabile-DSM-15176-MAF-2                     0   0
# Veillonella-dispar-ATCC-17748-MAF-2                           0   0
#
#                                                             AA4 AA7
# Acidaminococcus-fermentans-DSM-20731-MAF-2                    0   0
# Acidaminococcus-sp-D21-MAF-2                 1 hit FCJLID_00635   0
# Adlercreutzia-equolifaciens-DSM-19450                         0   0
# Akkermansia-muciniphila-ATCC-BAA-835-MAF-2                    0   0
# Alistipes-finegoldii-DSM-17242                                0   0
# ...                                                         ...  ..
# Solobacterium-moorei-DSM-22971-MAF-2                          0   0
# Streptococcus-thermophilus-ATCC-19258-MAF-2                   0   0
# Subdoligranulum-sp-4-3-54A2FAA-MAF-2                          0   0
# Subdoligranulum-variabile-DSM-15176-MAF-2                     0   0
# Veillonella-dispar-ATCC-17748-MAF-2                           0   0
#
# [120 rows x 385 columns]
#                                             GH1 GH2 GH3 GH4 GH5 GH5_1 GH5_2  \
# Acidaminococcus-fermentans-DSM-20731-MAF-2    0   0   1   0   0     0     0
# Acidaminococcus-sp-D21-MAF-2                  0   0   0   0   0     0     0
# Adlercreutzia-equolifaciens-DSM-19450         0   1   1   0   1     0     1
# Akkermansia-muciniphila-ATCC-BAA-835-MAF-2    0   6   1   0   0     0     0
# Alistipes-finegoldii-DSM-17242                0   8   7   0   2     0     1
# ...                                          ..  ..  ..  ..  ..   ...   ...
# Solobacterium-moorei-DSM-22971-MAF-2          0   2   0   2   0     0     0
# Streptococcus-thermophilus-ATCC-19258-MAF-2   2   1   1   0   0     0     0
# Subdoligranulum-sp-4-3-54A2FAA-MAF-2          3   8   8   2   0     0     0
# Subdoligranulum-variabile-DSM-15176-MAF-2     6   7  11   2   0     0     0
# Veillonella-dispar-ATCC-17748-MAF-2           0   0   1   0   0     0     0
#
#                                             GH5_4 GH5_5 GH5_7  ... PL37 PL38  \
# Acidaminococcus-fermentans-DSM-20731-MAF-2      0     0     0  ...    0    0
# Acidaminococcus-sp-D21-MAF-2                    0     0     0  ...    0    0
# Adlercreutzia-equolifaciens-DSM-19450           0     0     0  ...    0    0
# Akkermansia-muciniphila-ATCC-BAA-835-MAF-2      0     0     0  ...    0    1
# Alistipes-finegoldii-DSM-17242                  0     0     0  ...    0    0
# ...                                           ...   ...   ...  ...  ...  ...
# Solobacterium-moorei-DSM-22971-MAF-2            0     0     0  ...    0    0
# Streptococcus-thermophilus-ATCC-19258-MAF-2     0     0     0  ...    0    0
# Subdoligranulum-sp-4-3-54A2FAA-MAF-2            0     0     0  ...    0    0
# Subdoligranulum-variabile-DSM-15176-MAF-2       0     0     0  ...    0    0
# Veillonella-dispar-ATCC-17748-MAF-2             0     0     0  ...    0    0
#
#                                             PL40 PL42 AA1 AA1_2 AA1_3 AA3 AA4  \
# Acidaminococcus-fermentans-DSM-20731-MAF-2     0    0   0     0     0   0   0
# Acidaminococcus-sp-D21-MAF-2                   0    0   0     0     0   0   1
# Adlercreutzia-equolifaciens-DSM-19450          0    0   0     0     0   0   0
# Akkermansia-muciniphila-ATCC-BAA-835-MAF-2     0    0   1     1     1   0   0
# Alistipes-finegoldii-DSM-17242                 0    0   0     0     0   0   0
# ...                                          ...  ...  ..   ...   ...  ..  ..
# Solobacterium-moorei-DSM-22971-MAF-2           0    0   0     0     0   0   0
# Streptococcus-thermophilus-ATCC-19258-MAF-2    0    0   0     0     0   0   0
# Subdoligranulum-sp-4-3-54A2FAA-MAF-2           0    0   0     0     0   0   0
# Subdoligranulum-variabile-DSM-15176-MAF-2      0    0   0     0     0   0   0
# Veillonella-dispar-ATCC-17748-MAF-2            0    0   0     0     0   0   0
#
#                                             AA7
# Acidaminococcus-fermentans-DSM-20731-MAF-2    0
# Acidaminococcus-sp-D21-MAF-2                  0
# Adlercreutzia-equolifaciens-DSM-19450         0
# Akkermansia-muciniphila-ATCC-BAA-835-MAF-2    0
# Alistipes-finegoldii-DSM-17242                0
# ...                                          ..
# Solobacterium-moorei-DSM-22971-MAF-2          0
# Streptococcus-thermophilus-ATCC-19258-MAF-2   0
# Subdoligranulum-sp-4-3-54A2FAA-MAF-2          0
# Subdoligranulum-variabile-DSM-15176-MAF-2     0
# Veillonella-dispar-ATCC-17748-MAF-2           0
#
# [120 rows x 385 columns]

# %%
elements

# %%
print([s for s in soup.children])

# %% [markdown]
# # processing the other HTML file

# %%
rows = soup.find_all("tr")
elements = {}
for rowIndex, row in enumerate(rows):
    if rowIndex < 2:  continue
    label = row.find("nobr")
    if label is None:   break
    print(rowIndex)
    label = label.text.replace(".gbff_genome.RAST", '')
    elements[label] = []
    first = True
    # print(row is None)
    for td in row.find_all("td"):
        if first:  first = False  ;  continue
        hits = td.get("title")
        # print(hits)
        if hits is None:  hits = '0'
        elements[label].append(hits)
    print(len(elements[label]))


from pandas import DataFrame
from re import search

df = DataFrame(elements, index=features).T
display(df)
df.to_csv("CAZY_hits.csv")

# create a condensed CSV version
from json import dump
miniElements = {}
for org, hits in elements.items():
    hitsSet = set(hits)
    hitsSet.remove("0")
    miniElements[org] = list(hitsSet)
dump(miniElements, open("nonZeroHits.json", 'w'), indent=3)

df = DataFrame({org: [search(r"(\d+)(?= hit)", hit).group() if "hit" in hit else "0" for hit in hits]
                for org, hits in elements.items()}, index=features).T
display(df)
df.to_csv("CAZY_hits_numerical.csv")
