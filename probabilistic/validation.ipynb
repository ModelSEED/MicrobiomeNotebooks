# %% [markdown]
# # Organism recruitment validation

# %% [markdown]
# ## load BV-BRC 16S sequences

# %%
from json import load

# %% [markdown]
# ## subselect organisms for analysis

# %% [markdown]
# ## determine closest genomes

# %% [markdown]
# ## run alignment score

# %% [markdown]
# ## pull genomes

# %% [markdown]
# ## create metabolic models

# %% [markdown]
# ## compare metabolite models' behavior and reaction properties

# %% [markdown]
# ##
