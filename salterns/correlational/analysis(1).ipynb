# %% [markdown]
# # Loading content

# %%
import os
import cobra
from modelseedpy import MSBuilder, MSATPCorrection, MSMedia, MSGapfill
import modelseedpy
import json
from tqdm import tqdm
from glob import glob
import cobrakbase
# Out:
# modelseedpy 0.4.3
# cobrakbase 0.4.0

# %% [markdown]
# ## normalizing abundances

# %%
from math import pi

def fluxes_to_emissions(row):
    # TODO: LaTeX of the unit conversion
    # mmol/hr/g_bio -> umol/(m^2 * d)  via  / area (m^2) * (1000 umol / mmol) * (24 hours / day) * (g biomass / container)

    # defining the dimensions of the sampling system
    area_cm2 = pi * (5/2)**2 # cm^2
    area_m2 = area_cm2 * (1e-2)**2 # m^2
    volume_cm3 = 294.52 # cm^3

    # DNA per soil
    ugDNA_gSoil = 2 # approximate average from the provided spreadsheet
    DNA_per_biomass = 0.1
    gSoil_cm3 = 1.4   #  sourced from ChatGPT estimate
    gBiomass_gSoil = gSoil_cm3 * volume_cm3 * ugDNA_gSoil / DNA_per_biomass / 1000 / 1000  # estimated from Chris' spreadsheet
    
    return row / area_m2 * 1e3 * 24 * (gBiomass_gSoil)


from pandas import read_csv, DataFrame
def merge_depths_by_DNA(abundances):
    dna_df = read_csv("../data/SaltPondsDNA.csv").set_index("Sample")
    sample_dna = dna_df["DNA conc (µg/g soil)"].to_dict()
    unique_prefixes = {"_".join(i.split("_")[:-1]) for i in dna_df.index}
    # col_merged = {prefix: [prefix+"_D1", prefix+"_D2"] for prefix in unique_prefixes}
    # merged_depths = {}
    # for prefix in unique_prefixes:
    #     D1, D2 = prefix+"_D1", prefix+"_D2"
    #     total_dna = sample_dna[D1] + sample_dna[D2]
    #     merged_depths[prefix] = (sample_dna[D1]*abundances[D1] + sample_dna[D2]*abundances[D2]) / total_dna
    return DataFrame({prefix: (abundances[prefix+"_D1"]*sample_dna[prefix+"_D1"] + abundances[prefix+"_D2"]*sample_dna[prefix+"_D2"]) / (sample_dna[prefix+"_D1"] + sample_dna[prefix+"_D2"])
                      for prefix in unique_prefixes}, index=abundances.index)

# %%
# normalized_abundances = abundances.copy().T
# for col, column in normalized_abundances.iterrows():
#     # print(col)
#     # print(column)
#     normalized_abundances[col] = column/dna_df.loc[col]

from pandas import read_csv, DataFrame

dna_df = read_csv("../data/SaltPondsDNA.csv").set_index("Sample")
normalized_dna_df = read_csv("../data/SaltPondsDNA_methane_weighted.csv")
total_df = read_csv("../data/Cliff_Sample_Metadata_BGC_NMR.csv").set_index("Sample")
abundances = read_csv("../data/Cliff_310MAG_relabund.tsv", sep="\t")

normalized_methane = normalized_dna_df["CH4 (mmol/hr) / normalized_DNA"]
normalized_abundances = abundances.copy()
for col, val in dna_df["DNA conc (µg/g soil)"].items():
    normalized_abundances[col] = normalized_abundances[col] / val
    

unrestored_cols = [col for col in normalized_abundances.columns if ("R1_" in col or "R2_" in col) and "restored" not in col]
normalized_abundances.index.name = "MAG"
normalized_abundances.to_csv("normalized_MAG_abundances.csv")
display(normalized_abundances)


# averaged_normalized_abundances = DataFrame({prefix: normalized_abundances[cols].mean(axis=1) for prefix, cols in col_merged.items()}, index=normalized_abundances.index)
averaged_normalized_abundances = merge_depths_by_DNA(normalized_abundances)
unrestored_cols_simplified = [col for col in averaged_normalized_abundances.columns if ("R1_" in col or "R2_" in col) and "restored" not in col]
# averaged_normalized_abundances = normalized_abundances.groupby(prefixes, axis=1).mean()
averaged_normalized_abundances.to_csv("../data/averaged_normalized_MAG_abundances.csv")
display(averaged_normalized_abundances)

from pandas import read_csv, DataFrame, Series

averaged_normalized_abundances = read_csv("averaged_normalized_MAG_abundances.csv").set_index("Unnamed: 0")
averaged_unrestored_normalized_abundances = averaged_normalized_abundances[unrestored_cols_simplified]
averaged_unrestored_normalized_abundances.to_csv("averaged_normalized_abundances_unrestored.csv")

normalized_methane_df = total_df["CH4_umol_m2_d"] / dna_df["DNA conc (µg/g soil)"]
display(normalized_methane_df)
unique_prefixes = set(["_".join(col.split("_")[:-1]) for col in normalized_methane_df.index])
col_merged = {prefix: [prefix+"_D1", prefix+"_D2"] for prefix in unique_prefixes}
averaged_normalized_methane = Series({prefix: normalized_methane_df[cols].mean() for prefix, cols in col_merged.items()}, index=col_merged.keys())
averaged_unrestored_normalized_methane = averaged_normalized_methane[unrestored_cols_simplified]
methane_dic = averaged_unrestored_normalized_methane.to_dict()
json.dump(methane_dic, open("averaged_normalized_methane_unrestored.json", "w"), indent=3)
methane_dic
# Out:
#                                                     SF2_A_D1  SF2_A_D2  \
# MAG
# Salt_Pond_MetaGSF2_A_D1_MG_DASTool_bins_concoct...  0.006616  0.006035
# Salt_Pond_MetaGSF2_A_D2_MG_DASTool_bins_concoct...  0.000352  0.000896
# Salt_Pond_MetaGSF2_A_D2_MG_DASTool_bins_concoct...  0.000446  0.005475
# Salt_Pond_MetaGSF2_A_D2_MG_DASTool_bins_concoct...  0.004389  0.008007
# Salt_Pond_MetaGSF2_A_D2_MG_DASTool_bins_concoct...  0.000069  0.002987
# ...                                                      ...       ...
# Salt_Pond_MetaG_R2_restored_H2O_MG_DASTool_bins...  0.000001  0.000002
# Salt_Pond_MetaG_R2_restored_H2O_MG_DASTool_bins...  0.000002  0.000003
# Salt_Pond_MetaG_R2_restored_H2O_MG_DASTool_bins...  0.000005  0.000003
# Salt_Pond_MetaG_R2_restored_H2O_MG_DASTool_bins...  0.000002  0.000002
# unbinned_reads                                      0.804522  0.759152
#
#                                                         SF2_B_D1  SF2_B_D2  \
# MAG
# Salt_Pond_MetaGSF2_A_D1_MG_DASTool_bins_concoct...  3.731061e-03  0.006515
# Salt_Pond_MetaGSF2_A_D2_MG_DASTool_bins_concoct...  7.186752e-04  0.001256
# Salt_Pond_MetaGSF2_A_D2_MG_DASTool_bins_concoct...  1.458375e-03  0.003433
# Salt_Pond_MetaGSF2_A_D2_MG_DASTool_bins_concoct...  1.392826e-02  0.025495
# Salt_Pond_MetaGSF2_A_D2_MG_DASTool_bins_concoct...  4.803627e-05  0.000114
# ...                                                          ...       ...
# Salt_Pond_MetaG_R2_restored_H2O_MG_DASTool_bins...  9.636456e-07  0.000002
# Salt_Pond_MetaG_R2_restored_H2O_MG_DASTool_bins...  1.533073e-06  0.000003
# Salt_Pond_MetaG_R2_restored_H2O_MG_DASTool_bins...  2.890937e-06  0.000005
# Salt_Pond_MetaG_R2_restored_H2O_MG_DASTool_bins...  1.503871e-06  0.000003
# unbinned_reads                                      7.329279e-01  1.463329
#
#                                                     SF2_C_D1  SF2_C_D2  \
# MAG
# Salt_Pond_MetaGSF2_A_D1_MG_DASTool_bins_concoct...  0.007592  0.005036
# Salt_Pond_MetaGSF2_A_D2_MG_DASTool_bins_concoct...  0.002582  0.002143
# Salt_Pond_MetaGSF2_A_D2_MG_DASTool_bins_concoct...  0.012013  0.013398
# Salt_Pond_MetaGSF2_A_D2_MG_DASTool_bins_concoct...  0.021325  0.023352
# Salt_Pond_MetaGSF2_A_D2_MG_DASTool_bins_concoct...  0.000149  0.003686
# ...                                                      ...       ...
# Salt_Pond_MetaG_R2_restored_H2O_MG_DASTool_bins...  0.000002  0.000003
# Salt_Pond_MetaG_R2_restored_H2O_MG_DASTool_bins...  0.000005  0.000005
# Salt_Pond_MetaG_R2_restored_H2O_MG_DASTool_bins...  0.000006  0.000004
# Salt_Pond_MetaG_R2_restored_H2O_MG_DASTool_bins...  0.000004  0.000004
# unbinned_reads                                      1.602282  1.708192
#
#                                                          R1_A_D1  \
# MAG
# Salt_Pond_MetaGSF2_A_D1_MG_DASTool_bins_concoct...  1.644877e-07
# Salt_Pond_MetaGSF2_A_D2_MG_DASTool_bins_concoct...  1.930943e-07
# Salt_Pond_MetaGSF2_A_D2_MG_DASTool_bins_concoct...  2.252767e-07
# Salt_Pond_MetaGSF2_A_D2_MG_DASTool_bins_concoct...  2.109734e-07
# Salt_Pond_MetaGSF2_A_D2_MG_DASTool_bins_concoct...  4.398259e-06
# ...                                                          ...
# Salt_Pond_MetaG_R2_restored_H2O_MG_DASTool_bins...  1.394570e-07
# Salt_Pond_MetaG_R2_restored_H2O_MG_DASTool_bins...  3.861886e-07
# Salt_Pond_MetaG_R2_restored_H2O_MG_DASTool_bins...  4.866691e-06
# Salt_Pond_MetaG_R2_restored_H2O_MG_DASTool_bins...  7.773833e-06
# unbinned_reads                                      9.309582e-02
#
#                                                          R1_A_D2  \
# MAG
# Salt_Pond_MetaGSF2_A_D1_MG_DASTool_bins_concoct...  2.926898e-07
# Salt_Pond_MetaGSF2_A_D2_MG_DASTool_bins_concoct...  1.573208e-07
# Salt_Pond_MetaGSF2_A_D2_MG_DASTool_bins_concoct...  2.012243e-07
# Salt_Pond_MetaGSF2_A_D2_MG_DASTool_bins_concoct...  3.219588e-07
# Salt_Pond_MetaGSF2_A_D2_MG_DASTool_bins_concoct...  3.395202e-06
# ...                                                          ...
# Salt_Pond_MetaG_R2_restored_H2O_MG_DASTool_bins...  2.597622e-07
# Salt_Pond_MetaG_R2_restored_H2O_MG_DASTool_bins...  6.695280e-07
# Salt_Pond_MetaG_R2_restored_H2O_MG_DASTool_bins...  6.987969e-06
# Salt_Pond_MetaG_R2_restored_H2O_MG_DASTool_bins...  1.005755e-05
# unbinned_reads                                      9.058212e-02
#
#                                                          R1_B_D1  \
# MAG
# Salt_Pond_MetaGSF2_A_D1_MG_DASTool_bins_concoct...  6.317685e-07
# Salt_Pond_MetaGSF2_A_D2_MG_DASTool_bins_concoct...  1.340115e-07
# Salt_Pond_MetaGSF2_A_D2_MG_DASTool_bins_concoct...  5.130726e-07
# Salt_Pond_MetaGSF2_A_D2_MG_DASTool_bins_concoct...  4.862703e-07
# Salt_Pond_MetaGSF2_A_D2_MG_DASTool_bins_concoct...  5.701232e-06
# ...                                                          ...
# Salt_Pond_MetaG_R2_restored_H2O_MG_DASTool_bins...  3.867189e-07
# Salt_Pond_MetaG_R2_restored_H2O_MG_DASTool_bins...  2.059948e-06
# Salt_Pond_MetaG_R2_restored_H2O_MG_DASTool_bins...  2.025488e-05
# Salt_Pond_MetaG_R2_restored_H2O_MG_DASTool_bins...  8.906021e-06
# unbinned_reads                                      1.156331e-01
#
#                                                          R1_B_D2  ...  \
# MAG                                                               ...
# Salt_Pond_MetaGSF2_A_D1_MG_DASTool_bins_concoct...  3.836137e-07  ...
# Salt_Pond_MetaGSF2_A_D2_MG_DASTool_bins_concoct...  4.583437e-07  ...
# Salt_Pond_MetaGSF2_A_D2_MG_DASTool_bins_concoct...  2.192078e-07  ...
# Salt_Pond_MetaGSF2_A_D2_MG_DASTool_bins_concoct...  3.836137e-07  ...
# Salt_Pond_MetaGSF2_A_D2_MG_DASTool_bins_concoct...  7.373355e-06  ...
# ...                                                          ...  ...
# Salt_Pond_MetaG_R2_restored_H2O_MG_DASTool_bins...  5.579836e-07  ...
# Salt_Pond_MetaG_R2_restored_H2O_MG_DASTool_bins...  2.979234e-06  ...
# Salt_Pond_MetaG_R2_restored_H2O_MG_DASTool_bins...  2.169161e-05  ...
# Salt_Pond_MetaG_R2_restored_H2O_MG_DASTool_bins...  1.493104e-05  ...
# unbinned_reads                                      1.228118e-01  ...
#
#                                                         R2A_B_D1  R2A_B_D2  \
# MAG
# Salt_Pond_MetaGSF2_A_D1_MG_DASTool_bins_concoct...  7.961735e-05  0.000773
# Salt_Pond_MetaGSF2_A_D2_MG_DASTool_bins_concoct...  2.618992e-06  0.000037
# Salt_Pond_MetaGSF2_A_D2_MG_DASTool_bins_concoct...  4.467692e-06  0.000415
# Salt_Pond_MetaGSF2_A_D2_MG_DASTool_bins_concoct...  3.981895e-05  0.002120
# Salt_Pond_MetaGSF2_A_D2_MG_DASTool_bins_concoct...  5.118845e-05  0.001487
# ...                                                          ...       ...
# Salt_Pond_MetaG_R2_restored_H2O_MG_DASTool_bins...  8.935384e-07  0.000010
# Salt_Pond_MetaG_R2_restored_H2O_MG_DASTool_bins...  2.536827e-06  0.000019
# Salt_Pond_MetaG_R2_restored_H2O_MG_DASTool_bins...  7.600211e-07  0.000011
# Salt_Pond_MetaG_R2_restored_H2O_MG_DASTool_bins...  1.119491e-06  0.000008
# unbinned_reads                                      4.155628e-01  3.359769
#
#                                                     R2A_C_D1  R2A_C_D2  \
# MAG
# Salt_Pond_MetaGSF2_A_D1_MG_DASTool_bins_concoct...  0.000033  0.000057
# Salt_Pond_MetaGSF2_A_D2_MG_DASTool_bins_concoct...  0.000004  0.000002
# Salt_Pond_MetaGSF2_A_D2_MG_DASTool_bins_concoct...  0.000029  0.000542
# Salt_Pond_MetaGSF2_A_D2_MG_DASTool_bins_concoct...  0.000034  0.000205
# Salt_Pond_MetaGSF2_A_D2_MG_DASTool_bins_concoct...  0.000070  0.000513
# ...                                                      ...       ...
# Salt_Pond_MetaG_R2_restored_H2O_MG_DASTool_bins...  0.000002  0.000003
# Salt_Pond_MetaG_R2_restored_H2O_MG_DASTool_bins...  0.000003  0.000004
# Salt_Pond_MetaG_R2_restored_H2O_MG_DASTool_bins...  0.000002  0.000002
# Salt_Pond_MetaG_R2_restored_H2O_MG_DASTool_bins...  0.000002  0.000002
# unbinned_reads                                      0.557968  0.821472
#
#                                                          R2_A_D1   R2_A_D2  \
# MAG
# Salt_Pond_MetaGSF2_A_D1_MG_DASTool_bins_concoct...  3.459632e-07  0.000001
# Salt_Pond_MetaGSF2_A_D2_MG_DASTool_bins_concoct...  8.649080e-07  0.000001
# Salt_Pond_MetaGSF2_A_D2_MG_DASTool_bins_concoct...  1.049684e-06  0.000002
# Salt_Pond_MetaGSF2_A_D2_MG_DASTool_bins_concoct...  1.191214e-06  0.000003
# Salt_Pond_MetaGSF2_A_D2_MG_DASTool_bins_concoct...  3.742693e-06  0.000004
# ...                                                          ...       ...
# Salt_Pond_MetaG_R2_restored_H2O_MG_DASTool_bins...  8.090821e-05  0.000029
# Salt_Pond_MetaG_R2_restored_H2O_MG_DASTool_bins...  3.975864e-04  0.000110
# Salt_Pond_MetaG_R2_restored_H2O_MG_DASTool_bins...  6.362185e-05  0.000072
# Salt_Pond_MetaG_R2_restored_H2O_MG_DASTool_bins...  3.631827e-05  0.000029
# unbinned_reads                                      1.608085e-01  0.343942
#
#                                                      R2_B_D1       R2_B_D2  \
# MAG
# Salt_Pond_MetaGSF2_A_D1_MG_DASTool_bins_concoct...  0.000021  6.398778e-07
# Salt_Pond_MetaGSF2_A_D2_MG_DASTool_bins_concoct...  0.000005  5.576078e-07
# Salt_Pond_MetaGSF2_A_D2_MG_DASTool_bins_concoct...  0.000026  6.947245e-07
# Salt_Pond_MetaGSF2_A_D2_MG_DASTool_bins_concoct...  0.000024  1.000952e-06
# Salt_Pond_MetaGSF2_A_D2_MG_DASTool_bins_concoct...  0.000190  1.611578e-05
# ...                                                      ...           ...
# Salt_Pond_MetaG_R2_restored_H2O_MG_DASTool_bins...  0.000103  1.487350e-04
# Salt_Pond_MetaG_R2_restored_H2O_MG_DASTool_bins...  0.000462  5.955206e-04
# Salt_Pond_MetaG_R2_restored_H2O_MG_DASTool_bins...  0.000509  3.977298e-05
# Salt_Pond_MetaG_R2_restored_H2O_MG_DASTool_bins...  0.000359  5.656977e-05
# unbinned_reads                                      3.859278  1.933192e-01
#
#                                                          R2_C_D1   R2_C_D2
# MAG
# Salt_Pond_MetaGSF2_A_D1_MG_DASTool_bins_concoct...  1.452263e-06  0.000014
# Salt_Pond_MetaGSF2_A_D2_MG_DASTool_bins_concoct...  8.220354e-08  0.000010
# Salt_Pond_MetaGSF2_A_D2_MG_DASTool_bins_concoct...  9.919227e-07  0.000011
# Salt_Pond_MetaGSF2_A_D2_MG_DASTool_bins_concoct...  1.227573e-06  0.000015
# Salt_Pond_MetaGSF2_A_D2_MG_DASTool_bins_concoct...  1.103172e-05  0.000106
# ...                                                          ...       ...
# Salt_Pond_MetaG_R2_restored_H2O_MG_DASTool_bins...  1.742715e-06  0.005099
# Salt_Pond_MetaG_R2_restored_H2O_MG_DASTool_bins...  4.981535e-06  0.017430
# Salt_Pond_MetaG_R2_restored_H2O_MG_DASTool_bins...  4.194573e-05  0.000810
# Salt_Pond_MetaG_R2_restored_H2O_MG_DASTool_bins...  1.563511e-05  0.001089
# unbinned_reads                                      1.658099e-01  3.595310
#
# [311 rows x 24 columns]
#                                                             R1_C  \
# MAG
# Salt_Pond_MetaGSF2_A_D1_MG_DASTool_bins_concoct...  1.286943e-06
# Salt_Pond_MetaGSF2_A_D2_MG_DASTool_bins_concoct...  1.187038e-06
# Salt_Pond_MetaGSF2_A_D2_MG_DASTool_bins_concoct...  6.725687e-07
# Salt_Pond_MetaGSF2_A_D2_MG_DASTool_bins_concoct...  1.234089e-06
# Salt_Pond_MetaGSF2_A_D2_MG_DASTool_bins_concoct...  1.483049e-05
# ...                                                          ...
# Salt_Pond_MetaG_R2_restored_H2O_MG_DASTool_bins...  3.654357e-06
# Salt_Pond_MetaG_R2_restored_H2O_MG_DASTool_bins...  1.434370e-05
# Salt_Pond_MetaG_R2_restored_H2O_MG_DASTool_bins...  2.118231e-05
# Salt_Pond_MetaG_R2_restored_H2O_MG_DASTool_bins...  3.586259e-05
# unbinned_reads                                      2.673347e-01
#
#                                                             R2_B     R2A_B  \
# MAG
# Salt_Pond_MetaGSF2_A_D1_MG_DASTool_bins_concoct...  1.758620e-06  0.000155
# Salt_Pond_MetaGSF2_A_D2_MG_DASTool_bins_concoct...  8.034564e-07  0.000006
# Salt_Pond_MetaGSF2_A_D2_MG_DASTool_bins_concoct...  2.065217e-06  0.000049
# Salt_Pond_MetaGSF2_A_D2_MG_DASTool_bins_concoct...  2.255867e-06  0.000265
# Salt_Pond_MetaGSF2_A_D2_MG_DASTool_bins_concoct...  2.547706e-05  0.000207
# ...                                                          ...       ...
# Salt_Pond_MetaG_R2_restored_H2O_MG_DASTool_bins...  1.462709e-04  0.000002
# Salt_Pond_MetaG_R2_restored_H2O_MG_DASTool_bins...  5.882931e-04  0.000004
# Salt_Pond_MetaG_R2_restored_H2O_MG_DASTool_bins...  6.509313e-05  0.000002
# Salt_Pond_MetaG_R2_restored_H2O_MG_DASTool_bins...  7.288952e-05  0.000002
# unbinned_reads                                      3.911227e-01  0.734679
#
#                                                        R2A_C          R2_C  \
# MAG
# Salt_Pond_MetaGSF2_A_D1_MG_DASTool_bins_concoct...  0.000043  2.025077e-06
# Salt_Pond_MetaGSF2_A_D2_MG_DASTool_bins_concoct...  0.000003  5.352400e-07
# Salt_Pond_MetaGSF2_A_D2_MG_DASTool_bins_concoct...  0.000228  1.435731e-06
# Salt_Pond_MetaGSF2_A_D2_MG_DASTool_bins_concoct...  0.000101  1.826195e-06
# Salt_Pond_MetaGSF2_A_D2_MG_DASTool_bins_concoct...  0.000242  1.527826e-05
# ...                                                      ...           ...
# Salt_Pond_MetaG_R2_restored_H2O_MG_DASTool_bins...  0.000002  2.299363e-04
# Salt_Pond_MetaG_R2_restored_H2O_MG_DASTool_bins...  0.000003  7.850508e-04
# Salt_Pond_MetaG_R2_restored_H2O_MG_DASTool_bins...  0.000002  7.632178e-05
# Salt_Pond_MetaG_R2_restored_H2O_MG_DASTool_bins...  0.000002  6.370147e-05
# unbinned_reads                                      0.660442  3.193389e-01
#
#                                                        SF2_B     SF2_C  \
# MAG
# Salt_Pond_MetaGSF2_A_D1_MG_DASTool_bins_concoct...  0.004648  0.006482
# Salt_Pond_MetaGSF2_A_D2_MG_DASTool_bins_concoct...  0.000896  0.002391
# Salt_Pond_MetaGSF2_A_D2_MG_DASTool_bins_concoct...  0.002109  0.012614
# Salt_Pond_MetaGSF2_A_D2_MG_DASTool_bins_concoct...  0.017739  0.022205
# Salt_Pond_MetaGSF2_A_D2_MG_DASTool_bins_concoct...  0.000070  0.001685
# ...                                                      ...       ...
# Salt_Pond_MetaG_R2_restored_H2O_MG_DASTool_bins...  0.000001  0.000003
# Salt_Pond_MetaG_R2_restored_H2O_MG_DASTool_bins...  0.000002  0.000005
# Salt_Pond_MetaG_R2_restored_H2O_MG_DASTool_bins...  0.000004  0.000005
# Salt_Pond_MetaG_R2_restored_H2O_MG_DASTool_bins...  0.000002  0.000004
# unbinned_reads                                      0.973580  1.648274
#
#                                                             R1_A  \
# MAG
# Salt_Pond_MetaGSF2_A_D1_MG_DASTool_bins_concoct...  2.281245e-07
# Salt_Pond_MetaGSF2_A_D2_MG_DASTool_bins_concoct...  1.753371e-07
# Salt_Pond_MetaGSF2_A_D2_MG_DASTool_bins_concoct...  2.133376e-07
# Salt_Pond_MetaGSF2_A_D2_MG_DASTool_bins_concoct...  2.660642e-07
# Salt_Pond_MetaGSF2_A_D2_MG_DASTool_bins_concoct...  3.900363e-06
# ...                                                          ...
# Salt_Pond_MetaG_R2_restored_H2O_MG_DASTool_bins...  1.991740e-07
# Salt_Pond_MetaG_R2_restored_H2O_MG_DASTool_bins...  5.268323e-07
# Salt_Pond_MetaG_R2_restored_H2O_MG_DASTool_bins...  5.919649e-06
# Salt_Pond_MetaG_R2_restored_H2O_MG_DASTool_bins...  8.907424e-06
# unbinned_reads                                      9.184807e-02
#
#                                                             R2_A     SF2_A  \
# MAG
# Salt_Pond_MetaGSF2_A_D1_MG_DASTool_bins_concoct...  5.329121e-07  0.006326
# Salt_Pond_MetaGSF2_A_D2_MG_DASTool_bins_concoct...  9.825511e-07  0.000623
# Salt_Pond_MetaGSF2_A_D2_MG_DASTool_bins_concoct...  1.249110e-06  0.002955
# Salt_Pond_MetaGSF2_A_D2_MG_DASTool_bins_concoct...  1.564934e-06  0.006194
# Salt_Pond_MetaGSF2_A_D2_MG_DASTool_bins_concoct...  3.735220e-06  0.001525
# ...                                                          ...       ...
# Salt_Pond_MetaG_R2_restored_H2O_MG_DASTool_bins...  6.625106e-05  0.000002
# Salt_Pond_MetaG_R2_restored_H2O_MG_DASTool_bins...  3.166460e-04  0.000003
# Salt_Pond_MetaG_R2_restored_H2O_MG_DASTool_bins...  6.603605e-05  0.000004
# Salt_Pond_MetaG_R2_restored_H2O_MG_DASTool_bins...  3.411966e-05  0.000002
# unbinned_reads                                      2.124300e-01  0.781889
#
#                                                        R2A_A          R1_B
# MAG
# Salt_Pond_MetaGSF2_A_D1_MG_DASTool_bins_concoct...  0.000304  5.217232e-07
# Salt_Pond_MetaGSF2_A_D2_MG_DASTool_bins_concoct...  0.000032  2.778380e-07
# Salt_Pond_MetaGSF2_A_D2_MG_DASTool_bins_concoct...  0.000005  3.827570e-07
# Salt_Pond_MetaGSF2_A_D2_MG_DASTool_bins_concoct...  0.000047  4.407468e-07
# Salt_Pond_MetaGSF2_A_D2_MG_DASTool_bins_concoct...  0.000018  6.442742e-06
# ...                                                      ...           ...
# Salt_Pond_MetaG_R2_restored_H2O_MG_DASTool_bins...  0.000003  4.626670e-07
# Salt_Pond_MetaG_R2_restored_H2O_MG_DASTool_bins...  0.000008  2.467609e-06
# Salt_Pond_MetaG_R2_restored_H2O_MG_DASTool_bins...  0.000001  2.089201e-05
# Salt_Pond_MetaG_R2_restored_H2O_MG_DASTool_bins...  0.000001  1.157784e-05
# unbinned_reads                                      0.387967  1.188165e-01
#
# [311 rows x 12 columns]
# Sample
# R1_A_D1       152.928650
# R1_A_D2       155.159933
# R1_B_D1       311.067580
# R1_B_D2       390.397025
# R1_C_D1       293.811901
# R1_C_D2       232.230114
# R2A_A_D1       -5.576805
# R2A_A_D2      -62.329001
# R2A_B_D1       -0.781991
# R2A_B_D2       -6.432749
# R2A_C_D1       -4.654720
# R2A_C_D2       -7.314560
# R2_A_D1       332.237984
# R2_A_D2       846.415816
# R2_B_D1     10044.312500
# R2_B_D2       572.869534
# R2_C_D1       466.860306
# R2_C_D2      9961.768374
# SF2_A_D1        3.775568
# SF2_A_D2        3.792808
# SF2_B_D1       33.499461
# SF2_B_D2       68.174342
# SF2_C_D1       18.229167
# SF2_C_D2       23.748492
# dtype: float64
# {'R1_C': 263.0210073267493,
#  'R2_B': 5308.591017144301,
#  'R2_C': 5214.314339711316,
#  'R1_A': 154.04429155649183,
#  'R2_A': 589.3269001387226,
#  'R1_B': 350.7323023585634}

# %%
media = {'EX_cpd00067_e0': 1000.0,
 'EX_cpd00058_e0': 1000.0,
 'EX_cpd00013_e0': 1000.0,
 'EX_cpd00244_e0': 1000.0,
 'EX_cpd00205_e0': 1000.0,
 'EX_cpd00034_e0': 1000.0,
 'EX_cpd11574_e0': 1000.0,
 'EX_cpd00971_e0': 1000.0,
 'EX_cpd00048_e0': 1000.0,
 'EX_cpd00030_e0': 1000.0,
 'EX_cpd00305_e0': 100.0,
 'EX_cpd00001_e0': 1000.0,
 'EX_cpd10516_e0': 1000.0,
 'EX_cpd00007_e0': 1000.0,
 'EX_cpd00159_e0': 100.0,
 'EX_cpd25960_e0': 1000.0,
 "EX_cpd00009_e0": 100,
 'EX_cpd00063_e0': 1000.0,
 'EX_cpd00149_e0': 1000.0,
 'EX_cpd00254_e0': 1000.0,
 'EX_cpd00099_e0': 1000.0}

# %%
mepe = {  #mepn
    'Salt_Pond_MetaG_R1_B_D1_MG_DASTool_bins_metabat.20.contigs',
 'Salt_Pond_MetaG_R1_B_D1_MG_DASTool_bins_metabat.32.contigs',
 'Salt_Pond_MetaG_R1_B_D2_MG_DASTool_bins_concoct_out.51.contigs',
 'Salt_Pond_MetaG_R1_B_D2_MG_DASTool_bins_metabat.27.contigs',
 'Salt_Pond_MetaG_R1_B_D2_MG_DASTool_bins_metabat.28.contigs',
 'Salt_Pond_MetaG_R1_B_H2O_MG_DASTool_bins_metabat.7.contigs',
 'Salt_Pond_MetaG_R1_C_D1_MG_DASTool_bins_metabat.31.contigs',
 'Salt_Pond_MetaG_R1_C_H2O_MG_DASTool_bins_concoct_out.79.contigs',
 'Salt_Pond_MetaG_R2_A_D1_MG_DASTool_bins_concoct_out.35.contigs',
 'Salt_Pond_MetaG_R2_A_D1_MG_DASTool_bins_concoct_out.49.contigs',
 'Salt_Pond_MetaG_R2_A_D2_MG_DASTool_bins_metabat.14.contigs',
 'Salt_Pond_MetaG_R2_A_D2_MG_DASTool_bins_metabat.16.contigs',
 'Salt_Pond_MetaG_R2_B_D2_MG_DASTool_bins_concoct_out.143.contigs',
 'Salt_Pond_MetaG_R2_B_D2_MG_DASTool_bins_concoct_out.32.contigs',
 'Salt_Pond_MetaG_R2_B_D2_MG_DASTool_bins_metabat.10.contigs',
 'Salt_Pond_MetaG_R2_B_D2_MG_DASTool_bins_metabat.16.contigs',
 'Salt_Pond_MetaG_R2_B_D2_MG_DASTool_bins_metabat.19.contigs',
 'Salt_Pond_MetaG_R2_B_D2_MG_DASTool_bins_metabat.38.contigs',
 'Salt_Pond_MetaG_R2_B_D2_MG_DASTool_bins_metabat.55.contigs',
 'Salt_Pond_MetaG_R2_C_D1_MG_DASTool_bins_concoct_out.88.contigs',
 'Salt_Pond_MetaG_R2_C_D1_MG_DASTool_bins_concoct_out.95.contigs',
 'Salt_Pond_MetaG_R2_C_D1_MG_DASTool_bins_metabat.17.contigs',
 'Salt_Pond_MetaG_R2_C_D2_MG_DASTool_bins_concoct_out.18.contigs',
 'Salt_Pond_MetaG_R2_C_D2_MG_DASTool_bins_concoct_out.45.contigs',
 'Salt_Pond_MetaG_R2_C_D2_MG_DASTool_bins_concoct_out.47.contigs',
 'Salt_Pond_MetaG_R2_restored_C_black_MG_DASTool_bins_concoct_out.17.contigs',
 'Salt_Pond_MetaG_R2_restored_C_black_MG_DASTool_bins_metabat.8.contigs'}
mepe_striped = [x.replace(".contigs","") for x in mepe]


betaine = {'Salt_Pond_MetaG_R1_A_D1_MG_DASTool_bins.concoct_out.9.contigs',
 'Salt_Pond_MetaG_R1_A_D1_MG_DASTool_bins.metabat.47.contigs',
 'Salt_Pond_MetaG_R1_A_D1_MG_DASTool_bins.metabat.51.contigs',
 'Salt_Pond_MetaG_R1_A_D2_MG_DASTool_bins_metabat.27.contigs',
 'Salt_Pond_MetaG_R1_A_D2_MG_DASTool_bins_metabat.45.contigs',
 'Salt_Pond_MetaG_R1_A_D2_MG_DASTool_bins_metabat.48.contigs',
 'Salt_Pond_MetaG_R1_A_D2_MG_DASTool_bins_metabat.50.contigs',
 'Salt_Pond_MetaG_R1_B_D1_MG_DASTool_bins_concoct_out.59.contigs',
 'Salt_Pond_MetaG_R1_B_D1_MG_DASTool_bins_metabat.58.contigs',
 'Salt_Pond_MetaG_R1_B_D2_MG_DASTool_bins_concoct_out.73.contigs',
 'Salt_Pond_MetaG_R1_C_D1_MG_DASTool_bins_maxbin.047.contigs',
 'Salt_Pond_MetaG_R1_C_D2_MG_DASTool_bins_concoct_out.85.contigs',
 'Salt_Pond_MetaG_R1_C_D2_MG_DASTool_bins_metabat.40.contigs',
 'Salt_Pond_MetaG_R2_A_D1_MG_DASTool_bins_concoct_out.98.contigs',
 'Salt_Pond_MetaG_R2_B_D2_MG_DASTool_bins_metabat.52.contigs'}
betaine_striped = [x.replace(".contigs","") for x in betaine]

# %%
models = {}
for i in tqdm(mepe):
    # filename_model = f'./genome_scale/{i}.json'
    filename_model = f'../models/MePn_consumers/{i}.json'
    if os.path.exists(filename_model):
        models[i] = cobra.io.load_json_model(filename_model)
    else:
        print(f'skip {i}')
# Out:
#   0%|          | 0/27 [00:00<?, ?it/s]
#  48%|████▊     | 13/27 [00:08<00:07,  1.77it/s]
# skip Salt_Pond_MetaG_R2_A_D2_MG_DASTool_bins_metabat.14.contigs
#  63%|██████▎   | 17/27 [00:09<00:05,  1.91it/s]
# skip Salt_Pond_MetaG_R2_A_D2_MG_DASTool_bins_metabat.16.contigs
#  74%|███████▍  | 20/27 [00:10<00:02,  2.47it/s]
# skip Salt_Pond_MetaG_R1_C_D1_MG_DASTool_bins_metabat.31.contigs
# 100%|██████████| 27/27 [00:13<00:00,  2.01it/s]

# %%
from modelseedpy.biochem import from_local
msdb = from_local("../../../shared/code/ModelSEEDDatabase")

for cpd in media:
    print(msdb.compounds.get_by_id(cpd.split("_")[1]).name)
# Out:
# H+
# Cu2+
# NH3
# Ni2+
# K+
# Zn2+
# Molybdate
# Na+
# Sulfate
# Mn2+
# Thiamin
# H2O
# Fe+3
# O2
# L-Lactate
# MePn
# Ca2+
# Co2+
# Mg
# Cl-

# %% [markdown]
# # determine methane emission from methylphosphate as the sole phosphate source on lactate

# %%
methane_emissions = {}
for ID, model in models.items():
    model.medium = media
    sol = model.optimize()
    if sol.objective_value == 0:
        print(f"{ID} failed") #, end="\n\n")
        continue
    methane_emissions[ID] = sol.fluxes['EX_cpd01024_e0']
    # print(f"{sol.fluxes['EX_cpd01024_e0']} methane flux from {ID}")

methane_emissions = dict(sorted(methane_emissions.items(), key=lambda item: item[1], reverse=True))
print()
display(methane_emissions)
# Out:
# Salt_Pond_MetaG_R2_C_D1_MG_DASTool_bins_concoct_out.95.contigs failed
# Salt_Pond_MetaG_R2_C_D1_MG_DASTool_bins_concoct_out.88.contigs failed
# Salt_Pond_MetaG_R1_B_D2_MG_DASTool_bins_metabat.27.contigs failed
# Salt_Pond_MetaG_R2_restored_C_black_MG_DASTool_bins_concoct_out.17.contigs failed
# {'Salt_Pond_MetaG_R2_C_D1_MG_DASTool_bins_metabat.17.contigs': np.float64(0.3395442777379265),
#  'Salt_Pond_MetaG_R1_B_D1_MG_DASTool_bins_metabat.20.contigs': np.float64(0.33873119204370483),
#  'Salt_Pond_MetaG_R2_A_D1_MG_DASTool_bins_concoct_out.49.contigs': np.float64(0.3375697712315979),
#  'Salt_Pond_MetaG_R2_B_D2_MG_DASTool_bins_concoct_out.143.contigs': np.float64(0.33700864130145863),
#  'Salt_Pond_MetaG_R2_B_D2_MG_DASTool_bins_metabat.19.contigs': np.float64(0.335954875404964),
#  'Salt_Pond_MetaG_R2_B_D2_MG_DASTool_bins_metabat.38.contigs': np.float64(0.3353119564947358),
#  'Salt_Pond_MetaG_R1_C_H2O_MG_DASTool_bins_concoct_out.79.contigs': np.float64(0.3316040687817319),
#  'Salt_Pond_MetaG_R1_B_D2_MG_DASTool_bins_metabat.28.contigs': np.float64(0.3315597930392342),
#  'Salt_Pond_MetaG_R2_C_D2_MG_DASTool_bins_concoct_out.47.contigs': np.float64(0.3291262866745024),
#  'Salt_Pond_MetaG_R2_B_D2_MG_DASTool_bins_metabat.10.contigs': np.float64(0.3282013837550686),
#  'Salt_Pond_MetaG_R2_B_D2_MG_DASTool_bins_metabat.16.contigs': np.float64(0.32088367418281916),
#  'Salt_Pond_MetaG_R2_B_D2_MG_DASTool_bins_metabat.55.contigs': np.float64(0.31029962895306085),
#  'Salt_Pond_MetaG_R2_B_D2_MG_DASTool_bins_concoct_out.32.contigs': np.float64(0.3096064205624778),
#  'Salt_Pond_MetaG_R2_C_D2_MG_DASTool_bins_concoct_out.45.contigs': np.float64(0.30842275698597454),
#  'Salt_Pond_MetaG_R2_restored_C_black_MG_DASTool_bins_metabat.8.contigs': np.float64(0.307417685913447),
#  'Salt_Pond_MetaG_R1_B_H2O_MG_DASTool_bins_metabat.7.contigs': np.float64(0.30033569896859635),
#  'Salt_Pond_MetaG_R2_A_D1_MG_DASTool_bins_concoct_out.35.contigs': np.float64(0.2990211711440532),
#  'Salt_Pond_MetaG_R2_C_D2_MG_DASTool_bins_concoct_out.18.contigs': np.float64(0.29886263715054273),
#  'Salt_Pond_MetaG_R1_B_D1_MG_DASTool_bins_metabat.32.contigs': np.float64(0.29881335417177457),
#  'Salt_Pond_MetaG_R1_B_D2_MG_DASTool_bins_concoct_out.51.contigs': np.float64(0.2640522309627251)}

# %% [markdown]
# ## compare with the abundances of each respective species

# %%
# import json
# abundances = json.load()
from pandas import read_csv

display(abundances)
sample_totals = abundances.sum(axis=0)
unrestored = abundances[abundances.index.to_series().str.contains(r'R1|R2')]
member_totals = unrestored.sum(axis=1).sort_values(ascending=False)
most_abundant_members = member_totals[:8]
display(sample_totals)
display(most_abundant_members)
# Out:
#                                                     SF2_A_D1  SF2_A_D2  \
# Salt_Pond_MetaGSF2_A_D1_MG_DASTool_bins_concoct...  0.007762  0.007049
# Salt_Pond_MetaGSF2_A_D2_MG_DASTool_bins_concoct...  0.000413  0.001046
# Salt_Pond_MetaGSF2_A_D2_MG_DASTool_bins_concoct...  0.000524  0.006394
# Salt_Pond_MetaGSF2_A_D2_MG_DASTool_bins_concoct...  0.005150  0.009352
# Salt_Pond_MetaGSF2_A_D2_MG_DASTool_bins_concoct...  0.000081  0.003488
# ...                                                      ...       ...
# Salt_Pond_MetaG_R2_restored_H2O_MG_DASTool_bins...  0.000002  0.000003
# Salt_Pond_MetaG_R2_restored_H2O_MG_DASTool_bins...  0.000002  0.000004
# Salt_Pond_MetaG_R2_restored_H2O_MG_DASTool_bins...  0.000006  0.000003
# Salt_Pond_MetaG_R2_restored_H2O_MG_DASTool_bins...  0.000003  0.000002
# unbinned_reads                                      0.943973  0.886690
#
#                                                     SF2_B_D1  SF2_B_D2  \
# Salt_Pond_MetaGSF2_A_D1_MG_DASTool_bins_concoct...  0.004617  0.003961
# Salt_Pond_MetaGSF2_A_D2_MG_DASTool_bins_concoct...  0.000889  0.000764
# Salt_Pond_MetaGSF2_A_D2_MG_DASTool_bins_concoct...  0.001804  0.002087
# Salt_Pond_MetaGSF2_A_D2_MG_DASTool_bins_concoct...  0.017234  0.015501
# Salt_Pond_MetaGSF2_A_D2_MG_DASTool_bins_concoct...  0.000059  0.000069
# ...                                                      ...       ...
# Salt_Pond_MetaG_R2_restored_H2O_MG_DASTool_bins...  0.000001  0.000001
# Salt_Pond_MetaG_R2_restored_H2O_MG_DASTool_bins...  0.000002  0.000002
# Salt_Pond_MetaG_R2_restored_H2O_MG_DASTool_bins...  0.000004  0.000003
# Salt_Pond_MetaG_R2_restored_H2O_MG_DASTool_bins...  0.000002  0.000002
# unbinned_reads                                      0.906876  0.889704
#
#                                                     SF2_C_D1  SF2_C_D2  \
# Salt_Pond_MetaGSF2_A_D1_MG_DASTool_bins_concoct...  0.004373  0.002226
# Salt_Pond_MetaGSF2_A_D2_MG_DASTool_bins_concoct...  0.001487  0.000948
# Salt_Pond_MetaGSF2_A_D2_MG_DASTool_bins_concoct...  0.006919  0.005924
# Salt_Pond_MetaGSF2_A_D2_MG_DASTool_bins_concoct...  0.012283  0.010325
# Salt_Pond_MetaGSF2_A_D2_MG_DASTool_bins_concoct...  0.000086  0.001630
# ...                                                      ...       ...
# Salt_Pond_MetaG_R2_restored_H2O_MG_DASTool_bins...  0.000001  0.000001
# Salt_Pond_MetaG_R2_restored_H2O_MG_DASTool_bins...  0.000003  0.000002
# Salt_Pond_MetaG_R2_restored_H2O_MG_DASTool_bins...  0.000003  0.000002
# Salt_Pond_MetaG_R2_restored_H2O_MG_DASTool_bins...  0.000002  0.000002
# unbinned_reads                                      0.922914  0.755249
#
#                                                          R1_A_D1  \
# Salt_Pond_MetaGSF2_A_D1_MG_DASTool_bins_concoct...  7.930502e-07
# Salt_Pond_MetaGSF2_A_D2_MG_DASTool_bins_concoct...  9.309720e-07
# Salt_Pond_MetaGSF2_A_D2_MG_DASTool_bins_concoct...  1.086134e-06
# Salt_Pond_MetaGSF2_A_D2_MG_DASTool_bins_concoct...  1.017173e-06
# Salt_Pond_MetaGSF2_A_D2_MG_DASTool_bins_concoct...  2.120547e-05
# ...                                                          ...
# Salt_Pond_MetaG_R2_restored_H2O_MG_DASTool_bins...  6.723687e-07
# Salt_Pond_MetaG_R2_restored_H2O_MG_DASTool_bins...  1.861944e-06
# Salt_Pond_MetaG_R2_restored_H2O_MG_DASTool_bins...  2.346394e-05
# Salt_Pond_MetaG_R2_restored_H2O_MG_DASTool_bins...  3.748024e-05
# unbinned_reads                                      4.488460e-01
#
#                                                          R1_A_D2  \
# Salt_Pond_MetaGSF2_A_D1_MG_DASTool_bins_concoct...  1.390862e-06
# Salt_Pond_MetaGSF2_A_D2_MG_DASTool_bins_concoct...  7.475883e-07
# Salt_Pond_MetaGSF2_A_D2_MG_DASTool_bins_concoct...  9.562176e-07
# Salt_Pond_MetaGSF2_A_D2_MG_DASTool_bins_concoct...  1.529948e-06
# Salt_Pond_MetaGSF2_A_D2_MG_DASTool_bins_concoct...  1.613400e-05
# ...                                                          ...
# Salt_Pond_MetaG_R2_restored_H2O_MG_DASTool_bins...  1.234390e-06
# Salt_Pond_MetaG_R2_restored_H2O_MG_DASTool_bins...  3.181597e-06
# Salt_Pond_MetaG_R2_restored_H2O_MG_DASTool_bins...  3.320683e-05
# Salt_Pond_MetaG_R2_restored_H2O_MG_DASTool_bins...  4.779350e-05
# unbinned_reads                                      4.304462e-01
#
#                                                          R1_B_D1  \
# Salt_Pond_MetaGSF2_A_D1_MG_DASTool_bins_concoct...  2.735979e-06
# Salt_Pond_MetaGSF2_A_D2_MG_DASTool_bins_concoct...  5.803591e-07
# Salt_Pond_MetaGSF2_A_D2_MG_DASTool_bins_concoct...  2.221946e-06
# Salt_Pond_MetaGSF2_A_D2_MG_DASTool_bins_concoct...  2.105874e-06
# Salt_Pond_MetaGSF2_A_D2_MG_DASTool_bins_concoct...  2.469013e-05
# ...                                                          ...
# Salt_Pond_MetaG_R2_restored_H2O_MG_DASTool_bins...  1.674751e-06
# Salt_Pond_MetaG_R2_restored_H2O_MG_DASTool_bins...  8.920949e-06
# Salt_Pond_MetaG_R2_restored_H2O_MG_DASTool_bins...  8.771713e-05
# Salt_Pond_MetaG_R2_restored_H2O_MG_DASTool_bins...  3.856901e-05
# unbinned_reads                                      5.007683e-01
#
#                                                          R1_B_D2  ...  \
# Salt_Pond_MetaGSF2_A_D1_MG_DASTool_bins_concoct...  1.323723e-06  ...
# Salt_Pond_MetaGSF2_A_D2_MG_DASTool_bins_concoct...  1.581591e-06  ...
# Salt_Pond_MetaGSF2_A_D2_MG_DASTool_bins_concoct...  7.564132e-07  ...
# Salt_Pond_MetaGSF2_A_D2_MG_DASTool_bins_concoct...  1.323723e-06  ...
# Salt_Pond_MetaGSF2_A_D2_MG_DASTool_bins_concoct...  2.544299e-05  ...
# ...                                                          ...  ...
# Salt_Pond_MetaG_R2_restored_H2O_MG_DASTool_bins...  1.925415e-06  ...
# Salt_Pond_MetaG_R2_restored_H2O_MG_DASTool_bins...  1.028034e-05  ...
# Salt_Pond_MetaG_R2_restored_H2O_MG_DASTool_bins...  7.485053e-05  ...
# Salt_Pond_MetaG_R2_restored_H2O_MG_DASTool_bins...  5.152205e-05  ...
# unbinned_reads                                      4.237826e-01  ...
#
#                                                     R2A_B_D1  R2A_B_D2  \
# Salt_Pond_MetaGSF2_A_D1_MG_DASTool_bins_concoct...  0.000179  0.000212
# Salt_Pond_MetaGSF2_A_D2_MG_DASTool_bins_concoct...  0.000006  0.000010
# Salt_Pond_MetaGSF2_A_D2_MG_DASTool_bins_concoct...  0.000010  0.000114
# Salt_Pond_MetaGSF2_A_D2_MG_DASTool_bins_concoct...  0.000090  0.000580
# Salt_Pond_MetaGSF2_A_D2_MG_DASTool_bins_concoct...  0.000115  0.000407
# ...                                                      ...       ...
# Salt_Pond_MetaG_R2_restored_H2O_MG_DASTool_bins...  0.000002  0.000003
# Salt_Pond_MetaG_R2_restored_H2O_MG_DASTool_bins...  0.000006  0.000005
# Salt_Pond_MetaG_R2_restored_H2O_MG_DASTool_bins...  0.000002  0.000003
# Salt_Pond_MetaG_R2_restored_H2O_MG_DASTool_bins...  0.000003  0.000002
# unbinned_reads                                      0.935293  0.919233
#
#                                                     R2A_C_D1  R2A_C_D2  \
# Salt_Pond_MetaGSF2_A_D1_MG_DASTool_bins_concoct...  0.000051  0.000056
# Salt_Pond_MetaGSF2_A_D2_MG_DASTool_bins_concoct...  0.000006  0.000002
# Salt_Pond_MetaGSF2_A_D2_MG_DASTool_bins_concoct...  0.000044  0.000526
# Salt_Pond_MetaGSF2_A_D2_MG_DASTool_bins_concoct...  0.000052  0.000199
# Salt_Pond_MetaGSF2_A_D2_MG_DASTool_bins_concoct...  0.000107  0.000498
# ...                                                      ...       ...
# Salt_Pond_MetaG_R2_restored_H2O_MG_DASTool_bins...  0.000003  0.000002
# Salt_Pond_MetaG_R2_restored_H2O_MG_DASTool_bins...  0.000004  0.000004
# Salt_Pond_MetaG_R2_restored_H2O_MG_DASTool_bins...  0.000003  0.000002
# Salt_Pond_MetaG_R2_restored_H2O_MG_DASTool_bins...  0.000002  0.000001
# unbinned_reads                                      0.851087  0.797376
#
#                                                      R2_A_D1   R2_A_D2  \
# Salt_Pond_MetaGSF2_A_D1_MG_DASTool_bins_concoct...  0.000001  0.000002
# Salt_Pond_MetaGSF2_A_D2_MG_DASTool_bins_concoct...  0.000003  0.000002
# Salt_Pond_MetaGSF2_A_D2_MG_DASTool_bins_concoct...  0.000004  0.000003
# Salt_Pond_MetaGSF2_A_D2_MG_DASTool_bins_concoct...  0.000005  0.000004
# Salt_Pond_MetaGSF2_A_D2_MG_DASTool_bins_concoct...  0.000015  0.000006
# ...                                                      ...       ...
# Salt_Pond_MetaG_R2_restored_H2O_MG_DASTool_bins...  0.000323  0.000045
# Salt_Pond_MetaG_R2_restored_H2O_MG_DASTool_bins...  0.001588  0.000173
# Salt_Pond_MetaG_R2_restored_H2O_MG_DASTool_bins...  0.000254  0.000113
# Salt_Pond_MetaG_R2_restored_H2O_MG_DASTool_bins...  0.000145  0.000045
# unbinned_reads                                      0.642377  0.539301
#
#                                                          R2_B_D1   R2_B_D2  \
# Salt_Pond_MetaGSF2_A_D1_MG_DASTool_bins_concoct...  3.419824e-06  0.000002
# Salt_Pond_MetaGSF2_A_D2_MG_DASTool_bins_concoct...  8.182401e-07  0.000002
# Salt_Pond_MetaGSF2_A_D2_MG_DASTool_bins_concoct...  4.175123e-06  0.000002
# Salt_Pond_MetaGSF2_A_D2_MG_DASTool_bins_concoct...  3.881395e-06  0.000003
# Salt_Pond_MetaGSF2_A_D2_MG_DASTool_bins_concoct...  3.033782e-05  0.000045
# ...                                                          ...       ...
# Salt_Pond_MetaG_R2_restored_H2O_MG_DASTool_bins...  1.649068e-05  0.000417
# Salt_Pond_MetaG_R2_restored_H2O_MG_DASTool_bins...  7.385141e-05  0.001671
# Salt_Pond_MetaG_R2_restored_H2O_MG_DASTool_bins...  8.144636e-05  0.000112
# Salt_Pond_MetaG_R2_restored_H2O_MG_DASTool_bins...  5.744465e-05  0.000159
# unbinned_reads                                      6.174844e-01  0.542325
#
#                                                          R2_C_D1   R2_C_D2
# Salt_Pond_MetaGSF2_A_D1_MG_DASTool_bins_concoct...  4.941565e-06  0.000002
# Salt_Pond_MetaGSF2_A_D2_MG_DASTool_bins_concoct...  2.797112e-07  0.000002
# Salt_Pond_MetaGSF2_A_D2_MG_DASTool_bins_concoct...  3.375182e-06  0.000002
# Salt_Pond_MetaGSF2_A_D2_MG_DASTool_bins_concoct...  4.177021e-06  0.000002
# Salt_Pond_MetaGSF2_A_D2_MG_DASTool_bins_concoct...  3.753725e-05  0.000017
# ...                                                          ...       ...
# Salt_Pond_MetaG_R2_restored_H2O_MG_DASTool_bins...  5.929878e-06  0.000813
# Salt_Pond_MetaG_R2_restored_H2O_MG_DASTool_bins...  1.695050e-05  0.002780
# Salt_Pond_MetaG_R2_restored_H2O_MG_DASTool_bins...  1.427273e-04  0.000129
# Salt_Pond_MetaG_R2_restored_H2O_MG_DASTool_bins...  5.320108e-05  0.000174
# unbinned_reads                                      5.641958e-01  0.573332
#
# [311 rows x 24 columns]
# SF2_A_D1    1.0
# SF2_A_D2    1.0
# SF2_B_D1    1.0
# SF2_B_D2    1.0
# SF2_C_D1    1.0
# SF2_C_D2    1.0
# R1_A_D1     1.0
# R1_A_D2     1.0
# R1_B_D1     1.0
# R1_B_D2     1.0
# R1_C_D1     1.0
# R1_C_D2     1.0
# R2A_A_D1    1.0
# R2A_A_D2    1.0
# R2A_B_D1    1.0
# R2A_B_D2    1.0
# R2A_C_D1    1.0
# R2A_C_D2    1.0
# R2_A_D1     1.0
# R2_A_D2     1.0
# R2_B_D1     1.0
# R2_B_D2     1.0
# R2_C_D1     1.0
# R2_C_D2     1.0
# dtype: float64
# Salt_Pond_MetaG_R2_A_D1_MG_DASTool_bins_metabat.12    0.320442
# Salt_Pond_MetaG_R2_B_D1_MG_DASTool_bins_metabat.13    0.225916
# Salt_Pond_MetaG_R1_B_D1_MG_DASTool_bins_metabat.28    0.199881
# Salt_Pond_MetaG_R2_B_D1_MG_DASTool_bins_metabat.10    0.184577
# Salt_Pond_MetaG_R1_C_D1_MG_DASTool_bins_metabat.19    0.167538
# Salt_Pond_MetaG_R1_A_H2O_MG_DASTool_bins_metabat.8    0.139007
# Salt_Pond_MetaG_R1_B_D1_MG_DASTool_bins_metabat.29    0.119100
# Salt_Pond_MetaG_R2_C_D1_MG_DASTool_bins_metabat.17    0.115763
# dtype: float64

# %% [markdown]
# # notes
# - the Salt_Pond_MetaG_R2_C_D1_MG_DASTool_bins_metabat.17 organism both generates the most methane emission of all organisms and is the only one of the most abundant members that was defined with a model in the MePn set of organisms
# -

# %%
from pandas import read_csv

# compute the dimensions of the sampling core
def convert_methane(methane):
    # TODO: LaTeX of the unit conversion
    # umol/(m^2 * d) -> mmol/hr  via  * area (m^2) * (1 mmol/1000 umol) * (1 day / 24 hours)

    # defining the dimensions of the sampling system
    from math import pi
    # sample_volume = 294.52 # cm^3
    sample_area = pi * (5/2)**2 # cm^2
    
    ## standard units
    # sample_volume = sample_volume * (1e-2)**3 # m^3
    sample_area = sample_area * (1e-2)**2 # m^2

    # returning the mmol/hr methane fluxes
    gBiomass_gSoil = 5.9 * 1000
    
    return methane * sample_area / (1e3 * 24)

# print(sample_volume, sample_area)

# load and connect the DNA with the methane flux
methane = convert_methane(total_df["CH4_umol_m2_d"])
for sample in dna_df.index:
    dna_df.loc[sample, "methane"] = methane[sample]  # mmol/hr

# normalize the DNA/g by the methane flux
for sample in dna_df.index:
    dna_df.loc[sample, "CH4 (mmol/hr) / normalized_DNA"] = dna_df.loc[sample, "methane"] / dna_df.loc[sample, "DNA conc (µg/g soil)"]

# normalize to 1
# total_normalized_dna = dna_df.loc[:, "DNA/g/methane"].sum()
# dna_df["normalized DNA/g/methane"] = dna_df["DNA/g/methane"] / total_normalized_dna

display(dna_df)

dna_df.to_csv("../data/SaltPondsDNA_methane_weighted.csv")
# display(methane)
# Out:
#           DNA conc (µg/mL) in 20 µL extracted from 0.25 g soil  DNA (ug)  \
# Sample
# R1_A_D1                                           60.266667     1.205333
# R1_A_D2                                           59.400000     1.188000
# R1_B_D1                                           54.133333     1.082667
# R1_B_D2                                           43.133333     0.862667
# R1_C_D1                                           20.866667     0.417333
# R1_C_D2                                           26.400000     0.528000
# R2_A_D1                                           49.933333     0.998667
# R2_A_D2                                           19.600000     0.392000
# R2_B_D1                                            2.000000     0.040000
# R2_B_D2                                           35.066667     0.701333
# R2_C_D1                                           42.533333     0.850667
# R2_C_D2                                            1.993333     0.039867
# R2A_A_D1                                          54.466667     1.089333
# R2A_A_D2                                           4.873333     0.097467
# R2A_B_D1                                          28.133333     0.562667
# R2A_B_D2                                           3.420000     0.068400
# R2A_C_D1                                          19.066667     0.381333
# R2A_C_D2                                          12.133333     0.242667
# SF2_A_D1                                          14.666667     0.293333
# SF2_A_D2                                          14.600000     0.292000
# SF2_B_D1                                          15.466667     0.309333
# SF2_B_D2                                           7.600000     0.152000
# SF2_C_D1                                           7.200000     0.144000
# SF2_C_D2                                           5.526667     0.110533
#
#           DNA conc (µg/g soil)       methane  CH4 (mmol/hr) / normalized_DNA
# Sample
# R1_A_D1               4.821333  6.032185e-05                    1.251145e-05
# R1_A_D2               4.752000  6.032185e-05                    1.269399e-05
# R1_B_D1               4.330667  1.102118e-04                    2.544916e-05
# R1_B_D2               3.450667  1.102118e-04                    3.193928e-05
# R1_C_D1               1.669333  4.012648e-05                    2.403743e-05
# R1_C_D2               2.112000  4.012648e-05                    1.899928e-05
# R2_A_D1               3.994667  1.085797e-04                    2.718116e-05
# R2_A_D2               1.568000  1.085797e-04                    6.924723e-05
# R2_B_D1               0.160000  1.314797e-04                    8.217484e-04
# R2_B_D2               2.805333  1.314797e-04                    4.686778e-05
# R2_C_D1               3.402667  1.299646e-04                    3.819492e-05
# R2_C_D2               0.159467  1.299646e-04                    8.149953e-04
# R2A_A_D1              4.357333 -1.988039e-06                   -4.562513e-07
# R2A_A_D2              0.389867 -1.988039e-06                   -5.099279e-06
# R2A_B_D1              2.250667 -1.439897e-07                   -6.397645e-08
# R2A_B_D2              0.273600 -1.439897e-07                   -5.262780e-07
# R2A_C_D1              1.525333 -5.808674e-07                   -3.808134e-07
# R2A_C_D2              0.970667 -5.808674e-07                   -5.984211e-07
# SF2_A_D1              1.173333  3.624285e-07                    3.088879e-07
# SF2_A_D2              1.168000  3.624285e-07                    3.102984e-07
# SF2_B_D1              1.237333  3.391120e-06                    2.740668e-06
# SF2_B_D2              0.608000  3.391120e-06                    5.577500e-06
# SF2_C_D1              0.576000  8.590292e-07                    1.491370e-06
# SF2_C_D2              0.442133  8.590292e-07                    1.942919e-06

# %% [markdown]
# # correlate the normalized abundances of members with the normalized methane flux

# %%
correlations = {}
for index, row in normalized_abundances.iterrows():
    corr = row.corr(normalized_methane)
    correlations[index] = corr
    # print(f"{index} correlates {corr} with methane")

correlations = dict(sorted(correlations.items(), key=lambda item: item[1], reverse=True))
# print("total correlation", sum(correlations.values()))
merged_corr = 0
for org, val in correlations.items():
    if org in mepe_striped:  merged_corr += val
# print("summed mepe correlations", merged_corr)
print("max all correlations", max(correlations.values()))
unrestored_correlations = {k:v for k,v in correlations.items() if ("R1_" in k or "R2_" in k) and not "restored" in k}
print(unrestored_correlations['Salt_Pond_MetaG_R2_C_D1_MG_DASTool_bins_metabat.17'])
unrestored_correlations
# Out:
# max all correlations 0.9933389305491771
# 0.9736930734718282
# {'Salt_Pond_MetaG_R2_C_D2_MG_DASTool_bins_concoct_out.45': np.float64(0.9933389305491771),
#  'Salt_Pond_MetaG_R2_B_D2_MG_DASTool_bins_metabat.16': np.float64(0.993120804564738),
#  'Salt_Pond_MetaG_R2_B_D2_MG_DASTool_bins_metabat.55': np.float64(0.9910633253089762),
#  'Salt_Pond_MetaG_R2_C_D1_MG_DASTool_bins_concoct_out.98': np.float64(0.9897259768241059),
#  'Salt_Pond_MetaG_R2_C_D1_MG_DASTool_bins_concoct_out.95': np.float64(0.9893764565409581),
#  'Salt_Pond_MetaG_R2_B_D1_MG_DASTool_bins_metabat.13': np.float64(0.9876012116481486),
#  'Salt_Pond_MetaG_R1_B_D2_MG_DASTool_bins_metabat.16': np.float64(0.9872359225769332),
#  'Salt_Pond_MetaG_R1_B_H2O_MG_DASTool_bins_metabat.5': np.float64(0.9854061134057847),
#  'Salt_Pond_MetaG_R1_B_H2O_MG_DASTool_bins_metabat.7': np.float64(0.9853776265009595),
#  'Salt_Pond_MetaG_R1_B_D2_MG_DASTool_bins_metabat.30': np.float64(0.9837327339337952),
#  'Salt_Pond_MetaG_R2_B_D2_MG_DASTool_bins_metabat.52': np.float64(0.9830769058301974),
#  'Salt_Pond_MetaG_R1_B_D1_MG_DASTool_bins_metabat.32': np.float64(0.9830180440174051),
#  'Salt_Pond_MetaG_R1_B_H2O_MG_DASTool_bins_metabat.11': np.float64(0.9822720369608353),
#  'Salt_Pond_MetaG_R1_C_D2_MG_DASTool_bins_metabat.30': np.float64(0.9822702702526581),
#  'Salt_Pond_MetaG_R2_B_D1_MG_DASTool_bins_concoct_out.40': np.float64(0.9819724781554824),
#  'Salt_Pond_MetaG_R1_A_D2_MG_DASTool_bins_metabat.36': np.float64(0.9812577161234741),
#  'Salt_Pond_MetaG_R1_A_H2O_MG_DASTool_bins_maxbin.022': np.float64(0.9810057166033433),
#  'Salt_Pond_MetaG_R2_A_D1_MG_DASTool_bins_metabat.32': np.float64(0.9804771261925701),
#  'Salt_Pond_MetaG_R1_B_D2_MG_DASTool_bins_metabat.18': np.float64(0.9797948185326968),
#  'Salt_Pond_MetaG_R2_C_D1_MG_DASTool_bins_concoct_out.37': np.float64(0.9784081483978296),
#  'Salt_Pond_MetaG_R2_C_D1_MG_DASTool_bins_metabat.25': np.float64(0.9774579494482645),
#  'Salt_Pond_MetaG_R2_B_D2_MG_DASTool_bins_concoct_out.32': np.float64(0.9765730763403917),
#  'Salt_Pond_MetaG_R2_B_D1_MG_DASTool_bins_metabat.22': np.float64(0.9742030103824345),
#  'Salt_Pond_MetaG_R2_C_D1_MG_DASTool_bins_metabat.17': np.float64(0.9736930734718282),
#  'Salt_Pond_MetaG_R1_C_D2_MG_DASTool_bins_concoct_out.36': np.float64(0.9735363640129976),
#  'Salt_Pond_MetaG_R2_B_D2_MG_DASTool_bins_metabat.44': np.float64(0.9732834932889711),
#  'Salt_Pond_MetaG_R1_B_D2_MG_DASTool_bins_metabat.34': np.float64(0.9731996889220743),
#  'Salt_Pond_MetaG_R2_A_D1_MG_DASTool_bins_concoct_out.49': np.float64(0.9719877294136936),
#  'Salt_Pond_MetaG_R2_A_D1_MG_DASTool_bins_metabat.24': np.float64(0.9719446280777478),
#  'Salt_Pond_MetaG_R1_B_D2_MG_DASTool_bins_metabat.27': np.float64(0.9712863002264556),
#  'Salt_Pond_MetaG_R2_B_D2_MG_DASTool_bins_metabat.10': np.float64(0.9706977175935776),
#  'Salt_Pond_MetaG_R1_B_H2O_MG_DASTool_bins_concoct_out.13': np.float64(0.9685867668238233),
#  'Salt_Pond_MetaG_R2_A_D1_MG_DASTool_bins_concoct_out.84': np.float64(0.9682818064607562),
#  'Salt_Pond_MetaG_R1_C_D1_MG_DASTool_bins_concoct_out.45': np.float64(0.9659441340392655),
#  'Salt_Pond_MetaG_R2_B_D2_MG_DASTool_bins_metabat.62': np.float64(0.9645412832141552),
#  'Salt_Pond_MetaG_R1_B_D1_MG_DASTool_bins_metabat.49': np.float64(0.9617938135570683),
#  'Salt_Pond_MetaG_R1_B_D2_MG_DASTool_bins_concoct_out.51': np.float64(0.9612457439881801),
#  'Salt_Pond_MetaG_R1_A_D2_MG_DASTool_bins_metabat.15': np.float64(0.9604669623172198),
#  'Salt_Pond_MetaG_R1_B_D1_MG_DASTool_bins_metabat.29': np.float64(0.9601150967327471),
#  'Salt_Pond_MetaG_R2_A_D1_MG_DASTool_bins_metabat.12': np.float64(0.9590854432368837),
#  'Salt_Pond_MetaG_R1_C_D1_MG_DASTool_bins_metabat.27': np.float64(0.9579087846942652),
#  'Salt_Pond_MetaG_R2_A_D1_MG_DASTool_bins_metabat.9': np.float64(0.9558139719042481),
#  'Salt_Pond_MetaG_R1_A_D1_MG_DASTool_bins.concoct_out.9': np.float64(0.9556938040740716),
#  'Salt_Pond_MetaG_R1_C_H2O_MG_DASTool_bins_concoct_out.79': np.float64(0.9552548985595699),
#  'Salt_Pond_MetaG_R1_B_D2_MG_DASTool_bins_metabat.19': np.float64(0.9547660398196796),
#  'Salt_Pond_MetaG_R2_B_D2_MG_DASTool_bins_metabat.45': np.float64(0.9544193649619589),
#  'Salt_Pond_MetaG_R1_B_D1_MG_DASTool_bins_metabat.38': np.float64(0.9537705492716377),
#  'Salt_Pond_MetaG_R1_B_D2_MG_DASTool_bins_metabat.28': np.float64(0.9520363733551691),
#  'Salt_Pond_MetaG_R2_A_D2_MG_DASTool_bins_metabat.14': np.float64(0.9508916971592859),
#  'Salt_Pond_MetaG_R1_C_D2_MG_DASTool_bins_metabat.58': np.float64(0.9505321702399039),
#  'Salt_Pond_MetaG_R1_B_D2_MG_DASTool_bins_concoct_out.73': np.float64(0.9503542323803579),
#  'Salt_Pond_MetaG_R1_A_D2_MG_DASTool_bins_metabat.84': np.float64(0.9502725478769598),
#  'Salt_Pond_MetaG_R2_A_H2O_MG_DASTool_bins_metabat.14': np.float64(0.9502620130938962),
#  'Salt_Pond_MetaG_R1_B_D1_MG_DASTool_bins_concoct_out.59': np.float64(0.9496007722691331),
#  'Salt_Pond_MetaG_R2_A_D1_MG_DASTool_bins_metabat.50': np.float64(0.9479792855219236),
#  'Salt_Pond_MetaG_R1_B_D2_MG_DASTool_bins_metabat.37': np.float64(0.9452669367807547),
#  'Salt_Pond_MetaG_R1_C_H2O_MG_DASTool_bins_concoct_out.16': np.float64(0.9452539872368196),
#  'Salt_Pond_MetaG_R2_B_D2_MG_DASTool_bins_metabat.20': np.float64(0.9442363014917992),
#  'Salt_Pond_MetaG_R1_A_D2_MG_DASTool_bins_metabat.27': np.float64(0.940654085112924),
#  'Salt_Pond_MetaG_R1_A_D2_MG_DASTool_bins_concoct_out.109': np.float64(0.9384440579490787),
#  'Salt_Pond_MetaG_R1_B_D2_MG_DASTool_bins_concoct_out.87': np.float64(0.9364388908187844),
#  'Salt_Pond_MetaG_R2_B_D2_MG_DASTool_bins_metabat.43': np.float64(0.9363645213669529),
#  'Salt_Pond_MetaG_R1_B_D2_MG_DASTool_bins_metabat.14': np.float64(0.9356503447457806),
#  'Salt_Pond_MetaG_R2_A_D1_MG_DASTool_bins_metabat.10': np.float64(0.9353755223357306),
#  'Salt_Pond_MetaG_R1_B_H2O_MG_DASTool_bins_maxbin.028': np.float64(0.9330413324824479),
#  'Salt_Pond_MetaG_R1_B_D2_MG_DASTool_bins_concoct_out.37': np.float64(0.9252838963795987),
#  'Salt_Pond_MetaG_R1_B_D2_MG_DASTool_bins_maxbin.014': np.float64(0.9228499703065595),
#  'Salt_Pond_MetaG_R1_A_D1_MG_DASTool_bins.concoct_out.5': np.float64(0.9157381575377774),
#  'Salt_Pond_MetaG_R1_C_D1_MG_DASTool_bins_metabat.31': np.float64(0.9152311764762285),
#  'Salt_Pond_MetaG_R1_B_D1_MG_DASTool_bins_metabat.20': np.float64(0.9120200331963552),
#  'Salt_Pond_MetaG_R2_C_D1_MG_DASTool_bins_concoct_out.118': np.float64(0.9107432562257042),
#  'Salt_Pond_MetaG_R1_B_D1_MG_DASTool_bins_metabat.41': np.float64(0.9093022806416892),
#  'Salt_Pond_MetaG_R1_B_D1_MG_DASTool_bins_metabat.28': np.float64(0.9088326322637268),
#  'Salt_Pond_MetaG_R1_A_D2_MG_DASTool_bins_metabat.45': np.float64(0.9069206168125175),
#  'Salt_Pond_MetaG_R2_B_D2_MG_DASTool_bins_metabat.38': np.float64(0.9011626521027193),
#  'Salt_Pond_MetaG_R2_A_D1_MG_DASTool_bins_concoct_out.98': np.float64(0.9006990333107),
#  'Salt_Pond_MetaG_R1_B_H2O_MG_DASTool_bins_metabat.17': np.float64(0.8982449407600782),
#  'Salt_Pond_MetaG_R1_A_D1_MG_DASTool_bins.metabat.6': np.float64(0.8952623567881197),
#  'Salt_Pond_MetaG_R1_A_D1_MG_DASTool_bins.metabat.18': np.float64(0.884634229096664),
#  'Salt_Pond_MetaG_R2_A_D1_MG_DASTool_bins_metabat.61': np.float64(0.8830972351953948),
#  'Salt_Pond_MetaG_R1_C_H2O_MG_DASTool_bins_metabat.29': np.float64(0.8827371129824981),
#  'Salt_Pond_MetaG_R2_C_D1_MG_DASTool_bins_maxbin.062': np.float64(0.8826793703305901),
#  'Salt_Pond_MetaG_R1_B_D1_MG_DASTool_bins_metabat.16': np.float64(0.8767446240160867),
#  'Salt_Pond_MetaG_R2_B_D2_MG_DASTool_bins_concoct_out.4': np.float64(0.8756485987366244),
#  'Salt_Pond_MetaG_R2_A_D1_MG_DASTool_bins_concoct_out.35': np.float64(0.8754744169492978),
#  'Salt_Pond_MetaG_R1_A_H2O_MG_DASTool_bins_concoct_out.2': np.float64(0.8752743248731237),
#  'Salt_Pond_MetaG_R1_C_D2_MG_DASTool_bins_metabat.40': np.float64(0.8743054492400187),
#  'Salt_Pond_MetaG_R2_B_D1_MG_DASTool_bins_metabat.10': np.float64(0.8736940524366661),
#  'Salt_Pond_MetaG_R1_A_D1_MG_DASTool_bins.metabat.15': np.float64(0.869201426553978),
#  'Salt_Pond_MetaG_R1_B_D1_MG_DASTool_bins_metabat.40': np.float64(0.8687235523770542),
#  'Salt_Pond_MetaG_R1_B_D1_MG_DASTool_bins_concoct_out.53': np.float64(0.868238097476202),
#  'Salt_Pond_MetaG_R1_A_D1_MG_DASTool_bins.metabat.26': np.float64(0.8660527735950515),
#  'Salt_Pond_MetaG_R1_C_D2_MG_DASTool_bins_concoct_out.85': np.float64(0.8652377177614788),
#  'Salt_Pond_MetaG_R1_A_D2_MG_DASTool_bins_concoct_out.51': np.float64(0.8651937697356133),
#  'Salt_Pond_MetaG_R1_A_H2O_MG_DASTool_bins_metabat.6': np.float64(0.8571592750334204),
#  'Salt_Pond_MetaG_R1_C_H2O_MG_DASTool_bins_metabat.23': np.float64(0.8545603026612072),
#  'Salt_Pond_MetaG_R1_B_H2O_MG_DASTool_bins_concoct_out.22': np.float64(0.853612986746158),
#  'Salt_Pond_MetaG_R1_B_D2_MG_DASTool_bins_concoct_out.86': np.float64(0.8528734800090765),
#  'Salt_Pond_MetaG_R1_B_H2O_MG_DASTool_bins_concoct_out.19': np.float64(0.8514747173540393),
#  'Salt_Pond_MetaG_R1_A_D1_MG_DASTool_bins.metabat.47': np.float64(0.8433241829131413),
#  'Salt_Pond_MetaG_R2_B_D2_MG_DASTool_bins_concoct_out.80': np.float64(0.8336770671184135),
#  'Salt_Pond_MetaG_R2_B_D2_MG_DASTool_bins_concoct_out.39': np.float64(0.8274175879435913),
#  'Salt_Pond_MetaG_R2_A_D1_MG_DASTool_bins_metabat.7': np.float64(0.8272815571914246),
#  'Salt_Pond_MetaG_R1_A_H2O_MG_DASTool_bins_metabat.14': np.float64(0.8196396511880066),
#  'Salt_Pond_MetaG_R2_B_D2_MG_DASTool_bins_concoct_out.143': np.float64(0.8187483264883649),
#  'Salt_Pond_MetaG_R2_C_D1_MG_DASTool_bins_concoct_out.65': np.float64(0.8176196082630707),
#  'Salt_Pond_MetaG_R2_C_D1_MG_DASTool_bins_metabat.7': np.float64(0.8173516750688408),
#  'Salt_Pond_MetaG_R2_B_D2_MG_DASTool_bins_metabat.19': np.float64(0.8108608743655508),
#  'Salt_Pond_MetaG_R1_B_D1_MG_DASTool_bins_metabat.13': np.float64(0.8059848641762585),
#  'Salt_Pond_MetaG_R1_A_D1_MG_DASTool_bins.concoct_out.44': np.float64(0.7879872240217457),
#  'Salt_Pond_MetaG_R1_A_D2_MG_DASTool_bins_concoct_out.21': np.float64(0.7877556813211984),
#  'Salt_Pond_MetaG_R2_B_D2_MG_DASTool_bins_concoct_out.124': np.float64(0.7779045119041994),
#  'Salt_Pond_MetaG_R1_C_H2O_MG_DASTool_bins_concoct_out.67': np.float64(0.7699597654252786),
#  'Salt_Pond_MetaG_R2_A_H2O_MG_DASTool_bins_concoct_out.11': np.float64(0.7668737857292893),
#  'Salt_Pond_MetaG_R1_C_D1_MG_DASTool_bins_metabat.19': np.float64(0.7592707588408868),
#  'Salt_Pond_MetaG_R2_A_H2O_MG_DASTool_bins_concoct_out.45': np.float64(0.7534718013533213),
#  'Salt_Pond_MetaG_R2_A_D1_MG_DASTool_bins_concoct_out.93': np.float64(0.750393020111809),
#  'Salt_Pond_MetaG_R2_C_D2_MG_DASTool_bins_concoct_out.104': np.float64(0.748933053515011),
#  'Salt_Pond_MetaG_R2_C_D2_MG_DASTool_bins_concoct_out.47': np.float64(0.7473260424684764),
#  'Salt_Pond_MetaG_R2_A_D1_MG_DASTool_bins_maxbin.001': np.float64(0.7459051998554063),
#  'Salt_Pond_MetaG_R2_A_D1_MG_DASTool_bins_concoct_out.119': np.float64(0.7453922082058209),
#  'Salt_Pond_MetaG_R1_A_D2_MG_DASTool_bins_concoct_out.25': np.float64(0.744057843841925),
#  'Salt_Pond_MetaG_R2_C_D1_MG_DASTool_bins_concoct_out.88': np.float64(0.74375880111873),
#  'Salt_Pond_MetaG_R2_B_D2_MG_DASTool_bins_metabat.50': np.float64(0.7423579281658724),
#  'Salt_Pond_MetaG_R2_C_D1_MG_DASTool_bins_concoct_out.7': np.float64(0.7409046068366681),
#  'Salt_Pond_MetaG_R2_B_D1_MG_DASTool_bins_concoct_out.110': np.float64(0.732508889671971),
#  'Salt_Pond_MetaG_R2_A_H2O_MG_DASTool_bins_concoct_out.29': np.float64(0.7269873208921637),
#  'Salt_Pond_MetaG_R2_C_D1_MG_DASTool_bins_concoct_out.71': np.float64(0.7237469776154849),
#  'Salt_Pond_MetaG_R1_B_D1_MG_DASTool_bins_concoct_out.89': np.float64(0.7202894409907247),
#  'Salt_Pond_MetaG_R2_A_D1_MG_DASTool_bins_concoct_out.29': np.float64(0.7173301180037934),
#  'Salt_Pond_MetaG_R2_B_H2O_MG_DASTool_bins_metabat.29': np.float64(0.7073376190093803),
#  'Salt_Pond_MetaG_R2_C_D2_MG_DASTool_bins_concoct_out.18': np.float64(0.6950405946236947),
#  'Salt_Pond_MetaG_R1_B_D2_MG_DASTool_bins_metabat.78': np.float64(0.6913454111879178),
#  'Salt_Pond_MetaG_R2_C_D2_MG_DASTool_bins_concoct_out.100': np.float64(0.6896590417651067),
#  'Salt_Pond_MetaG_R1_C_D1_MG_DASTool_bins_maxbin.047': np.float64(0.6888540441306358),
#  'Salt_Pond_MetaG_R2_C_D2_MG_DASTool_bins_concoct_out.21': np.float64(0.6885885598387991),
#  'Salt_Pond_MetaG_R2_A_D1_MG_DASTool_bins_concoct_out.66': np.float64(0.6791071891227055),
#  'Salt_Pond_MetaG_R1_B_D1_MG_DASTool_bins_metabat.58': np.float64(0.6766639143898306),
#  'Salt_Pond_MetaG_R2_C_H2O_MG_DASTool_bins_concoct_out.35': np.float64(0.6681510208173838),
#  'Salt_Pond_MetaG_R1_B_D2_MG_DASTool_bins_concoct_out.120': np.float64(0.6612868330857458),
#  'Salt_Pond_MetaG_R2_A_H2O_MG_DASTool_bins_maxbin.035': np.float64(0.6412382163617548),
#  'Salt_Pond_MetaG_R2_C_H2O_MG_DASTool_bins_concoct_out.60': np.float64(0.6331448075441839),
#  'Salt_Pond_MetaG_R1_A_D1_MG_DASTool_bins.concoct_out.54': np.float64(0.5733764611662305),
#  'Salt_Pond_MetaG_R1_A_D1_MG_DASTool_bins.metabat.45': np.float64(0.5364134121194511),
#  'Salt_Pond_MetaG_R1_A_D1_MG_DASTool_bins.metabat.51': np.float64(0.48598312737275473),
#  'Salt_Pond_MetaG_R1_A_D2_MG_DASTool_bins_metabat.48': np.float64(0.47834469994989126),
#  'Salt_Pond_MetaG_R1_B_D2_MG_DASTool_bins_metabat.63': np.float64(0.3587288071574184),
#  'Salt_Pond_MetaG_R2_A_D2_MG_DASTool_bins_concoct_out.19': np.float64(0.34456526467749066),
#  'Salt_Pond_MetaG_R2_A_D1_MG_DASTool_bins_concoct_out.52': np.float64(0.3360993280802641),
#  'Salt_Pond_MetaG_R1_A_D2_MG_DASTool_bins_concoct_out.1': np.float64(0.2792482352953475),
#  'Salt_Pond_MetaG_R2_B_H2O_MG_DASTool_bins_metabat.16': np.float64(0.25049293445512993),
#  'Salt_Pond_MetaG_R2_C_H2O_MG_DASTool_bins_metabat.20': np.float64(0.22309959901354257),
#  'Salt_Pond_MetaG_R2_B_H2O_MG_DASTool_bins_metabat.17': np.float64(0.20682137995496436),
#  'Salt_Pond_MetaG_R2_C_H2O_MG_DASTool_bins_metabat.29': np.float64(0.20668424238579855),
#  'Salt_Pond_MetaG_R2_A_D2_MG_DASTool_bins_concoct_out.9': np.float64(0.1926843060801758),
#  'Salt_Pond_MetaG_R1_A_D2_MG_DASTool_bins_metabat.31': np.float64(0.18985871076960337),
#  'Salt_Pond_MetaG_R1_A_H2O_MG_DASTool_bins_metabat.8': np.float64(0.1734998251367914),
#  'Salt_Pond_MetaG_R1_A_D2_MG_DASTool_bins_metabat.50': np.float64(0.17105118366657665),
#  'Salt_Pond_MetaG_R2_A_D2_MG_DASTool_bins_metabat.16': np.float64(0.1667730330734882),
#  'Salt_Pond_MetaG_R2_A_D2_MG_DASTool_bins_concoct_out.67': np.float64(0.14743124641444186)}

# %%
import numpy as np
print(np.mean(list(unrestored_correlations.values())), np.mean(list(unrestored_correlations.values()))**2, np.std(list(unrestored_correlations.values())))
# Out:
# 0.8139577554324168 0.662527227628578 0.21198574084908497

# %% [markdown]
# ## look at the total abundances of MePn consumers and betaine reducers

# %%
merged_normalized_abundances = normalized_abundances.copy()
merged_normalized_abundances.loc["mepe"] = normalized_abundances.loc[mepe_striped].sum()
merged_normalized_abundances.loc["betaine_reducers"] = normalized_abundances.loc[betaine_striped].sum()
merged_normalized_abundances = merged_normalized_abundances.drop(mepe_striped)
merged_normalized_abundances
# Out:
#                                                     SF2_A_D1  SF2_A_D2  \
# Salt_Pond_MetaGSF2_A_D1_MG_DASTool_bins_concoct...  0.006616  0.006035
# Salt_Pond_MetaGSF2_A_D2_MG_DASTool_bins_concoct...  0.000352  0.000896
# Salt_Pond_MetaGSF2_A_D2_MG_DASTool_bins_concoct...  0.000446  0.005475
# Salt_Pond_MetaGSF2_A_D2_MG_DASTool_bins_concoct...  0.004389  0.008007
# Salt_Pond_MetaGSF2_A_D2_MG_DASTool_bins_concoct...  0.000069  0.002987
# ...                                                      ...       ...
# Salt_Pond_MetaG_R2_restored_H2O_MG_DASTool_bins...  0.000005  0.000003
# Salt_Pond_MetaG_R2_restored_H2O_MG_DASTool_bins...  0.000002  0.000002
# unbinned_reads                                      0.804522  0.759152
# mepe                                                0.000595  0.000745
# betaine_reducers                                    0.000013  0.000019
#
#                                                     SF2_B_D1  SF2_B_D2  \
# Salt_Pond_MetaGSF2_A_D1_MG_DASTool_bins_concoct...  0.003731  0.006515
# Salt_Pond_MetaGSF2_A_D2_MG_DASTool_bins_concoct...  0.000719  0.001256
# Salt_Pond_MetaGSF2_A_D2_MG_DASTool_bins_concoct...  0.001458  0.003433
# Salt_Pond_MetaGSF2_A_D2_MG_DASTool_bins_concoct...  0.013928  0.025495
# Salt_Pond_MetaGSF2_A_D2_MG_DASTool_bins_concoct...  0.000048  0.000114
# ...                                                      ...       ...
# Salt_Pond_MetaG_R2_restored_H2O_MG_DASTool_bins...  0.000003  0.000005
# Salt_Pond_MetaG_R2_restored_H2O_MG_DASTool_bins...  0.000002  0.000003
# unbinned_reads                                      0.732928  1.463329
# mepe                                                0.001242  0.003200
# betaine_reducers                                    0.000022  0.000093
#
#                                                     SF2_C_D1  SF2_C_D2  \
# Salt_Pond_MetaGSF2_A_D1_MG_DASTool_bins_concoct...  0.007592  0.005036
# Salt_Pond_MetaGSF2_A_D2_MG_DASTool_bins_concoct...  0.002582  0.002143
# Salt_Pond_MetaGSF2_A_D2_MG_DASTool_bins_concoct...  0.012013  0.013398
# Salt_Pond_MetaGSF2_A_D2_MG_DASTool_bins_concoct...  0.021325  0.023352
# Salt_Pond_MetaGSF2_A_D2_MG_DASTool_bins_concoct...  0.000149  0.003686
# ...                                                      ...       ...
# Salt_Pond_MetaG_R2_restored_H2O_MG_DASTool_bins...  0.000006  0.000004
# Salt_Pond_MetaG_R2_restored_H2O_MG_DASTool_bins...  0.000004  0.000004
# unbinned_reads                                      1.602282  1.708192
# mepe                                                0.001659  0.003441
# betaine_reducers                                    0.000043  0.000147
#
#                                                          R1_A_D1  \
# Salt_Pond_MetaGSF2_A_D1_MG_DASTool_bins_concoct...  1.644877e-07
# Salt_Pond_MetaGSF2_A_D2_MG_DASTool_bins_concoct...  1.930943e-07
# Salt_Pond_MetaGSF2_A_D2_MG_DASTool_bins_concoct...  2.252767e-07
# Salt_Pond_MetaGSF2_A_D2_MG_DASTool_bins_concoct...  2.109734e-07
# Salt_Pond_MetaGSF2_A_D2_MG_DASTool_bins_concoct...  4.398259e-06
# ...                                                          ...
# Salt_Pond_MetaG_R2_restored_H2O_MG_DASTool_bins...  4.866691e-06
# Salt_Pond_MetaG_R2_restored_H2O_MG_DASTool_bins...  7.773833e-06
# unbinned_reads                                      9.309582e-02
# mepe                                                1.387740e-02
# betaine_reducers                                    1.754022e-02
#
#                                                          R1_A_D2  \
# Salt_Pond_MetaGSF2_A_D1_MG_DASTool_bins_concoct...  2.926898e-07
# Salt_Pond_MetaGSF2_A_D2_MG_DASTool_bins_concoct...  1.573208e-07
# Salt_Pond_MetaGSF2_A_D2_MG_DASTool_bins_concoct...  2.012243e-07
# Salt_Pond_MetaGSF2_A_D2_MG_DASTool_bins_concoct...  3.219588e-07
# Salt_Pond_MetaGSF2_A_D2_MG_DASTool_bins_concoct...  3.395202e-06
# ...                                                          ...
# Salt_Pond_MetaG_R2_restored_H2O_MG_DASTool_bins...  6.987969e-06
# Salt_Pond_MetaG_R2_restored_H2O_MG_DASTool_bins...  1.005755e-05
# unbinned_reads                                      9.058212e-02
# mepe                                                1.490227e-02
# betaine_reducers                                    1.889628e-02
#
#                                                          R1_B_D1  \
# Salt_Pond_MetaGSF2_A_D1_MG_DASTool_bins_concoct...  6.317685e-07
# Salt_Pond_MetaGSF2_A_D2_MG_DASTool_bins_concoct...  1.340115e-07
# Salt_Pond_MetaGSF2_A_D2_MG_DASTool_bins_concoct...  5.130726e-07
# Salt_Pond_MetaGSF2_A_D2_MG_DASTool_bins_concoct...  4.862703e-07
# Salt_Pond_MetaGSF2_A_D2_MG_DASTool_bins_concoct...  5.701232e-06
# ...                                                          ...
# Salt_Pond_MetaG_R2_restored_H2O_MG_DASTool_bins...  2.025488e-05
# Salt_Pond_MetaG_R2_restored_H2O_MG_DASTool_bins...  8.906021e-06
# unbinned_reads                                      1.156331e-01
# mepe                                                2.393991e-02
# betaine_reducers                                    1.058171e-02
#
#                                                          R1_B_D2  ...  \
# Salt_Pond_MetaGSF2_A_D1_MG_DASTool_bins_concoct...  3.836137e-07  ...
# Salt_Pond_MetaGSF2_A_D2_MG_DASTool_bins_concoct...  4.583437e-07  ...
# Salt_Pond_MetaGSF2_A_D2_MG_DASTool_bins_concoct...  2.192078e-07  ...
# Salt_Pond_MetaGSF2_A_D2_MG_DASTool_bins_concoct...  3.836137e-07  ...
# Salt_Pond_MetaGSF2_A_D2_MG_DASTool_bins_concoct...  7.373355e-06  ...
# ...                                                          ...  ...
# Salt_Pond_MetaG_R2_restored_H2O_MG_DASTool_bins...  2.169161e-05  ...
# Salt_Pond_MetaG_R2_restored_H2O_MG_DASTool_bins...  1.493104e-05  ...
# unbinned_reads                                      1.228118e-01  ...
# mepe                                                2.761568e-02  ...
# betaine_reducers                                    1.771237e-02  ...
#
#                                                         R2A_B_D1  R2A_B_D2  \
# Salt_Pond_MetaGSF2_A_D1_MG_DASTool_bins_concoct...  7.961735e-05  0.000773
# Salt_Pond_MetaGSF2_A_D2_MG_DASTool_bins_concoct...  2.618992e-06  0.000037
# Salt_Pond_MetaGSF2_A_D2_MG_DASTool_bins_concoct...  4.467692e-06  0.000415
# Salt_Pond_MetaGSF2_A_D2_MG_DASTool_bins_concoct...  3.981895e-05  0.002120
# Salt_Pond_MetaGSF2_A_D2_MG_DASTool_bins_concoct...  5.118845e-05  0.001487
# ...                                                          ...       ...
# Salt_Pond_MetaG_R2_restored_H2O_MG_DASTool_bins...  7.600211e-07  0.000011
# Salt_Pond_MetaG_R2_restored_H2O_MG_DASTool_bins...  1.119491e-06  0.000008
# unbinned_reads                                      4.155628e-01  3.359769
# mepe                                                1.615404e-03  0.004680
# betaine_reducers                                    3.584424e-05  0.000073
#
#                                                     R2A_C_D1  R2A_C_D2  \
# Salt_Pond_MetaGSF2_A_D1_MG_DASTool_bins_concoct...  0.000033  0.000057
# Salt_Pond_MetaGSF2_A_D2_MG_DASTool_bins_concoct...  0.000004  0.000002
# Salt_Pond_MetaGSF2_A_D2_MG_DASTool_bins_concoct...  0.000029  0.000542
# Salt_Pond_MetaGSF2_A_D2_MG_DASTool_bins_concoct...  0.000034  0.000205
# Salt_Pond_MetaGSF2_A_D2_MG_DASTool_bins_concoct...  0.000070  0.000513
# ...                                                      ...       ...
# Salt_Pond_MetaG_R2_restored_H2O_MG_DASTool_bins...  0.000002  0.000002
# Salt_Pond_MetaG_R2_restored_H2O_MG_DASTool_bins...  0.000002  0.000002
# unbinned_reads                                      0.557968  0.821472
# mepe                                                0.001490  0.001183
# betaine_reducers                                    0.000018  0.000018
#
#                                                          R2_A_D1   R2_A_D2  \
# Salt_Pond_MetaGSF2_A_D1_MG_DASTool_bins_concoct...  3.459632e-07  0.000001
# Salt_Pond_MetaGSF2_A_D2_MG_DASTool_bins_concoct...  8.649080e-07  0.000001
# Salt_Pond_MetaGSF2_A_D2_MG_DASTool_bins_concoct...  1.049684e-06  0.000002
# Salt_Pond_MetaGSF2_A_D2_MG_DASTool_bins_concoct...  1.191214e-06  0.000003
# Salt_Pond_MetaGSF2_A_D2_MG_DASTool_bins_concoct...  3.742693e-06  0.000004
# ...                                                          ...       ...
# Salt_Pond_MetaG_R2_restored_H2O_MG_DASTool_bins...  6.362185e-05  0.000072
# Salt_Pond_MetaG_R2_restored_H2O_MG_DASTool_bins...  3.631827e-05  0.000029
# unbinned_reads                                      1.608085e-01  0.343942
# mepe                                                1.827708e-02  0.024067
# betaine_reducers                                    1.147432e-02  0.003282
#
#                                                      R2_B_D1       R2_B_D2  \
# Salt_Pond_MetaGSF2_A_D1_MG_DASTool_bins_concoct...  0.000021  6.398778e-07
# Salt_Pond_MetaGSF2_A_D2_MG_DASTool_bins_concoct...  0.000005  5.576078e-07
# Salt_Pond_MetaGSF2_A_D2_MG_DASTool_bins_concoct...  0.000026  6.947245e-07
# Salt_Pond_MetaGSF2_A_D2_MG_DASTool_bins_concoct...  0.000024  1.000952e-06
# Salt_Pond_MetaGSF2_A_D2_MG_DASTool_bins_concoct...  0.000190  1.611578e-05
# ...                                                      ...           ...
# Salt_Pond_MetaG_R2_restored_H2O_MG_DASTool_bins...  0.000509  3.977298e-05
# Salt_Pond_MetaG_R2_restored_H2O_MG_DASTool_bins...  0.000359  5.656977e-05
# unbinned_reads                                      3.859278  1.933192e-01
# mepe                                                0.434797  4.643770e-02
# betaine_reducers                                    0.115867  1.414065e-02
#
#                                                          R2_C_D1   R2_C_D2
# Salt_Pond_MetaGSF2_A_D1_MG_DASTool_bins_concoct...  1.452263e-06  0.000014
# Salt_Pond_MetaGSF2_A_D2_MG_DASTool_bins_concoct...  8.220354e-08  0.000010
# Salt_Pond_MetaGSF2_A_D2_MG_DASTool_bins_concoct...  9.919227e-07  0.000011
# Salt_Pond_MetaGSF2_A_D2_MG_DASTool_bins_concoct...  1.227573e-06  0.000015
# Salt_Pond_MetaGSF2_A_D2_MG_DASTool_bins_concoct...  1.103172e-05  0.000106
# ...                                                          ...       ...
# Salt_Pond_MetaG_R2_restored_H2O_MG_DASTool_bins...  4.194573e-05  0.000810
# Salt_Pond_MetaG_R2_restored_H2O_MG_DASTool_bins...  1.563511e-05  0.001089
# unbinned_reads                                      1.658099e-01  3.595310
# mepe                                                2.330005e-02  0.564502
# betaine_reducers                                    4.936361e-03  0.249306
#
# [286 rows x 24 columns]

# %% [markdown]
# # MePn reducers

# %% [markdown]
# # TODO correlate with all the experimental metabolites, including MePn

# %%
merged_correlations = {}
for index, row in merged_normalized_abundances.iterrows():
    corr = row.corr(normalized_methane)
    merged_correlations[index] = corr
    # print(f"{index} correlates {corr} with methane")

merged_correlations = dict(sorted(merged_correlations.items(), key=lambda item: item[1], reverse=True))
merged_correlations
# print("max all correlations", max(merged_correlations.values()))
# unrestored_merged_correlations = {k:v for k,v in merged_correlations.items() if ("R1_" in k or "R2_" in k) and not "restored" in k}
# unrestored_merged_correlations
# Out:
# {'Salt_Pond_MetaG_R2_restored_C_black_MG_DASTool_bins_metabat.13': np.float64(0.9922588688990923),
#  'Salt_Pond_MetaG_R2_C_D1_MG_DASTool_bins_concoct_out.98': np.float64(0.9897259768241059),
#  'Salt_Pond_MetaG_R2_B_D1_MG_DASTool_bins_metabat.13': np.float64(0.9876012116481486),
#  'Salt_Pond_MetaG_R1_B_D2_MG_DASTool_bins_metabat.16': np.float64(0.9872359225769332),
#  'mepe': np.float64(0.986741540640257),
#  'Salt_Pond_MetaG_R1_B_H2O_MG_DASTool_bins_metabat.5': np.float64(0.9854061134057847),
#  'Salt_Pond_MetaG_R1_B_D2_MG_DASTool_bins_metabat.30': np.float64(0.9837327339337952),
#  'Salt_Pond_MetaG_R2_B_D2_MG_DASTool_bins_metabat.52': np.float64(0.9830769058301974),
#  'Salt_Pond_MetaG_R1_B_H2O_MG_DASTool_bins_metabat.11': np.float64(0.9822720369608353),
#  'Salt_Pond_MetaG_R1_C_D2_MG_DASTool_bins_metabat.30': np.float64(0.9822702702526581),
#  'Salt_Pond_MetaG_R2_B_D1_MG_DASTool_bins_concoct_out.40': np.float64(0.9819724781554824),
#  'Salt_Pond_MetaG_R1_A_D2_MG_DASTool_bins_metabat.36': np.float64(0.9812577161234741),
#  'Salt_Pond_MetaG_R1_A_H2O_MG_DASTool_bins_maxbin.022': np.float64(0.9810057166033433),
#  'Salt_Pond_MetaG_R2_A_D1_MG_DASTool_bins_metabat.32': np.float64(0.9804771261925701),
#  'Salt_Pond_MetaG_R1_B_D2_MG_DASTool_bins_metabat.18': np.float64(0.9797948185326968),
#  'Salt_Pond_MetaG_R2_C_D1_MG_DASTool_bins_concoct_out.37': np.float64(0.9784081483978296),
#  'Salt_Pond_MetaG_R2_C_D1_MG_DASTool_bins_metabat.25': np.float64(0.9774579494482645),
#  'Salt_Pond_MetaGSF2_C_H2O_MG_DASTool_bins_metabat.13': np.float64(0.9764313275105435),
#  'Salt_Pond_MetaG_R2_B_D1_MG_DASTool_bins_metabat.22': np.float64(0.9742030103824345),
#  'Salt_Pond_MetaG_R1_C_D2_MG_DASTool_bins_concoct_out.36': np.float64(0.9735363640129976),
#  'Salt_Pond_MetaG_R2_B_D2_MG_DASTool_bins_metabat.44': np.float64(0.9732834932889711),
#  'Salt_Pond_MetaG_R1_B_D2_MG_DASTool_bins_metabat.34': np.float64(0.9731996889220743),
#  'Salt_Pond_MetaG_R2_A_D1_MG_DASTool_bins_metabat.24': np.float64(0.9719446280777478),
#  'Salt_Pond_MetaG_R2_restored_H2O_MG_DASTool_bins_maxbin.005': np.float64(0.9694063626382542),
#  'Salt_Pond_MetaG_R1_B_H2O_MG_DASTool_bins_concoct_out.13': np.float64(0.9685867668238233),
#  'Salt_Pond_MetaG_R2_A_D1_MG_DASTool_bins_concoct_out.84': np.float64(0.9682818064607562),
#  'Salt_Pond_MetaG_R1_C_D1_MG_DASTool_bins_concoct_out.45': np.float64(0.9659441340392655),
#  'Salt_Pond_MetaG_R2_B_D2_MG_DASTool_bins_metabat.62': np.float64(0.9645412832141552),
#  'Salt_Pond_MetaG_R1_B_D1_MG_DASTool_bins_metabat.49': np.float64(0.9617938135570683),
#  'Salt_Pond_MetaG_R1_A_D2_MG_DASTool_bins_metabat.15': np.float64(0.9604669623172198),
#  'Salt_Pond_MetaG_R1_B_D1_MG_DASTool_bins_metabat.29': np.float64(0.9601150967327471),
#  'Salt_Pond_MetaG_R2_A_D1_MG_DASTool_bins_metabat.12': np.float64(0.9590854432368837),
#  'Salt_Pond_MetaG_R1_C_D1_MG_DASTool_bins_metabat.27': np.float64(0.9579087846942652),
#  'Salt_Pond_MetaG_R2_A_D1_MG_DASTool_bins_metabat.9': np.float64(0.9558139719042481),
#  'Salt_Pond_MetaG_R1_A_D1_MG_DASTool_bins.concoct_out.9': np.float64(0.9556938040740716),
#  'Salt_Pond_MetaG_R1_B_D2_MG_DASTool_bins_metabat.19': np.float64(0.9547660398196796),
#  'Salt_Pond_MetaG_R2_B_D2_MG_DASTool_bins_metabat.45': np.float64(0.9544193649619589),
#  'Salt_Pond_MetaG_R1_B_D1_MG_DASTool_bins_metabat.38': np.float64(0.9537705492716377),
#  'Salt_Pond_MetaG_R1_C_D2_MG_DASTool_bins_metabat.58': np.float64(0.9505321702399039),
#  'Salt_Pond_MetaG_R1_B_D2_MG_DASTool_bins_concoct_out.73': np.float64(0.9503542323803579),
#  'Salt_Pond_MetaG_R1_A_D2_MG_DASTool_bins_metabat.84': np.float64(0.9502725478769598),
#  'Salt_Pond_MetaG_R2_A_H2O_MG_DASTool_bins_metabat.14': np.float64(0.9502620130938962),
#  'Salt_Pond_MetaG_R1_B_D1_MG_DASTool_bins_concoct_out.59': np.float64(0.9496007722691331),
#  'Salt_Pond_MetaG_R2_A_D1_MG_DASTool_bins_metabat.50': np.float64(0.9479792855219236),
#  'Salt_Pond_MetaG_R1_B_D2_MG_DASTool_bins_metabat.37': np.float64(0.9452669367807547),
#  'Salt_Pond_MetaG_R1_C_H2O_MG_DASTool_bins_concoct_out.16': np.float64(0.9452539872368196),
#  'Salt_Pond_MetaG_R2_B_D2_MG_DASTool_bins_metabat.20': np.float64(0.9442363014917992),
#  'Salt_Pond_MetaG_R1_A_D2_MG_DASTool_bins_metabat.27': np.float64(0.940654085112924),
#  'Salt_Pond_MetaG_R1_A_D2_MG_DASTool_bins_concoct_out.109': np.float64(0.9384440579490787),
#  'Salt_Pond_MetaG_R1_B_D2_MG_DASTool_bins_concoct_out.87': np.float64(0.9364388908187844),
#  'Salt_Pond_MetaG_R2_B_D2_MG_DASTool_bins_metabat.43': np.float64(0.9363645213669529),
#  'Salt_Pond_MetaG_R1_B_D2_MG_DASTool_bins_metabat.14': np.float64(0.9356503447457806),
#  'Salt_Pond_MetaG_R2_A_D1_MG_DASTool_bins_metabat.10': np.float64(0.9353755223357306),
#  'Salt_Pond_MetaG_R1_B_H2O_MG_DASTool_bins_maxbin.028': np.float64(0.9330413324824479),
#  'Salt_Pond_MetaG_R1_B_D2_MG_DASTool_bins_concoct_out.37': np.float64(0.9252838963795987),
#  'Salt_Pond_MetaG_R1_B_D2_MG_DASTool_bins_maxbin.014': np.float64(0.9228499703065595),
#  'betaine_reducers': np.float64(0.9225367989360246),
#  'Salt_Pond_MetaG_R1_A_D1_MG_DASTool_bins.concoct_out.5': np.float64(0.9157381575377774),
#  'Salt_Pond_MetaG_R2_C_D1_MG_DASTool_bins_concoct_out.118': np.float64(0.9107432562257042),
#  'Salt_Pond_MetaG_R1_B_D1_MG_DASTool_bins_metabat.41': np.float64(0.9093022806416892),
#  'Salt_Pond_MetaG_R1_B_D1_MG_DASTool_bins_metabat.28': np.float64(0.9088326322637268),
#  'Salt_Pond_MetaG_R1_A_D2_MG_DASTool_bins_metabat.45': np.float64(0.9069206168125175),
#  'Salt_Pond_MetaG_R2_restored_C_black_MG_DASTool_bins_metabat.22': np.float64(0.905777725295137),
#  'Salt_Pond_MetaG_R2_A_D1_MG_DASTool_bins_concoct_out.98': np.float64(0.9006990333107),
#  'Salt_Pond_MetaG_R1_B_H2O_MG_DASTool_bins_metabat.17': np.float64(0.8982449407600782),
#  'Salt_Pond_MetaG_R1_A_D1_MG_DASTool_bins.metabat.6': np.float64(0.8952623567881197),
#  'Salt_Pond_MetaG_R1_A_D1_MG_DASTool_bins.metabat.18': np.float64(0.884634229096664),
#  'Salt_Pond_MetaG_R2_A_D1_MG_DASTool_bins_metabat.61': np.float64(0.8830972351953948),
#  'Salt_Pond_MetaG_R1_C_H2O_MG_DASTool_bins_metabat.29': np.float64(0.8827371129824981),
#  'Salt_Pond_MetaG_R2_C_D1_MG_DASTool_bins_maxbin.062': np.float64(0.8826793703305901),
#  'Salt_Pond_MetaG_R2_restored_H2O_MG_DASTool_bins_maxbin.017': np.float64(0.878218073862409),
#  'Salt_Pond_MetaG_R1_B_D1_MG_DASTool_bins_metabat.16': np.float64(0.8767446240160867),
#  'Salt_Pond_MetaG_R2_B_D2_MG_DASTool_bins_concoct_out.4': np.float64(0.8756485987366244),
#  'Salt_Pond_MetaG_R1_A_H2O_MG_DASTool_bins_concoct_out.2': np.float64(0.8752743248731237),
#  'Salt_Pond_MetaG_R1_C_D2_MG_DASTool_bins_metabat.40': np.float64(0.8743054492400187),
#  'Salt_Pond_MetaG_R2_B_D1_MG_DASTool_bins_metabat.10': np.float64(0.8736940524366661),
#  'Salt_Pond_MetaG_R2A_C_H2O_MG_DASTool_bins_metabat.5': np.float64(0.8703884182781652),
#  'Salt_Pond_MetaG_R1_A_D1_MG_DASTool_bins.metabat.15': np.float64(0.869201426553978),
#  'Salt_Pond_MetaG_R1_B_D1_MG_DASTool_bins_metabat.40': np.float64(0.8687235523770542),
#  'Salt_Pond_MetaG_R1_B_D1_MG_DASTool_bins_concoct_out.53': np.float64(0.868238097476202),
#  'Salt_Pond_MetaG_R1_A_D1_MG_DASTool_bins.metabat.26': np.float64(0.8660527735950515),
#  'Salt_Pond_MetaG_R1_C_D2_MG_DASTool_bins_concoct_out.85': np.float64(0.8652377177614788),
#  'Salt_Pond_MetaG_R1_A_D2_MG_DASTool_bins_concoct_out.51': np.float64(0.8651937697356133),
#  'Salt_Pond_MetaG_R1_A_H2O_MG_DASTool_bins_metabat.6': np.float64(0.8571592750334204),
#  'Salt_Pond_MetaG_R1_C_H2O_MG_DASTool_bins_metabat.23': np.float64(0.8545603026612072),
#  'Salt_Pond_MetaG_R1_B_H2O_MG_DASTool_bins_concoct_out.22': np.float64(0.853612986746158),
#  'Salt_Pond_MetaG_R1_B_D2_MG_DASTool_bins_concoct_out.86': np.float64(0.8528734800090765),
#  'Salt_Pond_MetaG_R1_B_H2O_MG_DASTool_bins_concoct_out.19': np.float64(0.8514747173540393),
#  'Salt_Pond_MetaG_R1_A_D1_MG_DASTool_bins.metabat.47': np.float64(0.8433241829131413),
#  'Salt_Pond_MetaG_R2_restored_C_black_MG_DASTool_bins_concoct_out.43': np.float64(0.834921235061558),
#  'Salt_Pond_MetaG_R2_B_D2_MG_DASTool_bins_concoct_out.80': np.float64(0.8336770671184135),
#  'Salt_Pond_MetaG_R2_restored_C_black_MG_DASTool_bins_concoct_out.57': np.float64(0.8302919616019487),
#  'Salt_Pond_MetaG_R2_B_D2_MG_DASTool_bins_concoct_out.39': np.float64(0.8274175879435913),
#  'Salt_Pond_MetaG_R2_A_D1_MG_DASTool_bins_metabat.7': np.float64(0.8272815571914246),
#  'Salt_Pond_MetaGSF2_B_H2O_MG_DASTool_bins_metabat.8': np.float64(0.8212340507918946),
#  'Salt_Pond_MetaG_R2_restored_C_black_MG_DASTool_bins_concoct_out.51': np.float64(0.8200555985225901),
#  'Salt_Pond_MetaG_R1_A_H2O_MG_DASTool_bins_metabat.14': np.float64(0.8196396511880066),
#  'Salt_Pond_MetaG_R2_restored_C_black_MG_DASTool_bins_concoct_out.26': np.float64(0.8181638013744471),
#  'Salt_Pond_MetaG_R2_C_D1_MG_DASTool_bins_concoct_out.65': np.float64(0.8176196082630707),
#  'Salt_Pond_MetaG_R2_C_D1_MG_DASTool_bins_metabat.7': np.float64(0.8173516750688408),
#  'Salt_Pond_MetaG_R1_B_D1_MG_DASTool_bins_metabat.13': np.float64(0.8059848641762585),
#  'Salt_Pond_MetaG_R2A_A_H2O_MG_DASTool_bins_metabat.16': np.float64(0.7944272047497819),
#  'Salt_Pond_MetaG_R1_A_D1_MG_DASTool_bins.concoct_out.44': np.float64(0.7879872240217457),
#  'Salt_Pond_MetaG_R1_A_D2_MG_DASTool_bins_concoct_out.21': np.float64(0.7877556813211984),
#  'Salt_Pond_MetaG_R2_B_D2_MG_DASTool_bins_concoct_out.124': np.float64(0.7779045119041994),
#  'Salt_Pond_MetaG_R1_C_H2O_MG_DASTool_bins_concoct_out.67': np.float64(0.7699597654252786),
#  'Salt_Pond_MetaG_R2_A_H2O_MG_DASTool_bins_concoct_out.11': np.float64(0.7668737857292893),
#  'Salt_Pond_MetaG_R2_restored_H2O_MG_DASTool_bins_concoct_out.34': np.float64(0.7625833190155767),
#  'Salt_Pond_MetaG_R1_C_D1_MG_DASTool_bins_metabat.19': np.float64(0.7592707588408868),
#  'Salt_Pond_MetaG_R2_restored_C_black_MG_DASTool_bins_concoct_out.12': np.float64(0.7579198461236559),
#  'Salt_Pond_MetaG_R2_A_H2O_MG_DASTool_bins_concoct_out.45': np.float64(0.7534718013533213),
#  'Salt_Pond_MetaG_R2_A_D1_MG_DASTool_bins_concoct_out.93': np.float64(0.750393020111809),
#  'Salt_Pond_MetaG_R2_C_D2_MG_DASTool_bins_concoct_out.104': np.float64(0.748933053515011),
#  'Salt_Pond_MetaG_R2_restored_DShore_MG_DASTool_bins_metabat.27': np.float64(0.748926628276073),
#  'Salt_Pond_MetaG_R2_A_D1_MG_DASTool_bins_maxbin.001': np.float64(0.7459051998554063),
#  'Salt_Pond_MetaG_R2_A_D1_MG_DASTool_bins_concoct_out.119': np.float64(0.7453922082058209),
#  'Salt_Pond_MetaG_R1_A_D2_MG_DASTool_bins_concoct_out.25': np.float64(0.744057843841925),
#  'Salt_Pond_MetaG_R2_B_D2_MG_DASTool_bins_metabat.50': np.float64(0.7423579281658724),
#  'Salt_Pond_MetaG_R2_restored_C_black_MG_DASTool_bins_metabat.2': np.float64(0.7415207097957857),
#  'Salt_Pond_MetaG_R2_C_D1_MG_DASTool_bins_concoct_out.7': np.float64(0.7409046068366681),
#  'Salt_Pond_MetaG_R2_restored_C_black_MG_DASTool_bins_concoct_out.25': np.float64(0.739731826321595),
#  'Salt_Pond_MetaG_R2_B_D1_MG_DASTool_bins_concoct_out.110': np.float64(0.732508889671971),
#  'Salt_Pond_MetaG_R2_A_H2O_MG_DASTool_bins_concoct_out.29': np.float64(0.7269873208921637),
#  'Salt_Pond_MetaG_R2_C_D1_MG_DASTool_bins_concoct_out.71': np.float64(0.7237469776154849),
#  'Salt_Pond_MetaG_R1_B_D1_MG_DASTool_bins_concoct_out.89': np.float64(0.7202894409907247),
#  'Salt_Pond_MetaG_R2_restored_DShore_MG_DASTool_bins_metabat.18': np.float64(0.7193288937384797),
#  'Salt_Pond_MetaG_R2_A_D1_MG_DASTool_bins_concoct_out.29': np.float64(0.7173301180037934),
#  'Salt_Pond_MetaG_R2A_B_H2O_MG_DASTool_bins_concoct_out.69': np.float64(0.7120545606386289),
#  'Salt_Pond_MetaG_R2_B_H2O_MG_DASTool_bins_metabat.29': np.float64(0.7073376190093803),
#  'Salt_Pond_MetaG_R2_restored_H2O_MG_DASTool_bins_maxbin.002': np.float64(0.7039326844327266),
#  'Salt_Pond_MetaG_R2_restored_H2O_MG_DASTool_bins_concoct_out.44': np.float64(0.6996739906310048),
#  'Salt_Pond_MetaG_R2A_B_H2O_MG_DASTool_bins_concoct_out.59': np.float64(0.6915804990681481),
#  'Salt_Pond_MetaG_R1_B_D2_MG_DASTool_bins_metabat.78': np.float64(0.6913454111879178),
#  'Salt_Pond_MetaG_R2_C_D2_MG_DASTool_bins_concoct_out.100': np.float64(0.6896590417651067),
#  'Salt_Pond_MetaG_R1_C_D1_MG_DASTool_bins_maxbin.047': np.float64(0.6888540441306358),
#  'Salt_Pond_MetaG_R2_C_D2_MG_DASTool_bins_concoct_out.21': np.float64(0.6885885598387991),
#  'unbinned_reads': np.float64(0.6846774439959641),
#  'Salt_Pond_MetaG_R2_A_D1_MG_DASTool_bins_concoct_out.66': np.float64(0.6791071891227055),
#  'Salt_Pond_MetaG_R2_restored_DShore_MG_DASTool_bins_concoct_out.21': np.float64(0.6767834011919458),
#  'Salt_Pond_MetaG_R1_B_D1_MG_DASTool_bins_metabat.58': np.float64(0.6766639143898306),
#  'Salt_Pond_MetaGSF2_C_H2O_MG_DASTool_bins_metabat.29': np.float64(0.6756226997785084),
#  'Salt_Pond_MetaG_R2_C_H2O_MG_DASTool_bins_concoct_out.35': np.float64(0.6681510208173838),
#  'Salt_Pond_MetaG_R1_B_D2_MG_DASTool_bins_concoct_out.120': np.float64(0.6612868330857458),
#  'Salt_Pond_MetaG_R2_A_H2O_MG_DASTool_bins_maxbin.035': np.float64(0.6412382163617548),
#  'Salt_Pond_MetaG_R2A_A_H2O_MG_DASTool_bins_concoct_out.78': np.float64(0.6396092515971872),
#  'Salt_Pond_MetaG_R2_restored_DShore_MG_DASTool_bins_concoct_out.7': np.float64(0.6380988986678099),
#  'Salt_Pond_MetaG_R2_C_H2O_MG_DASTool_bins_concoct_out.60': np.float64(0.6331448075441839),
#  'Salt_Pond_MetaG_R1_A_D1_MG_DASTool_bins.concoct_out.54': np.float64(0.5733764611662305),
#  'Salt_Pond_MetaGSF2_B_H2O_MG_DASTool_bins_metabat.19': np.float64(0.572541211287764),
#  'Salt_Pond_MetaG_R1_A_D1_MG_DASTool_bins.metabat.45': np.float64(0.5364134121194511),
#  'Salt_Pond_MetaG_R2A_A_H2O_MG_DASTool_bins_concoct_out.62': np.float64(0.532743499716566),
#  'Salt_Pond_MetaG_R2A_C_H2O_MG_DASTool_bins_concoct_out.67': np.float64(0.5266028640506193),
#  'Salt_Pond_MetaGSF2_B_H2O_MG_DASTool_bins_metabat.28': np.float64(0.5263288115341359),
#  'Salt_Pond_MetaG_R1_A_D1_MG_DASTool_bins.metabat.51': np.float64(0.48598312737275473),
#  'Salt_Pond_MetaG_R1_A_D2_MG_DASTool_bins_metabat.48': np.float64(0.47834469994989126),
#  'Salt_Pond_MetaG_R2A_B_H2O_MG_DASTool_bins_maxbin.029': np.float64(0.44086214310284916),
#  'Salt_Pond_MetaG_R2_restored_DShore_MG_DASTool_bins_concoct_out.37': np.float64(0.4332157272230367),
#  'Salt_Pond_MetaG_R2A_A_H2O_MG_DASTool_bins_metabat.20': np.float64(0.38638925336461233),
#  'Salt_Pond_MetaG_R2A_A_H2O_MG_DASTool_bins_metabat.22': np.float64(0.3830134329052896),
#  'Salt_Pond_MetaGSF2_A_H2O_MG_DASTool_bins_metabat.34': np.float64(0.37702520438222076),
#  'Salt_Pond_MetaG_R2_restored_DShore_MG_DASTool_bins_concoct_out.2': np.float64(0.3755811654129987),
#  'Salt_Pond_MetaG_R2A_C_H2O_MG_DASTool_bins_metabat.16': np.float64(0.36491596616432354),
#  'Salt_Pond_MetaG_R1_B_D2_MG_DASTool_bins_metabat.63': np.float64(0.3587288071574184),
#  'Salt_Pond_MetaG_R2A_B_H2O_MG_DASTool_bins_concoct_out.80': np.float64(0.35380775800439757),
#  'Salt_Pond_MetaG_R2_A_D2_MG_DASTool_bins_concoct_out.19': np.float64(0.34456526467749066),
#  'Salt_Pond_MetaG_R2_A_D1_MG_DASTool_bins_concoct_out.52': np.float64(0.3360993280802641),
#  'Salt_Pond_MetaG_R2_restored_DShore_MG_DASTool_bins_concoct_out.89': np.float64(0.30735519301072933),
#  'Salt_Pond_MetaG_R1_A_D2_MG_DASTool_bins_concoct_out.1': np.float64(0.2792482352953475),
#  'Salt_Pond_MetaGSF2_B_H2O_MG_DASTool_bins_metabat.25': np.float64(0.2611503099090698),
#  'Salt_Pond_MetaG_R2_B_H2O_MG_DASTool_bins_metabat.16': np.float64(0.25049293445512993),
#  'Salt_Pond_MetaG_R2A_B_H2O_MG_DASTool_bins_metabat.42': np.float64(0.24903525748359023),
#  'Salt_Pond_MetaG_R2_restored_DShore_MG_DASTool_bins_concoct_out.40': np.float64(0.23682561221423074),
#  'Salt_Pond_MetaG_R2_C_H2O_MG_DASTool_bins_metabat.20': np.float64(0.22309959901354257),
#  'Salt_Pond_MetaG_R2_restored_DShore_MG_DASTool_bins_maxbin.037': np.float64(0.22087788337247774),
#  'Salt_Pond_MetaGSF2_A_H2O_MG_DASTool_bins_metabat.28': np.float64(0.21524115304437447),
#  'Salt_Pond_MetaG_R2_B_H2O_MG_DASTool_bins_metabat.17': np.float64(0.20682137995496436),
#  'Salt_Pond_MetaG_R2_C_H2O_MG_DASTool_bins_metabat.29': np.float64(0.20668424238579855),
#  'Salt_Pond_MetaGSF2_C_D2_MG_DASTool_bins_concoct_out.25': np.float64(0.1966356430843446),
#  'Salt_Pond_MetaG_R2_A_D2_MG_DASTool_bins_concoct_out.9': np.float64(0.1926843060801758),
#  'Salt_Pond_MetaG_R1_A_D2_MG_DASTool_bins_metabat.31': np.float64(0.18985871076960337),
#  'Salt_Pond_MetaGSF2_C_H2O_MG_DASTool_bins_metabat.49': np.float64(0.17995876779329664),
#  'Salt_Pond_MetaG_R1_A_H2O_MG_DASTool_bins_metabat.8': np.float64(0.1734998251367914),
#  'Salt_Pond_MetaG_R1_A_D2_MG_DASTool_bins_metabat.50': np.float64(0.17105118366657665),
#  'Salt_Pond_MetaG_R2_restored_DShore_MG_DASTool_bins_concoct_out.17': np.float64(0.1488037515641839),
#  'Salt_Pond_MetaG_R2_A_D2_MG_DASTool_bins_concoct_out.67': np.float64(0.14743124641444186),
#  'Salt_Pond_MetaG_R2A_B_H2O_MG_DASTool_bins_metabat.10': np.float64(0.14525758461611446),
#  'Salt_Pond_MetaG_R2_restored_DShore_MG_DASTool_bins_concoct_out.38': np.float64(0.09102250861383027),
#  'Salt_Pond_MetaG_R2_restored_DShore_MG_DASTool_bins_metabat.11': np.float64(0.07390453624135698),
#  'Salt_Pond_MetaGSF2_B_H2O_MG_DASTool_bins_metabat.39': np.float64(0.0731825402377435),
#  'Salt_Pond_MetaGSF2_B_H2O_MG_DASTool_bins_metabat.11': np.float64(0.04865058663600852),
#  'Salt_Pond_MetaGSF2_B_D2_MG_DASTool_bins_metabat.4': np.float64(0.046815557613844545),
#  'Salt_Pond_MetaG_R2_restored_DShore_MG_DASTool_bins_metabat.23': np.float64(0.04167952732418519),
#  'Salt_Pond_MetaG_R2A_A_D1_MG_DASTool_bins_concoct_out.42': np.float64(0.006047450434187325),
#  'Salt_Pond_MetaG_R2_restored_DShore_MG_DASTool_bins_metabat.15': np.float64(-0.006861256565504931),
#  'Salt_Pond_MetaGSF2_C_H2O_MG_DASTool_bins_metabat.16': np.float64(-0.01077699497405032),
#  'Salt_Pond_MetaG_R2_restored_DShore_MG_DASTool_bins_concoct_out.12': np.float64(-0.02142489515886885),
#  'Salt_Pond_MetaG_R2A_A_D1_MG_DASTool_bins_metabat.17': np.float64(-0.022236700468824675),
#  'Salt_Pond_MetaG_R2A_A_H2O_MG_DASTool_bins_metabat.49': np.float64(-0.0284102067361088),
#  'Salt_Pond_MetaG_R2_restored_DShore_MG_DASTool_bins_concoct_out.68': np.float64(-0.030912029531917132),
#  'Salt_Pond_MetaG_R2_restored_DShore_MG_DASTool_bins_metabat.8': np.float64(-0.04461519697944313),
#  'Salt_Pond_MetaG_R2A_C_H2O_MG_DASTool_bins_metabat.4': np.float64(-0.04560076989724983),
#  'Salt_Pond_MetaG_R2A_A_D1_MG_DASTool_bins_concoct_out.50': np.float64(-0.05545745808180864),
#  'Salt_Pond_MetaGSF2_C_D2_MG_DASTool_bins_concoct_out.17': np.float64(-0.05564810770893442),
#  'Salt_Pond_MetaGSF2_A_H2O_MG_DASTool_bins_metabat.23': np.float64(-0.062325655042951976),
#  'Salt_Pond_MetaG_R2A_C_D2_MG_DASTool_bins_concoct_out.69': np.float64(-0.06384240498307812),
#  'Salt_Pond_MetaG_R2_restored_DShore_MG_DASTool_bins_concoct_out.46': np.float64(-0.06389723853728994),
#  'Salt_Pond_MetaGSF2_C_D2_MG_DASTool_bins_concoct_out.42': np.float64(-0.06439190295496738),
#  'Salt_Pond_MetaGSF2_C_D2_MG_DASTool_bins_concoct_out.15': np.float64(-0.07101569439691813),
#  'Salt_Pond_MetaG_R2A_A_D2_MG_DASTool_bins_concoct_out.10': np.float64(-0.07173466304679482),
#  'Salt_Pond_MetaGSF2_C_D2_MG_DASTool_bins_concoct_out.26': np.float64(-0.07435866661245881),
#  'Salt_Pond_MetaG_R2A_B_D2_MG_DASTool_bins_concoct_out.54': np.float64(-0.07597803954222919),
#  'Salt_Pond_MetaG_R2A_B_D2_MG_DASTool_bins_concoct_out.47': np.float64(-0.07654599505429555),
#  'Salt_Pond_MetaGSF2_C_D2_MG_DASTool_bins_concoct_out.39': np.float64(-0.07840219699940476),
#  'Salt_Pond_MetaGSF2_C_D2_MG_DASTool_bins_concoct_out.8': np.float64(-0.07937030574474215),
#  'Salt_Pond_MetaG_R2_restored_DShore_MG_DASTool_bins_concoct_out.20': np.float64(-0.08069545316929687),
#  'Salt_Pond_MetaGSF2_C_D2_MG_DASTool_bins_concoct_out.3': np.float64(-0.0811804501040194),
#  'Salt_Pond_MetaGSF2_A_H2O_MG_DASTool_bins_concoct_out.33': np.float64(-0.08193216671811551),
#  'Salt_Pond_MetaG_R2A_A_D2_MG_DASTool_bins_concoct_out.59': np.float64(-0.08333587727109089),
#  'Salt_Pond_MetaGSF2_C_D2_MG_DASTool_bins_metabat.19': np.float64(-0.0833666999880665),
#  'Salt_Pond_MetaGSF2_B_H2O_MG_DASTool_bins_concoct_out.14': np.float64(-0.08522005114951328),
#  'Salt_Pond_MetaGSF2_C_D2_MG_DASTool_bins_concoct_out.24': np.float64(-0.085377613053223),
#  'Salt_Pond_MetaG_R2A_B_D2_MG_DASTool_bins_concoct_out.37': np.float64(-0.0874095179788496),
#  'Salt_Pond_MetaGSF2_C_D2_MG_DASTool_bins_concoct_out.13': np.float64(-0.08746744532809231),
#  'Salt_Pond_MetaGSF2_C_D2_MG_DASTool_bins_concoct_out.32': np.float64(-0.09319736933364112),
#  'Salt_Pond_MetaG_R2_restored_DShore_MG_DASTool_bins_metabat.13': np.float64(-0.09431623200860122),
#  'Salt_Pond_MetaG_R2A_C_D2_MG_DASTool_bins_concoct_out.34': np.float64(-0.0980243231528738),
#  'Salt_Pond_MetaG_R2A_C_D2_MG_DASTool_bins_metabat.38': np.float64(-0.0984378517522627),
#  'Salt_Pond_MetaG_R2A_C_D1_MG_DASTool_bins_maxbin.009': np.float64(-0.09876576728185299),
#  'Salt_Pond_MetaG_R2A_C_D2_MG_DASTool_bins_concoct_out.31': np.float64(-0.09931590541400667),
#  'Salt_Pond_MetaG_R2A_A_D2_MG_DASTool_bins_metabat.16': np.float64(-0.10199630575528047),
#  'Salt_Pond_MetaG_R2A_C_D1_MG_DASTool_bins_metabat.5': np.float64(-0.10299482475329237),
#  'Salt_Pond_MetaG_R2A_C_D2_MG_DASTool_bins_metabat.10': np.float64(-0.1031516259027125),
#  'Salt_Pond_MetaGSF2_C_D2_MG_DASTool_bins_metabat.11': np.float64(-0.10357383023573602),
#  'Salt_Pond_MetaG_R2_restored_DShore_MG_DASTool_bins_metabat.25': np.float64(-0.10376138240347814),
#  'Salt_Pond_MetaG_R2A_A_D2_MG_DASTool_bins_concoct_out.25': np.float64(-0.10463458324185392),
#  'Salt_Pond_MetaGSF2_B_D2_MG_DASTool_bins_concoct_out.42': np.float64(-0.1053012528397066),
#  'Salt_Pond_MetaGSF2_A_D2_MG_DASTool_bins_concoct_out.33': np.float64(-0.10597472692377909),
#  'Salt_Pond_MetaG_R2A_C_D2_MG_DASTool_bins_concoct_out.36': np.float64(-0.10757824726338316),
#  'Salt_Pond_MetaGSF2_A_D2_MG_DASTool_bins_concoct_out.40': np.float64(-0.10826747740702619),
#  'Salt_Pond_MetaGSF2_C_D2_MG_DASTool_bins_metabat.16': np.float64(-0.11039569573142605),
#  'Salt_Pond_MetaG_R2A_B_D2_MG_DASTool_bins_concoct_out.11': np.float64(-0.11180190499484835),
#  'Salt_Pond_MetaG_R2A_C_D2_MG_DASTool_bins_concoct_out.21': np.float64(-0.11221907687596568),
#  'Salt_Pond_MetaG_R2A_A_D1_MG_DASTool_bins_concoct_out.24': np.float64(-0.1126753494476047),
#  'Salt_Pond_MetaG_R2A_C_D2_MG_DASTool_bins_concoct_out.16': np.float64(-0.11295489550554645),
#  'Salt_Pond_MetaG_R2A_C_D2_MG_DASTool_bins_concoct_out.51': np.float64(-0.11354427766120674),
#  'Salt_Pond_MetaG_R2A_C_D2_MG_DASTool_bins_concoct_out.4': np.float64(-0.11388567853182618),
#  'Salt_Pond_MetaG_R2A_A_D2_MG_DASTool_bins_metabat.7': np.float64(-0.114345047199903),
#  'Salt_Pond_MetaG_R2A_C_D1_MG_DASTool_bins_concoct_out.10': np.float64(-0.11484070597453766),
#  'Salt_Pond_MetaG_R2A_A_D2_MG_DASTool_bins_concoct_out.37': np.float64(-0.11520992601469278),
#  'Salt_Pond_MetaG_R2A_C_D2_MG_DASTool_bins_concoct_out.49': np.float64(-0.11611669834966018),
#  'Salt_Pond_MetaG_R2A_C_D1_MG_DASTool_bins_metabat.17': np.float64(-0.11719154626112423),
#  'Salt_Pond_MetaG_R2A_A_D2_MG_DASTool_bins_concoct_out.51': np.float64(-0.11854977713489466),
#  'Salt_Pond_MetaG_R2A_C_D2_MG_DASTool_bins_concoct_out.9': np.float64(-0.11943040203392),
#  'Salt_Pond_MetaG_R2A_C_D2_MG_DASTool_bins_concoct_out.41': np.float64(-0.11996675445627743),
#  'Salt_Pond_MetaGSF2_B_D1_MG_DASTool_bins_concoct_out.44': np.float64(-0.12019843948697759),
#  'Salt_Pond_MetaG_R2A_C_D2_MG_DASTool_bins_metabat.27': np.float64(-0.12821320662254088),
#  'Salt_Pond_MetaG_R2A_C_D1_MG_DASTool_bins_concoct_out.8': np.float64(-0.12828236170559532),
#  'Salt_Pond_MetaG_R2A_B_D1_MG_DASTool_bins_concoct_out.4': np.float64(-0.12862630182947804),
#  'Salt_Pond_MetaG_R2A_C_D2_MG_DASTool_bins_concoct_out.42': np.float64(-0.12967669220940287),
#  'Salt_Pond_MetaGSF2_B_H2O_MG_DASTool_bins_concoct_out.91': np.float64(-0.13281447138991775),
#  'Salt_Pond_MetaG_R2A_C_D2_MG_DASTool_bins_maxbin.022': np.float64(-0.1329931140905071),
#  'Salt_Pond_MetaG_R2A_C_D1_MG_DASTool_bins_metabat.16': np.float64(-0.13730637089904726),
#  'Salt_Pond_MetaG_R2A_A_D1_MG_DASTool_bins_concoct_out.51': np.float64(-0.14311262142230619),
#  'Salt_Pond_MetaG_R2A_C_D2_MG_DASTool_bins_concoct_out.45': np.float64(-0.1487222410570641),
#  'Salt_Pond_MetaG_R2A_B_D2_MG_DASTool_bins_metabat.6': np.float64(-0.14901794932394463),
#  'Salt_Pond_MetaG_R2A_C_D1_MG_DASTool_bins_concoct_out.15': np.float64(-0.14965690062406325),
#  'Salt_Pond_MetaGSF2_C_D1_MG_DASTool_bins_concoct_out.13': np.float64(-0.14980673312446585),
#  'Salt_Pond_MetaG_R2A_C_D2_MG_DASTool_bins_concoct_out.10': np.float64(-0.15064878720451966),
#  'Salt_Pond_MetaGSF2_A_D2_MG_DASTool_bins_concoct_out.13': np.float64(-0.15209435860293763),
#  'Salt_Pond_MetaG_R2A_A_D1_MG_DASTool_bins_metabat.10': np.float64(-0.15320837660027833),
#  'Salt_Pond_MetaG_R2A_C_D1_MG_DASTool_bins_metabat.18': np.float64(-0.15341309962213126),
#  'Salt_Pond_MetaG_R2A_C_D2_MG_DASTool_bins_metabat.18': np.float64(-0.15342662112392744),
#  'Salt_Pond_MetaGSF2_B_D1_MG_DASTool_bins_metabat.9': np.float64(-0.1569440757296567),
#  'Salt_Pond_MetaG_R2A_A_D1_MG_DASTool_bins_concoct_out.46': np.float64(-0.16259059744007215),
#  'Salt_Pond_MetaG_R2A_C_D1_MG_DASTool_bins_concoct_out.52': np.float64(-0.16472583928999662),
#  'Salt_Pond_MetaGSF2_A_D2_MG_DASTool_bins_concoct_out.11': np.float64(-0.16795403920422836),
#  'Salt_Pond_MetaG_R2A_C_D1_MG_DASTool_bins_metabat.4': np.float64(-0.17500478582484313),
#  'Salt_Pond_MetaGSF2_A_D2_MG_DASTool_bins_concoct_out.28': np.float64(-0.18175487063934),
#  'Salt_Pond_MetaGSF2_A_D2_MG_DASTool_bins_concoct_out.55': np.float64(-0.18658160906876542),
#  'Salt_Pond_MetaGSF2_A_H2O_MG_DASTool_bins_metabat.14': np.float64(-0.19416004661244868),
#  'Salt_Pond_MetaGSF2_A_D2_MG_DASTool_bins_concoct_out.8': np.float64(-0.20240779517931912),
#  'Salt_Pond_MetaG_R2A_A_D1_MG_DASTool_bins_concoct_out.6': np.float64(-0.20429507365349614),
#  'Salt_Pond_MetaGSF2_B_D2_MG_DASTool_bins_concoct_out.55': np.float64(-0.20520627112278608),
#  'Salt_Pond_MetaGSF2_A_D1_MG_DASTool_bins_concoct_out.23': np.float64(-0.20828468537014275),
#  'Salt_Pond_MetaG_R2A_A_D1_MG_DASTool_bins_metabat.14': np.float64(-0.21314066151156572),
#  'Salt_Pond_MetaGSF2_A_H2O_MG_DASTool_bins_concoct_out.23': np.float64(-0.21370521549301794)}

# %% [markdown]
# # Simulation

# %%
dontGrow = []
for ID, model in models.items():
    ogMedia = model.medium
    model.medium = media
    sol = model.optimize()
    if sol.status == "infeasible":
        print(ID, "is infeasible")
    elif sol.objective_value == 0:
        print(ID, "doesn't grow")
        dontGrow.append(ID)
    else: print(sol)
    model.medium = ogMedia
# Out:
# <Solution 5.118 at 0x16b5ac250>
# <Solution 4.006 at 0x30ac52690>
# <Solution 5.084 at 0x30ac532d0>
# <Solution 4.976 at 0x30ac500d0>
# Salt_Pond_MetaG_R2_restored_C_black_MG_DASTool_bins_concoct_out.17.contigs doesn't grow
# <Solution 4.866 at 0x30ac516d0>
# <Solution 5.084 at 0x30ac50990>
# <Solution 0.002 at 0x30ac52690>
# <Solution 5.150 at 0x30ac50350>
# <Solution 0.002 at 0x30ac50390>
# <Solution 0.002 at 0x30ac50190>
# <Solution 5.106 at 0x30ac50e50>
# <Solution 5.114 at 0x30ac50910>
# <Solution 5.023 at 0x30ac50050>
# <Solution 4.695 at 0x30ac50d90>
# <Solution 4.990 at 0x30ac53290>
# <Solution 5.111 at 0x30ac512d0>
# Salt_Pond_MetaG_R2_C_D1_MG_DASTool_bins_concoct_out.88.contigs doesn't grow
# Salt_Pond_MetaG_R2_C_D1_MG_DASTool_bins_concoct_out.95.contigs doesn't grow
# <Solution 5.136 at 0x30ac50150>
# <Solution 5.024 at 0x30ac50310>
# Salt_Pond_MetaG_R1_B_D2_MG_DASTool_bins_metabat.27.contigs doesn't grow
# <Solution 5.093 at 0x30ac50050>
# <Solution 5.148 at 0x30ac511d0>

# %%
config = cobra.Configuration()
config
# Out:
# solver: glpk
# tolerance: 1e-07
# lower_bound: -1000.0
# upper_bound: 1000.0
# processes: 335
# cache_directory: /home/afreiburger/.cache/cobrapy
# max_cache_size: 104857600
# cache_expiration: None

# %% [markdown]
# ## simulate the MePn-consuming organisms

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

from optlang.symbolics import Zero
import numpy as np

sols = {}
# methane_production, lactate_consumption, = {}, {}
# media["EX_cpd00009_e0"] = 10
fits, fluxes = {}, {}

with open("sols_log.txt", 'w') as f:
    for multiple in [0.07, .33]: # + list(np.logspace(-1, 1, 10)):
        fluxes[multiple] = {"methane": {}, "lactate": {}, "phosphate": {}, "MePn": {}}
        for orgID, row in averaged_unrestored_normalized_abundances.iterrows():
            # print(orgID)
            ID = orgID+".contigs"
            if ID not in models or ID in dontGrow:  continue
            model = models[ID].copy()

            # phosphate ratio constraint
            constraint = model.problem.Constraint(Zero, lb=0, ub=None, name="Phosphate_ratio")
            model.add_cons_vars(constraint)
            model.solver.update()
            # MePn >= multiple * Pi
            constraint.set_linear_coefficients(coefficients = {
                model.reactions.EX_cpd00009_e0.forward_variable: multiple,
                model.reactions.EX_cpd00009_e0.reverse_variable: -multiple,
                model.reactions.EX_cpd25960_e0.forward_variable: -1,
                model.reactions.EX_cpd25960_e0.reverse_variable: 1})
                # model.reactions.EX_cpd00009_e0.forward_variable: multiple,
                # model.reactions.EX_cpd25960_e0.forward_variable: -1})
            # display(constraint.ub, constraint.expression, constraint.lb)
            model.solver.update()
            
            model.medium = media
            bio = model.reactions.get_by_id("bio1")
            model.solver.configuration.timeout = 15
            sols[ID] = {}
            for k, dic in fluxes[multiple].items():
                fluxes[multiple][k][ID] = {}
            f.write(f"\n\n{orgID}")
            for sample, abundance in row.items():
                # fix the biomass
                bio.bounds = (abundance, abundance)
                # define lactate as a the objective
                EX = model.reactions.get_by_id("EX_cpd00159_e0")
                EX.bounds = (-1000, 0)
                model.objective = EX
                f.write(f"\noptimizing {sample} at {abundance}")
                sols[ID][sample] = model.optimize()
                if sols[ID][sample].status == "infeasible":
                    f.write(f"Feasibility Error: {ID} {sample}")
                
                fluxes[multiple]["methane"][ID][sample] = sols[ID][sample].fluxes.EX_cpd01024_e0
                fluxes[multiple]["lactate"][ID][sample] = sols[ID][sample].fluxes.EX_cpd00159_e0
                fluxes[multiple]["phosphate"][ID][sample] = sols[ID][sample].fluxes.EX_cpd00009_e0
                # fluxes[multiple]["phosphate"][ID][sample] = model.reactions.EX_cpd00009_e0.reverse_variable.primal
                fluxes[multiple]["MePn"][ID][sample] = sols[ID][sample].fluxes.EX_cpd25960_e0
                # fluxes[multiple]["MePn"][ID][sample] = model.reactions.EX_cpd25960_e0.reverse_variable.primal
                
                bio.bounds = (0, 0)
                bio_flux = sols[ID][sample].fluxes.bio1
                if bio_flux != abundance:
                    f.write(f"\nAbundance Error: {bio_flux} != {abundance}")
                f.write(f"\noptimized at {sols[ID][sample].fluxes.EX_cpd00159_e0}")
    
        # determine the linear regression of fitting the experimental data with the simulation fluxes
        mdl = LinearRegression()
        xs = np.array(list(methane_dic.values())).reshape(-1, 1)
        methane_df = DataFrame(fluxes[multiple]["methane"])
        ys = np.array(fluxes_to_emissions(methane_df.T.sum()).to_list())
        mdl.fit(xs, ys)
        y_pred = mdl.predict(xs)
        fits[multiple] = {"eq": f"y = {mdl.coef_[0]:.2f}x + {mdl.intercept_:.2f}",
                          "R2": f"$R^2$ = {r2_score(ys, y_pred):.8f}"}

        mepn_df = DataFrame(fluxes[multiple]["MePn"])
        phosphate_df = DataFrame(fluxes[multiple]["phosphate"])
        # display(mepn_df)
        print("\nMinimum MePn/Phosphate ratio", multiple)
        print("total MePn consumed:", mepn_df.sum(axis=1).to_dict())
        print("total inorganic Phosphate consumed:", phosphate_df.sum(axis=1).to_dict())
        print(fits[multiple])
        # print(sum(list(.values()))
        # break
        # print(fluxes[multiple]["phosphate"]['Salt_Pond_MetaG_R1_B_H2O_MG_DASTool_bins_metabat.7.contigs'])
        # print(fluxes[multiple]["MePn"]['Salt_Pond_MetaG_R1_B_H2O_MG_DASTool_bins_metabat.7.contigs'])

json.dump(fits, open("fits.json", 'w'), indent=3)
json.dump(fluxes, open("saltern_fluxes.json", 'w'), indent=3)
# Out:
# /Users/andrewfreiburger/Documents/venv_microbiome_stable/lib/python3.11/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# /Users/andrewfreiburger/Documents/venv_microbiome_stable/lib/python3.11/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# /Users/andrewfreiburger/Documents/venv_microbiome_stable/lib/python3.11/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# /Users/andrewfreiburger/Documents/venv_microbiome_stable/lib/python3.11/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# /Users/andrewfreiburger/Documents/venv_microbiome_stable/lib/python3.11/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# /Users/andrewfreiburger/Documents/venv_microbiome_stable/lib/python3.11/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# /Users/andrewfreiburger/Documents/venv_microbiome_stable/lib/python3.11/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# Minimum MePn/Phosphate ratio 0.07
# total MePn consumed: {'R2_C': -0.028365322674484703, 'R1_A': -0.0017717546724596899, 'R2_B': -0.027858955793534822, 'R2_A': -0.001641265739627526, 'R1_C': -0.005920965529428517, 'R1_B': -0.0028507609560914395}
# total inorganic Phosphate consumed: {'R2_C': -0.14867171963939776, 'R1_A': -0.007103016454197414, 'R2_B': -0.10928480236801683, 'R2_A': -0.007311309058859013, 'R1_C': -0.022707394458154877, 'R1_B': -0.012291319596803485}
# {'eq': 'y = 0.51x + 138.48', 'R2': '$R^2$ = 0.97828062'}
# /Users/andrewfreiburger/Documents/venv_microbiome_stable/lib/python3.11/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# /Users/andrewfreiburger/Documents/venv_microbiome_stable/lib/python3.11/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# /Users/andrewfreiburger/Documents/venv_microbiome_stable/lib/python3.11/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# /Users/andrewfreiburger/Documents/venv_microbiome_stable/lib/python3.11/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# /Users/andrewfreiburger/Documents/venv_microbiome_stable/lib/python3.11/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# /Users/andrewfreiburger/Documents/venv_microbiome_stable/lib/python3.11/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# /Users/andrewfreiburger/Documents/venv_microbiome_stable/lib/python3.11/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# /Users/andrewfreiburger/Documents/venv_microbiome_stable/lib/python3.11/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# /Users/andrewfreiburger/Documents/venv_microbiome_stable/lib/python3.11/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# /Users/andrewfreiburger/Documents/venv_microbiome_stable/lib/python3.11/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# /Users/andrewfreiburger/Documents/venv_microbiome_stable/lib/python3.11/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# /Users/andrewfreiburger/Documents/venv_microbiome_stable/lib/python3.11/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# /Users/andrewfreiburger/Documents/venv_microbiome_stable/lib/python3.11/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# /Users/andrewfreiburger/Documents/venv_microbiome_stable/lib/python3.11/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# /Users/andrewfreiburger/Documents/venv_microbiome_stable/lib/python3.11/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# Minimum MePn/Phosphate ratio 0.33
# total MePn consumed: {'R2_C': -0.056440860480034764, 'R1_A': -0.003085649417768163, 'R2_B': -0.048044952158359015, 'R2_A': -0.003010561802076154, 'R1_C': -0.010098177352233666, 'R1_B': -0.005143213806276558}
# total inorganic Phosphate consumed: {'R2_C': -0.12059618183613853, 'R1_A': -0.005789121709098119, 'R2_B': -0.08909880600318905, 'R2_A': -0.005942012996409809, 'R1_C': -0.018530182635350365, 'R1_B': -0.009998866746618838}
# {'eq': 'y = 0.95x + 223.77', 'R2': '$R^2$ = 0.96812476'}
# /Users/andrewfreiburger/Documents/venv_microbiome_stable/lib/python3.11/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)

# %%
# display(model.reactions.EX_cpd00009_e0.reaction)
# viewing the phosphate constraints
for cons in model.constraints:
    if "Phosphate" in cons.name:
        print(cons.name)
        print(cons.ub, ">=", cons.expression, ">=", cons.lb)
# Out:
# Phosphate_ratio
# 0 >= 10.0*EX_cpd00009_e0_reverse_97c79 - 1.0*EX_cpd25960_e0_reverse_e4a29 >= None

# %% [markdown]
# ### compute the methane emission from substrate addition of MePn

# %%
additional_methane_generated = 10 # umol
hours_equilibrated = 14 * 24 # hours
volume_added = 10 # mL
concentration_added = 100 # umol/L
substrate_added = concentration_added * (volume_added/1000)  # umol
substrate_flux = substrate_added #  / hours_equilibrated  # not divided by time because all of the substrate was added at once
additional_methane_flux = additional_methane_generated / hours_equilibrated  # umol/hr
print(additional_methane_flux, "umol/hr methane flux from addition")
# Out:
# 0.02976190476190476 umol/hr methane flux from addition

# %%
substrate_added
# Out:
# 1.0

# %%
averaged_unrestored_normalized_abundances
# Out:
#                                                             R1_A      R2_B  \
# Unnamed: 0
# Salt_Pond_MetaGSF2_A_D1_MG_DASTool_bins_concoct...  2.285888e-07  0.000011
# Salt_Pond_MetaGSF2_A_D2_MG_DASTool_bins_concoct...  1.752075e-07  0.000003
# Salt_Pond_MetaGSF2_A_D2_MG_DASTool_bins_concoct...  2.132505e-07  0.000013
# Salt_Pond_MetaGSF2_A_D2_MG_DASTool_bins_concoct...  2.664661e-07  0.000013
# Salt_Pond_MetaGSF2_A_D2_MG_DASTool_bins_concoct...  3.896730e-06  0.000103
# ...                                                          ...       ...
# Salt_Pond_MetaG_R2_restored_H2O_MG_DASTool_bins...  1.996096e-07  0.000126
# Salt_Pond_MetaG_R2_restored_H2O_MG_DASTool_bins...  5.278583e-07  0.000529
# Salt_Pond_MetaG_R2_restored_H2O_MG_DASTool_bins...  5.927330e-06  0.000274
# Salt_Pond_MetaG_R2_restored_H2O_MG_DASTool_bins...  8.915694e-06  0.000208
# unbinned_reads                                      9.183897e-02  2.026298
#
#                                                             R1_C      R2_C  \
# Unnamed: 0
# Salt_Pond_MetaGSF2_A_D1_MG_DASTool_bins_concoct...  1.282414e-06  0.000008
# Salt_Pond_MetaGSF2_A_D2_MG_DASTool_bins_concoct...  1.089267e-06  0.000005
# Salt_Pond_MetaGSF2_A_D2_MG_DASTool_bins_concoct...  6.679555e-07  0.000006
# Salt_Pond_MetaGSF2_A_D2_MG_DASTool_bins_concoct...  1.226690e-06  0.000008
# Salt_Pond_MetaGSF2_A_D2_MG_DASTool_bins_concoct...  1.540657e-05  0.000058
# ...                                                          ...       ...
# Salt_Pond_MetaG_R2_restored_H2O_MG_DASTool_bins...  3.355478e-06  0.002550
# Salt_Pond_MetaG_R2_restored_H2O_MG_DASTool_bins...  1.325396e-05  0.008717
# Salt_Pond_MetaG_R2_restored_H2O_MG_DASTool_bins...  2.215507e-05  0.000426
# Salt_Pond_MetaG_R2_restored_H2O_MG_DASTool_bins...  3.752668e-05  0.000552
# unbinned_reads                                      2.711032e-01  1.880560
#
#                                                             R2_A          R1_B
# Unnamed: 0
# Salt_Pond_MetaGSF2_A_D1_MG_DASTool_bins_concoct...  6.775749e-07  5.076911e-07
# Salt_Pond_MetaGSF2_A_D2_MG_DASTool_bins_concoct...  1.073584e-06  2.961776e-07
# Salt_Pond_MetaGSF2_A_D2_MG_DASTool_bins_concoct...  1.403428e-06  3.661402e-07
# Salt_Pond_MetaGSF2_A_D2_MG_DASTool_bins_concoct...  1.854122e-06  4.349420e-07
# Salt_Pond_MetaGSF2_A_D2_MG_DASTool_bins_concoct...  3.729437e-06  6.537293e-06
# ...                                                          ...           ...
# Salt_Pond_MetaG_R2_restored_H2O_MG_DASTool_bins...  5.490922e-05  4.723512e-07
# Salt_Pond_MetaG_R2_restored_H2O_MG_DASTool_bins...  2.540135e-04  2.519591e-06
# Salt_Pond_MetaG_R2_restored_H2O_MG_DASTool_bins...  6.790419e-05  2.097325e-05
# Salt_Pond_MetaG_R2_restored_H2O_MG_DASTool_bins...  3.241835e-05  1.191853e-05
# unbinned_reads                                      2.523752e-01  1.192224e-01
#
# [311 rows x 6 columns]

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

from optlang.symbolics import Zero
import numpy as np

# methane_production, lactate_consumption, = {}, {}
# media["EX_cpd00009_e0"] = 10
 # mmol and divided by 3 to account for the lack of a community model to share it among all members
 ## yet there are generally 1-3 MePn consumers per sample so dividing by 3 is a reasonable approximation
media["EX_cpd25960_e0"] = substrate_flux / 1000 # / 3   # mmol
display(media)
print("members", len(averaged_unrestored_normalized_abundances.index))
fits_addition, fluxes_addition = {}, {}
MePn_consumers = {}

fluxes_addition = {"methane": {}, "lactate": {}, "phosphate": {}, "MePn": {}}
total_methane_emissions = np.array([0.0]*len(averaged_unrestored_normalized_abundances.columns))
total_MePn_consumption = np.array([0.0]*len(averaged_unrestored_normalized_abundances.columns))
for orgID, row in averaged_unrestored_normalized_abundances.iterrows():
    # print(orgID)
    ID = orgID+".contigs"
    if ID not in models or ID in dontGrow:  continue
    model = models[ID].copy()


    model.medium = media
    bio = model.reactions.get_by_id("bio1")
    model.solver.configuration.timeout = 15
    for k, dic in fluxes_addition.items():
        fluxes_addition[k][ID] = {}
    for sample, abundance in row.items():
        # constrain biomass and lactate consumption
        bio.bounds = (abundance, abundance)
        EX = model.reactions.get_by_id("EX_cpd00159_e0")
        # EX.bounds = (-1000, 0)
        model.objective = EX
        # model.objective_direction = "max"
        # print(model.reactions.get_by_id("EX_cpd25960_e0").bounds)
        # model.reactions.get_by_id("EX_cpd25960_e0").lower_bound = -media["EX_cpd25960_e0"]
        sol = model.optimize()
        if sol.status == "infeasible":
            print(f"Feasibility Error: {ID} in {sample}")
            continue

        if abs(sol.fluxes.EX_cpd25960_e0) > 1e-9:
            MePn_consumers[sample] = MePn_consumers.get(sample, set())
            MePn_consumers[sample].add(ID)
        if abs(model.reactions.get_by_id("EX_cpd25960_e0").lower_bound) < abs(sol.fluxes.EX_cpd25960_e0):
            display(model.medium)
            raise ValueError(f"MePn flux {sol.fluxes.EX_cpd25960_e0} is greater than the lower bound \
                {model.reactions.get_by_id('EX_cpd25960_e0').lower_bound} for {ID} {sample}")

        fluxes_addition["methane"][ID][sample] = sol.fluxes.EX_cpd01024_e0
        fluxes_addition["lactate"][ID][sample] = sol.fluxes.EX_cpd00159_e0
        fluxes_addition["phosphate"][ID][sample] = sol.fluxes.EX_cpd00009_e0
        fluxes_addition["MePn"][ID][sample] = sol.fluxes.EX_cpd25960_e0
        
        bio.bounds = (0, 0)
        bio_flux = sol.fluxes.bio1
        if bio_flux != abundance:
            print(f"Abundance Error: {bio_flux} != {abundance}")

    # print("methylphosphonate consumption")
    # display(DataFrame(fluxes_addition["MePn"]))

    xs = np.array(list(methane_dic.values())).reshape(-1, 1)
    methane_df = DataFrame(fluxes_addition["methane"])
    methane_producing_members = methane_df.sum()[methane_df.sum() > 0].index
    if len(methane_producing_members) == 0:
        print(f"Skipping {ID} because no methane was produced")
        continue
    ys = np.array(methane_df.T.sum().to_list())
    mdl = LinearRegression()
    mdl.fit(xs, ys)
    y_pred = mdl.predict(xs)
    fits_addition = {"eq": f"y = {mdl.coef_[0]:.2f}x + {mdl.intercept_:.2f}",
                        "R2": f"$R^2$ = {r2_score(ys, y_pred):.8f}"}

    mepn_addition_df = DataFrame(fluxes_addition["MePn"])
    phosphate_addition_df = DataFrame(fluxes_addition["phosphate"])
    print(f"\nSubstrate addition: {ID}")
    print(ys)
    total_methane_emissions += ys * 1000
    total_MePn_consumption += np.array(mepn_addition_df.T.sum().to_list()) * 1000
    print("total MePn consumed:", mepn_addition_df.sum(axis=1).to_dict())
    print("total inorganic Phosphate consumed:", phosphate_addition_df.sum(axis=1).to_dict())
    print(fits_addition)
    # print(sum(list(.values()))
    # break
    # print(fluxes[multiple]["phosphate"]['Salt_Pond_MetaG_R1_B_H2O_MG_DASTool_bins_metabat.7.contigs'])
    # print(fluxes[multiple]["MePn"]['Salt_Pond_MetaG_R1_B_H2O_MG_DASTool_bins_metabat.7.contigs'])

print("methane producing members", methane_producing_members)
print("MePn consumers", MePn_consumers)
print("Total methane emissions from addition (umol/hr):", dict(zip(averaged_unrestored_normalized_abundances.columns, total_methane_emissions)))
print("Total MePn consumption from addition (umol/hr):", dict(zip(averaged_unrestored_normalized_abundances.columns, total_MePn_consumption)))
# json.dump(fits_addition, open("fits_addition.json", 'w'), indent=3)
# json.dump(fluxes_addition, open("saltern_fluxes_addition.json", 'w'), indent=3)
# Out:
# {'EX_cpd00067_e0': 1000.0,
#  'EX_cpd00058_e0': 1000.0,
#  'EX_cpd00013_e0': 1000.0,
#  'EX_cpd00244_e0': 1000.0,
#  'EX_cpd00205_e0': 1000.0,
#  'EX_cpd00034_e0': 1000.0,
#  'EX_cpd11574_e0': 1000.0,
#  'EX_cpd00971_e0': 1000.0,
#  'EX_cpd00048_e0': 1000.0,
#  'EX_cpd00030_e0': 1000.0,
#  'EX_cpd00305_e0': 100.0,
#  'EX_cpd00001_e0': 1000.0,
#  'EX_cpd10516_e0': 1000.0,
#  'EX_cpd00007_e0': 1000.0,
#  'EX_cpd00159_e0': 100.0,
#  'EX_cpd25960_e0': 0.001,
#  'EX_cpd00009_e0': 100,
#  'EX_cpd00063_e0': 1000.0,
#  'EX_cpd00149_e0': 1000.0,
#  'EX_cpd00254_e0': 1000.0,
#  'EX_cpd00099_e0': 1000.0}
# members 311
# Skipping Salt_Pond_MetaG_R1_B_D1_MG_DASTool_bins_metabat.20.contigs because no methane was produced
# Skipping Salt_Pond_MetaG_R1_B_D1_MG_DASTool_bins_metabat.32.contigs because no methane was produced
# Skipping Salt_Pond_MetaG_R1_B_D2_MG_DASTool_bins_concoct_out.51.contigs because no methane was produced
# Skipping Salt_Pond_MetaG_R1_B_D2_MG_DASTool_bins_metabat.28.contigs because no methane was produced
# Skipping Salt_Pond_MetaG_R1_B_H2O_MG_DASTool_bins_metabat.7.contigs because no methane was produced
# Skipping Salt_Pond_MetaG_R1_C_H2O_MG_DASTool_bins_concoct_out.79.contigs because no methane was produced
# Skipping Salt_Pond_MetaG_R2_A_D1_MG_DASTool_bins_concoct_out.35.contigs because no methane was produced
# Skipping Salt_Pond_MetaG_R2_A_D1_MG_DASTool_bins_concoct_out.49.contigs because no methane was produced
# Skipping Salt_Pond_MetaG_R2_B_D2_MG_DASTool_bins_concoct_out.143.contigs because no methane was produced
# Skipping Salt_Pond_MetaG_R2_B_D2_MG_DASTool_bins_concoct_out.32.contigs because no methane was produced
# Skipping Salt_Pond_MetaG_R2_B_D2_MG_DASTool_bins_metabat.10.contigs because no methane was produced
# Skipping Salt_Pond_MetaG_R2_B_D2_MG_DASTool_bins_metabat.16.contigs because no methane was produced
# Skipping Salt_Pond_MetaG_R2_B_D2_MG_DASTool_bins_metabat.19.contigs because no methane was produced
# Skipping Salt_Pond_MetaG_R2_B_D2_MG_DASTool_bins_metabat.38.contigs because no methane was produced
# /Users/andrewfreiburger/Documents/venv_microbiome_stable/lib/python3.11/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# Feasibility Error: Salt_Pond_MetaG_R2_B_D2_MG_DASTool_bins_metabat.55.contigs in R2_C
# Feasibility Error: Salt_Pond_MetaG_R2_B_D2_MG_DASTool_bins_metabat.55.contigs in R2_B
# Feasibility Error: Salt_Pond_MetaG_R2_B_D2_MG_DASTool_bins_metabat.55.contigs in R1_C
#
# Substrate addition: Salt_Pond_MetaG_R2_B_D2_MG_DASTool_bins_metabat.55.contigs
# [0.         0.00051612 0.         0.00029195 0.         0.00065104]
# total MePn consumed: {'R2_C': 6.613994683108191e-15, 'R1_A': -0.000516120728840569, 'R2_B': 0.0, 'R2_A': -0.0002919458280365592, 'R1_C': 0.0, 'R1_B': -0.0006510439244997369}
# total inorganic Phosphate consumed: {'R2_C': -0.10379167696766105, 'R1_A': -0.006199545173508544, 'R2_B': -0.08697230009499916, 'R2_A': -0.005980229045029967, 'R1_C': -0.01908141252603887, 'R1_B': -0.010501867524882549}
# {'eq': 'y = -0.00x + 0.00', 'R2': '$R^2$ = 0.42572329'}
#
# Substrate addition: Salt_Pond_MetaG_R2_C_D1_MG_DASTool_bins_metabat.17.contigs
# [0.         0.00051612 0.         0.00029195 0.         0.00065104]
# total MePn consumed: {'R2_C': 6.0649775917401e-15, 'R1_A': -0.000516120728840569, 'R2_B': 0.0, 'R2_A': -0.0002919458280365592, 'R1_C': 0.0, 'R1_B': -0.0006510439244997369}
# total inorganic Phosphate consumed: {'R2_C': -0.11750206028743598, 'R1_A': -0.007357548071379402, 'R2_B': -0.10769182484859119, 'R2_A': -0.007141895863779237, 'R1_C': -0.022610845204294773, 'R1_B': -0.012585331754054189}
# {'eq': 'y = -0.00x + 0.00', 'R2': '$R^2$ = 0.42572329'}
#
# Substrate addition: Salt_Pond_MetaG_R2_C_D2_MG_DASTool_bins_concoct_out.18.contigs
# [0.         0.00051612 0.         0.00029195 0.         0.00065104]
# total MePn consumed: {'R2_C': 6.017828879397669e-15, 'R1_A': -0.000516120728840569, 'R2_B': 0.0, 'R2_A': -0.0002919458280365592, 'R1_C': 0.0, 'R1_B': -0.0006510439244997369}
# total inorganic Phosphate consumed: {'R2_C': -0.13822801719109176, 'R1_A': -0.007371526860304464, 'R2_B': -0.10836899367456225, 'R2_A': -0.0072499555743919175, 'R1_C': -0.022660762467787157, 'R1_B': -0.012614669483909473}
# {'eq': 'y = -0.00x + 0.00', 'R2': '$R^2$ = 0.42572329'}
# /Users/andrewfreiburger/Documents/venv_microbiome_stable/lib/python3.11/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)
# Feasibility Error: Salt_Pond_MetaG_R2_C_D2_MG_DASTool_bins_concoct_out.45.contigs in R2_C
# Feasibility Error: Salt_Pond_MetaG_R2_C_D2_MG_DASTool_bins_concoct_out.45.contigs in R2_B
# Feasibility Error: Salt_Pond_MetaG_R2_C_D2_MG_DASTool_bins_concoct_out.45.contigs in R1_C
# Feasibility Error: Salt_Pond_MetaG_R2_C_D2_MG_DASTool_bins_concoct_out.45.contigs in R1_B
#
# Substrate addition: Salt_Pond_MetaG_R2_C_D2_MG_DASTool_bins_concoct_out.45.contigs
# [0.         0.00120488 0.         0.00104683 0.         0.00065104]
# total MePn consumed: {'R2_C': 6.017828879397669e-15, 'R1_A': -0.0012048801815508691, 'R2_B': 0.0, 'R2_A': -0.0010468300746156536, 'R1_C': 0.0, 'R1_B': -0.0006510439244997369}
# total inorganic Phosphate consumed: {'R2_C': -0.13822801719109176, 'R1_A': -0.007504737825156458, 'R2_B': -0.10836899367456225, 'R2_A': -0.007395955543631649, 'R1_C': -0.022660762467787157, 'R1_B': -0.012614669483909473}
# {'eq': 'y = -0.00x + 0.00', 'R2': '$R^2$ = 0.43799016'}
#
# Substrate addition: Salt_Pond_MetaG_R2_C_D2_MG_DASTool_bins_concoct_out.47.contigs
# [0.         0.00120488 0.         0.00104683 0.         0.00065104]
# total MePn consumed: {'R2_C': 6.000926754319452e-15, 'R1_A': -0.0012048801815508691, 'R2_B': 0.0, 'R2_A': -0.0010468300746156536, 'R1_C': 0.0, 'R1_B': -0.0006510439244997369}
# total inorganic Phosphate consumed: {'R2_C': -0.1536703763480207, 'R1_A': -0.007534346652322825, 'R2_B': -0.11048727471839108, 'R2_A': -0.007759340978992926, 'R1_C': -0.022863808250131984, 'R1_B': -0.012812024664229588}
# {'eq': 'y = -0.00x + 0.00', 'R2': '$R^2$ = 0.43799016'}
# Feasibility Error: Salt_Pond_MetaG_R2_restored_C_black_MG_DASTool_bins_metabat.8.contigs in R2_C
# Feasibility Error: Salt_Pond_MetaG_R2_restored_C_black_MG_DASTool_bins_metabat.8.contigs in R2_B
#
# Substrate addition: Salt_Pond_MetaG_R2_restored_C_black_MG_DASTool_bins_metabat.8.contigs
# [0.         0.00130128 0.         0.00115095 0.00097943 0.00080853]
# total MePn consumed: {'R2_C': 6.000926754319452e-15, 'R1_A': -0.0013012792832524424, 'R2_B': 0.0, 'R2_A': -0.0011509524188044857, 'R1_C': -0.000979433118816566, 'R1_B': -0.0008085269309628087}
# total inorganic Phosphate consumed: {'R2_C': -0.1536703763480207, 'R1_A': -0.007573491843200581, 'R2_B': -0.11048727471839108, 'R2_A': -0.007801622379682168, 'R1_C': -0.023261530799193162, 'R1_B': -0.012875974454736948}
# {'eq': 'y = -0.00x + 0.00', 'R2': '$R^2$ = 0.91854238'}
# methane producing members Index(['Salt_Pond_MetaG_R2_B_D2_MG_DASTool_bins_metabat.55.contigs',
#        'Salt_Pond_MetaG_R2_C_D2_MG_DASTool_bins_concoct_out.45.contigs',
#        'Salt_Pond_MetaG_R2_restored_C_black_MG_DASTool_bins_metabat.8.contigs'],
#       dtype='object')
# MePn consumers {'R1_A': {'Salt_Pond_MetaG_R2_C_D2_MG_DASTool_bins_concoct_out.45.contigs', 'Salt_Pond_MetaG_R2_restored_C_black_MG_DASTool_bins_metabat.8.contigs', 'Salt_Pond_MetaG_R2_B_D2_MG_DASTool_bins_metabat.55.contigs'}, 'R2_A': {'Salt_Pond_MetaG_R2_C_D2_MG_DASTool_bins_concoct_out.45.contigs', 'Salt_Pond_MetaG_R2_restored_C_black_MG_DASTool_bins_metabat.8.contigs', 'Salt_Pond_MetaG_R2_B_D2_MG_DASTool_bins_metabat.55.contigs'}, 'R1_B': {'Salt_Pond_MetaG_R2_restored_C_black_MG_DASTool_bins_metabat.8.contigs', 'Salt_Pond_MetaG_R2_B_D2_MG_DASTool_bins_metabat.55.contigs'}, 'R1_C': {'Salt_Pond_MetaG_R2_restored_C_black_MG_DASTool_bins_metabat.8.contigs'}}
# Total methane emissions from addition (umol/hr): {'R2_C': 0.0, 'R1_A': 5.259401832875888, 'R2_B': 0.0, 'R2_A': 4.12045005214547, 'R1_C': 0.9794331188165663, 'R1_B': 4.063746553461494}
# Total MePn consumption from addition (umol/hr): {'R2_C': 3.671648354228253e-11, 'R1_A': -5.259401832875888, 'R2_B': 0.0, 'R2_A': -4.12045005214547, 'R1_C': -0.979433118816566, 'R1_B': -4.063746553461494}
# /Users/andrewfreiburger/Documents/venv_microbiome_stable/lib/python3.11/site-packages/cobra/util/solver.py:554: UserWarning: Solver status is 'infeasible'.
#   warn(f"Solver status is '{status}'.", UserWarning)

# %%
display(MePn_consumers)
mepn_consumers_all_samples = set([v for x in MePn_consumers.values() for v in x])

from pandas import read_csv
phylogeny = read_csv("../data/Saltern_phylogeny.csv")
phylogeny = dict(zip(phylogeny["User Genome"], phylogeny["Classification"]))
# display(phylogeny)
mepn_consumers_phylogeny = {mem: phylogeny[mem + "__"] for mem in mepn_consumers_all_samples}
mepn_consumers_phylogeny
# Out:
# {'R1_A': {'Salt_Pond_MetaG_R2_B_D2_MG_DASTool_bins_metabat.55.contigs',
#   'Salt_Pond_MetaG_R2_C_D2_MG_DASTool_bins_concoct_out.45.contigs',
#   'Salt_Pond_MetaG_R2_restored_C_black_MG_DASTool_bins_metabat.8.contigs'},
#  'R2_A': {'Salt_Pond_MetaG_R2_B_D2_MG_DASTool_bins_metabat.55.contigs',
#   'Salt_Pond_MetaG_R2_C_D2_MG_DASTool_bins_concoct_out.45.contigs',
#   'Salt_Pond_MetaG_R2_restored_C_black_MG_DASTool_bins_metabat.8.contigs'},
#  'R1_B': {'Salt_Pond_MetaG_R2_B_D2_MG_DASTool_bins_metabat.55.contigs',
#   'Salt_Pond_MetaG_R2_restored_C_black_MG_DASTool_bins_metabat.8.contigs'},
#  'R1_C': {'Salt_Pond_MetaG_R2_restored_C_black_MG_DASTool_bins_metabat.8.contigs'}}
# {'Salt_Pond_MetaG_R2_C_D2_MG_DASTool_bins_concoct_out.45.contigs': 'd__Bacteria;p__Proteobacteria;c__Alphaproteobacteria;o__Rhodobacterales;f__Rhodobacteraceae;g__Roseovarius;s__',
#  'Salt_Pond_MetaG_R2_restored_C_black_MG_DASTool_bins_metabat.8.contigs': 'd__Bacteria;p__Proteobacteria;c__Alphaproteobacteria;o__Rhodobacterales;f__Rhodobacteraceae;g__Albimonas;s__',
#  'Salt_Pond_MetaG_R2_B_D2_MG_DASTool_bins_metabat.55.contigs': 'd__Bacteria;p__Proteobacteria;c__Alphaproteobacteria;o__Rhodobacterales;f__Rhodobacteraceae;g__Roseovarius;s__'}

# %% [markdown]
# Salt_Pond_MetaG_R2_B_D2_MG_DASTool_bins_metabat.55.contigs = Roseovarius
# Salt_Pond_MetaG_R2_C_D2_MG_DASTool_bins_concoct_out.45.contigs = Roseovarius
# Salt_Pond_MetaG_R2_restored_C_black_MG_DASTool_bins_metabat.8.contigs = Albimonas

# %% [markdown]
# ## simulate the betaine-consuming organisms

# %%
from cobra.core import Reaction
def _add_atpm(model):
    if 'ATPM_c0' not in model.reactions:
        atpm = Reaction(f'ATPM_c0', f'ATPM', 'ATPM', 0, 1000)
        atpm.add_metabolites({
            model.metabolites.cpd00001_c0: -1,
            model.metabolites.cpd00002_c0: -1,
            model.metabolites.cpd00008_c0: 1,
            model.metabolites.cpd00009_c0: 1,
            model.metabolites.cpd00067_c0: 1,
        })
        model.add_reactions([atpm])
    return model

models = {}
for mdl_name in tqdm(betaine):
    mdl_path = f"models/{mdl_name}__.RAST_gapfilled_betaine.json"
    if os.path.exists(mdl_path):
        print(mdl_name)
        models[mdl_name] = _add_atpm(cobra.io.load_json_model(mdl_path))
    else:
        print(f'skip {i}')
# Out:
#   0%|          | 0/15 [00:00<?, ?it/s]
# Salt_Pond_MetaG_R1_C_D2_MG_DASTool_bins_metabat.40.contigs
#   7%|▋         | 1/15 [00:00<00:12,  1.16it/s]
# Salt_Pond_MetaG_R1_B_D2_MG_DASTool_bins_concoct_out.73.contigs
#  13%|█▎        | 2/15 [00:01<00:07,  1.64it/s]
# Salt_Pond_MetaG_R1_C_D2_MG_DASTool_bins_concoct_out.85.contigs
#  20%|██        | 3/15 [00:01<00:05,  2.16it/s]
# Salt_Pond_MetaG_R1_A_D1_MG_DASTool_bins.metabat.47.contigs
#  27%|██▋       | 4/15 [00:02<00:05,  2.08it/s]
# Salt_Pond_MetaG_R1_A_D2_MG_DASTool_bins_metabat.48.contigs
#  33%|███▎      | 5/15 [00:02<00:04,  2.41it/s]
# Salt_Pond_MetaG_R1_C_D1_MG_DASTool_bins_maxbin.047.contigs
#  40%|████      | 6/15 [00:02<00:03,  2.79it/s]
# Salt_Pond_MetaG_R2_B_D2_MG_DASTool_bins_metabat.52.contigs
#  47%|████▋     | 7/15 [00:03<00:02,  2.76it/s]
# Salt_Pond_MetaG_R1_A_D1_MG_DASTool_bins.metabat.51.contigs
#  53%|█████▎    | 8/15 [00:03<00:02,  3.04it/s]
# Salt_Pond_MetaG_R1_A_D1_MG_DASTool_bins.concoct_out.9.contigs
#  60%|██████    | 9/15 [00:03<00:01,  3.22it/s]
# Salt_Pond_MetaG_R2_A_D1_MG_DASTool_bins_concoct_out.98.contigs
#  67%|██████▋   | 10/15 [00:03<00:01,  2.89it/s]
# Salt_Pond_MetaG_R1_B_D1_MG_DASTool_bins_metabat.58.contigs
#  73%|███████▎  | 11/15 [00:04<00:01,  2.93it/s]
# Salt_Pond_MetaG_R1_A_D2_MG_DASTool_bins_metabat.27.contigs
#  80%|████████  | 12/15 [00:04<00:01,  2.94it/s]
# Salt_Pond_MetaG_R1_A_D2_MG_DASTool_bins_metabat.50.contigs
#  87%|████████▋ | 13/15 [00:05<00:00,  2.81it/s]
# Salt_Pond_MetaG_R1_A_D2_MG_DASTool_bins_metabat.45.contigs
#  93%|█████████▎| 14/15 [00:05<00:00,  2.99it/s]
# Salt_Pond_MetaG_R1_B_D1_MG_DASTool_bins_concoct_out.59.contigs
# 100%|██████████| 15/15 [00:05<00:00,  2.66it/s]

# %%
list(models.values())[0].optimize()
# Out:
# <Solution 1.044 at 0x14f77d550>

# %%
from cobra.io import load_json_model                                                                                                                        
from glob import glob                                                                                                                                       
  
# Key betaine utilization reactions from the literature summary                                                                                             
betaine_reactions = {                                     
    'rxn17220_c0': 'Betaine reductase (BET + Red-Thioredoxin + Pi → TMA + AcP + Ox-Thioredoxin)',                                                           
    'rxn07207_c0': 'Glycine reductase (Glycine + Red-Thioredoxin + Pi → AcP + NH3 + Ox-Thioredoxin)',                                                       
    'rxn27318_c0': 'Thioredoxin reductase (NADPH + Ox-Thioredoxin → NADP + Red-Thioredoxin)',                                                               
}                                                                                                                                                           
                                                                                                                                                            
# Key metabolites                                                                                                                                           
betaine_metabolites = {                                   
    'cpd00540_c0': 'Glycine betaine (cytoplasmic)',
    'cpd00540_e0': 'Glycine betaine (extracellular)',                                                                                                       
    'cpd00441_c0': 'Trimethylamine (TMA)',
}                                                                                                                                                           
                                                        
# Betaine transport/exchange                                                                                                                                
betaine_transport = {                                     
    'EX_cpd00540_e0': 'Betaine exchange',
}                                                                                                                                                           

gapfilled_models = sorted(glob('models/*_gapfilled_betaine.json'))                                                                                                  
print(f"{len(gapfilled_models)} gapfilled betaine models\n")
                                                                                                                                                            
# for model_path in gapfilled_models:                       
#     model = load_json_model(model_path)                                                                                                                     
    # short_name = model_path.split('bins')[1].split('.contigs')[0]
for short_name, model in models.items():
    print(f"=== {short_name} ({len(model.reactions)} rxns) ===")                                                                                            
                                                                                                                                                            
    # Check reactions                                                                                                                                       
    for rxn_id, desc in {**betaine_reactions, **betaine_transport}.items():                                                                                 
        present = rxn_id in model.reactions                                                                                                                 
        if present:
            rxn = model.reactions.get_by_id(rxn_id)                                                                                                         
            print(f"  [YES] {rxn_id}: {desc}  bounds=({rxn.lower_bound}, {rxn.upper_bound})")                                                               
        else:                                                                                                                                               
            print(f"  [ NO] {rxn_id}: {desc}")                                                                                                              
                                                                                                                                                            
    # Check metabolites                                                                                                                                     
    for met_id, desc in betaine_metabolites.items():
        present = met_id in model.metabolites                                                                                                               
        print(f"  {'[YES]' if present else '[ NO]'} {met_id}: {desc}")
                                                                                                                                                            
    # Test betaine flux if rxn17220 exists                                                                                                                  
    if 'rxn17220_c0' in model.reactions:                                                                                                                    
        with model:                                                                                                                                         
            model.objective = 'rxn17220_c0'   
            model.medium = {**model.medium, 'EX_cpd00540_e0': 100}            
            sol = model.optimize()                                                                                                                          
            print(f"  >> Betaine reductase max flux: {sol.objective_value:.4f} ({sol.status})")
                                                                                                                                                            
    print()
# Out:
# 15 gapfilled betaine models
#
# === .concoct_out.9 (995 rxns) ===
#   [YES] rxn17220_c0: Betaine reductase (BET + Red-Thioredoxin + Pi → TMA + AcP + Ox-Thioredoxin)  bounds=(0.0, 1000.0)
#   [YES] rxn07207_c0: Glycine reductase (Glycine + Red-Thioredoxin + Pi → AcP + NH3 + Ox-Thioredoxin)  bounds=(0.0, 1000.0)
#   [YES] rxn27318_c0: Thioredoxin reductase (NADPH + Ox-Thioredoxin → NADP + Red-Thioredoxin)  bounds=(-1000.0, 1000.0)
#   [YES] EX_cpd00540_e0: Betaine exchange  bounds=(-0.0, 100.0)
#   [YES] cpd00540_c0: Glycine betaine (cytoplasmic)
#   [YES] cpd00540_e0: Glycine betaine (extracellular)
#   [YES] cpd00441_c0: Trimethylamine (TMA)
#   >> Betaine reductase max flux: 100.0000 (optimal)
#
# === .metabat.47 (994 rxns) ===
#   [YES] rxn17220_c0: Betaine reductase (BET + Red-Thioredoxin + Pi → TMA + AcP + Ox-Thioredoxin)  bounds=(0.0, 1000.0)
#   [YES] rxn07207_c0: Glycine reductase (Glycine + Red-Thioredoxin + Pi → AcP + NH3 + Ox-Thioredoxin)  bounds=(0.0, 1000.0)
#   [YES] rxn27318_c0: Thioredoxin reductase (NADPH + Ox-Thioredoxin → NADP + Red-Thioredoxin)  bounds=(-1000.0, 1000.0)
#   [YES] EX_cpd00540_e0: Betaine exchange  bounds=(-0.0, 100.0)
#   [YES] cpd00540_c0: Glycine betaine (cytoplasmic)
#   [YES] cpd00540_e0: Glycine betaine (extracellular)
#   [YES] cpd00441_c0: Trimethylamine (TMA)
#   >> Betaine reductase max flux: 50.0000 (optimal)
#
# === .metabat.51 (936 rxns) ===
#   [YES] rxn17220_c0: Betaine reductase (BET + Red-Thioredoxin + Pi → TMA + AcP + Ox-Thioredoxin)  bounds=(0.0, 1000.0)
#   [YES] rxn07207_c0: Glycine reductase (Glycine + Red-Thioredoxin + Pi → AcP + NH3 + Ox-Thioredoxin)  bounds=(0.0, 1000.0)
#   [YES] rxn27318_c0: Thioredoxin reductase (NADPH + Ox-Thioredoxin → NADP + Red-Thioredoxin)  bounds=(-1000.0, 1000.0)
#   [YES] EX_cpd00540_e0: Betaine exchange  bounds=(-0.0, 100.0)
#   [YES] cpd00540_c0: Glycine betaine (cytoplasmic)
#   [YES] cpd00540_e0: Glycine betaine (extracellular)
#   [YES] cpd00441_c0: Trimethylamine (TMA)
#   >> Betaine reductase max flux: 100.0000 (optimal)
#
# === _metabat.27 (1107 rxns) ===
#   [YES] rxn17220_c0: Betaine reductase (BET + Red-Thioredoxin + Pi → TMA + AcP + Ox-Thioredoxin)  bounds=(0.0, 1000.0)
#   [YES] rxn07207_c0: Glycine reductase (Glycine + Red-Thioredoxin + Pi → AcP + NH3 + Ox-Thioredoxin)  bounds=(0.0, 1000.0)
#   [YES] rxn27318_c0: Thioredoxin reductase (NADPH + Ox-Thioredoxin → NADP + Red-Thioredoxin)  bounds=(-1000.0, 1000.0)
#   [YES] EX_cpd00540_e0: Betaine exchange  bounds=(-0.0, 100.0)
#   [YES] cpd00540_c0: Glycine betaine (cytoplasmic)
#   [YES] cpd00540_e0: Glycine betaine (extracellular)
#   [YES] cpd00441_c0: Trimethylamine (TMA)
#   >> Betaine reductase max flux: 100.0000 (optimal)
#
# === _metabat.45 (1021 rxns) ===
#   [YES] rxn17220_c0: Betaine reductase (BET + Red-Thioredoxin + Pi → TMA + AcP + Ox-Thioredoxin)  bounds=(0.0, 1000.0)
#   [YES] rxn07207_c0: Glycine reductase (Glycine + Red-Thioredoxin + Pi → AcP + NH3 + Ox-Thioredoxin)  bounds=(0.0, 1000.0)
#   [YES] rxn27318_c0: Thioredoxin reductase (NADPH + Ox-Thioredoxin → NADP + Red-Thioredoxin)  bounds=(-1000.0, 1000.0)
#   [YES] EX_cpd00540_e0: Betaine exchange  bounds=(-0.0, 100.0)
#   [YES] cpd00540_c0: Glycine betaine (cytoplasmic)
#   [YES] cpd00540_e0: Glycine betaine (extracellular)
#   [YES] cpd00441_c0: Trimethylamine (TMA)
#   >> Betaine reductase max flux: 100.0000 (optimal)
#
# === _metabat.48 (927 rxns) ===
#   [YES] rxn17220_c0: Betaine reductase (BET + Red-Thioredoxin + Pi → TMA + AcP + Ox-Thioredoxin)  bounds=(0.0, 1000.0)
#   [YES] rxn07207_c0: Glycine reductase (Glycine + Red-Thioredoxin + Pi → AcP + NH3 + Ox-Thioredoxin)  bounds=(0.0, 1000.0)
#   [YES] rxn27318_c0: Thioredoxin reductase (NADPH + Ox-Thioredoxin → NADP + Red-Thioredoxin)  bounds=(-1000.0, 1000.0)
#   [YES] EX_cpd00540_e0: Betaine exchange  bounds=(-0.0, 100.0)
#   [YES] cpd00540_c0: Glycine betaine (cytoplasmic)
#   [YES] cpd00540_e0: Glycine betaine (extracellular)
#   [YES] cpd00441_c0: Trimethylamine (TMA)
#   >> Betaine reductase max flux: 100.0000 (optimal)
#
# === _metabat.50 (929 rxns) ===
#   [YES] rxn17220_c0: Betaine reductase (BET + Red-Thioredoxin + Pi → TMA + AcP + Ox-Thioredoxin)  bounds=(0.0, 1000.0)
#   [YES] rxn07207_c0: Glycine reductase (Glycine + Red-Thioredoxin + Pi → AcP + NH3 + Ox-Thioredoxin)  bounds=(0.0, 1000.0)
#   [YES] rxn27318_c0: Thioredoxin reductase (NADPH + Ox-Thioredoxin → NADP + Red-Thioredoxin)  bounds=(-1000.0, 1000.0)
#   [YES] EX_cpd00540_e0: Betaine exchange  bounds=(-0.0, 100.0)
#   [YES] cpd00540_c0: Glycine betaine (cytoplasmic)
#   [YES] cpd00540_e0: Glycine betaine (extracellular)
#   [YES] cpd00441_c0: Trimethylamine (TMA)
#   >> Betaine reductase max flux: 100.0000 (optimal)
#
# === _concoct_out.59 (1135 rxns) ===
#   [YES] rxn17220_c0: Betaine reductase (BET + Red-Thioredoxin + Pi → TMA + AcP + Ox-Thioredoxin)  bounds=(0.0, 1000.0)
#   [YES] rxn07207_c0: Glycine reductase (Glycine + Red-Thioredoxin + Pi → AcP + NH3 + Ox-Thioredoxin)  bounds=(0.0, 1000.0)
#   [YES] rxn27318_c0: Thioredoxin reductase (NADPH + Ox-Thioredoxin → NADP + Red-Thioredoxin)  bounds=(-1000.0, 1000.0)
#   [YES] EX_cpd00540_e0: Betaine exchange  bounds=(-0.0, 100.0)
#   [YES] cpd00540_c0: Glycine betaine (cytoplasmic)
#   [YES] cpd00540_e0: Glycine betaine (extracellular)
#   [YES] cpd00441_c0: Trimethylamine (TMA)
#   >> Betaine reductase max flux: 100.0000 (optimal)
#
# === _metabat.58 (937 rxns) ===
#   [YES] rxn17220_c0: Betaine reductase (BET + Red-Thioredoxin + Pi → TMA + AcP + Ox-Thioredoxin)  bounds=(0.0, 1000.0)
#   [YES] rxn07207_c0: Glycine reductase (Glycine + Red-Thioredoxin + Pi → AcP + NH3 + Ox-Thioredoxin)  bounds=(0.0, 1000.0)
#   [YES] rxn27318_c0: Thioredoxin reductase (NADPH + Ox-Thioredoxin → NADP + Red-Thioredoxin)  bounds=(-1000.0, 1000.0)
#   [YES] EX_cpd00540_e0: Betaine exchange  bounds=(-0.0, 100.0)
#   [YES] cpd00540_c0: Glycine betaine (cytoplasmic)
#   [YES] cpd00540_e0: Glycine betaine (extracellular)
#   [YES] cpd00441_c0: Trimethylamine (TMA)
#   >> Betaine reductase max flux: 100.0000 (optimal)
#
# === _concoct_out.73 (1030 rxns) ===
#   [YES] rxn17220_c0: Betaine reductase (BET + Red-Thioredoxin + Pi → TMA + AcP + Ox-Thioredoxin)  bounds=(0.0, 1000.0)
#   [YES] rxn07207_c0: Glycine reductase (Glycine + Red-Thioredoxin + Pi → AcP + NH3 + Ox-Thioredoxin)  bounds=(0.0, 1000.0)
#   [YES] rxn27318_c0: Thioredoxin reductase (NADPH + Ox-Thioredoxin → NADP + Red-Thioredoxin)  bounds=(-1000.0, 1000.0)
#   [YES] EX_cpd00540_e0: Betaine exchange  bounds=(-0.0, 100.0)
#   [YES] cpd00540_c0: Glycine betaine (cytoplasmic)
#   [YES] cpd00540_e0: Glycine betaine (extracellular)
#   [YES] cpd00441_c0: Trimethylamine (TMA)
#   >> Betaine reductase max flux: 100.0000 (optimal)
#
# === _maxbin.047 (842 rxns) ===
#   [YES] rxn17220_c0: Betaine reductase (BET + Red-Thioredoxin + Pi → TMA + AcP + Ox-Thioredoxin)  bounds=(0.0, 1000.0)
#   [YES] rxn07207_c0: Glycine reductase (Glycine + Red-Thioredoxin + Pi → AcP + NH3 + Ox-Thioredoxin)  bounds=(0.0, 1000.0)
#   [YES] rxn27318_c0: Thioredoxin reductase (NADPH + Ox-Thioredoxin → NADP + Red-Thioredoxin)  bounds=(-1000.0, 1000.0)
#   [YES] EX_cpd00540_e0: Betaine exchange  bounds=(-0.0, 100.0)
#   [YES] cpd00540_c0: Glycine betaine (cytoplasmic)
#   [YES] cpd00540_e0: Glycine betaine (extracellular)
#   [YES] cpd00441_c0: Trimethylamine (TMA)
#   >> Betaine reductase max flux: 100.0000 (optimal)
#
# === _concoct_out.85 (1036 rxns) ===
#   [YES] rxn17220_c0: Betaine reductase (BET + Red-Thioredoxin + Pi → TMA + AcP + Ox-Thioredoxin)  bounds=(0.0, 1000.0)
#   [YES] rxn07207_c0: Glycine reductase (Glycine + Red-Thioredoxin + Pi → AcP + NH3 + Ox-Thioredoxin)  bounds=(0.0, 1000.0)
#   [YES] rxn27318_c0: Thioredoxin reductase (NADPH + Ox-Thioredoxin → NADP + Red-Thioredoxin)  bounds=(-1000.0, 1000.0)
#   [YES] EX_cpd00540_e0: Betaine exchange  bounds=(-0.0, 100.0)
#   [YES] cpd00540_c0: Glycine betaine (cytoplasmic)
#   [YES] cpd00540_e0: Glycine betaine (extracellular)
#   [YES] cpd00441_c0: Trimethylamine (TMA)
#   >> Betaine reductase max flux: 100.0000 (optimal)
#
# === _metabat.40 (946 rxns) ===
#   [YES] rxn17220_c0: Betaine reductase (BET + Red-Thioredoxin + Pi → TMA + AcP + Ox-Thioredoxin)  bounds=(0.0, 1000.0)
#   [YES] rxn07207_c0: Glycine reductase (Glycine + Red-Thioredoxin + Pi → AcP + NH3 + Ox-Thioredoxin)  bounds=(0.0, 1000.0)
#   [YES] rxn27318_c0: Thioredoxin reductase (NADPH + Ox-Thioredoxin → NADP + Red-Thioredoxin)  bounds=(-1000.0, 1000.0)
#   [YES] EX_cpd00540_e0: Betaine exchange  bounds=(-0.0, 100.0)
#   [YES] cpd00540_c0: Glycine betaine (cytoplasmic)
#   [YES] cpd00540_e0: Glycine betaine (extracellular)
#   [YES] cpd00441_c0: Trimethylamine (TMA)
#   >> Betaine reductase max flux: 100.0000 (optimal)
#
# === _concoct_out.98 (958 rxns) ===
#   [YES] rxn17220_c0: Betaine reductase (BET + Red-Thioredoxin + Pi → TMA + AcP + Ox-Thioredoxin)  bounds=(0.0, 1000.0)
#   [YES] rxn07207_c0: Glycine reductase (Glycine + Red-Thioredoxin + Pi → AcP + NH3 + Ox-Thioredoxin)  bounds=(0.0, 1000.0)
#   [YES] rxn27318_c0: Thioredoxin reductase (NADPH + Ox-Thioredoxin → NADP + Red-Thioredoxin)  bounds=(-1000.0, 1000.0)
#   [YES] EX_cpd00540_e0: Betaine exchange  bounds=(-0.0, 100.0)
#   [YES] cpd00540_c0: Glycine betaine (cytoplasmic)
#   [YES] cpd00540_e0: Glycine betaine (extracellular)
#   [YES] cpd00441_c0: Trimethylamine (TMA)
#   >> Betaine reductase max flux: 100.0000 (optimal)
#
# === _metabat.52 (945 rxns) ===
#   [YES] rxn17220_c0: Betaine reductase (BET + Red-Thioredoxin + Pi → TMA + AcP + Ox-Thioredoxin)  bounds=(0.0, 1000.0)
#   [YES] rxn07207_c0: Glycine reductase (Glycine + Red-Thioredoxin + Pi → AcP + NH3 + Ox-Thioredoxin)  bounds=(0.0, 1000.0)
#   [YES] rxn27318_c0: Thioredoxin reductase (NADPH + Ox-Thioredoxin → NADP + Red-Thioredoxin)  bounds=(-1000.0, 1000.0)
#   [YES] EX_cpd00540_e0: Betaine exchange  bounds=(-0.0, 100.0)
#   [YES] cpd00540_c0: Glycine betaine (cytoplasmic)
#   [YES] cpd00540_e0: Glycine betaine (extracellular)
#   [YES] cpd00441_c0: Trimethylamine (TMA)
#   >> Betaine reductase max flux: 100.0000 (optimal)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

from optlang.symbolics import Zero
import numpy as np

sols = {}
with open("sols_log_betaine.txt", 'w') as f:
    fluxes = {"betaine": {}, "TMA": {}, "methane": {}, "lactate": {}, "phosphate": {}}
    for orgID, row in averaged_unrestored_normalized_abundances.iterrows():
        # print(orgID)
        ID = orgID+".contigs"
        if ID not in models:  continue # or ID in dontGrow:  continue
        model = models[ID].copy()
        print(orgID, model.slim_optimize(), end=" ")
        media.pop("EX_cpd25960_e0", None)
        model.medium = {k: v for k, v in {**media, "EX_cpd00540_e0": 0.1}.items() if k in model.reactions}
        print(model.medium)
        # print(model.medium)
        bio = model.reactions.get_by_id("bio1")
        model.solver.configuration.timeout = 15
        sols[ID] = {}
        for k, dic in fluxes.items():
            fluxes[k][ID] = {}
        # print(model.slim_optimize())
        f.write(f"\n\n{orgID}")
        for sample, abundance in row.items():
            # fix the biomass
            bio.bounds = (abundance, abundance)
            # define lactate as a the objective
            EX = model.reactions.get_by_id("EX_cpd00159_e0")
            EX.bounds = (-1000, 0)
            model.objective = EX
            f.write(f"\noptimizing {sample} at {abundance}")
            sols[ID][sample] = model.optimize()
            if sols[ID][sample].status == "infeasible":
                f.write(f"Feasibility Error: {ID} {sample}")
            
            # fluxes["methane"][ID][sample] = sols[ID][sample].fluxes.EX_cpd01024_e0
            fluxes["TMA"][ID][sample] = sols[ID][sample].fluxes.EX_cpd00441_e0
            fluxes["betaine"][ID][sample] = sols[ID][sample].fluxes.EX_cpd00540_e0
            fluxes["lactate"][ID][sample] = sols[ID][sample].fluxes.EX_cpd00159_e0
            fluxes["phosphate"][ID][sample] = sols[ID][sample].fluxes.EX_cpd00009_e0
            # fluxes[multiple]["phosphate"][ID][sample] = model.reactions.EX_cpd00009_e0.reverse_variable.primal
            # fluxes[multiple]["MePn"][ID][sample] = model.reactions.EX_cpd25960_e0.reverse_variable.primal
            
            bio.bounds = (0, 0)
            bio_flux = sols[ID][sample].fluxes.bio1
            if bio_flux != abundance:
                f.write(f"\nAbundance Error: {bio_flux} != {abundance}")
            f.write(f"\noptimized at {sols[ID][sample].fluxes.EX_cpd00159_e0}")

    # determine the linear regression of fitting the experimental data with the simulation fluxes
    mdl = LinearRegression()
    xs = np.array(list(methane_dic.values())).reshape(-1, 1)
    print(fluxes)
    betaine_df = DataFrame(fluxes["betaine"])
    TMA_df = DataFrame(fluxes["TMA"])
    ys = np.array(fluxes_to_emissions(betaine_df.T.sum()).to_list())
    mdl.fit(xs, ys)
    y_pred = mdl.predict(xs)
    fits = {"eq": f"y = {mdl.coef_[0]:.2f}x + {mdl.intercept_:.2f}",
                        "R2": f"$R^2$ = {r2_score(ys, y_pred):.8f}"}

    methane_df = DataFrame(fluxes["methane"])
    # display(mepn_df)
    print("total TMA flux:", TMA_df.sum(axis=1).to_dict())
    print("total betaine flux:", betaine_df.sum(axis=1).to_dict())
    print("total methane flux:", methane_df.sum(axis=1).to_dict())
    print(fits)
    # print(sum(list(.values()))
    # break
    # print(fluxes[multiple]["phosphate"]['Salt_Pond_MetaG_R1_B_H2O_MG_DASTool_bins_metabat.7.contigs'])
    # print(fluxes[multiple]["MePn"]['Salt_Pond_MetaG_R1_B_H2O_MG_DASTool_bins_metabat.7.contigs'])

json.dump(fits, open("fits_betaine.json", 'w'), indent=3)
json.dump(fluxes, open("saltern_fluxes_betaine.json", 'w'), indent=3)
# Out:
# Salt_Pond_MetaG_R1_A_D1_MG_DASTool_bins.concoct_out.9 1.0129209710842437 {'EX_cpd00971_e0': 1000.0, 'EX_cpd00058_e0': 1000.0, 'EX_cpd00244_e0': 1000.0, 'EX_cpd00067_e0': 1000.0, 'EX_cpd00205_e0': 1000.0, 'EX_cpd00009_e0': 100, 'EX_cpd00034_e0': 1000.0, 'EX_cpd11574_e0': 1000.0, 'EX_cpd00305_e0': 100.0, 'EX_cpd00159_e0': 100.0, 'EX_cpd00540_e0': 0.1, 'EX_cpd00254_e0': 1000.0, 'EX_cpd00030_e0': 1000.0, 'EX_cpd00001_e0': 1000.0, 'EX_cpd00149_e0': 1000.0, 'EX_cpd00013_e0': 1000.0, 'EX_cpd10516_e0': 1000.0, 'EX_cpd00007_e0': 1000.0, 'EX_cpd00048_e0': 1000.0, 'EX_cpd00063_e0': 1000.0, 'EX_cpd00099_e0': 1000.0}
# Salt_Pond_MetaG_R1_A_D1_MG_DASTool_bins.metabat.47 0.04290869123710751 {'EX_cpd00067_e0': 1000.0, 'EX_cpd00971_e0': 1000.0, 'EX_cpd00058_e0': 1000.0, 'EX_cpd00244_e0': 1000.0, 'EX_cpd00205_e0': 1000.0, 'EX_cpd00009_e0': 100, 'EX_cpd00034_e0': 1000.0, 'EX_cpd00159_e0': 100.0, 'EX_cpd00540_e0': 0.1, 'EX_cpd10516_e0': 1000.0, 'EX_cpd00001_e0': 1000.0, 'EX_cpd00013_e0': 1000.0, 'EX_cpd00007_e0': 1000.0, 'EX_cpd00305_e0': 100.0, 'EX_cpd00030_e0': 1000.0, 'EX_cpd00048_e0': 1000.0, 'EX_cpd00149_e0': 1000.0, 'EX_cpd00063_e0': 1000.0, 'EX_cpd00254_e0': 1000.0, 'EX_cpd00099_e0': 1000.0, 'EX_cpd11574_e0': 1000.0}
# Salt_Pond_MetaG_R1_A_D1_MG_DASTool_bins.metabat.51 1.3793735734617922 {'EX_cpd00067_e0': 1000.0, 'EX_cpd00971_e0': 1000.0, 'EX_cpd00058_e0': 1000.0, 'EX_cpd00013_e0': 1000.0, 'EX_cpd00205_e0': 1000.0, 'EX_cpd00009_e0': 100, 'EX_cpd00034_e0': 1000.0, 'EX_cpd00540_e0': 0.1, 'EX_cpd00254_e0': 1000.0, 'EX_cpd00305_e0': 100.0, 'EX_cpd00149_e0': 1000.0, 'EX_cpd00001_e0': 1000.0, 'EX_cpd10516_e0': 1000.0, 'EX_cpd00007_e0': 1000.0, 'EX_cpd00030_e0': 1000.0, 'EX_cpd00048_e0': 1000.0, 'EX_cpd00063_e0': 1000.0, 'EX_cpd00099_e0': 1000.0, 'EX_cpd00244_e0': 1000.0, 'EX_cpd11574_e0': 1000.0, 'EX_cpd00159_e0': 100.0}
# Salt_Pond_MetaG_R1_A_D2_MG_DASTool_bins_metabat.27 0.7488953271559535 {'EX_cpd00067_e0': 1000.0, 'EX_cpd00971_e0': 1000.0, 'EX_cpd00058_e0': 1000.0, 'EX_cpd00013_e0': 1000.0, 'EX_cpd00205_e0': 1000.0, 'EX_cpd00009_e0': 100, 'EX_cpd00034_e0': 1000.0, 'EX_cpd00540_e0': 0.1, 'EX_cpd00254_e0': 1000.0, 'EX_cpd00149_e0': 1000.0, 'EX_cpd00001_e0': 1000.0, 'EX_cpd10516_e0': 1000.0, 'EX_cpd00007_e0': 1000.0, 'EX_cpd00305_e0': 100.0, 'EX_cpd00030_e0': 1000.0, 'EX_cpd00159_e0': 100.0, 'EX_cpd00048_e0': 1000.0, 'EX_cpd00063_e0': 1000.0, 'EX_cpd00099_e0': 1000.0, 'EX_cpd00244_e0': 1000.0, 'EX_cpd11574_e0': 1000.0}
# Salt_Pond_MetaG_R1_A_D2_MG_DASTool_bins_metabat.45 1.327645103383939 {'EX_cpd00067_e0': 1000.0, 'EX_cpd00971_e0': 1000.0, 'EX_cpd00058_e0': 1000.0, 'EX_cpd00013_e0': 1000.0, 'EX_cpd00244_e0': 1000.0, 'EX_cpd00205_e0': 1000.0, 'EX_cpd00009_e0': 100, 'EX_cpd00034_e0': 1000.0, 'EX_cpd00540_e0': 0.1, 'EX_cpd00254_e0': 1000.0, 'EX_cpd00048_e0': 1000.0, 'EX_cpd00149_e0': 1000.0, 'EX_cpd00001_e0': 1000.0, 'EX_cpd10516_e0': 1000.0, 'EX_cpd00305_e0': 100.0, 'EX_cpd00030_e0': 1000.0, 'EX_cpd00063_e0': 1000.0, 'EX_cpd00099_e0': 1000.0, 'EX_cpd00007_e0': 1000.0, 'EX_cpd11574_e0': 1000.0, 'EX_cpd00159_e0': 100.0}
# Salt_Pond_MetaG_R1_A_D2_MG_DASTool_bins_metabat.48 1.025557186835506 {'EX_cpd00067_e0': 1000.0, 'EX_cpd00971_e0': 1000.0, 'EX_cpd00058_e0': 1000.0, 'EX_cpd00013_e0': 1000.0, 'EX_cpd00205_e0': 1000.0, 'EX_cpd00009_e0': 100, 'EX_cpd00034_e0': 1000.0, 'EX_cpd00540_e0': 0.1, 'EX_cpd00030_e0': 1000.0, 'EX_cpd00254_e0': 1000.0, 'EX_cpd00305_e0': 100.0, 'EX_cpd00149_e0': 1000.0, 'EX_cpd00001_e0': 1000.0, 'EX_cpd10516_e0': 1000.0, 'EX_cpd00007_e0': 1000.0, 'EX_cpd00048_e0': 1000.0, 'EX_cpd00063_e0': 1000.0, 'EX_cpd00099_e0': 1000.0, 'EX_cpd00244_e0': 1000.0, 'EX_cpd11574_e0': 1000.0, 'EX_cpd00159_e0': 100.0}
# Salt_Pond_MetaG_R1_A_D2_MG_DASTool_bins_metabat.50 1.3679779062238884 {'EX_cpd00067_e0': 1000.0, 'EX_cpd00971_e0': 1000.0, 'EX_cpd00058_e0': 1000.0, 'EX_cpd00013_e0': 1000.0, 'EX_cpd00205_e0': 1000.0, 'EX_cpd00009_e0': 100, 'EX_cpd00034_e0': 1000.0, 'EX_cpd00540_e0': 0.1, 'EX_cpd00030_e0': 1000.0, 'EX_cpd00254_e0': 1000.0, 'EX_cpd00305_e0': 100.0, 'EX_cpd00149_e0': 1000.0, 'EX_cpd00001_e0': 1000.0, 'EX_cpd10516_e0': 1000.0, 'EX_cpd00007_e0': 1000.0, 'EX_cpd00048_e0': 1000.0, 'EX_cpd00063_e0': 1000.0, 'EX_cpd00099_e0': 1000.0, 'EX_cpd00244_e0': 1000.0, 'EX_cpd11574_e0': 1000.0, 'EX_cpd00159_e0': 100.0}
# Salt_Pond_MetaG_R1_B_D1_MG_DASTool_bins_concoct_out.59 3.998934510809238 {'EX_cpd00067_e0': 1000.0, 'EX_cpd00971_e0': 1000.0, 'EX_cpd00058_e0': 1000.0, 'EX_cpd00013_e0': 1000.0, 'EX_cpd00244_e0': 1000.0, 'EX_cpd00205_e0': 1000.0, 'EX_cpd00009_e0': 100, 'EX_cpd00034_e0': 1000.0, 'EX_cpd00540_e0': 0.1, 'EX_cpd00254_e0': 1000.0, 'EX_cpd00048_e0': 1000.0, 'EX_cpd00149_e0': 1000.0, 'EX_cpd00001_e0': 1000.0, 'EX_cpd10516_e0': 1000.0, 'EX_cpd00007_e0': 1000.0, 'EX_cpd00305_e0': 100.0, 'EX_cpd00030_e0': 1000.0, 'EX_cpd00063_e0': 1000.0, 'EX_cpd00099_e0': 1000.0, 'EX_cpd11574_e0': 1000.0, 'EX_cpd00159_e0': 100.0}
# Salt_Pond_MetaG_R1_B_D1_MG_DASTool_bins_metabat.58 1.1245979493809535 {'EX_cpd00067_e0': 1000.0, 'EX_cpd00971_e0': 1000.0, 'EX_cpd00058_e0': 1000.0, 'EX_cpd00244_e0': 1000.0, 'EX_cpd00205_e0': 1000.0, 'EX_cpd00009_e0': 100, 'EX_cpd11574_e0': 1000.0, 'EX_cpd00540_e0': 0.1, 'EX_cpd00254_e0': 1000.0, 'EX_cpd00030_e0': 1000.0, 'EX_cpd00149_e0': 1000.0, 'EX_cpd00034_e0': 1000.0, 'EX_cpd00001_e0': 1000.0, 'EX_cpd00013_e0': 1000.0, 'EX_cpd10516_e0': 1000.0, 'EX_cpd00305_e0': 100.0, 'EX_cpd00048_e0': 1000.0, 'EX_cpd00063_e0': 1000.0, 'EX_cpd00099_e0': 1000.0, 'EX_cpd00007_e0': 1000.0, 'EX_cpd00159_e0': 100.0}
# Salt_Pond_MetaG_R1_B_D2_MG_DASTool_bins_concoct_out.73 0.8702442070841331 {'EX_cpd00067_e0': 1000.0, 'EX_cpd00971_e0': 1000.0, 'EX_cpd00058_e0': 1000.0, 'EX_cpd00013_e0': 1000.0, 'EX_cpd00244_e0': 1000.0, 'EX_cpd00205_e0': 1000.0, 'EX_cpd00009_e0': 100, 'EX_cpd00034_e0': 1000.0, 'EX_cpd00540_e0': 0.1, 'EX_cpd00254_e0': 1000.0, 'EX_cpd00149_e0': 1000.0, 'EX_cpd00001_e0': 1000.0, 'EX_cpd10516_e0': 1000.0, 'EX_cpd00305_e0': 100.0, 'EX_cpd00030_e0': 1000.0, 'EX_cpd00048_e0': 1000.0, 'EX_cpd00063_e0': 1000.0, 'EX_cpd00099_e0': 1000.0, 'EX_cpd00007_e0': 1000.0, 'EX_cpd11574_e0': 1000.0, 'EX_cpd00159_e0': 100.0}
# Salt_Pond_MetaG_R1_C_D1_MG_DASTool_bins_maxbin.047 1.367586420928375 {'EX_cpd00067_e0': 1000.0, 'EX_cpd00971_e0': 1000.0, 'EX_cpd00058_e0': 1000.0, 'EX_cpd00013_e0': 1000.0, 'EX_cpd00205_e0': 1000.0, 'EX_cpd00009_e0': 100, 'EX_cpd00540_e0': 0.1, 'EX_cpd00030_e0': 1000.0, 'EX_cpd00254_e0': 1000.0, 'EX_cpd00305_e0': 100.0, 'EX_cpd00149_e0': 1000.0, 'EX_cpd00034_e0': 1000.0, 'EX_cpd00001_e0': 1000.0, 'EX_cpd10516_e0': 1000.0, 'EX_cpd00048_e0': 1000.0, 'EX_cpd00063_e0': 1000.0, 'EX_cpd00099_e0': 1000.0, 'EX_cpd00007_e0': 1000.0, 'EX_cpd00244_e0': 1000.0, 'EX_cpd11574_e0': 1000.0, 'EX_cpd00159_e0': 100.0}
# Salt_Pond_MetaG_R1_C_D2_MG_DASTool_bins_concoct_out.85 1.1204706745855675 {'EX_cpd00067_e0': 1000.0, 'EX_cpd00971_e0': 1000.0, 'EX_cpd00058_e0': 1000.0, 'EX_cpd00013_e0': 1000.0, 'EX_cpd00244_e0': 1000.0, 'EX_cpd00009_e0': 100, 'EX_cpd00034_e0': 1000.0, 'EX_cpd11574_e0': 1000.0, 'EX_cpd00159_e0': 100.0, 'EX_cpd00205_e0': 1000.0, 'EX_cpd00540_e0': 0.1, 'EX_cpd00030_e0': 1000.0, 'EX_cpd00254_e0': 1000.0, 'EX_cpd00001_e0': 1000.0, 'EX_cpd00149_e0': 1000.0, 'EX_cpd10516_e0': 1000.0, 'EX_cpd00007_e0': 1000.0, 'EX_cpd00305_e0': 100.0, 'EX_cpd00048_e0': 1000.0, 'EX_cpd00063_e0': 1000.0, 'EX_cpd00099_e0': 1000.0}
# Salt_Pond_MetaG_R1_C_D2_MG_DASTool_bins_metabat.40 1.0437720267024821 {'EX_cpd00067_e0': 1000.0, 'EX_cpd00058_e0': 1000.0, 'EX_cpd00244_e0': 1000.0, 'EX_cpd00205_e0': 1000.0, 'EX_cpd00009_e0': 100, 'EX_cpd00034_e0': 1000.0, 'EX_cpd00159_e0': 100.0, 'EX_cpd00540_e0': 0.1, 'EX_cpd00971_e0': 1000.0, 'EX_cpd00254_e0': 1000.0, 'EX_cpd00149_e0': 1000.0, 'EX_cpd00001_e0': 1000.0, 'EX_cpd00013_e0': 1000.0, 'EX_cpd10516_e0': 1000.0, 'EX_cpd00007_e0': 1000.0, 'EX_cpd00305_e0': 100.0, 'EX_cpd00030_e0': 1000.0, 'EX_cpd00048_e0': 1000.0, 'EX_cpd00063_e0': 1000.0, 'EX_cpd00099_e0': 1000.0, 'EX_cpd11574_e0': 1000.0}
# Salt_Pond_MetaG_R2_A_D1_MG_DASTool_bins_concoct_out.98 1.1389761447040798 {'EX_cpd00067_e0': 1000.0, 'EX_cpd00971_e0': 1000.0, 'EX_cpd00058_e0': 1000.0, 'EX_cpd00244_e0': 1000.0, 'EX_cpd00205_e0': 1000.0, 'EX_cpd00009_e0': 100, 'EX_cpd00540_e0': 0.1, 'EX_cpd00254_e0': 1000.0, 'EX_cpd00149_e0': 1000.0, 'EX_cpd00034_e0': 1000.0, 'EX_cpd00001_e0': 1000.0, 'EX_cpd00013_e0': 1000.0, 'EX_cpd10516_e0': 1000.0, 'EX_cpd00007_e0': 1000.0, 'EX_cpd00305_e0': 100.0, 'EX_cpd00030_e0': 1000.0, 'EX_cpd00048_e0': 1000.0, 'EX_cpd00063_e0': 1000.0, 'EX_cpd00099_e0': 1000.0, 'EX_cpd11574_e0': 1000.0, 'EX_cpd00159_e0': 100.0}
# Salt_Pond_MetaG_R2_B_D2_MG_DASTool_bins_metabat.52 0.4400622894005093 {'EX_cpd00067_e0': 1000.0, 'EX_cpd00063_e0': 1000.0, 'EX_cpd00971_e0': 1000.0, 'EX_cpd00058_e0': 1000.0, 'EX_cpd00244_e0': 1000.0, 'EX_cpd00205_e0': 1000.0, 'EX_cpd00009_e0': 100, 'EX_cpd00034_e0': 1000.0, 'EX_cpd11574_e0': 1000.0, 'EX_cpd00159_e0': 100.0, 'EX_cpd00540_e0': 0.1, 'EX_cpd00254_e0': 1000.0, 'EX_cpd00048_e0': 1000.0, 'EX_cpd00149_e0': 1000.0, 'EX_cpd00001_e0': 1000.0, 'EX_cpd00013_e0': 1000.0, 'EX_cpd10516_e0': 1000.0, 'EX_cpd00007_e0': 1000.0, 'EX_cpd00305_e0': 100.0, 'EX_cpd00030_e0': 1000.0, 'EX_cpd00099_e0': 1000.0}
# {'betaine': {'Salt_Pond_MetaG_R1_A_D1_MG_DASTool_bins.concoct_out.9.contigs': {'R1_C': np.float64(-0.1), 'R2_B': np.float64(-0.1), 'R2_C': np.float64(-0.1), 'R1_A': np.float64(-0.1), 'R2_A': np.float64(-0.1), 'R1_B': np.float64(-0.1)}, 'Salt_Pond_MetaG_R1_A_D1_MG_DASTool_bins.metabat.47.contigs': {'R1_C': np.float64(-0.004155173944330431), 'R2_B': np.float64(-0.016189024367368715), 'R2_C': np.float64(-0.059260881157459894), 'R1_A': np.float64(-0.003266969474764042), 'R2_A': np.float64(-0.0014186011073906296), 'R1_B': np.float64(-0.004386622400931961)}, 'Salt_Pond_MetaG_R1_A_D1_MG_DASTool_bins.metabat.51.contigs': {'R1_C': np.float64(0.0), 'R2_B': np.float64(0.0), 'R2_C': np.float64(0.0), 'R1_A': np.float64(0.0), 'R2_A': np.float64(0.0), 'R1_B': np.float64(0.0)}, 'Salt_Pond_MetaG_R1_A_D2_MG_DASTool_bins_metabat.27.contigs': {'R1_C': np.float64(-0.1), 'R2_B': np.float64(-0.1), 'R2_C': np.float64(-0.1), 'R1_A': np.float64(-0.1), 'R2_A': np.float64(-0.1), 'R1_B': np.float64(-0.1)}, 'Salt_Pond_MetaG_R1_A_D2_MG_DASTool_bins_metabat.45.contigs': {'R1_C': np.float64(-0.04049835052607321), 'R2_B': np.float64(-0.1), 'R2_C': np.float64(-0.1), 'R1_A': np.float64(-0.04309736398630432), 'R2_A': np.float64(-0.02667366807003116), 'R1_B': np.float64(-0.03873150159343811)}, 'Salt_Pond_MetaG_R1_A_D2_MG_DASTool_bins_metabat.48.contigs': {'R1_C': np.float64(-0.1), 'R2_B': np.float64(-0.1), 'R2_C': np.float64(-0.1), 'R1_A': np.float64(-0.1), 'R2_A': np.float64(-0.1), 'R1_B': np.float64(-0.1)}, 'Salt_Pond_MetaG_R1_A_D2_MG_DASTool_bins_metabat.50.contigs': {'R1_C': np.float64(0.0), 'R2_B': np.float64(0.0), 'R2_C': np.float64(0.0), 'R1_A': np.float64(0.0), 'R2_A': np.float64(0.0), 'R1_B': np.float64(0.0)}, 'Salt_Pond_MetaG_R1_B_D1_MG_DASTool_bins_concoct_out.59.contigs': {'R1_C': np.float64(0.0), 'R2_B': np.float64(0.0), 'R2_C': np.float64(0.0), 'R1_A': np.float64(0.0), 'R2_A': np.float64(0.0), 'R1_B': np.float64(0.0)}, 'Salt_Pond_MetaG_R1_B_D1_MG_DASTool_bins_metabat.58.contigs': {'R1_C': np.float64(-0.010620624142021317), 'R2_B': np.float64(-0.017376308062454465), 'R2_C': np.float64(-0.05538545280165857), 'R1_A': np.float64(-0.02773869657846126), 'R2_A': np.float64(-0.004749024914201657), 'R1_B': np.float64(-0.04266112324083004)}, 'Salt_Pond_MetaG_R1_B_D2_MG_DASTool_bins_concoct_out.73.contigs': {'R1_C': np.float64(-0.02039362806224093), 'R2_B': np.float64(-0.1), 'R2_C': np.float64(-0.1), 'R1_A': np.float64(-0.01538698570803064), 'R2_A': np.float64(-0.010511101911279047), 'R1_B': np.float64(-0.026983937243229922)}, 'Salt_Pond_MetaG_R1_C_D1_MG_DASTool_bins_maxbin.047.contigs': {'R1_C': np.float64(0.0), 'R2_B': np.float64(0.0), 'R2_C': np.float64(0.0), 'R1_A': np.float64(0.0), 'R2_A': np.float64(0.0), 'R1_B': np.float64(0.0)}, 'Salt_Pond_MetaG_R1_C_D2_MG_DASTool_bins_concoct_out.85.contigs': {'R1_C': np.float64(-0.1), 'R2_B': np.float64(-0.1), 'R2_C': np.float64(-0.1), 'R1_A': np.float64(-0.1), 'R2_A': np.float64(-0.1), 'R1_B': np.float64(-0.1)}, 'Salt_Pond_MetaG_R1_C_D2_MG_DASTool_bins_metabat.40.contigs': {'R1_C': np.float64(-0.1), 'R2_B': np.float64(-0.1), 'R2_C': np.float64(-0.1), 'R1_A': np.float64(-0.1), 'R2_A': np.float64(-0.09140306704143274), 'R1_B': np.float64(-0.1)}, 'Salt_Pond_MetaG_R2_A_D1_MG_DASTool_bins_concoct_out.98.contigs': {'R1_C': np.float64(-0.1), 'R2_B': np.float64(-0.1), 'R2_C': np.float64(-0.1), 'R1_A': np.float64(-0.1), 'R2_A': np.float64(-0.1), 'R1_B': np.float64(-0.1)}, 'Salt_Pond_MetaG_R2_B_D2_MG_DASTool_bins_metabat.52.contigs': {'R1_C': np.float64(-0.1), 'R2_B': np.float64(-0.1), 'R2_C': np.float64(-0.1), 'R1_A': np.float64(-0.1), 'R2_A': np.float64(-0.1), 'R1_B': np.float64(-0.1)}}, 'TMA': {'Salt_Pond_MetaG_R1_A_D1_MG_DASTool_bins.concoct_out.9.contigs': {'R1_C': np.float64(0.09999999999999999), 'R2_B': np.float64(0.09999999999999999), 'R2_C': np.float64(0.09999999999999999), 'R1_A': np.float64(0.09999999999999999), 'R2_A': np.float64(0.09999999999999999), 'R1_B': np.float64(0.09999999999999999)}, 'Salt_Pond_MetaG_R1_A_ ...
# total TMA flux: {'R1_C': 0.7756677766746658, 'R2_B': 0.9335653324298231, 'R2_C': 1.0146463339591183, 'R1_A': 0.7894900157475602, 'R2_A': 0.7347554630443351, 'R1_B': 0.8127631844784299}
# total betaine flux: {'R1_C': -0.7756677766746658, 'R2_B': -0.9335653324298231, 'R2_C': -1.0146463339591183, 'R1_A': -0.7894900157475603, 'R2_A': -0.7347554630443351, 'R1_B': -0.81276318447843}
# total methane flux: {}
# {'eq': 'y = -3.95x + -77202.90', 'R2': '$R^2$ = 0.86221939'}

# %% [markdown]
# ## plot the correlational and modeling v experimental figures

# %%
# correlate the methane emissions with fluxes in the experimental units
import matplotlib.pyplot as plt
# from seaborn import color_palette
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import make_pipeline, Pipeline

from matplotlib.ticker import LogLocator, LogFormatterMathtext, NullFormatter
from sklearn.metrics import r2_score
from adjustText import adjust_text
import json
from pandas import DataFrame

log = False
linear = True
# display(fluxes)

for fluxes_file in ['saltern_fluxes.json', 'saltern_fluxes_betaine.json']:
    # display(DataFrame(methane_sols).T.sum())
    fluxes = json.load(open(fluxes_file))
    betaine = False
    if "betaine" in fluxes_file:
        betaine = True
        # fluxes_in_emissions = fluxes_to_emissions(DataFrame(fluxes["methane"]).T.sum()).to_dict()
        fluxes_in_emissions = fluxes_to_emissions(DataFrame(fluxes["TMA"]).T.sum()).to_dict()
    else:
        fluxes_in_emissions = fluxes_to_emissions(DataFrame(fluxes["0.07"]["methane"]).T.sum()).to_dict()
    print("fluxes_in_emissions")
    display(fluxes_in_emissions)
    # total_df = read_csv("../Cliff/data/Cliff_Sample_Metadata_BGC_NMR.csv").set_index("Sample")
    # emissions = total_df["CH4_umol_m2_d"].loc[unrestored_cols].to_list()

    combined = {ID: {"fluxes": emissions, "methane": methane_dic[ID]} for ID, emissions in fluxes_in_emissions.items()}
    combined_df = DataFrame(combined).T
    methane_ary = np.array(list(combined_df["methane"].values))
    emission_fluxes = np.array(list(combined_df["fluxes"].values))
    if betaine:
        TMA_to_methane = 0.06
        emission_fluxes = np.array(list(combined_df["fluxes"].values)) * TMA_to_methane

    # plot the figure
    fig, ax = plt.subplots(figsize=(8, 6), dpi=300)
    xs = np.array(methane_ary).reshape(-1, 1)
    ys = np.array(emission_fluxes)
    xs_flat = np.array(xs).flatten()
    ys_flat = np.array(ys).flatten()
    title = "Betaine " if betaine else "MePn "
    if log:
        xs = np.log(xs)
        ys = np.log(ys)
        title += r"Methane emissions $\left[LOG\left(\frac{umol~~CH_4}{m^2*day*\left(\frac{ug DNA}{g soil}\right)}\right)\right]$"
    else:
        ax.set_xscale('log'); ax.set_yscale('log')

        # Major ticks = decades
        ax.xaxis.set_major_locator(LogLocator(base=10, subs=(1.0,)))
        ax.yaxis.set_major_locator(LogLocator(base=10, subs=(1.0,)))

        # 9 log-spaced minor ticks per decade
        ax.xaxis.set_minor_locator(LogLocator(base=10, subs=np.arange(2, 10), numticks=100))
        ax.yaxis.set_minor_locator(LogLocator(base=10, subs=np.arange(2, 10), numticks=100))

        # Label only 10^n
        if betaine:
            y_min, y_max = ys_flat.min(), ys_flat.max()
            low_magnitude = np.log10(y_min)
            high_magnitude = np.log10(y_max)
            ax.set_ylim(10**(low_magnitude-0.4), 10**(high_magnitude+0.4))
            fmt_x = LogFormatterMathtext(base=10, labelOnlyBase=True)
            fmt_y = LogFormatterMathtext(base=10, labelOnlyBase=False)
            ax.xaxis.set_major_formatter(fmt_x)
            ax.yaxis.set_major_formatter(fmt_y)
            # ax.yaxis.set_major_locator(LogLocator(base=10, subs=np.arange(1, 10), numticks=10))
            # ax.yaxis.set_major_formatter(LogFormatterMathtext(base=10, labelOnlyBase=False))
            ax.yaxis.set_major_locator(LogLocator(base=10, subs=(1.0,)))
            ax.yaxis.set_major_formatter(LogFormatterMathtext(base=10, labelOnlyBase=True))
            print("here")
        else:
            ax.yaxis.set_major_locator(LogLocator(base=10, subs=np.arange(1, 10), numticks=10))
            ax.yaxis.set_major_formatter(LogFormatterMathtext(base=10, labelOnlyBase=False))
            fmt = LogFormatterMathtext(base=10, labelOnlyBase=True)
            ax.xaxis.set_major_formatter(fmt)
            ax.yaxis.set_major_formatter(fmt)
        ax.xaxis.set_minor_formatter(NullFormatter())
        ax.yaxis.set_minor_formatter(NullFormatter())
        plt.setp(ax.get_xticklabels(), rotation=90)
        title += r"Methane emissions $\left[\left(\frac{umol~~CH_4}{m^2*day*\left(\frac{ug DNA}{g soil}\right)}\right)\right]$"

    print(xs, ys)

    mdl = LinearRegression()
    mdl.fit(xs, ys)
    ax.scatter(xs, ys)
    ax.grid(True, which='both', axis='both', linestyle='--', color='gray', alpha=0.3)
    offset = .05
    label_size = 13
    texts = []
    # xs = np.array(xs).flatten()
    # ys = np.array(ys).flatten()
    # for xi, yi, label in zip(xs, ys, list(combined_df.index)):
    #     texts.append(plt.text(float(xi), float(yi) + offset, label, fontsize=label_size, ha='center', va='bottom'))
    # adjust_text(texts, arrowprops=dict(arrowstyle='->', color='gray'))

    texts = []
    for xi, yi, label in zip(xs_flat, ys_flat, list(combined_df.index)):
        texts.append(plt.text(float(xi), float(yi) + offset, label, fontsize=label_size, ha='center', va='bottom'))
    adjust_text(texts, arrowprops=dict(arrowstyle='->', color='gray'))

    # add the regression
    y_pred = mdl.predict(xs)
    trendline_color = "green"
    sorted_idx = np.argsort(methane_ary)
    sorted_xs = xs[sorted_idx]
    sorted_ys = y_pred[sorted_idx]
    ax.plot(sorted_xs, sorted_ys, color=trendline_color, linestyle='--', label='Trendline')

    ## create the equation for the plot
    eq = f"y = {mdl.coef_[0]:.2f}x + {mdl.intercept_:.2f}"
    r2_text = f"$R^2$ = {r2_score(ys, y_pred):.5f}"

    # Add labels and title
    ax.text(0.3, 0.8, eq + '\n' + r2_text, transform=plt.gca().transAxes, fontsize=label_size, color=trendline_color, verticalalignment='top')
    axes_size = 20
    plt.xlabel('Experimental measurement', fontsize=axes_size)
    plt.ylabel('Metabolic modeling', fontsize=axes_size)
    plt.title(title, fontsize=axes_size+4)
    plt.tight_layout()
    fig.savefig(f"{'betaine' if betaine else 'mepn'}_experiment_modeling.png")
    fig.show()



######################################################################################################
# compute the correlation between the normalized abundances and experimental methane fluxes
display(averaged_unrestored_normalized_abundances) #, unrestored_normalized_methane_df)
for samples in ["MePn", "Betaine"]:
    fig, ax = plt.subplots(figsize=(8, 6), dpi=300)
    if samples == "MePn":
        sample_totals = averaged_unrestored_normalized_abundances.loc[list(mepe_striped)].sum()
        title = 'MePn consumer correlation'
        export_name = "MePn_consumers_new.png"
    else:
        sample_totals = averaged_unrestored_normalized_abundances.loc[list(betaine_striped)].sum()
        title = 'Betaine consumer correlation'
        export_name = "Betaine_consumers_new.png"
    
    all_xs = np.array(sample_totals.to_list())# unrestored_normalized_abundances.to_numpy().flatten()
    xs = all_xs.reshape(-1, 1)
    all_ys = averaged_unrestored_normalized_methane.to_list() #*311)
    ys = np.array(all_ys)
    if log:
        xs = np.log(xs)
        ys = np.log(ys)
        plt.xlabel(r'Abundances $\left[LOG\left(\frac{rel.ab}{\frac{ug DNA}{g soil}}\right)\right]$', fontsize=axes_size)
        plt.ylabel(r"Methane emissions $\left[LOG\left(\frac{umol~~CH_4}{m^2*day*\left(\frac{ug DNA}{g soil}\right)}\right)\right]$", fontsize=axes_size)
    else:
        ax.set_xscale('log'); ax.set_yscale('log')

        # Major ticks = decades
        ax.xaxis.set_major_locator(LogLocator(base=10, subs=(1.0,)))
        ax.yaxis.set_major_locator(LogLocator(base=10, subs=(1.0,)))

        # 9 log-spaced minor ticks
        ax.xaxis.set_minor_locator(LogLocator(base=10, subs=np.arange(2, 10), numticks=100))
        ax.yaxis.set_minor_locator(LogLocator(base=10, subs=np.arange(2, 10), numticks=100))

        # Label only 10^n
        fmt = LogFormatterMathtext(base=10, labelOnlyBase=True)
        ax.xaxis.set_major_formatter(fmt)
        ax.yaxis.set_major_formatter(fmt)
        ax.xaxis.set_minor_formatter(NullFormatter())
        ax.yaxis.set_minor_formatter(NullFormatter())
        plt.setp(ax.get_xticklabels(), rotation=90)
        plt.xlabel(r'Abundances $\left[\left(\frac{rel.ab}{\frac{ug DNA}{g soil}}\right)\right]$', fontsize=axes_size)
        plt.ylabel(r"Methane emissions $\left[\left(\frac{umol~~CH_4}{m^2*day*\left(\frac{ug DNA}{g soil}\right)}\right)\right]$", fontsize=axes_size)

    if linear:
        model = LinearRegression()
        model.fit(xs, ys)
        y_pred = model.predict(xs)
        coef = model.coef_[0]
        intercept = model.intercept_
    else:
        # model = make_pipeline(PolynomialFeatures(degree=3), LinearRegression())
        # model.fit(xs, ys)

        poly = PolynomialFeatures(degree=2, include_bias=False)
        lin  = LinearRegression()
        model = Pipeline([("poly", poly), ("lin", lin)])
        model.fit(xs, ys)
        y_pred = model.predict(xs)

        # 1) Get polynomial term names
        # If you have original column names, pass them to get_feature_names_out:
        # e.g., poly.get_feature_names_out(["x1","x2"])
        term_names = model.named_steps["poly"].get_feature_names_out()  # uses x0,x1,... by default

        # 2) Get coefficients and intercept
        coef = model.named_steps["lin"].coef_
        intercept = model.named_steps["lin"].intercept_

    display(sample_totals)
    ax.scatter(xs, ys)
    # for xi, yi, label in zip(np.log(xs), np.log(ys), list(sample_totals.index)):
    #     ax.text(xi, yi, label, fontsize=9, ha='right', va='top')  # adjust ha/va for positioning
    xs_flat = np.array(xs).flatten()
    ys_flat = np.array(ys).flatten()
    texts = []
    for xi, yi, label in zip(xs_flat, ys_flat, list(sample_totals.index)):
        texts.append(plt.text(float(xi), float(yi) + offset, label, fontsize=label_size, ha='center', va='bottom'))
    adjust_text(texts, arrowprops=dict(arrowstyle='->', color='gray'))

        
    # add the regression
    sorted_idx = np.argsort(all_xs)
    sorted_xs = all_xs[sorted_idx]
    sorted_ys = y_pred[sorted_idx]
    # if log:
    #     sorted_xs = np.log(sorted_xs)
    #     sorted_ys = np.log(sorted_ys)
    ax.plot(sorted_xs, sorted_ys, color=trendline_color, linestyle='--', label='Trendline')
    ax.grid(True, which='both', axis='both', linestyle='--', color='gray', alpha=0.3)
    
    ## create the equation for the plot
    if linear:
        eq = f"y = {coef:.2f}x + {intercept:.2f}"
    else:
        precision = 4
        parts = [f"{intercept:.{precision}g}"]
        for c, t in zip(coef, term_names):
            sign = " + " if c >= 0 else " - "
            parts.append(f"{sign}{abs(c):.{precision}g}*{t}")
        eq = "y = " + "".join(parts)
        # print(model.named_steps['polynomialfeatures'].coef_)
        # eq = f"y = {model.named_steps['polynomialfeatures'].coef_}x^3 + {model.named_steps['linearregression'].intercept_:.2f}"
    r2_text = f"$R^2$ = {r2_score(all_ys, y_pred):.3f}"
    
    # Add labels and title
    ax.text(0.2, 0.7, eq + '\n' + r2_text, transform=plt.gca().transAxes, fontsize=label_size, color=trendline_color, verticalalignment='top')

    plt.title(title, fontsize=axes_size+4)
    plt.tight_layout()
    fig.savefig(export_name)
    fig.show()
# Out:
# fluxes_in_emissions
# {'R2_C': 2859.1826719957417,
#  'R1_A': 178.59025663352702,
#  'R2_B': 2808.1416375502013,
#  'R2_A': 165.43716483452206,
#  'R1_C': 596.82458886511,
#  'R1_B': 287.35249802006496}
# [[5214.31433971]
#  [ 154.04429156]
#  [5308.59101714]
#  [ 589.32690014]
#  [ 263.02100733]
#  [ 350.73230236]] [2859.182672    178.59025663 2808.14163755  165.43716483  596.82458887
#   287.35249802]
# fluxes_in_emissions
# /var/folders/j8/f5pb70wx5gn1qv1nz77lfhyr0000gn/T/ipykernel_43343/580000162.py:130: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# {'R1_C': 78186.1673757208,
#  'R2_B': 94102.00801488648,
#  'R2_C': 102274.85333242436,
#  'R1_A': 79579.4286792825,
#  'R2_A': 74062.26652870823,
#  'R1_B': 81925.3297473352}
# here
# [[ 263.02100733]
#  [5308.59101714]
#  [5214.31433971]
#  [ 154.04429156]
#  [ 589.32690014]
#  [ 350.73230236]] [4691.17004254 5646.12048089 6136.49119995 4774.76572076 4443.73599172
#  4915.51978484]
# /var/folders/j8/f5pb70wx5gn1qv1nz77lfhyr0000gn/T/ipykernel_43343/580000162.py:130: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
#                                                             R1_C      R2_B  \
# Unnamed: 0
# Salt_Pond_MetaGSF2_A_D1_MG_DASTool_bins_concoct...  1.282414e-06  0.000011
# Salt_Pond_MetaGSF2_A_D2_MG_DASTool_bins_concoct...  1.089267e-06  0.000003
# Salt_Pond_MetaGSF2_A_D2_MG_DASTool_bins_concoct...  6.679555e-07  0.000013
# Salt_Pond_MetaGSF2_A_D2_MG_DASTool_bins_concoct...  1.226690e-06  0.000013
# Salt_Pond_MetaGSF2_A_D2_MG_DASTool_bins_concoct...  1.540657e-05  0.000103
# ...                                                          ...       ...
# Salt_Pond_MetaG_R2_restored_H2O_MG_DASTool_bins...  3.355478e-06  0.000126
# Salt_Pond_MetaG_R2_restored_H2O_MG_DASTool_bins...  1.325396e-05  0.000529
# Salt_Pond_MetaG_R2_restored_H2O_MG_DASTool_bins...  2.215507e-05  0.000274
# Salt_Pond_MetaG_R2_restored_H2O_MG_DASTool_bins...  3.752668e-05  0.000208
# unbinned_reads                                      2.711032e-01  2.026298
#
#                                                         R2_C          R1_A  \
# Unnamed: 0
# Salt_Pond_MetaGSF2_A_D1_MG_DASTool_bins_concoct...  0.000008  2.285888e-07
# Salt_Pond_MetaGSF2_A_D2_MG_DASTool_bins_concoct...  0.000005  1.752075e-07
# Salt_Pond_MetaGSF2_A_D2_MG_DASTool_bins_concoct...  0.000006  2.132505e-07
# Salt_Pond_MetaGSF2_A_D2_MG_DASTool_bins_concoct...  0.000008  2.664661e-07
# Salt_Pond_MetaGSF2_A_D2_MG_DASTool_bins_concoct...  0.000058  3.896730e-06
# ...                                                      ...           ...
# Salt_Pond_MetaG_R2_restored_H2O_MG_DASTool_bins...  0.002550  1.996096e-07
# Salt_Pond_MetaG_R2_restored_H2O_MG_DASTool_bins...  0.008717  5.278583e-07
# Salt_Pond_MetaG_R2_restored_H2O_MG_DASTool_bins...  0.000426  5.927330e-06
# Salt_Pond_MetaG_R2_restored_H2O_MG_DASTool_bins...  0.000552  8.915694e-06
# unbinned_reads                                      1.880560  9.183897e-02
#
#                                                             R2_A          R1_B
# Unnamed: 0
# Salt_Pond_MetaGSF2_A_D1_MG_DASTool_bins_concoct...  6.775749e-07  5.076911e-07
# Salt_Pond_MetaGSF2_A_D2_MG_DASTool_bins_concoct...  1.073584e-06  2.961776e-07
# Salt_Pond_MetaGSF2_A_D2_MG_DASTool_bins_concoct...  1.403428e-06  3.661402e-07
# Salt_Pond_MetaGSF2_A_D2_MG_DASTool_bins_concoct...  1.854122e-06  4.349420e-07
# Salt_Pond_MetaGSF2_A_D2_MG_DASTool_bins_concoct...  3.729437e-06  6.537293e-06
# ...                                                          ...           ...
# Salt_Pond_MetaG_R2_restored_H2O_MG_DASTool_bins...  5.490922e-05  4.723512e-07
# Salt_Pond_MetaG_R2_restored_H2O_MG_DASTool_bins...  2.540135e-04  2.519591e-06
# Salt_Pond_MetaG_R2_restored_H2O_MG_DASTool_bins...  6.790419e-05  2.097325e-05
# Salt_Pond_MetaG_R2_restored_H2O_MG_DASTool_bins...  3.241835e-05  1.191853e-05
# unbinned_reads                                      2.523752e-01  1.192224e-01
#
# [311 rows x 6 columns]
# R1_C    0.048425
# R2_B    0.240617
# R2_C    0.293901
# R1_A    0.014390
# R2_A    0.021172
# R1_B    0.025778
# dtype: float64
# /var/folders/j8/f5pb70wx5gn1qv1nz77lfhyr0000gn/T/ipykernel_43343/580000162.py:245: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# R1_C    0.016532
# R2_B    0.065004
# R2_C    0.127121
# R1_A    0.018218
# R2_A    0.007378
# R1_B    0.014147
# dtype: float64
# /var/folders/j8/f5pb70wx5gn1qv1nz77lfhyr0000gn/T/ipykernel_43343/580000162.py:245: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
# Grab the metabolite by ID

for ID, content in sols.items():
    model = models[ID]
    try:
        print(list(model.metabolites)[0])
        met = model.metabolites.get_by_id("cpd01024_c0")  # e.g., D-glucose
    except KeyError:
        print(f"Metabolite cpd01024_c0 not found in model {ID}")
        continue
    metReactions = [rxn.id for rxn in met.reactions]
    for sample, sol in content.items():
        methane_flux = fluxes["methane"][ID][sample]
        if methane_flux == 0:   continue
        tma_flux = fluxes["TMA"][ID][sample]
        betaine_flux = fluxes["betaine"][ID][sample]
        lactate_flux = fluxes["lactate"][ID][sample]
        print(ID, sample)
        print(methane_flux, tma_flux, betaine_flux, lactate_flux)
        
        for rxn in metReactions:
            flux = sol.fluxes[rxn]
            stoich = sol.model.reactions.get_by_id(rxn).metabolites[met]  # stoichiometric coefficient
            print(f"{rxn}: stoich={stoich:+.2f}, flux={flux:.4f}")
        non_zero_fluxes = {k:f for k,f in sol.fluxes.to_dict().items() if f != 0}
        # betaine_fluxes = sol.fluxes
        # display(betaine_fluxes)
        break
    break
# Out:
# cpd00012_c0
# Metabolite cpd01024_c0 not found in model Salt_Pond_MetaG_R1_A_D1_MG_DASTool_bins.concoct_out.9.contigs
# cpd00012_c0
# Metabolite cpd01024_c0 not found in model Salt_Pond_MetaG_R1_A_D1_MG_DASTool_bins.metabat.47.contigs
# cpd00012_c0
# Metabolite cpd01024_c0 not found in model Salt_Pond_MetaG_R1_A_D1_MG_DASTool_bins.metabat.51.contigs
# cpd00443_c0
# Metabolite cpd01024_c0 not found in model Salt_Pond_MetaG_R1_A_D2_MG_DASTool_bins_metabat.27.contigs
# cpd00443_c0
# Metabolite cpd01024_c0 not found in model Salt_Pond_MetaG_R1_A_D2_MG_DASTool_bins_metabat.45.contigs
# cpd00012_c0
# Metabolite cpd01024_c0 not found in model Salt_Pond_MetaG_R1_A_D2_MG_DASTool_bins_metabat.48.contigs
# cpd00012_c0
# Metabolite cpd01024_c0 not found in model Salt_Pond_MetaG_R1_A_D2_MG_DASTool_bins_metabat.50.contigs
# cpd00443_c0
# Metabolite cpd01024_c0 not found in model Salt_Pond_MetaG_R1_B_D1_MG_DASTool_bins_concoct_out.59.contigs
# cpd00443_c0
# Metabolite cpd01024_c0 not found in model Salt_Pond_MetaG_R1_B_D1_MG_DASTool_bins_metabat.58.contigs
# cpd00443_c0
# Metabolite cpd01024_c0 not found in model Salt_Pond_MetaG_R1_B_D2_MG_DASTool_bins_concoct_out.73.contigs
# cpd00012_c0
# Metabolite cpd01024_c0 not found in model Salt_Pond_MetaG_R1_C_D1_MG_DASTool_bins_maxbin.047.contigs
# cpd00012_c0
# Metabolite cpd01024_c0 not found in model Salt_Pond_MetaG_R1_C_D2_MG_DASTool_bins_concoct_out.85.contigs
# cpd00012_c0
# Metabolite cpd01024_c0 not found in model Salt_Pond_MetaG_R1_C_D2_MG_DASTool_bins_metabat.40.contigs
# cpd00443_c0
# Metabolite cpd01024_c0 not found in model Salt_Pond_MetaG_R2_A_D1_MG_DASTool_bins_concoct_out.98.contigs
# cpd00012_c0
# Metabolite cpd01024_c0 not found in model Salt_Pond_MetaG_R2_B_D2_MG_DASTool_bins_metabat.52.contigs

# %% [markdown]
# ##### Claude updated visualization

# %%
import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt
from matplotlib.ticker import LogLocator, LogFormatterMathtext, NullFormatter
import numpy as np
import json
from pandas import DataFrame, read_csv, Series
from math import pi
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import make_pipeline, Pipeline
from sklearn.metrics import r2_score
from adjustText import adjust_text

def fluxes_to_emissions(row):
    area_cm2 = pi * (5/2)**2
    area_m2 = area_cm2 * (1e-2)**2
    volume_cm3 = 294.52
    ugDNA_gSoil = 2
    DNA_per_biomass = 0.1
    gSoil_cm3 = 1.4
    gBiomass_gSoil = gSoil_cm3 * volume_cm3 * ugDNA_gSoil / DNA_per_biomass / 1000 / 1000
    return row / area_m2 * 1e3 * 24 * (gBiomass_gSoil)

methane_dic = json.load(open("averaged_normalized_methane_unrestored.json"))
averaged_unrestored_normalized_abundances = read_csv("averaged_normalized_abundances_unrestored.csv", index_col=0)
averaged_unrestored_normalized_methane = Series(methane_dic)

betaine = {'Salt_Pond_MetaG_R1_A_D1_MG_DASTool_bins.concoct_out.9.contigs',
'Salt_Pond_MetaG_R1_A_D1_MG_DASTool_bins.metabat.47.contigs',
'Salt_Pond_MetaG_R1_A_D1_MG_DASTool_bins.metabat.51.contigs',
'Salt_Pond_MetaG_R1_A_D2_MG_DASTool_bins_metabat.27.contigs',
'Salt_Pond_MetaG_R1_A_D2_MG_DASTool_bins_metabat.45.contigs',
'Salt_Pond_MetaG_R1_A_D2_MG_DASTool_bins_metabat.48.contigs',
'Salt_Pond_MetaG_R1_A_D2_MG_DASTool_bins_metabat.50.contigs',
'Salt_Pond_MetaG_R1_B_D1_MG_DASTool_bins_concoct_out.59.contigs',
'Salt_Pond_MetaG_R1_B_D1_MG_DASTool_bins_metabat.58.contigs',
'Salt_Pond_MetaG_R1_B_D2_MG_DASTool_bins_concoct_out.73.contigs',
'Salt_Pond_MetaG_R1_C_D1_MG_DASTool_bins_maxbin.047.contigs',
'Salt_Pond_MetaG_R1_C_D2_MG_DASTool_bins_concoct_out.85.contigs',
'Salt_Pond_MetaG_R1_C_D2_MG_DASTool_bins_metabat.40.contigs',
'Salt_Pond_MetaG_R2_A_D1_MG_DASTool_bins_concoct_out.98.contigs',
'Salt_Pond_MetaG_R2_B_D2_MG_DASTool_bins_metabat.52.contigs'}
betaine_striped = [x.replace(".contigs","") for x in betaine]

mepe = {'Salt_Pond_MetaG_R1_B_D1_MG_DASTool_bins_metabat.20.contigs',
'Salt_Pond_MetaG_R1_B_D1_MG_DASTool_bins_metabat.32.contigs',
'Salt_Pond_MetaG_R1_B_D2_MG_DASTool_bins_concoct_out.51.contigs',
'Salt_Pond_MetaG_R1_B_D2_MG_DASTool_bins_metabat.27.contigs',
'Salt_Pond_MetaG_R1_B_D2_MG_DASTool_bins_metabat.28.contigs',
'Salt_Pond_MetaG_R1_B_H2O_MG_DASTool_bins_metabat.7.contigs',
'Salt_Pond_MetaG_R1_C_D1_MG_DASTool_bins_metabat.31.contigs',
'Salt_Pond_MetaG_R1_C_H2O_MG_DASTool_bins_concoct_out.79.contigs',
'Salt_Pond_MetaG_R2_A_D1_MG_DASTool_bins_concoct_out.35.contigs',
'Salt_Pond_MetaG_R2_A_D1_MG_DASTool_bins_concoct_out.49.contigs',
'Salt_Pond_MetaG_R2_A_D2_MG_DASTool_bins_metabat.14.contigs',
'Salt_Pond_MetaG_R2_A_D2_MG_DASTool_bins_metabat.16.contigs',
'Salt_Pond_MetaG_R2_B_D2_MG_DASTool_bins_concoct_out.143.contigs',
'Salt_Pond_MetaG_R2_B_D2_MG_DASTool_bins_concoct_out.32.contigs',
'Salt_Pond_MetaG_R2_B_D2_MG_DASTool_bins_metabat.10.contigs',
'Salt_Pond_MetaG_R2_B_D2_MG_DASTool_bins_metabat.16.contigs',
'Salt_Pond_MetaG_R2_B_D2_MG_DASTool_bins_metabat.19.contigs',
'Salt_Pond_MetaG_R2_B_D2_MG_DASTool_bins_metabat.38.contigs',
'Salt_Pond_MetaG_R2_B_D2_MG_DASTool_bins_metabat.55.contigs',
'Salt_Pond_MetaG_R2_C_D1_MG_DASTool_bins_concoct_out.88.contigs',
'Salt_Pond_MetaG_R2_C_D1_MG_DASTool_bins_concoct_out.95.contigs',
'Salt_Pond_MetaG_R2_C_D1_MG_DASTool_bins_metabat.17.contigs',
'Salt_Pond_MetaG_R2_C_D2_MG_DASTool_bins_concoct_out.18.contigs',
'Salt_Pond_MetaG_R2_C_D2_MG_DASTool_bins_concoct_out.45.contigs',
'Salt_Pond_MetaG_R2_C_D2_MG_DASTool_bins_concoct_out.47.contigs',
'Salt_Pond_MetaG_R2_restored_C_black_MG_DASTool_bins_concoct_out.17.contigs',
'Salt_Pond_MetaG_R2_restored_C_black_MG_DASTool_bins_metabat.8.contigs'}
mepe_striped = [x.replace(".contigs","") for x in mepe]

log = False
linear = True

# === FIRST PLOT SECTION: flux vs methane correlations ===
for fluxes_file in ['saltern_fluxes.json', 'saltern_fluxes_betaine.json']:
    fluxes = json.load(open(fluxes_file))

    # Handle different file structures
    if "0.07" in fluxes:
        flux_groups = {"methane": fluxes["0.07"]["methane"]}
    else:
        flux_groups = fluxes

    for flux_type, flux_data in flux_groups.items():
        summed = DataFrame(flux_data).T.sum().abs()
        fluxes_in_emissions = fluxes_to_emissions(summed).to_dict()

        combined = {ID: {"fluxes": em, "methane": methane_dic[ID]}
                    for ID, em in fluxes_in_emissions.items() if ID in methane_dic}
        combined_df = DataFrame(combined).T
        methane_ary = np.array(list(combined_df["methane"].values))
        emission_fluxes = np.array(list(combined_df["fluxes"].values))

        fig, ax = plt.subplots(figsize=(8, 6), dpi=300)
        xs = methane_ary.reshape(-1, 1)
        ys = emission_fluxes

        if log:
            xs = np.log(xs)
            ys = np.log(ys)
            title = r"Methane emissions $\left[LOG\left(\frac{umol~~CH_4}{m^2*day*\left(\frac{ug DNA}{g soil}\right)}\right)\right]$"
        else:
            ax.set_xscale('log'); ax.set_yscale('log')
            ax.xaxis.set_major_locator(LogLocator(base=10, subs=(1.0,)))
            ax.yaxis.set_major_locator(LogLocator(base=10, subs=(1.0,)))
            ax.xaxis.set_minor_locator(LogLocator(base=10, subs=np.arange(2, 10), numticks=100))
            ax.yaxis.set_minor_locator(LogLocator(base=10, subs=np.arange(2, 10), numticks=100))
            fmt = LogFormatterMathtext(base=10, labelOnlyBase=True)
            ax.xaxis.set_major_formatter(fmt)
            ax.yaxis.set_major_formatter(fmt)
            ax.xaxis.set_minor_formatter(NullFormatter())
            ax.yaxis.set_minor_formatter(NullFormatter())
            plt.setp(ax.get_xticklabels(), rotation=90)
            title = f"{flux_type.capitalize()} flux correlation"

        mdl = LinearRegression()
        mdl.fit(xs, ys)
        ax.scatter(xs.flatten(), ys)
        ax.grid(True, which='both', axis='both', linestyle='--', color='gray', alpha=0.3)
        label_size = 13
        texts = []
        for xi, yi, label in zip(xs.flatten(), ys, list(combined_df.index)):
            texts.append(ax.text(xi, yi, label, fontsize=label_size, ha='center', va='bottom'))
        adjust_text(texts, ax=ax, arrowprops=dict(arrowstyle='->', color='gray'))

        y_pred = mdl.predict(xs)
        trendline_color = "green"
        sorted_idx = np.argsort(methane_ary)
        ax.plot(xs.flatten()[sorted_idx], y_pred[sorted_idx], color=trendline_color, linestyle='--', label='Trendline')

        eq = f"y = {mdl.coef_[0]:.2f}x + {mdl.intercept_:.2f}"
        r2_text = f"$R^2$ = {r2_score(ys, y_pred):.5f}"
        ax.text(0.3, 0.8, eq + '\n' + r2_text, transform=ax.transAxes, fontsize=label_size, color=trendline_color, verticalalignment='top')

        axes_size = 20
        ax.set_xlabel('Experimental measurement', fontsize=axes_size)
        ax.set_ylabel('Metabolic modeling (|flux|)', fontsize=axes_size)
        ax.set_title(title, fontsize=axes_size+4)
        plt.tight_layout()
        fname = f"experiment_modeling_{fluxes_file.replace('.json','')}_{flux_type}.png"
        fig.savefig(fname)
        plt.close(fig)
        print(f"Saved {fname}: R2={r2_score(ys, y_pred):.5f}")


# === SECOND PLOT SECTION: abundance vs methane correlations ===
for samples in ["MePn", "Betaine"]:
    fig, ax = plt.subplots(figsize=(8, 6), dpi=300)
    if samples == "MePn":
        sample_totals = averaged_unrestored_normalized_abundances.loc[list(mepe_striped)].sum()
        title = 'MePn consumer correlation'
        export_name = "MePn_consumers_new.png"
    else:
        sample_totals = averaged_unrestored_normalized_abundances.loc[list(betaine_striped)].sum()
        title = 'Betaine consumer correlation'
        export_name = "Betaine_consumers_new.png"

    all_xs = np.array(sample_totals.to_list())
    xs = all_xs.reshape(-1, 1)
    all_ys = averaged_unrestored_normalized_methane.to_list()
    ys = np.array(all_ys)

    if log:
        xs = np.log(xs)
        ys = np.log(ys)
        ax.set_xlabel(r'Abundances $\left[LOG\left(\frac{rel.ab}{\frac{ug DNA}{g soil}}\right)\right]$', fontsize=20)
        ax.set_ylabel(r"Methane emissions $\left[LOG\left(\frac{umol~~CH_4}{m^2*day*\left(\frac{ug DNA}{g soil}\right)}\right)\right]$", fontsize=20)
    else:
        ax.set_xscale('log'); ax.set_yscale('log')
        ax.xaxis.set_major_locator(LogLocator(base=10, subs=(1.0,)))
        ax.yaxis.set_major_locator(LogLocator(base=10, subs=(1.0,)))
        ax.xaxis.set_minor_locator(LogLocator(base=10, subs=np.arange(2, 10), numticks=100))
        ax.yaxis.set_minor_locator(LogLocator(base=10, subs=np.arange(2, 10), numticks=100))
        fmt = LogFormatterMathtext(base=10, labelOnlyBase=True)
        ax.xaxis.set_major_formatter(fmt)
        ax.yaxis.set_major_formatter(fmt)
        ax.xaxis.set_minor_formatter(NullFormatter())
        ax.yaxis.set_minor_formatter(NullFormatter())
        plt.setp(ax.get_xticklabels(), rotation=90)
        ax.set_xlabel(r'Abundances $\left[\left(\frac{rel.ab}{\frac{ug DNA}{g soil}}\right)\right]$', fontsize=20)
        ax.set_ylabel(r"Methane emissions $\left[\left(\frac{umol~~CH_4}{m^2*day*\left(\frac{ug DNA}{g soil}\right)}\right)\right]$", fontsize=20)

    if linear:
        model = LinearRegression()
        model.fit(xs, ys)
        y_pred = model.predict(xs)
        coef = model.coef_[0]
        intercept = model.intercept_
    else:
        poly = PolynomialFeatures(degree=2, include_bias=False)
        lin = LinearRegression()
        model = Pipeline([("poly", poly), ("lin", lin)])
        model.fit(xs, ys)
        y_pred = model.predict(xs)
        term_names = model.named_steps["poly"].get_feature_names_out()
        coef = model.named_steps["lin"].coef_
        intercept = model.named_steps["lin"].intercept_

    ax.scatter(all_xs, ys)
    label_size = 13
    texts = []
    for xi, yi, label in zip(all_xs, ys, list(sample_totals.index)):
        texts.append(ax.text(xi, yi, label, fontsize=label_size, ha='center', va='bottom'))
    adjust_text(texts, ax=ax, arrowprops=dict(arrowstyle='->', color='gray'))

    sorted_idx = np.argsort(all_xs)
    sorted_xs = all_xs[sorted_idx]
    sorted_ys = y_pred[sorted_idx]
    trendline_color = "green"
    ax.plot(sorted_xs, sorted_ys, color=trendline_color, linestyle='--', label='Trendline')
    ax.grid(True, which='both', axis='both', linestyle='--', color='gray', alpha=0.3)

    if linear:
        eq = f"y = {coef:.2f}x + {intercept:.2f}"
    else:
        precision = 4
        parts = [f"{intercept:.{precision}g}"]
        for c, t in zip(coef, term_names):
            sign = " + " if c >= 0 else " - "
            parts.append(f"{sign}{abs(c):.{precision}g}*{t}")
        eq = "y = " + "".join(parts)
    r2_text = f"$R^2$ = {r2_score(all_ys, y_pred):.3f}"

    ax.text(0.2, 0.7, eq + '\n' + r2_text, transform=ax.transAxes, fontsize=label_size, color=trendline_color, verticalalignment='top')
    axes_size = 20
    ax.set_title(title, fontsize=axes_size+4)
    plt.tight_layout()
    fig.savefig(export_name)
    plt.close(fig)
    print(f"Saved {export_name}")

print("\nDone!")
