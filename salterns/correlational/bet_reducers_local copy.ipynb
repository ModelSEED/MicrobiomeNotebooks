# %%
import cobra
from modelseedpy import MSBuilder, MSATPCorrection, MSMedia, MSGapfill
import json
from tqdm import tqdm
import cobrakbase
# Out:
# modelseedpy 0.4.3
# cobrakbase 0.4.0

# %%
config = cobra.Configuration()
config
# Out:
# solver: glpk
# tolerance: 1e-07
# lower_bound: -1000.0
# upper_bound: 1000.0
# processes: 31
# cache_directory: C:\Users\filip\AppData\Local\opencobra\cobrapy\Cache
# max_cache_size: 104857600
# cache_expiration: None

# %% [markdown]
# # examining the Betaine-consuming taxa

# %%
target_model_ids = {
    'Salt_Pond_MetaG_R1_A_D1_MG_DASTool_bins.concoct_out.9.contigs',
 'Salt_Pond_MetaG_R1_A_D1_MG_DASTool_bins.metabat.47.contigs',
 'Salt_Pond_MetaG_R1_A_D1_MG_DASTool_bins.metabat.51.contigs',
 'Salt_Pond_MetaG_R1_A_D2_MG_DASTool_bins_metabat.27.contigs',
 'Salt_Pond_MetaG_R1_A_D2_MG_DASTool_bins_metabat.45.contigs',
 'Salt_Pond_MetaG_R1_A_D2_MG_DASTool_bins_metabat.48.contigs',
 'Salt_Pond_MetaG_R1_A_D2_MG_DASTool_bins_metabat.50.contigs',
 'Salt_Pond_MetaG_R1_B_D1_MG_DASTool_bins_concoct_out.59.contigs',
 'Salt_Pond_MetaG_R1_B_D1_MG_DASTool_bins_metabat.58.contigs',
 'Salt_Pond_MetaG_R1_B_D2_MG_DASTool_bins_concoct_out.73.contigs',
 'Salt_Pond_MetaG_R1_C_D1_MG_DASTool_bins_maxbin.047.contigs',
 'Salt_Pond_MetaG_R1_C_D2_MG_DASTool_bins_concoct_out.85.contigs',
 'Salt_Pond_MetaG_R1_C_D2_MG_DASTool_bins_metabat.40.contigs',
 'Salt_Pond_MetaG_R2_A_D1_MG_DASTool_bins_concoct_out.98.contigs',
 'Salt_Pond_MetaG_R2_B_D2_MG_DASTool_bins_metabat.52.contigs'}

# %%
from json import dump
from pandas import read_csv

phylogeny = read_csv("/home/freiburger/Documents/MicrobiomeNotebooks/salterns/data/Saltern_phylogeny.csv")
phylogeny = dict(zip(phylogeny["User Genome"], phylogeny["Classification"]))

definitions = {'d': 'Kingdom', 'p': 'Phylum', 'c': 'Class', 'o': 'Order', 'f': 'Family', 'g': 'Genus', 's': 'Species'}
for MAG, taxa in phylogeny.items():
    phylogeny[MAG] = {definitions[level]: tax for level, tax in (p.split('__') for p in taxa.split(';'))}

dump(phylogeny, open("/home/freiburger/Documents/MicrobiomeNotebooks/salterns/data/Saltern_phylogeny.json", "w"), indent=2)
phylogeny
# Out:
# {'Salt_Pond_MetaG_R1_A_D1_MG_DASTool_bins.concoct_out.44.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Desulfobacterota_F',
#   'Class': 'Desulfuromonadia',
#   'Order': 'Desulfuromonadales',
#   'Family': 'SZUA-401',
#   'Genus': '',
#   'Species': ''},
#  'Salt_Pond_MetaG_R1_A_D1_MG_DASTool_bins.concoct_out.54.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Proteobacteria',
#   'Class': 'Gammaproteobacteria',
#   'Order': 'Thiohalorhabdales',
#   'Family': 'Thiohalorhabdaceae',
#   'Genus': 'Thiohalorhabdus',
#   'Species': ''},
#  'Salt_Pond_MetaG_R1_A_D1_MG_DASTool_bins.concoct_out.9.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Firmicutes_A',
#   'Class': 'Clostridia',
#   'Order': 'Tissierellales',
#   'Family': 'Dethiosulfatibacteraceae',
#   'Genus': 'UBA8670',
#   'Species': ''},
#  'Salt_Pond_MetaG_R1_A_D1_MG_DASTool_bins.metabat.15.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Bacteroidota',
#   'Class': 'Rhodothermia',
#   'Order': 'Balneolales',
#   'Family': 'Balneolaceae',
#   'Genus': 'Fodinibius',
#   'Species': ''},
#  'Salt_Pond_MetaG_R1_A_D1_MG_DASTool_bins.metabat.18.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Bacteroidota',
#   'Class': 'Rhodothermia',
#   'Order': 'Balneolales',
#   'Family': 'Balneolaceae',
#   'Genus': 'YR4-1',
#   'Species': ''},
#  'Salt_Pond_MetaG_R1_A_D1_MG_DASTool_bins.metabat.26.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Proteobacteria',
#   'Class': 'Gammaproteobacteria',
#   'Order': 'Pseudomonadales',
#   'Family': 'Halomonadaceae',
#   'Genus': 'Halomonas',
#   'Species': 'Halomonas fontilapidosi'},
#  'Salt_Pond_MetaG_R1_A_D1_MG_DASTool_bins.metabat.45.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Proteobacteria',
#   'Class': 'Gammaproteobacteria',
#   'Order': 'Thiohalospirales',
#   'Family': 'Thiohalospiraceae',
#   'Genus': 'Thiohalospira',
#   'Species': ''},
#  'Salt_Pond_MetaG_R1_A_D1_MG_DASTool_bins.metabat.47.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Firmicutes_F',
#   'Class': 'Halanaerobiia',
#   'Order': 'Halanaerobiales',
#   'Family': '',
#   'Genus': '',
#   'Species': ''},
#  'Salt_Pond_MetaG_R1_A_D1_MG_DASTool_bins.metabat.51.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Firmicutes_A',
#   'Class': 'Clostridia',
#   'Order': 'Peptostreptococcales',
#   'Family': 'BM714',
#   'Genus': 'BM714',
#   'Species': ''},
#  'Salt_Pond_MetaG_R1_A_D1_MG_DASTool_bins.metabat.6.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Bacteroidota',
#   'Class': 'Rhodothermia',
#   'Order': 'Balneolales',
#   'Family': 'Balneolaceae',
#   'Genus': 'Fodinibius',
#   'Species': ''},
#  'Salt_Pond_MetaG_R1_A_D2_MG_DASTool_bins_concoct_out.1.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Firmicutes_F',
#   'Class': 'Halanaerobiia',
#   'Order': 'Halanaerobiales',
#   'Family': '',
#   'Genus': '',
#   'Species': ''},
#  'Salt_Pond_MetaG_R1_A_D2_MG_DASTool_bins_concoct_out.109.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Bacteroidota',
#   'Class': 'Bacteroidia',
#   'Order': 'Bacteroidales',
#   'Family': 'Prolixibacteraceae',
#   'Genus': 'Tangfeifania',
#   'Species': 'Tangfeifania diversioriginum'},
#  'Salt_Pond_MetaG_R1_A_D2_MG_DASTool_bins_concoct_out.25.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Spirochaetota',
#   'Class': 'Spirochaetia',
#   'Order': 'Sphaerochaetales',
#   'Family': 'Sphaerochaetaceae',
#   'Genus': 'RZYO01',
#   'Species': ''},
#  'Salt_Pond_MetaG_R1_A_D2_MG_DASTool_bins_concoct_out.51.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Bacteroidota',
#   'Class': 'Bacteroidia',
#   'Order': 'Bacteroidales',
#   'Family': 'VadinHA17',
#   'Genus': '',
#   'Species': ''},
#  'Salt_Pond_MetaG_R1_A_D2_MG_DASTool_bins_metabat.15.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Spirochaetota',
#   'Class': 'Spirochaetia',
#   'Order': 'DSM-16054',
#   'Family': 'Sediminispirochaetaceae',
#   'Genus': '',
#   'Species': ''},
#  'Salt_Pond_MetaG_R1_A_D2_MG_DASTool_bins_metabat.27.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Firmicutes_A',
#   'Class': 'Clostridia',
#   'Order': 'Peptostreptococcales',
#   'Family': 'Acidaminobacteraceae',
#   'Genus': '',
#   'Species': ''},
#  'Salt_Pond_MetaG_R1_A_D2_MG_DASTool_bins_metabat.31.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Bacteroidota',
#   'Class': 'Bacteroidia',
#   'Order': 'Bacteroidales',
#   'Family': 'UBA12077',
#   'Genus': 'UBA12077',
#   'Species': ''},
#  'Salt_Pond_MetaG_R1_A_D2_MG_DASTool_bins_metabat.36.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Bacteroidota',
#   'Class': 'Bacteroidia',
#   'Order': 'Bacteroidales',
#   'Family': 'UBA12077',
#   'Genus': 'UBA12077',
#   'Species': ''},
#  'Salt_Pond_MetaG_R1_A_D2_MG_DASTool_bins_metabat.45.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Firmicutes_F',
#   'Class': 'Halanaerobiia',
#   'Order': 'Halanaerobiales',
#   'Family': 'Halanaerobiaceae',
#   'Genus': 'Halanaerobium',
#   'Species': 'Halanaerobium saccharolyticum'},
#  'Salt_Pond_MetaG_R1_A_D2_MG_DASTool_bins_metabat.48.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Firmicutes_A',
#   'Class': 'Clostridia',
#   'Order': 'Peptostreptococcales',
#   'Family': 'BM714',
#   'Genus': 'BM714',
#   'Species': ''},
#  'Salt_Pond_MetaG_R1_A_D2_MG_DASTool_bins_metabat.50.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Firmicutes_A',
#   'Class': 'Clostridia',
#   'Order': 'Peptostreptococcales',
#   'Family': 'BM714',
#   'Genus': 'BM714',
#   'Species': ''},
#  'Salt_Pond_MetaG_R1_A_D2_MG_DASTool_bins_metabat.84.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Patescibacteria',
#   'Class': 'ABY1',
#   'Order': 'UBA2591',
#   'Family': 'UBA6264',
#   'Genus': '',
#   'Species': ''},
#  'Salt_Pond_MetaG_R1_A_H2O_MG_DASTool_bins_concoct_out.2.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Bacteroidota',
#   'Class': 'Bacteroidia',
#   'Order': 'Flavobacteriales',
#   'Family': 'Flavobacteriaceae',
#   'Genus': 'Psychroflexus',
#   'Species': ''},
#  'Salt_Pond_MetaG_R1_A_H2O_MG_DASTool_bins_maxbin.022.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Proteobacteria',
#   'Class': 'Gammaproteobacteria',
#   'Order': 'Nitrococcales',
#   'Family': 'Nitrococcaceae',
#   'Genus': 'Spiribacter',
#   'Species': ''},
#  'Salt_Pond_MetaG_R1_A_H2O_MG_DASTool_bins_metabat.6.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Bacteroidota',
#   'Class': 'Bacteroidia',
#   'Order': 'Flavobacteriales',
#   'Family': 'Flavobacteriaceae',
#   'Genus': 'Psychroflexus',
#   'Species': ''},
#  'Salt_Pond_MetaG_R1_B_D1_MG_DASTool_bins_concoct_out.53.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Bacteroidota',
#   'Class': 'Rhodothermia',
#   'Order': 'Balneolales',
#   'Family': 'Balneolaceae',
#   'Genus': 'Gracilimonas',
#   'Species': ''},
#  'Salt_Pond_MetaG_R1_B_D1_MG_DASTool_bins_concoct_out.59.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Firmicutes_F',
#   'Class': 'Halanaerobiia',
#   'Order': 'Halanaerobiales',
#   'Family': 'Halanaerobiaceae',
#   'Genus': 'Halanaerobium',
#   'Species': ''},
#  'Salt_Pond_MetaG_R1_B_D1_MG_DASTool_bins_concoct_out.89.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Bacteroidota',
#   'Class': 'Bacteroidia',
#   'Order': 'Flavobacteriales',
#   'Family': 'Flavobacteriaceae',
#   'Genus': 'Psychroflexus',
#   'Species': ''},
#  'Salt_Pond_MetaG_R1_B_D1_MG_DASTool_bins_metabat.13.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Bacteroidota',
#   'Class': 'Rhodothermia',
#   'Order': 'Balneolales',
#   'Family': 'Balneolaceae',
#   'Genus': '',
#   'Species': ''},
#  'Salt_Pond_MetaG_R1_B_D1_MG_DASTool_bins_metabat.16.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Actinobacteriota',
#   'Class': 'Acidimicrobiia',
#   'Order': 'Acidimicrobiales',
#   'Family': 'Ilumatobacteraceae',
#   'Genus': 'JABSQH01',
#   'Species': ''},
#  'Salt_Pond_MetaG_R1_B_D1_MG_DASTool_bins_metabat.20.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Proteobacteria',
#   'Class': 'Alphaproteobacteria',
#   'Order': 'Rhodobacterales',
#   'Family': 'Rhodobacteraceae',
#   'Genus': 'IMCC34051',
#   'Species': ''},
#  'Salt_Pond_MetaG_R1_B_D1_MG_DASTool_bins_metabat.28.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Bacteroidota',
#   'Class': 'Bacteroidia',
#   'Order': 'Chitinophagales',
#   'Family': 'Saprospiraceae',
#   'Genus': '',
#   'Species': ''},
#  'Salt_Pond_MetaG_R1_B_D1_MG_DASTool_bins_metabat.29.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Proteobacteria',
#   'Class': 'Gammaproteobacteria',
#   'Order': 'Xanthomonadales',
#   'Family': 'Wenzhouxiangellaceae',
#   'Genus': 'GCA-2722315',
#   'Species': ''},
#  'Salt_Pond_MetaG_R1_B_D1_MG_DASTool_bins_metabat.32.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Proteobacteria',
#   'Class': 'Alphaproteobacteria',
#   'Order': 'Rhodobacterales',
#   'Family': 'Rhodobacteraceae',
#   'Genus': 'Roseovarius',
#   'Species': ''},
#  'Salt_Pond_MetaG_R1_B_D1_MG_DASTool_bins_metabat.38.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Proteobacteria',
#   'Class': 'Gammaproteobacteria',
#   'Order': 'Xanthomonadales',
#   'Family': 'Wenzhouxiangellaceae',
#   'Genus': 'GCA-2722315',
#   'Species': ''},
#  'Salt_Pond_MetaG_R1_B_D1_MG_DASTool_bins_metabat.40.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Proteobacteria',
#   'Class': 'Alphaproteobacteria',
#   'Order': 'Rhodobacterales',
#   'Family': 'Rhodobacteraceae',
#   'Genus': 'HLUCCA08',
#   'Species': ''},
#  'Salt_Pond_MetaG_R1_B_D1_MG_DASTool_bins_metabat.41.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Deinococcota',
#   'Class': 'Deinococci',
#   'Order': 'Deinococcales',
#   'Family': 'Trueperaceae',
#   'Genus': 'SLSQ01',
#   'Species': ''},
#  'Salt_Pond_MetaG_R1_B_D1_MG_DASTool_bins_metabat.49.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Spirochaetota',
#   'Class': 'Spirochaetia',
#   'Order': 'DSM-16054',
#   'Family': 'Sediminispirochaetaceae',
#   'Genus': '',
#   'Species': ''},
#  'Salt_Pond_MetaG_R1_B_D1_MG_DASTool_bins_metabat.58.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Synergistota',
#   'Class': 'Synergistia',
#   'Order': 'Synergistales',
#   'Family': '',
#   'Genus': '',
#   'Species': ''},
#  'Salt_Pond_MetaG_R1_B_D2_MG_DASTool_bins_concoct_out.120.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Caldatribacteriota',
#   'Class': 'JS1',
#   'Order': 'SB-45',
#   'Family': 'UBA6794',
#   'Genus': '',
#   'Species': ''},
#  'Salt_Pond_MetaG_R1_B_D2_MG_DASTool_bins_concoct_out.37.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Proteobacteria',
#   'Class': 'Alphaproteobacteria',
#   'Order': 'Rhodobacterales',
#   'Family': 'Rhodobacteraceae',
#   'Genus': 'Marivita',
#   'Species': ''},
#  'Salt_Pond_MetaG_R1_B_D2_MG_DASTool_bins_concoct_out.51.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Proteobacteria',
#   'Class': 'Alphaproteobacteria',
#   'Order': 'Rhodobacterales',
#   'Family': 'Rhodobacteraceae',
#   'Genus': 'Roseovarius',
#   'Species': ''},
#  'Salt_Pond_MetaG_R1_B_D2_MG_DASTool_bins_concoct_out.73.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Firmicutes_F',
#   'Class': 'Halanaerobiia',
#   'Order': 'Halanaerobiales',
#   'Family': 'Halanaerobiaceae',
#   'Genus': 'Halanaerobium',
#   'Species': ''},
#  'Salt_Pond_MetaG_R1_B_D2_MG_DASTool_bins_concoct_out.86.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Bacteroidota',
#   'Class': 'Bacteroidia',
#   'Order': 'Chitinophagales',
#   'Family': 'Saprospiraceae',
#   'Genus': '',
#   'Species': ''},
#  'Salt_Pond_MetaG_R1_B_D2_MG_DASTool_bins_concoct_out.87.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Bacteroidota',
#   'Class': 'Bacteroidia',
#   'Order': 'Flavobacteriales',
#   'Family': 'Flavobacteriaceae',
#   'Genus': 'Salegentibacter',
#   'Species': ''},
#  'Salt_Pond_MetaG_R1_B_D2_MG_DASTool_bins_maxbin.014.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Proteobacteria',
#   'Class': 'Gammaproteobacteria',
#   'Order': 'Pseudomonadales',
#   'Family': 'Halieaceae',
#   'Genus': 'Chromatocurvus',
#   'Species': ''},
#  'Salt_Pond_MetaG_R1_B_D2_MG_DASTool_bins_metabat.14.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Bacteroidota',
#   'Class': 'Rhodothermia',
#   'Order': 'Balneolales',
#   'Family': 'Balneolaceae',
#   'Genus': 'SW132',
#   'Species': ''},
#  'Salt_Pond_MetaG_R1_B_D2_MG_DASTool_bins_metabat.16.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Proteobacteria',
#   'Class': 'Gammaproteobacteria',
#   'Order': 'Woeseiales',
#   'Family': 'Woeseiaceae',
#   'Genus': '',
#   'Species': ''},
#  'Salt_Pond_MetaG_R1_B_D2_MG_DASTool_bins_metabat.18.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Proteobacteria',
#   'Class': 'Alphaproteobacteria',
#   'Order': 'Rhodobacterales',
#   'Family': 'Rhodobacteraceae',
#   'Genus': 'Roseovarius',
#   'Species': ''},
#  'Salt_Pond_MetaG_R1_B_D2_MG_DASTool_bins_metabat.19.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Spirochaetota',
#   'Class': 'Spirochaetia',
#   'Order': 'DSM-16054',
#   'Family': 'Sediminispirochaetaceae',
#   'Genus': 'DSBN01',
#   'Species': ''},
#  'Salt_Pond_MetaG_R1_B_D2_MG_DASTool_bins_metabat.27.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Gemmatimonadota',
#   'Class': 'Gemmatimonadetes',
#   'Order': 'Longimicrobiales',
#   'Family': 'UBA6960',
#   'Genus': '',
#   'Species': ''},
#  'Salt_Pond_MetaG_R1_B_D2_MG_DASTool_bins_metabat.28.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Proteobacteria',
#   'Class': 'Alphaproteobacteria',
#   'Order': 'Rhodobacterales',
#   'Family': 'Rhodobacteraceae',
#   'Genus': 'Marivita',
#   'Species': ''},
#  'Salt_Pond_MetaG_R1_B_D2_MG_DASTool_bins_metabat.30.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Desulfobacterota_F',
#   'Class': 'Desulfuromonadia',
#   'Order': 'Desulfuromonadales',
#   'Family': 'BM103',
#   'Genus': '',
#   'Species': ''},
#  'Salt_Pond_MetaG_R1_B_D2_MG_DASTool_bins_metabat.34.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Bacteroidota',
#   'Class': 'Bacteroidia',
#   'Order': 'Flavobacteriales',
#   'Family': 'Flavobacteriaceae',
#   'Genus': 'Muricauda',
#   'Species': ''},
#  'Salt_Pond_MetaG_R1_B_D2_MG_DASTool_bins_metabat.37.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Bacteroidota',
#   'Class': 'Bacteroidia',
#   'Order': 'Flavobacteriales',
#   'Family': 'Cryomorphaceae',
#   'Genus': 'Cryomorpha',
#   'Species': ''},
#  'Salt_Pond_MetaG_R1_B_D2_MG_DASTool_bins_metabat.63.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Firmicutes_A',
#   'Class': 'Clostridia',
#   'Order': 'Peptostreptococcales',
#   'Family': 'Anaerovoracaceae',
#   'Genus': 'JAAYHV01',
#   'Species': ''},
#  'Salt_Pond_MetaG_R1_B_D2_MG_DASTool_bins_metabat.78.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Patescibacteria',
#   'Class': 'ABY1',
#   'Order': 'BM507',
#   'Family': '',
#   'Genus': '',
#   'Species': ''},
#  'Salt_Pond_MetaG_R1_B_H2O_MG_DASTool_bins_concoct_out.13.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Bacteroidota',
#   'Class': 'Bacteroidia',
#   'Order': 'Flavobacteriales',
#   'Family': 'Schleiferiaceae',
#   'Genus': '',
#   'Species': ''},
#  'Salt_Pond_MetaG_R1_B_H2O_MG_DASTool_bins_concoct_out.19.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Actinobacteriota',
#   'Class': 'Actinomycetia',
#   'Order': 'Actinomycetales',
#   'Family': 'Microbacteriaceae',
#   'Genus': '',
#   'Species': ''},
#  'Salt_Pond_MetaG_R1_B_H2O_MG_DASTool_bins_concoct_out.22.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Proteobacteria',
#   'Class': 'Gammaproteobacteria',
#   'Order': 'Halothiobacillales',
#   'Family': 'Halothiobacillaceae',
#   'Genus': 'Guyparkeria',
#   'Species': ''},
#  'Salt_Pond_MetaG_R1_B_H2O_MG_DASTool_bins_maxbin.028.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Proteobacteria',
#   'Class': 'Gammaproteobacteria',
#   'Order': 'Nitrococcales',
#   'Family': 'Nitrococcaceae',
#   'Genus': 'Spiribacter',
#   'Species': ''},
#  'Salt_Pond_MetaG_R1_B_H2O_MG_DASTool_bins_metabat.11.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Bacteroidota',
#   'Class': 'Bacteroidia',
#   'Order': 'Flavobacteriales',
#   'Family': 'Flavobacteriaceae',
#   'Genus': 'Psychroflexus',
#   'Species': ''},
#  'Salt_Pond_MetaG_R1_B_H2O_MG_DASTool_bins_metabat.5.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Proteobacteria',
#   'Class': 'Gammaproteobacteria',
#   'Order': 'Pseudomonadales',
#   'Family': 'Halomonadaceae',
#   'Genus': 'Halomonas',
#   'Species': ''},
#  'Salt_Pond_MetaG_R1_B_H2O_MG_DASTool_bins_metabat.7.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Proteobacteria',
#   'Class': 'Gammaproteobacteria',
#   'Order': 'Thiotrichales',
#   'Family': 'Thiotrichaceae',
#   'Genus': 'Thiolinea',
#   'Species': ''},
#  'Salt_Pond_MetaG_R1_C_D1_MG_DASTool_bins_concoct_out.45.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Spirochaetota',
#   'Class': 'Spirochaetia',
#   'Order': 'DSM-16054',
#   'Family': 'Sediminispirochaetaceae',
#   'Genus': '',
#   'Species': ''},
#  'Salt_Pond_MetaG_R1_C_D1_MG_DASTool_bins_maxbin.047.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Firmicutes_A',
#   'Class': 'Clostridia',
#   'Order': 'Peptostreptococcales',
#   'Family': 'BM714',
#   'Genus': 'BM714',
#   'Species': ''},
#  'Salt_Pond_MetaG_R1_C_D1_MG_DASTool_bins_metabat.19.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Bacteroidota',
#   'Class': 'Bacteroidia',
#   'Order': 'Chitinophagales',
#   'Family': 'Saprospiraceae',
#   'Genus': '',
#   'Species': ''},
#  'Salt_Pond_MetaG_R1_C_D1_MG_DASTool_bins_metabat.27.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Desulfobacterota',
#   'Class': 'Desulfobacteria',
#   'Order': 'Desulfobacterales',
#   'Family': 'Desulfobacteraceae',
#   'Genus': 'Desulfobacter',
#   'Species': ''},
#  'Salt_Pond_MetaG_R1_C_D2_MG_DASTool_bins_concoct_out.36.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Planctomycetota',
#   'Class': 'Planctomycetes',
#   'Order': 'Pirellulales',
#   'Family': 'Pirellulaceae',
#   'Genus': 'Roseimaritima',
#   'Species': ''},
#  'Salt_Pond_MetaG_R1_C_D2_MG_DASTool_bins_concoct_out.85.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Firmicutes_A',
#   'Class': 'Clostridia',
#   'Order': 'Tissierellales',
#   'Family': 'Dethiosulfatibacteraceae',
#   'Genus': 'UBA8670',
#   'Species': ''},
#  'Salt_Pond_MetaG_R1_C_D2_MG_DASTool_bins_metabat.30.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Bacteroidota',
#   'Class': 'Rhodothermia',
#   'Order': 'Balneolales',
#   'Family': 'Balneolaceae',
#   'Genus': '',
#   'Species': ''},
#  'Salt_Pond_MetaG_R1_C_D2_MG_DASTool_bins_metabat.40.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Firmicutes_F',
#   'Class': 'Halanaerobiia',
#   'Order': 'Halanaerobiales',
#   'Family': '',
#   'Genus': '',
#   'Species': ''},
#  'Salt_Pond_MetaG_R1_C_D2_MG_DASTool_bins_metabat.58.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Patescibacteria',
#   'Class': 'Paceibacteria',
#   'Order': 'Paceibacterales',
#   'Family': '',
#   'Genus': '',
#   'Species': ''},
#  'Salt_Pond_MetaG_R1_C_H2O_MG_DASTool_bins_concoct_out.16.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Mcinerneyibacteriota',
#   'Class': 'Mcinerneyibacteria',
#   'Order': 'Mcinerneyibacteriales',
#   'Family': 'Mcinerneyibacteriaceae',
#   'Genus': 'Mcinerneyibacterium',
#   'Species': ''},
#  'Salt_Pond_MetaG_R1_C_H2O_MG_DASTool_bins_concoct_out.67.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Proteobacteria',
#   'Class': 'Gammaproteobacteria',
#   'Order': 'Nitrococcales',
#   'Family': 'Nitrococcaceae',
#   'Genus': 'Spiribacter',
#   'Species': ''},
#  'Salt_Pond_MetaG_R1_C_H2O_MG_DASTool_bins_concoct_out.79.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Proteobacteria',
#   'Class': 'Alphaproteobacteria',
#   'Order': 'Rhodobacterales',
#   'Family': 'Rhodobacteraceae',
#   'Genus': 'Roseovarius',
#   'Species': ''},
#  'Salt_Pond_MetaG_R1_C_H2O_MG_DASTool_bins_metabat.23.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Proteobacteria',
#   'Class': 'Gammaproteobacteria',
#   'Order': 'Nitrococcales',
#   'Family': 'Nitrococcaceae',
#   'Genus': 'Spiribacter',
#   'Species': ''},
#  'Salt_Pond_MetaG_R2_A_D1_MG_DASTool_bins_concoct_out.119.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Thermotogota',
#   'Class': 'Thermotogae',
#   'Order': 'MWEM01',
#   'Family': '',
#   'Genus': '',
#   'Species': ''},
#  'Salt_Pond_MetaG_R2_A_D1_MG_DASTool_bins_concoct_out.29.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Proteobacteria',
#   'Class': 'Gammaproteobacteria',
#   'Order': 'Xanthomonadales',
#   'Family': 'Wenzhouxiangellaceae',
#   'Genus': 'Wenzhouxiangella',
#   'Species': ''},
#  'Salt_Pond_MetaG_R2_A_D1_MG_DASTool_bins_concoct_out.35.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Proteobacteria',
#   'Class': 'Alphaproteobacteria',
#   'Order': 'Rhizobiales',
#   'Family': 'Beijerinckiaceae',
#   'Genus': 'Salinarimonas',
#   'Species': ''},
#  'Salt_Pond_MetaG_R2_A_D1_MG_DASTool_bins_concoct_out.49.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Proteobacteria',
#   'Class': 'Alphaproteobacteria',
#   'Order': 'Rhodobacterales',
#   'Family': 'Rhodobacteraceae',
#   'Genus': 'Roseovarius',
#   'Species': ''},
#  'Salt_Pond_MetaG_R2_A_D1_MG_DASTool_bins_concoct_out.52.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Spirochaetota',
#   'Class': 'UBA12135',
#   'Order': 'UBA12135',
#   'Family': '',
#   'Genus': '',
#   'Species': ''},
#  'Salt_Pond_MetaG_R2_A_D1_MG_DASTool_bins_concoct_out.66.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Krumholzibacteriota',
#   'Class': 'Krumholzibacteria',
#   'Order': 'Krumholzibacteriales',
#   'Family': 'Krumholzibacteriaceae',
#   'Genus': '',
#   'Species': ''},
#  'Salt_Pond_MetaG_R2_A_D1_MG_DASTool_bins_concoct_out.84.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Desulfobacterota',
#   'Class': 'Desulfobacteria',
#   'Order': 'Desulfobacterales',
#   'Family': 'SURF-3',
#   'Genus': '',
#   'Species': ''},
#  'Salt_Pond_MetaG_R2_A_D1_MG_DASTool_bins_concoct_out.93.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Patescibacteria',
#   'Class': 'ABY1',
#   'Order': 'BM507',
#   'Family': 'BM507',
#   'Genus': '',
#   'Species': ''},
#  'Salt_Pond_MetaG_R2_A_D1_MG_DASTool_bins_concoct_out.98.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Synergistota',
#   'Class': 'Synergistia',
#   'Order': 'Synergistales',
#   'Family': '',
#   'Genus': '',
#   'Species': ''},
#  'Salt_Pond_MetaG_R2_A_D1_MG_DASTool_bins_maxbin.001.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Actinobacteriota',
#   'Class': 'Actinomycetia',
#   'Order': 'Nanopelagicales',
#   'Family': 'S36-B12',
#   'Genus': 'S36-B12',
#   'Species': ''},
#  'Salt_Pond_MetaG_R2_A_D1_MG_DASTool_bins_metabat.10.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Bacteroidota',
#   'Class': 'Rhodothermia',
#   'Order': 'Balneolales',
#   'Family': 'Balneolaceae',
#   'Genus': 'Rhodohalobacter',
#   'Species': ''},
#  'Salt_Pond_MetaG_R2_A_D1_MG_DASTool_bins_metabat.12.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Proteobacteria',
#   'Class': 'Gammaproteobacteria',
#   'Order': 'Xanthomonadales',
#   'Family': 'Wenzhouxiangellaceae',
#   'Genus': 'GCA-2722315',
#   'Species': ''},
#  'Salt_Pond_MetaG_R2_A_D1_MG_DASTool_bins_metabat.24.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Bacteroidota',
#   'Class': 'Bacteroidia',
#   'Order': 'Bacteroidales',
#   'Family': 'UBA12077',
#   'Genus': '',
#   'Species': ''},
#  'Salt_Pond_MetaG_R2_A_D1_MG_DASTool_bins_metabat.32.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Desulfobacterota',
#   'Class': 'Desulfobacteria',
#   'Order': 'Desulfobacterales',
#   'Family': 'SURF-3',
#   'Genus': '',
#   'Species': ''},
#  'Salt_Pond_MetaG_R2_A_D1_MG_DASTool_bins_metabat.50.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Proteobacteria',
#   'Class': 'Gammaproteobacteria',
#   'Order': 'PWYM01',
#   'Family': 'PWYM01',
#   'Genus': '',
#   'Species': ''},
#  'Salt_Pond_MetaG_R2_A_D1_MG_DASTool_bins_metabat.61.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Bipolaricaulota',
#   'Class': 'Bipolaricaulia',
#   'Order': '',
#   'Family': '',
#   'Genus': '',
#   'Species': ''},
#  'Salt_Pond_MetaG_R2_A_D1_MG_DASTool_bins_metabat.7.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Spirochaetota',
#   'Class': 'Spirochaetia',
#   'Order': 'DSM-16054',
#   'Family': 'Sediminispirochaetaceae',
#   'Genus': '',
#   'Species': ''},
#  'Salt_Pond_MetaG_R2_A_D1_MG_DASTool_bins_metabat.9.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Spirochaetota',
#   'Class': 'Spirochaetia',
#   'Order': 'DSM-16054',
#   'Family': 'Sediminispirochaetaceae',
#   'Genus': '',
#   'Species': ''},
#  'Salt_Pond_MetaG_R2_B_D1_MG_DASTool_bins_concoct_out.110.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Proteobacteria',
#   'Class': 'Gammaproteobacteria',
#   'Order': 'Pseudomonadales',
#   'Family': 'Oleiphilaceae',
#   'Genus': 'Marinobacter',
#   'Species': ''},
#  'Salt_Pond_MetaG_R2_B_D1_MG_DASTool_bins_concoct_out.40.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Bacteroidota',
#   'Class': 'Bacteroidia',
#   'Order': 'Bacteroidales',
#   'Family': 'Prolixibacteraceae',
#   'Genus': 'Tangfeifania',
#   'Species': ''},
#  'Salt_Pond_MetaG_R2_B_D1_MG_DASTool_bins_metabat.10.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Bacteroidota',
#   'Class': 'Rhodothermia',
#   'Order': 'Balneolales',
#   'Family': 'Balneolaceae',
#   'Genus': 'SW132',
#   'Species': ''},
#  'Salt_Pond_MetaG_R2_B_D1_MG_DASTool_bins_metabat.13.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Proteobacteria',
#   'Class': 'Alphaproteobacteria',
#   'Order': 'Rhodobacterales',
#   'Family': 'Rhodobacteraceae',
#   'Genus': '',
#   'Species': ''},
#  'Salt_Pond_MetaG_R2_B_D1_MG_DASTool_bins_metabat.22.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Proteobacteria',
#   'Class': 'Gammaproteobacteria',
#   'Order': 'Xanthomonadales',
#   'Family': 'Wenzhouxiangellaceae',
#   'Genus': 'GCA-2722315',
#   'Species': ''},
#  'Salt_Pond_MetaG_R2_B_D2_MG_DASTool_bins_concoct_out.124.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Proteobacteria',
#   'Class': 'Gammaproteobacteria',
#   'Order': 'Pseudomonadales',
#   'Family': 'Halieaceae',
#   'Genus': 'Halioglobus',
#   'Species': ''},
#  'Salt_Pond_MetaG_R2_B_D2_MG_DASTool_bins_concoct_out.143.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Proteobacteria',
#   'Class': 'Alphaproteobacteria',
#   'Order': 'Rhodobacterales',
#   'Family': 'Rhodobacteraceae',
#   'Genus': 'Roseovarius',
#   'Species': ''},
#  'Salt_Pond_MetaG_R2_B_D2_MG_DASTool_bins_concoct_out.32.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Proteobacteria',
#   'Class': 'Alphaproteobacteria',
#   'Order': 'Rhodobacterales',
#   'Family': 'Rhodobacteraceae',
#   'Genus': 'Maliponia',
#   'Species': ''},
#  'Salt_Pond_MetaG_R2_B_D2_MG_DASTool_bins_concoct_out.39.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Proteobacteria',
#   'Class': 'Gammaproteobacteria',
#   'Order': 'Woeseiales',
#   'Family': 'Woeseiaceae',
#   'Genus': '',
#   'Species': ''},
#  'Salt_Pond_MetaG_R2_B_D2_MG_DASTool_bins_concoct_out.4.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Planctomycetota',
#   'Class': 'Planctomycetes',
#   'Order': 'Pirellulales',
#   'Family': 'Pirellulaceae',
#   'Genus': 'Crateriforma',
#   'Species': ''},
#  'Salt_Pond_MetaG_R2_B_D2_MG_DASTool_bins_concoct_out.80.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Spirochaetota',
#   'Class': 'UBA4802',
#   'Order': 'UBA4802',
#   'Family': '',
#   'Genus': '',
#   'Species': ''},
#  'Salt_Pond_MetaG_R2_B_D2_MG_DASTool_bins_metabat.10.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Proteobacteria',
#   'Class': 'Alphaproteobacteria',
#   'Order': 'Rhodobacterales',
#   'Family': 'Rhodobacteraceae',
#   'Genus': 'Marivita',
#   'Species': ''},
#  'Salt_Pond_MetaG_R2_B_D2_MG_DASTool_bins_metabat.16.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Proteobacteria',
#   'Class': 'Alphaproteobacteria',
#   'Order': 'Rhodobacterales',
#   'Family': 'Rhodobacteraceae',
#   'Genus': 'Roseovarius',
#   'Species': ''},
#  'Salt_Pond_MetaG_R2_B_D2_MG_DASTool_bins_metabat.19.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Proteobacteria',
#   'Class': 'Alphaproteobacteria',
#   'Order': 'Rhodobacterales',
#   'Family': 'Rhodobacteraceae',
#   'Genus': 'Roseicyclus',
#   'Species': ''},
#  'Salt_Pond_MetaG_R2_B_D2_MG_DASTool_bins_metabat.20.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Bacteroidota',
#   'Class': 'Bacteroidia',
#   'Order': 'Bacteroidales',
#   'Family': 'Salinivirgaceae',
#   'Genus': 'Salinivirga',
#   'Species': ''},
#  'Salt_Pond_MetaG_R2_B_D2_MG_DASTool_bins_metabat.38.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Proteobacteria',
#   'Class': 'Alphaproteobacteria',
#   'Order': 'Rhodobacterales',
#   'Family': 'Rhodobacteraceae',
#   'Genus': 'Roseovarius',
#   'Species': ''},
#  'Salt_Pond_MetaG_R2_B_D2_MG_DASTool_bins_metabat.43.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Actinobacteriota',
#   'Class': 'Actinomycetia',
#   'Order': 'Nitriliruptorales',
#   'Family': 'Nitriliruptoraceae',
#   'Genus': 'T1Sed10-7',
#   'Species': ''},
#  'Salt_Pond_MetaG_R2_B_D2_MG_DASTool_bins_metabat.44.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Desulfobacterota',
#   'Class': 'Desulfobacteria',
#   'Order': 'Desulfobacterales',
#   'Family': 'SURF-3',
#   'Genus': '',
#   'Species': ''},
#  'Salt_Pond_MetaG_R2_B_D2_MG_DASTool_bins_metabat.45.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Desulfobacterota_F',
#   'Class': 'Desulfuromonadia',
#   'Order': 'Desulfuromonadales',
#   'Family': 'Geopsychrobacteraceae',
#   'Genus': 'SLDV01',
#   'Species': ''},
#  'Salt_Pond_MetaG_R2_B_D2_MG_DASTool_bins_metabat.50.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Proteobacteria',
#   'Class': 'Gammaproteobacteria',
#   'Order': 'PWYM01',
#   'Family': 'PWYM01',
#   'Genus': 'XN24',
#   'Species': ''},
#  'Salt_Pond_MetaG_R2_B_D2_MG_DASTool_bins_metabat.52.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Firmicutes_F',
#   'Class': 'Halanaerobiia',
#   'Order': 'Halanaerobiales',
#   'Family': '',
#   'Genus': '',
#   'Species': ''},
#  'Salt_Pond_MetaG_R2_B_D2_MG_DASTool_bins_metabat.55.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Proteobacteria',
#   'Class': 'Alphaproteobacteria',
#   'Order': 'Rhodobacterales',
#   'Family': 'Rhodobacteraceae',
#   'Genus': 'Roseovarius',
#   'Species': ''},
#  'Salt_Pond_MetaG_R2_B_D2_MG_DASTool_bins_metabat.62.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Desulfobacterota',
#   'Class': 'Desulfovibrionia',
#   'Order': 'Desulfovibrionales',
#   'Family': 'Desulfohalobiaceae',
#   'Genus': '',
#   'Species': ''},
#  'Salt_Pond_MetaG_R2_C_D1_MG_DASTool_bins_concoct_out.118.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Spirochaetota',
#   'Class': 'Spirochaetia',
#   'Order': 'Spirochaetales_C',
#   'Family': 'Alkalispirochaetaceae',
#   'Genus': 'Alkalispirochaeta',
#   'Species': ''},
#  'Salt_Pond_MetaG_R2_C_D1_MG_DASTool_bins_concoct_out.37.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Desulfobacterota',
#   'Class': 'Desulfovibrionia',
#   'Order': 'Desulfovibrionales',
#   'Family': 'Desulfomicrobiaceae',
#   'Genus': '',
#   'Species': ''},
#  'Salt_Pond_MetaG_R2_C_D1_MG_DASTool_bins_concoct_out.65.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Proteobacteria',
#   'Class': 'Gammaproteobacteria',
#   'Order': 'Pseudomonadales',
#   'Family': 'Oleiphilaceae',
#   'Genus': 'Marinobacter',
#   'Species': ''},
#  'Salt_Pond_MetaG_R2_C_D1_MG_DASTool_bins_concoct_out.7.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Bacteroidota',
#   'Class': 'Bacteroidia',
#   'Order': 'Chitinophagales',
#   'Family': 'Saprospiraceae',
#   'Genus': 'DT-110',
#   'Species': ''},
#  'Salt_Pond_MetaG_R2_C_D1_MG_DASTool_bins_concoct_out.71.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Bacteroidota',
#   'Class': 'Bacteroidia',
#   'Order': 'Chitinophagales',
#   'Family': 'Saprospiraceae',
#   'Genus': 'DT-110',
#   'Species': ''},
#  'Salt_Pond_MetaG_R2_C_D1_MG_DASTool_bins_concoct_out.88.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Bacteroidota',
#   'Class': 'Bacteroidia',
#   'Order': 'Chitinophagales',
#   'Family': 'Saprospiraceae',
#   'Genus': 'Phaeodactylibacter',
#   'Species': ''},
#  'Salt_Pond_MetaG_R2_C_D1_MG_DASTool_bins_concoct_out.95.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Desulfobacterota',
#   'Class': 'Desulfobacteria',
#   'Order': 'Desulfobacterales',
#   'Family': 'Desulfobacteraceae',
#   'Genus': 'Desulfotignum',
#   'Species': ''},
#  'Salt_Pond_MetaG_R2_C_D1_MG_DASTool_bins_concoct_out.98.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Bacteroidota',
#   'Class': 'Bacteroidia',
#   'Order': 'Bacteroidales',
#   'Family': 'GCA-2748055',
#   'Genus': '',
#   'Species': ''},
#  'Salt_Pond_MetaG_R2_C_D1_MG_DASTool_bins_maxbin.062.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Desulfobacterota',
#   'Class': 'Desulfobacteria',
#   'Order': 'Desulfobacterales',
#   'Family': 'Desulfobacteraceae',
#   'Genus': '4572-130',
#   'Species': ''},
#  'Salt_Pond_MetaG_R2_C_D1_MG_DASTool_bins_metabat.17.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Proteobacteria',
#   'Class': 'Alphaproteobacteria',
#   'Order': 'Rhodobacterales',
#   'Family': 'Rhodobacteraceae',
#   'Genus': 'Roseovarius',
#   'Species': ''},
#  'Salt_Pond_MetaG_R2_C_D1_MG_DASTool_bins_metabat.25.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Proteobacteria',
#   'Class': 'Gammaproteobacteria',
#   'Order': 'Woeseiales',
#   'Family': 'Woeseiaceae',
#   'Genus': '',
#   'Species': ''},
#  'Salt_Pond_MetaG_R2_C_D1_MG_DASTool_bins_metabat.7.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Krumholzibacteriota',
#   'Class': 'Krumholzibacteria',
#   'Order': '',
#   'Family': '',
#   'Genus': '',
#   'Species': ''},
#  'Salt_Pond_MetaG_R2_C_D2_MG_DASTool_bins_concoct_out.100.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Bacteroidota',
#   'Class': 'Bacteroidia',
#   'Order': 'Flavobacteriales',
#   'Family': 'Flavobacteriaceae',
#   'Genus': 'Maribacter',
#   'Species': ''},
#  'Salt_Pond_MetaG_R2_C_D2_MG_DASTool_bins_concoct_out.104.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Bacteroidota',
#   'Class': 'Bacteroidia',
#   'Order': 'Bacteroidales',
#   'Family': 'UBA7960',
#   'Genus': '',
#   'Species': ''},
#  'Salt_Pond_MetaG_R2_C_D2_MG_DASTool_bins_concoct_out.18.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Proteobacteria',
#   'Class': 'Alphaproteobacteria',
#   'Order': 'Rhodobacterales',
#   'Family': 'Rhodobacteraceae',
#   'Genus': 'Roseicyclus',
#   'Species': ''},
#  'Salt_Pond_MetaG_R2_C_D2_MG_DASTool_bins_concoct_out.21.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Marinisomatota',
#   'Class': 'UBA2242',
#   'Order': 'UBA2242',
#   'Family': '',
#   'Genus': '',
#   'Species': ''},
#  'Salt_Pond_MetaG_R2_C_D2_MG_DASTool_bins_concoct_out.45.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Proteobacteria',
#   'Class': 'Alphaproteobacteria',
#   'Order': 'Rhodobacterales',
#   'Family': 'Rhodobacteraceae',
#   'Genus': 'Roseovarius',
#   'Species': ''},
#  'Salt_Pond_MetaG_R2_C_D2_MG_DASTool_bins_concoct_out.47.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Proteobacteria',
#   'Class': 'Alphaproteobacteria',
#   'Order': 'Rhodobacterales',
#   'Family': 'Rhodobacteraceae',
#   'Genus': 'Roseovarius',
#   'Species': ''},
#  'Salt_Pond_MetaG_R2_restored_C_black_MG_DASTool_bins_concoct_out.12.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Verrucomicrobiota',
#   'Class': 'Verrucomicrobiae',
#   'Order': 'Opitutales',
#   'Family': '',
#   'Genus': '',
#   'Species': ''},
#  'Salt_Pond_MetaG_R2_restored_C_black_MG_DASTool_bins_concoct_out.17.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Desulfobacterota',
#   'Class': 'Desulfobacteria',
#   'Order': 'Desulfobacterales',
#   'Family': 'Desulfobacteraceae',
#   'Genus': 'Desulfotignum',
#   'Species': ''},
#  'Salt_Pond_MetaG_R2_restored_C_black_MG_DASTool_bins_concoct_out.25.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Desulfobacterota',
#   'Class': 'Desulfobacteria',
#   'Order': 'Desulfobacterales',
#   'Family': 'Desulfobacteraceae',
#   'Genus': 'Desulfobacter',
#   'Species': ''},
#  'Salt_Pond_MetaG_R2_restored_C_black_MG_DASTool_bins_concoct_out.26.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Bacteroidota',
#   'Class': 'Bacteroidia',
#   'Order': 'Bacteroidales',
#   'Family': 'UBA12170',
#   'Genus': '',
#   'Species': ''},
#  'Salt_Pond_MetaG_R2_restored_C_black_MG_DASTool_bins_concoct_out.43.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Bacteroidota',
#   'Class': 'Bacteroidia',
#   'Order': 'Flavobacteriales',
#   'Family': 'Cryomorphaceae',
#   'Genus': 'Cryomorpha',
#   'Species': ''},
#  'Salt_Pond_MetaG_R2_restored_C_black_MG_DASTool_bins_concoct_out.51.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Bacteroidota',
#   'Class': 'Rhodothermia',
#   'Order': 'Balneolales',
#   'Family': 'Balneolaceae',
#   'Genus': '',
#   'Species': ''},
#  'Salt_Pond_MetaG_R2_restored_C_black_MG_DASTool_bins_concoct_out.57.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Verrucomicrobiota',
#   'Class': 'Verrucomicrobiae',
#   'Order': 'Opitutales',
#   'Family': 'DSM-45221',
#   'Genus': 'WN38',
#   'Species': ''},
#  'Salt_Pond_MetaG_R2_restored_C_black_MG_DASTool_bins_metabat.13.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Bacteroidota',
#   'Class': 'Bacteroidia',
#   'Order': 'Bacteroidales',
#   'Family': 'UBA12077',
#   'Genus': 'UBA12077',
#   'Species': ''},
#  'Salt_Pond_MetaG_R2_restored_C_black_MG_DASTool_bins_metabat.2.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Bacteroidota',
#   'Class': 'Bacteroidia',
#   'Order': 'Chitinophagales',
#   'Family': 'Saprospiraceae',
#   'Genus': '',
#   'Species': ''},
#  'Salt_Pond_MetaG_R2_restored_C_black_MG_DASTool_bins_metabat.22.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Spirochaetota',
#   'Class': 'Spirochaetia',
#   'Order': 'Spirochaetales_C',
#   'Family': 'SLST01',
#   'Genus': 'SLST01',
#   'Species': ''},
#  'Salt_Pond_MetaG_R2_restored_C_black_MG_DASTool_bins_metabat.8.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Proteobacteria',
#   'Class': 'Alphaproteobacteria',
#   'Order': 'Rhodobacterales',
#   'Family': 'Rhodobacteraceae',
#   'Genus': 'Albimonas',
#   'Species': ''},
#  'Salt_Pond_MetaG_R2_restored_DShore_MG_DASTool_bins_concoct_out.17.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Gemmatimonadota',
#   'Class': 'Gemmatimonadetes',
#   'Order': 'KS3-K002',
#   'Family': 'JABDQB01',
#   'Genus': '',
#   'Species': ''},
#  'Salt_Pond_MetaG_R2_restored_DShore_MG_DASTool_bins_concoct_out.2.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Proteobacteria',
#   'Class': 'Gammaproteobacteria',
#   'Order': 'Thiohalobacterales',
#   'Family': '',
#   'Genus': '',
#   'Species': ''},
#  'Salt_Pond_MetaG_R2_restored_DShore_MG_DASTool_bins_concoct_out.20.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Proteobacteria',
#   'Class': 'Gammaproteobacteria',
#   'Order': 'UBA4486',
#   'Family': 'UBA4486',
#   'Genus': '',
#   'Species': ''},
#  'Salt_Pond_MetaG_R2_restored_DShore_MG_DASTool_bins_concoct_out.21.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Proteobacteria',
#   'Class': 'Gammaproteobacteria',
#   'Order': 'Thiohalorhabdales',
#   'Family': 'Thiohalorhabdaceae',
#   'Genus': 'Thiohalorhabdus',
#   'Species': ''},
#  'Salt_Pond_MetaG_R2_restored_DShore_MG_DASTool_bins_concoct_out.38.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Proteobacteria',
#   'Class': 'Gammaproteobacteria',
#   'Order': 'Xanthomonadales',
#   'Family': '',
#   'Genus': '',
#   'Species': ''},
#  'Salt_Pond_MetaG_R2_restored_DShore_MG_DASTool_bins_concoct_out.46.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Spirochaetota',
#   'Class': 'Spirochaetia',
#   'Order': 'Spirochaetales_C',
#   'Family': 'PWMO01',
#   'Genus': '',
#   'Species': ''},
#  'Salt_Pond_MetaG_R2_restored_DShore_MG_DASTool_bins_concoct_out.68.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Gemmatimonadota',
#   'Class': 'Gemmatimonadetes',
#   'Order': 'KS3-K002',
#   'Family': '',
#   'Genus': '',
#   'Species': ''},
#  'Salt_Pond_MetaG_R2_restored_DShore_MG_DASTool_bins_concoct_out.7.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Proteobacteria',
#   'Class': 'Gammaproteobacteria',
#   'Order': 'Thiohalomonadales',
#   'Family': '',
#   'Genus': '',
#   'Species': ''},
#  'Salt_Pond_MetaG_R2_restored_DShore_MG_DASTool_bins_concoct_out.89.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Proteobacteria',
#   'Class': 'Gammaproteobacteria',
#   'Order': 'XJ16',
#   'Family': 'Halofilaceae',
#   'Genus': 'Halofilum',
#   'Species': ''},
#  'Salt_Pond_MetaG_R2_restored_DShore_MG_DASTool_bins_maxbin.037.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Marinisomatota',
#   'Class': '',
#   'Order': '',
#   'Family': '',
#   'Genus': '',
#   'Species': ''},
#  'Salt_Pond_MetaG_R2_restored_DShore_MG_DASTool_bins_metabat.11.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Bacteroidota',
#   'Class': 'Rhodothermia',
#   'Order': 'Balneolales',
#   'Family': 'Balneolaceae',
#   'Genus': '',
#   'Species': ''},
#  'Salt_Pond_MetaG_R2_restored_DShore_MG_DASTool_bins_metabat.13.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Marinisomatota',
#   'Class': '',
#   'Order': '',
#   'Family': '',
#   'Genus': '',
#   'Species': ''},
#  'Salt_Pond_MetaG_R2_restored_DShore_MG_DASTool_bins_metabat.15.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Marinisomatota',
#   'Class': '',
#   'Order': '',
#   'Family': '',
#   'Genus': '',
#   'Species': ''},
#  'Salt_Pond_MetaG_R2_restored_DShore_MG_DASTool_bins_metabat.18.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Proteobacteria',
#   'Class': 'Gammaproteobacteria',
#   'Order': 'Thiohalomonadales',
#   'Family': 'UBA6429',
#   'Genus': 'Thiohalophilus',
#   'Species': ''},
#  'Salt_Pond_MetaG_R2_restored_DShore_MG_DASTool_bins_metabat.23.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Proteobacteria',
#   'Class': 'Gammaproteobacteria',
#   'Order': 'XJ16',
#   'Family': 'Halofilaceae',
#   'Genus': 'Halofilum',
#   'Species': ''},
#  'Salt_Pond_MetaG_R2_restored_DShore_MG_DASTool_bins_metabat.25.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Proteobacteria',
#   'Class': 'Alphaproteobacteria',
#   'Order': '',
#   'Family': '',
#   'Genus': '',
#   'Species': ''},
#  'Salt_Pond_MetaG_R2_restored_DShore_MG_DASTool_bins_metabat.27.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Acidobacteriota',
#   'Class': 'Aminicenantia',
#   'Order': 'Aminicenantales',
#   'Family': '',
#   'Genus': '',
#   'Species': ''},
#  'Salt_Pond_MetaG_R2_restored_DShore_MG_DASTool_bins_metabat.8.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Bacteroidota',
#   'Class': 'Rhodothermia',
#   'Order': 'Balneolales',
#   'Family': 'Balneolaceae',
#   'Genus': '',
#   'Species': ''},
#  'Salt_Pond_MetaG_R2_restored_H2O_MG_DASTool_bins_concoct_out.34.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Actinobacteriota',
#   'Class': 'Actinomycetia',
#   'Order': 'Actinomycetales',
#   'Family': 'Microbacteriaceae',
#   'Genus': 'Pontimonas',
#   'Species': ''},
#  'Salt_Pond_MetaG_R2_restored_H2O_MG_DASTool_bins_concoct_out.44.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Actinobacteriota',
#   'Class': 'Actinomycetia',
#   'Order': 'Nanopelagicales',
#   'Family': 'S36-B12',
#   'Genus': 'S36-B12',
#   'Species': ''},
#  'Salt_Pond_MetaG_R2_restored_H2O_MG_DASTool_bins_maxbin.002.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Actinobacteriota',
#   'Class': 'Actinomycetia',
#   'Order': 'Nanopelagicales',
#   'Family': 'S36-B12',
#   'Genus': 'S36-B12',
#   'Species': ''},
#  'Salt_Pond_MetaG_R2_restored_H2O_MG_DASTool_bins_maxbin.005.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Proteobacteria',
#   'Class': 'Gammaproteobacteria',
#   'Order': 'Burkholderiales',
#   'Family': 'Burkholderiaceae',
#   'Genus': 'SCGC-AAA027-K21',
#   'Species': ''},
#  'Salt_Pond_MetaG_R2_restored_H2O_MG_DASTool_bins_maxbin.017.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Actinobacteriota',
#   'Class': 'Actinomycetia',
#   'Order': 'Nanopelagicales',
#   'Family': 'S36-B12',
#   'Genus': 'S36-B12',
#   'Species': ''},
#  'Salt_Pond_MetaG_R2A_A_D1_MG_DASTool_bins_concoct_out.24.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Actinobacteriota',
#   'Class': 'Actinomycetia',
#   'Order': 'Actinomycetales',
#   'Family': 'Dermatophilaceae',
#   'Genus': 'Ornithinicoccus_A',
#   'Species': ''},
#  'Salt_Pond_MetaG_R2A_A_D1_MG_DASTool_bins_concoct_out.42.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Bacteroidota',
#   'Class': 'Bacteroidia',
#   'Order': 'Flavobacteriales',
#   'Family': 'Flavobacteriaceae',
#   'Genus': 'Gramella',
#   'Species': ''},
#  'Salt_Pond_MetaG_R2A_A_D1_MG_DASTool_bins_concoct_out.46.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Chloroflexota',
#   'Class': 'Anaerolineae',
#   'Order': 'Anaerolineales',
#   'Family': 'EnvOPS12',
#   'Genus': 'UBA12294',
#   'Species': ''},
#  'Salt_Pond_MetaG_R2A_A_D1_MG_DASTool_bins_concoct_out.50.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Bacteroidota',
#   'Class': 'Bacteroidia',
#   'Order': 'Flavobacteriales',
#   'Family': 'Flavobacteriaceae',
#   'Genus': 'Lutibacter',
#   'Species': ''},
#  'Salt_Pond_MetaG_R2A_A_D1_MG_DASTool_bins_concoct_out.51.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Desulfobacterota_F',
#   'Class': 'Desulfuromonadia',
#   'Order': 'Desulfuromonadales',
#   'Family': 'Geopsychrobacteraceae',
#   'Genus': 'BM509',
#   'Species': ''},
#  'Salt_Pond_MetaG_R2A_A_D1_MG_DASTool_bins_concoct_out.6.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Proteobacteria',
#   'Class': 'Gammaproteobacteria',
#   'Order': 'Woeseiales',
#   'Family': 'Woeseiaceae',
#   'Genus': 'JAACFB01',
#   'Species': ''},
#  'Salt_Pond_MetaG_R2A_A_D1_MG_DASTool_bins_metabat.10.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Proteobacteria',
#   'Class': 'Gammaproteobacteria',
#   'Order': 'Xanthomonadales',
#   'Family': 'SZUA-36',
#   'Genus': '',
#   'Species': ''},
#  'Salt_Pond_MetaG_R2A_A_D1_MG_DASTool_bins_metabat.14.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Chloroflexota',
#   'Class': 'Anaerolineae',
#   'Order': 'Anaerolineales',
#   'Family': 'UBA11579',
#   'Genus': 'UBA11579',
#   'Species': ''},
#  'Salt_Pond_MetaG_R2A_A_D1_MG_DASTool_bins_metabat.17.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Actinobacteriota',
#   'Class': 'Actinomycetia',
#   'Order': 'Nitriliruptorales',
#   'Family': '',
#   'Genus': '',
#   'Species': ''},
#  'Salt_Pond_MetaG_R2A_A_D2_MG_DASTool_bins_concoct_out.10.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Acidobacteriota',
#   'Class': 'Thermoanaerobaculia',
#   'Order': 'UBA5704',
#   'Family': 'UBA5704',
#   'Genus': '',
#   'Species': ''},
#  'Salt_Pond_MetaG_R2A_A_D2_MG_DASTool_bins_concoct_out.25.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Bacteroidota',
#   'Class': 'Bacteroidia',
#   'Order': 'Flavobacteriales',
#   'Family': 'Flavobacteriaceae',
#   'Genus': '',
#   'Species': ''},
#  'Salt_Pond_MetaG_R2A_A_D2_MG_DASTool_bins_concoct_out.37.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Actinobacteriota',
#   'Class': 'Thermoleophilia',
#   'Order': 'Solirubrobacterales',
#   'Family': '70-9',
#   'Genus': '',
#   'Species': ''},
#  'Salt_Pond_MetaG_R2A_A_D2_MG_DASTool_bins_concoct_out.51.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Proteobacteria',
#   'Class': 'Gammaproteobacteria',
#   'Order': 'Xanthomonadales',
#   'Family': 'SZUA-36',
#   'Genus': 'SHZL01',
#   'Species': ''},
#  'Salt_Pond_MetaG_R2A_A_D2_MG_DASTool_bins_concoct_out.59.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Bacteroidota',
#   'Class': 'Rhodothermia',
#   'Order': 'Rhodothermales',
#   'Family': '',
#   'Genus': '',
#   'Species': ''},
#  'Salt_Pond_MetaG_R2A_A_D2_MG_DASTool_bins_metabat.7.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Bacteroidota',
#   'Class': 'Bacteroidia',
#   'Order': 'Flavobacteriales',
#   'Family': 'Flavobacteriaceae',
#   'Genus': '',
#   'Species': ''},
#  'Salt_Pond_MetaG_R2A_A_H2O_MG_DASTool_bins_concoct_out.62.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Actinobacteriota',
#   'Class': 'Actinomycetia',
#   'Order': 'Actinomycetales',
#   'Family': 'Microbacteriaceae',
#   'Genus': 'Aquiluna',
#   'Species': ''},
#  'Salt_Pond_MetaG_R2A_A_H2O_MG_DASTool_bins_concoct_out.78.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Bacteroidota',
#   'Class': 'Bacteroidia',
#   'Order': 'Flavobacteriales',
#   'Family': 'Flavobacteriaceae',
#   'Genus': 'MAG-120531',
#   'Species': ''},
#  'Salt_Pond_MetaG_R2A_A_H2O_MG_DASTool_bins_metabat.16.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Proteobacteria',
#   'Class': 'Gammaproteobacteria',
#   'Order': 'Pseudomonadales',
#   'Family': 'Halieaceae',
#   'Genus': 'IMCC3088',
#   'Species': ''},
#  'Salt_Pond_MetaG_R2A_A_H2O_MG_DASTool_bins_metabat.20.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Proteobacteria',
#   'Class': 'Gammaproteobacteria',
#   'Order': 'Pseudomonadales',
#   'Family': 'Nitrincolaceae',
#   'Genus': 'Marinobacterium',
#   'Species': ''},
#  'Salt_Pond_MetaG_R2A_A_H2O_MG_DASTool_bins_metabat.22.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Proteobacteria',
#   'Class': 'Alphaproteobacteria',
#   'Order': 'Puniceispirillales',
#   'Family': 'Puniceispirillaceae',
#   'Genus': 'UBA3439',
#   'Species': ''},
#  'Salt_Pond_MetaG_R2A_A_H2O_MG_DASTool_bins_metabat.49.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Actinobacteriota',
#   'Class': 'Acidimicrobiia',
#   'Order': 'Actinomarinales',
#   'Family': 'Actinomarinaceae',
#   'Genus': 'Actinomarina',
#   'Species': 'Actinomarina sp014384285'},
#  'Salt_Pond_MetaG_R2A_B_D1_MG_DASTool_bins_concoct_out.4.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Acidobacteriota',
#   'Class': 'Thermoanaerobaculia',
#   'Order': 'UBA5704',
#   'Family': 'UBA5704',
#   'Genus': '',
#   'Species': ''},
#  'Salt_Pond_MetaG_R2A_B_D2_MG_DASTool_bins_concoct_out.11.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Bacteroidota',
#   'Class': 'Ignavibacteria',
#   'Order': 'Ignavibacteriales',
#   'Family': 'Ignavibacteriaceae',
#   'Genus': '',
#   'Species': ''},
# ...
#   'Order': 'Desulfobulbales',
#   'Family': 'Desulfurivibrionaceae',
#   'Genus': '',
#   'Species': ''},
#  'Salt_Pond_MetaG_R2A_C_D2_MG_DASTool_bins_concoct_out.34.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Bacteroidota',
#   'Class': 'Bacteroidia',
#   'Order': 'Bacteroidales',
#   'Family': 'Prolixibacteraceae',
#   'Genus': 'Sunxiuqinia',
#   'Species': ''},
#  'Salt_Pond_MetaG_R2A_C_D2_MG_DASTool_bins_concoct_out.36.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Krumholzibacteriota',
#   'Class': 'Krumholzibacteria',
#   'Order': 'LZORAL124-64-63',
#   'Family': '',
#   'Genus': '',
#   'Species': ''},
#  'Salt_Pond_MetaG_R2A_C_D2_MG_DASTool_bins_concoct_out.4.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Bacteroidota',
#   'Class': 'Bacteroidia',
#   'Order': 'Bacteroidales',
#   'Family': 'Prolixibacteraceae',
#   'Genus': 'WC007',
#   'Species': ''},
#  'Salt_Pond_MetaG_R2A_C_D2_MG_DASTool_bins_concoct_out.41.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Deinococcota',
#   'Class': 'Deinococci',
#   'Order': 'Deinococcales',
#   'Family': 'Trueperaceae',
#   'Genus': 'JAAYYF01',
#   'Species': ''},
#  'Salt_Pond_MetaG_R2A_C_D2_MG_DASTool_bins_concoct_out.42.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Desulfobacterota_F',
#   'Class': 'Desulfuromonadia',
#   'Order': 'Desulfuromonadales',
#   'Family': 'Geothermobacteraceae',
#   'Genus': '',
#   'Species': ''},
#  'Salt_Pond_MetaG_R2A_C_D2_MG_DASTool_bins_concoct_out.45.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Chloroflexota',
#   'Class': 'Anaerolineae',
#   'Order': 'Anaerolineales',
#   'Family': 'EnvOPS12',
#   'Genus': 'UBA12294',
#   'Species': ''},
#  'Salt_Pond_MetaG_R2A_C_D2_MG_DASTool_bins_concoct_out.49.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Bacteroidota',
#   'Class': 'Rhodothermia',
#   'Order': 'Balneolales',
#   'Family': 'M1805',
#   'Genus': '',
#   'Species': ''},
#  'Salt_Pond_MetaG_R2A_C_D2_MG_DASTool_bins_concoct_out.51.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Desulfobacterota',
#   'Class': 'Desulfobulbia',
#   'Order': 'Desulfobulbales',
#   'Family': 'Desulfurivibrionaceae',
#   'Genus': '',
#   'Species': ''},
#  'Salt_Pond_MetaG_R2A_C_D2_MG_DASTool_bins_concoct_out.69.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Desulfobacterota_F',
#   'Class': 'Desulfuromonadia',
#   'Order': 'Desulfuromonadales',
#   'Family': 'Trichloromonadaceae',
#   'Genus': 'ATBO01',
#   'Species': ''},
#  'Salt_Pond_MetaG_R2A_C_D2_MG_DASTool_bins_concoct_out.9.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Proteobacteria',
#   'Class': 'Gammaproteobacteria',
#   'Order': 'Burkholderiales',
#   'Family': 'SG8-39',
#   'Genus': 'SG8-39',
#   'Species': ''},
#  'Salt_Pond_MetaG_R2A_C_D2_MG_DASTool_bins_maxbin.022.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'SAR324',
#   'Class': 'SAR324',
#   'Order': '',
#   'Family': '',
#   'Genus': '',
#   'Species': ''},
#  'Salt_Pond_MetaG_R2A_C_D2_MG_DASTool_bins_metabat.10.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Acidobacteriota',
#   'Class': 'Acidobacteriae',
#   'Order': 'UBA7540',
#   'Family': 'UBA7540',
#   'Genus': 'SCRD01',
#   'Species': ''},
#  'Salt_Pond_MetaG_R2A_C_D2_MG_DASTool_bins_metabat.18.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Desulfobacterota',
#   'Class': 'Desulfobacteria',
#   'Order': 'Desulfatiglandales',
#   'Family': 'Desulfatiglandaceae',
#   'Genus': 'NaphS2',
#   'Species': ''},
#  'Salt_Pond_MetaG_R2A_C_D2_MG_DASTool_bins_metabat.27.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Gemmatimonadota',
#   'Class': 'Gemmatimonadetes',
#   'Order': 'Gemmatimonadales',
#   'Family': 'GWC2-71-9',
#   'Genus': '',
#   'Species': ''},
#  'Salt_Pond_MetaG_R2A_C_D2_MG_DASTool_bins_metabat.38.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Proteobacteria',
#   'Class': 'Gammaproteobacteria',
#   'Order': 'Burkholderiales',
#   'Family': 'Gallionellaceae',
#   'Genus': '',
#   'Species': ''},
#  'Salt_Pond_MetaG_R2A_C_H2O_MG_DASTool_bins_concoct_out.67.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Campylobacterota',
#   'Class': 'Campylobacteria',
#   'Order': 'Campylobacterales',
#   'Family': 'Arcobacteraceae',
#   'Genus': 'Aliarcobacter',
#   'Species': ''},
#  'Salt_Pond_MetaG_R2A_C_H2O_MG_DASTool_bins_metabat.16.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Bacteroidota',
#   'Class': 'Bacteroidia',
#   'Order': 'Flavobacteriales',
#   'Family': 'Schleiferiaceae',
#   'Genus': 'UBA10364',
#   'Species': ''},
#  'Salt_Pond_MetaG_R2A_C_H2O_MG_DASTool_bins_metabat.4.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Proteobacteria',
#   'Class': 'Gammaproteobacteria',
#   'Order': 'Pseudomonadales',
#   'Family': 'Nitrincolaceae',
#   'Genus': 'Marinobacterium',
#   'Species': 'Marinobacterium sp013373575'},
#  'Salt_Pond_MetaG_R2A_C_H2O_MG_DASTool_bins_metabat.5.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Proteobacteria',
#   'Class': 'Gammaproteobacteria',
#   'Order': 'Pseudomonadales',
#   'Family': 'DT-91',
#   'Genus': '',
#   'Species': ''},
#  'Salt_Pond_MetaGSF2_A_D1_MG_DASTool_bins_concoct_out.23.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Desulfobacterota',
#   'Class': 'Desulfobulbia',
#   'Order': 'Desulfobulbales',
#   'Family': 'BM004',
#   'Genus': 'BM004',
#   'Species': 'BM004 sp002868955'},
#  'Salt_Pond_MetaGSF2_A_D2_MG_DASTool_bins_concoct_out.11.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Campylobacterota',
#   'Class': 'Campylobacteria',
#   'Order': 'Campylobacterales',
#   'Family': 'Sulfurovaceae',
#   'Genus': 'Sulfurovum',
#   'Species': ''},
#  'Salt_Pond_MetaGSF2_A_D2_MG_DASTool_bins_concoct_out.13.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Desulfobacterota',
#   'Class': 'Desulfobacteria',
#   'Order': 'Desulfobacterales',
#   'Family': 'UBA11574',
#   'Genus': 'JAAXQD01',
#   'Species': ''},
#  'Salt_Pond_MetaGSF2_A_D2_MG_DASTool_bins_concoct_out.28.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Desulfobacterota',
#   'Class': 'Desulfobacteria',
#   'Order': 'Desulfobacterales',
#   'Family': 'UBA11574',
#   'Genus': 'UBA11574',
#   'Species': 'UBA11574 sp002868985'},
#  'Salt_Pond_MetaGSF2_A_D2_MG_DASTool_bins_concoct_out.33.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Proteobacteria',
#   'Class': 'Gammaproteobacteria',
#   'Order': 'Thiohalobacterales',
#   'Family': '',
#   'Genus': '',
#   'Species': ''},
#  'Salt_Pond_MetaGSF2_A_D2_MG_DASTool_bins_concoct_out.40.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Bacteroidota',
#   'Class': 'Rhodothermia',
#   'Order': 'Balneolales',
#   'Family': '',
#   'Genus': '',
#   'Species': ''},
#  'Salt_Pond_MetaGSF2_A_D2_MG_DASTool_bins_concoct_out.55.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Proteobacteria',
#   'Class': 'Gammaproteobacteria',
#   'Order': 'Pseudomonadales',
#   'Family': 'Halieaceae',
#   'Genus': 'Halioglobus',
#   'Species': ''},
#  'Salt_Pond_MetaGSF2_A_D2_MG_DASTool_bins_concoct_out.8.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Desulfobacterota',
#   'Class': 'Syntrophobacteria',
#   'Order': 'BM002',
#   'Family': 'BM002',
#   'Genus': 'BM002',
#   'Species': 'BM002 sp002899795'},
#  'Salt_Pond_MetaGSF2_A_H2O_MG_DASTool_bins_concoct_out.23.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Desulfobacterota_F',
#   'Class': 'Desulfuromonadia',
#   'Order': 'Desulfuromonadales',
#   'Family': 'BM103',
#   'Genus': 'M0040',
#   'Species': ''},
#  'Salt_Pond_MetaGSF2_A_H2O_MG_DASTool_bins_concoct_out.33.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Bacteroidota',
#   'Class': 'Bacteroidia',
#   'Order': 'NS11-12g',
#   'Family': 'UBA955',
#   'Genus': 'VMCP01',
#   'Species': 'VMCP01 sp008081305'},
#  'Salt_Pond_MetaGSF2_A_H2O_MG_DASTool_bins_metabat.14.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Desulfobacterota_F',
#   'Class': 'Desulfuromonadia',
#   'Order': 'Desulfuromonadales',
#   'Family': 'BM103',
#   'Genus': 'M0040',
#   'Species': ''},
#  'Salt_Pond_MetaGSF2_A_H2O_MG_DASTool_bins_metabat.23.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Proteobacteria',
#   'Class': 'Gammaproteobacteria',
#   'Order': 'Pseudomonadales',
#   'Family': 'Litoricolaceae',
#   'Genus': 'HIMB30',
#   'Species': 'HIMB30 sp002691485'},
#  'Salt_Pond_MetaGSF2_A_H2O_MG_DASTool_bins_metabat.28.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Bacteroidota',
#   'Class': 'Bacteroidia',
#   'Order': 'Flavobacteriales',
#   'Family': 'Flavobacteriaceae',
#   'Genus': 'MAG-120531',
#   'Species': ''},
#  'Salt_Pond_MetaGSF2_A_H2O_MG_DASTool_bins_metabat.34.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Proteobacteria',
#   'Class': 'Gammaproteobacteria',
#   'Order': 'Chromatiales',
#   'Family': 'Sedimenticolaceae',
#   'Genus': 'VMDJ01',
#   'Species': 'VMDJ01 sp008080925'},
#  'Salt_Pond_MetaGSF2_B_D1_MG_DASTool_bins_concoct_out.44.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Bacteroidota',
#   'Class': 'Bacteroidia',
#   'Order': 'Flavobacteriales',
#   'Family': 'Flavobacteriaceae',
#   'Genus': 'Yeosuana',
#   'Species': ''},
#  'Salt_Pond_MetaGSF2_B_D1_MG_DASTool_bins_metabat.9.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Desulfobacterota',
#   'Class': 'Desulfobacteria',
#   'Order': 'Desulfobacterales',
#   'Family': 'UBA11574',
#   'Genus': 'JAAXQD01',
#   'Species': ''},
#  'Salt_Pond_MetaGSF2_B_D2_MG_DASTool_bins_concoct_out.42.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Planctomycetota',
#   'Class': 'Phycisphaerae',
#   'Order': 'SM23-33',
#   'Family': 'SM23-33',
#   'Genus': 'UBA12270',
#   'Species': ''},
#  'Salt_Pond_MetaGSF2_B_D2_MG_DASTool_bins_concoct_out.55.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Proteobacteria',
#   'Class': 'Gammaproteobacteria',
#   'Order': 'BM003',
#   'Family': 'BM003',
#   'Genus': 'BM003',
#   'Species': 'BM003 sp002868855'},
#  'Salt_Pond_MetaGSF2_B_D2_MG_DASTool_bins_metabat.4.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Bacteroidota',
#   'Class': 'Rhodothermia',
#   'Order': 'Balneolales',
#   'Family': 'Balneolaceae',
#   'Genus': '',
#   'Species': ''},
#  'Salt_Pond_MetaGSF2_B_H2O_MG_DASTool_bins_concoct_out.14.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Actinobacteriota',
#   'Class': 'Actinomycetia',
#   'Order': 'Actinomycetales',
#   'Family': 'Microbacteriaceae',
#   'Genus': 'Aquiluna',
#   'Species': ''},
#  'Salt_Pond_MetaGSF2_B_H2O_MG_DASTool_bins_concoct_out.91.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Proteobacteria',
#   'Class': 'Gammaproteobacteria',
#   'Order': 'Pseudomonadales',
#   'Family': 'Pseudohongiellaceae',
#   'Genus': 'RFVC01',
#   'Species': ''},
#  'Salt_Pond_MetaGSF2_B_H2O_MG_DASTool_bins_metabat.11.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Proteobacteria',
#   'Class': 'Gammaproteobacteria',
#   'Order': 'Pseudomonadales',
#   'Family': 'Pseudohongiellaceae',
#   'Genus': 'OM182',
#   'Species': 'OM182 sp003482475'},
#  'Salt_Pond_MetaGSF2_B_H2O_MG_DASTool_bins_metabat.19.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Proteobacteria',
#   'Class': 'Alphaproteobacteria',
#   'Order': 'Rhodobacterales',
#   'Family': 'Rhodobacteraceae',
#   'Genus': 'Planktomarina',
#   'Species': 'Planktomarina temperata'},
#  'Salt_Pond_MetaGSF2_B_H2O_MG_DASTool_bins_metabat.25.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Bacteroidota',
#   'Class': 'Bacteroidia',
#   'Order': 'Flavobacteriales',
#   'Family': 'Schleiferiaceae',
#   'Genus': 'UBA10364',
#   'Species': ''},
#  'Salt_Pond_MetaGSF2_B_H2O_MG_DASTool_bins_metabat.28.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Bacteroidota',
#   'Class': 'Bacteroidia',
#   'Order': 'Flavobacteriales',
#   'Family': 'Flavobacteriaceae',
#   'Genus': 'UBA3478',
#   'Species': ''},
#  'Salt_Pond_MetaGSF2_B_H2O_MG_DASTool_bins_metabat.39.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Proteobacteria',
#   'Class': 'Gammaproteobacteria',
#   'Order': 'SAR86',
#   'Family': 'D2472',
#   'Genus': 'D2472',
#   'Species': ''},
#  'Salt_Pond_MetaGSF2_B_H2O_MG_DASTool_bins_metabat.8.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Proteobacteria',
#   'Class': 'Alphaproteobacteria',
#   'Order': 'Rhodobacterales',
#   'Family': 'Rhodobacteraceae',
#   'Genus': 'HIMB11',
#   'Species': 'HIMB11 sp003486095'},
#  'Salt_Pond_MetaGSF2_C_D1_MG_DASTool_bins_concoct_out.13.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Campylobacterota',
#   'Class': 'Campylobacteria',
#   'Order': 'Campylobacterales',
#   'Family': 'Sulfurovaceae',
#   'Genus': 'Sulfurovum',
#   'Species': ''},
#  'Salt_Pond_MetaGSF2_C_D2_MG_DASTool_bins_concoct_out.13.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Planctomycetota',
#   'Class': 'Planctomycetes',
#   'Order': 'Pirellulales',
#   'Family': 'UBA11386',
#   'Genus': '',
#   'Species': ''},
#  'Salt_Pond_MetaGSF2_C_D2_MG_DASTool_bins_concoct_out.15.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Bacteroidota',
#   'Class': 'Rhodothermia',
#   'Order': 'Balneolales',
#   'Family': 'Balneolaceae',
#   'Genus': '',
#   'Species': ''},
#  'Salt_Pond_MetaGSF2_C_D2_MG_DASTool_bins_concoct_out.17.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Bacteroidota',
#   'Class': 'Bacteroidia',
#   'Order': 'Bacteroidales',
#   'Family': 'UBA10428',
#   'Genus': '',
#   'Species': ''},
#  'Salt_Pond_MetaGSF2_C_D2_MG_DASTool_bins_concoct_out.24.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Bacteroidota',
#   'Class': 'Rhodothermia',
#   'Order': 'Balneolales',
#   'Family': '',
#   'Genus': '',
#   'Species': ''},
#  'Salt_Pond_MetaGSF2_C_D2_MG_DASTool_bins_concoct_out.26.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Bacteroidota',
#   'Class': 'Rhodothermia',
#   'Order': 'Balneolales',
#   'Family': 'Balneolaceae',
#   'Genus': 'SMO-BIN1',
#   'Species': ''},
#  'Salt_Pond_MetaGSF2_C_D2_MG_DASTool_bins_concoct_out.3.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Proteobacteria',
#   'Class': 'Gammaproteobacteria',
#   'Order': 'Nevskiales',
#   'Family': '',
#   'Genus': '',
#   'Species': ''},
#  'Salt_Pond_MetaGSF2_C_D2_MG_DASTool_bins_concoct_out.32.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Bacteroidota',
#   'Class': 'Bacteroidia',
#   'Order': 'Bacteroidales',
#   'Family': 'GCA-2748055',
#   'Genus': '',
#   'Species': ''},
#  'Salt_Pond_MetaGSF2_C_D2_MG_DASTool_bins_concoct_out.39.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Proteobacteria',
#   'Class': 'Gammaproteobacteria',
#   'Order': 'SLND01',
#   'Family': '',
#   'Genus': '',
#   'Species': ''},
#  'Salt_Pond_MetaGSF2_C_D2_MG_DASTool_bins_concoct_out.42.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Desulfobacterota_F',
#   'Class': 'Desulfuromonadia',
#   'Order': 'Desulfuromonadales',
#   'Family': 'Trichloromonadaceae',
#   'Genus': 'DDH964',
#   'Species': ''},
#  'Salt_Pond_MetaGSF2_C_D2_MG_DASTool_bins_concoct_out.8.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Proteobacteria',
#   'Class': 'Gammaproteobacteria',
#   'Order': 'UBA5335',
#   'Family': 'UBA5335',
#   'Genus': '',
#   'Species': ''},
#  'Salt_Pond_MetaGSF2_C_D2_MG_DASTool_bins_metabat.11.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Proteobacteria',
#   'Class': 'Gammaproteobacteria',
#   'Order': 'UBA5335',
#   'Family': 'UBA5335',
#   'Genus': '',
#   'Species': ''},
#  'Salt_Pond_MetaGSF2_C_D2_MG_DASTool_bins_metabat.16.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Deinococcota',
#   'Class': 'Deinococci',
#   'Order': 'Deinococcales',
#   'Family': 'Trueperaceae',
#   'Genus': 'JAAYYF01',
#   'Species': ''},
#  'Salt_Pond_MetaGSF2_C_D2_MG_DASTool_bins_metabat.19.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Proteobacteria',
#   'Class': 'Gammaproteobacteria',
#   'Order': 'SLND01',
#   'Family': '',
#   'Genus': '',
#   'Species': ''},
#  'Salt_Pond_MetaGSF2_C_H2O_MG_DASTool_bins_metabat.13.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Proteobacteria',
#   'Class': 'Alphaproteobacteria',
#   'Order': 'Rhodobacterales',
#   'Family': 'Rhodobacteraceae',
#   'Genus': 'HIMB11',
#   'Species': ''},
#  'Salt_Pond_MetaGSF2_C_H2O_MG_DASTool_bins_metabat.16.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Verrucomicrobiota',
#   'Class': 'Verrucomicrobiae',
#   'Order': 'Opitutales',
#   'Family': 'MB11C04',
#   'Genus': 'MB11C04',
#   'Species': ''},
#  'Salt_Pond_MetaGSF2_C_H2O_MG_DASTool_bins_metabat.29.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Bacteroidota',
#   'Class': 'Bacteroidia',
#   'Order': 'Flavobacteriales',
#   'Family': 'Flavobacteriaceae',
#   'Genus': 'MS024-2A',
#   'Species': ''},
#  'Salt_Pond_MetaGSF2_C_H2O_MG_DASTool_bins_metabat.49.contigs__': {'Kingdom': 'Bacteria',
#   'Phylum': 'Actinobacteriota',
#   'Class': 'Actinomycetia',
#   'Order': 'Actinomycetales',
#   'Family': 'Microbacteriaceae',
#   'Genus': 'Aquiluna',
#   'Species': ''}}

# %%
from json import load, dump

phylogeny = load(open("../../../MicrobiomeNotebooks/salterns/data/Saltern_phylogeny.json", "r"))
betaine_reducers_taxonomy = {}
orders = set()
for model in target_model_ids:
    taxa = phylogeny.get(model+"__", {})
    orders.add(taxa["Order"])
    betaine_reducers_taxonomy[model] = taxa
print(orders)
display(betaine_reducers_taxonomy)
dump(betaine_reducers_taxonomy, open("betaine_reducers_taxonomy.json", "w"))
# Out:
# {'Halanaerobiales', 'Peptostreptococcales', 'Tissierellales', 'Synergistales'}
# {'Salt_Pond_MetaG_R1_A_D1_MG_DASTool_bins.metabat.47.contigs': {'Kingdom': 'Bacteria',
#   'Phylum': 'Firmicutes_F',
#   'Class': 'Halanaerobiia',
#   'Order': 'Halanaerobiales',
#   'Family': '',
#   'Genus': '',
#   'Species': ''},
#  'Salt_Pond_MetaG_R1_A_D2_MG_DASTool_bins_metabat.45.contigs': {'Kingdom': 'Bacteria',
#   'Phylum': 'Firmicutes_F',
#   'Class': 'Halanaerobiia',
#   'Order': 'Halanaerobiales',
#   'Family': 'Halanaerobiaceae',
#   'Genus': 'Halanaerobium',
#   'Species': 'Halanaerobium saccharolyticum'},
#  'Salt_Pond_MetaG_R1_B_D1_MG_DASTool_bins_concoct_out.59.contigs': {'Kingdom': 'Bacteria',
#   'Phylum': 'Firmicutes_F',
#   'Class': 'Halanaerobiia',
#   'Order': 'Halanaerobiales',
#   'Family': 'Halanaerobiaceae',
#   'Genus': 'Halanaerobium',
#   'Species': ''},
#  'Salt_Pond_MetaG_R2_A_D1_MG_DASTool_bins_concoct_out.98.contigs': {'Kingdom': 'Bacteria',
#   'Phylum': 'Synergistota',
#   'Class': 'Synergistia',
#   'Order': 'Synergistales',
#   'Family': '',
#   'Genus': '',
#   'Species': ''},
#  'Salt_Pond_MetaG_R1_A_D2_MG_DASTool_bins_metabat.48.contigs': {'Kingdom': 'Bacteria',
#   'Phylum': 'Firmicutes_A',
#   'Class': 'Clostridia',
#   'Order': 'Peptostreptococcales',
#   'Family': 'BM714',
#   'Genus': 'BM714',
#   'Species': ''},
#  'Salt_Pond_MetaG_R1_C_D1_MG_DASTool_bins_maxbin.047.contigs': {'Kingdom': 'Bacteria',
#   'Phylum': 'Firmicutes_A',
#   'Class': 'Clostridia',
#   'Order': 'Peptostreptococcales',
#   'Family': 'BM714',
#   'Genus': 'BM714',
#   'Species': ''},
#  'Salt_Pond_MetaG_R1_C_D2_MG_DASTool_bins_metabat.40.contigs': {'Kingdom': 'Bacteria',
#   'Phylum': 'Firmicutes_F',
#   'Class': 'Halanaerobiia',
#   'Order': 'Halanaerobiales',
#   'Family': '',
#   'Genus': '',
#   'Species': ''},
#  'Salt_Pond_MetaG_R1_C_D2_MG_DASTool_bins_concoct_out.85.contigs': {'Kingdom': 'Bacteria',
#   'Phylum': 'Firmicutes_A',
#   'Class': 'Clostridia',
#   'Order': 'Tissierellales',
#   'Family': 'Dethiosulfatibacteraceae',
#   'Genus': 'UBA8670',
#   'Species': ''},
#  'Salt_Pond_MetaG_R1_A_D2_MG_DASTool_bins_metabat.50.contigs': {'Kingdom': 'Bacteria',
#   'Phylum': 'Firmicutes_A',
#   'Class': 'Clostridia',
#   'Order': 'Peptostreptococcales',
#   'Family': 'BM714',
#   'Genus': 'BM714',
#   'Species': ''},
#  'Salt_Pond_MetaG_R2_B_D2_MG_DASTool_bins_metabat.52.contigs': {'Kingdom': 'Bacteria',
#   'Phylum': 'Firmicutes_F',
#   'Class': 'Halanaerobiia',
#   'Order': 'Halanaerobiales',
#   'Family': '',
#   'Genus': '',
#   'Species': ''},
#  'Salt_Pond_MetaG_R1_B_D2_MG_DASTool_bins_concoct_out.73.contigs': {'Kingdom': 'Bacteria',
#   'Phylum': 'Firmicutes_F',
#   'Class': 'Halanaerobiia',
#   'Order': 'Halanaerobiales',
#   'Family': 'Halanaerobiaceae',
#   'Genus': 'Halanaerobium',
#   'Species': ''},
#  'Salt_Pond_MetaG_R1_A_D1_MG_DASTool_bins.concoct_out.9.contigs': {'Kingdom': 'Bacteria',
#   'Phylum': 'Firmicutes_A',
#   'Class': 'Clostridia',
#   'Order': 'Tissierellales',
#   'Family': 'Dethiosulfatibacteraceae',
#   'Genus': 'UBA8670',
#   'Species': ''},
#  'Salt_Pond_MetaG_R1_A_D1_MG_DASTool_bins.metabat.51.contigs': {'Kingdom': 'Bacteria',
#   'Phylum': 'Firmicutes_A',
#   'Class': 'Clostridia',
#   'Order': 'Peptostreptococcales',
#   'Family': 'BM714',
#   'Genus': 'BM714',
#   'Species': ''},
#  'Salt_Pond_MetaG_R1_B_D1_MG_DASTool_bins_metabat.58.contigs': {'Kingdom': 'Bacteria',
#   'Phylum': 'Synergistota',
#   'Class': 'Synergistia',
#   'Order': 'Synergistales',
#   'Family': '',
#   'Genus': '',
#   'Species': ''},
#  'Salt_Pond_MetaG_R1_A_D2_MG_DASTool_bins_metabat.27.contigs': {'Kingdom': 'Bacteria',
#   'Phylum': 'Firmicutes_A',
#   'Class': 'Clostridia',
#   'Order': 'Peptostreptococcales',
#   'Family': 'Acidaminobacteraceae',
#   'Genus': '',
#   'Species': ''}}

# %%
from modelseedpy import MSBuilder
models_base = {}
for i in tqdm(target_model_ids):
    model = cobra.io.load_json_model(f'./models/{i}__.RAST.json')
    MSBuilder.add_atpm(model)
    models_base[i] = model
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 15/15 [07:00<00:00, 28.05s/it]

# %%
M_CORE_EMPTY = {
    'EX_cpd00001_e0': 1000,
    'EX_cpd00067_e0': 1000,
    'EX_cpd00007_e0': 100,
} 
for model_name in models_base:
    print(model_name)
    model_base = models_base[model_name]
    disable = ['rxn23850_c0', 'rxn09193_c0', 'rxn05315_c0', 'rxn05206_c0']
    for rxn_id in disable:
        if rxn_id in model_base.reactions:
            rxn = model_base.reactions.get_by_id(rxn_id)
            rxn.lower_bound = 0
            rxn.upper_bound = 0
    disable_lb = [
        'rxn09188_c0', 'rxn00929_c0', 
              'rxn00145_c0', 'rxn00499_c0', 'rxn00146_c0',
              'rxn08934_c0', 'rxn08941_c0', 'rxn08935_c0', 'rxn08942_c0', # not sure about these
              'rxn11942_c0', 'rxn11941_c0',
              'rxn43329_c0', 'rxn11940_c0',
              'rxn40559_c0', 'rxn04159_c0', 'rxn04705_c0',
        'rxn14415_c0',
        'sul00003_c0', 'rxn48579_c0',
        'rxn39860_c0'
             ]
    for rxn_id in disable_lb:
        if rxn_id in model_base.reactions:
            rxn = model_base.reactions.get_by_id(rxn_id)
            rxn.lower_bound = 0
    rxn_balance_check = ['rxn15395_c0', 'rxn28338_c0']
    for rxn_id in rxn_balance_check:
        if rxn_id in model_base.reactions:
            rxn = model_base.reactions.get_by_id(rxn_id)
            check = {'charge': -1, 'H': -1}
            if rxn.check_mass_balance() == check:
                print(rxn)
                rxn.add_metabolites({
                    model_base.metabolites.cpd00067_c0: +1
                })
                print(rxn.check_mass_balance())
    model_base.medium = {k:v for k, v in M_CORE_EMPTY.items() if k in model_base.reactions}
    model_base.objective = 'ATPM_c0'
    sol = cobra.flux_analysis.pfba(model_base)
    if sol.fluxes['ATPM_c0'] > 0.0:
        raise ValueError('!')
        break
print('no moar loops!')
# Out:
# Salt_Pond_MetaG_R1_B_D1_MG_DASTool_bins_metabat.58.contigs
# Salt_Pond_MetaG_R1_B_D1_MG_DASTool_bins_concoct_out.59.contigs
# Salt_Pond_MetaG_R1_C_D2_MG_DASTool_bins_concoct_out.85.contigs
# Salt_Pond_MetaG_R1_A_D1_MG_DASTool_bins.metabat.47.contigs
# Salt_Pond_MetaG_R1_A_D1_MG_DASTool_bins.concoct_out.9.contigs
# Salt_Pond_MetaG_R2_A_D1_MG_DASTool_bins_concoct_out.98.contigs
# Salt_Pond_MetaG_R1_A_D2_MG_DASTool_bins_metabat.45.contigs
# Salt_Pond_MetaG_R2_B_D2_MG_DASTool_bins_metabat.52.contigs
# Salt_Pond_MetaG_R1_C_D1_MG_DASTool_bins_maxbin.047.contigs
# Salt_Pond_MetaG_R1_A_D2_MG_DASTool_bins_metabat.27.contigs
# Salt_Pond_MetaG_R1_B_D2_MG_DASTool_bins_concoct_out.73.contigs
# Salt_Pond_MetaG_R1_A_D2_MG_DASTool_bins_metabat.50.contigs
# Salt_Pond_MetaG_R1_C_D2_MG_DASTool_bins_metabat.40.contigs
# Salt_Pond_MetaG_R1_A_D1_MG_DASTool_bins.metabat.51.contigs
# Salt_Pond_MetaG_R1_A_D2_MG_DASTool_bins_metabat.48.contigs
# no moar loops!

# %%
template_neg = cobrakbase.io.load_kbase_zip_object('./GramNegModelTemplateV6_test.json.zip')
from modelseedpy.core.mstemplate import MSTemplateReaction, MSTemplateSpecies
rxs17220_c = MSTemplateReaction('rxs17220_c', 'rxs17220_c', 'Betaine Reductase', '', 0, 1000, gapfill_direction='>')
rxs17220_c.add_metabolites({
    template_neg.compcompounds.cpd28060_c: -1,
    template_neg.compcompounds.cpd00540_e: -1,
    template_neg.compcompounds.cpd00067_c: -2,
    template_neg.compcompounds.cpd00009_c: -1,
    template_neg.compcompounds.cpd27735_c:  1,
    template_neg.compcompounds.cpd00441_e:  1,
    template_neg.compcompounds.cpd00196_c:  1,
    template_neg.compcompounds.cpd00001_c:  1,
})
print(rxs17220_c.check_mass_balance())
template_neg.add_reactions([rxs17220_c])
for model_id, model in models_base.items():
    if 'rxs17220_c0' not in model.reactions:
        model.add_reactions([template_neg.reactions.rxs17220_c.to_reaction(model)])
        print('added Betaine Reductase')
# Out:
# {}

# %%
template_core = cobrakbase.io.load_kbase_zip_object('./CoreBacV5.1.json.zip')
template_core.add_reactions([rxs17220_c, template_neg.reactions.rxn27318_c])

# %%
from modelseedpy.core.msatpcorrection import load_default_medias

# %%
medias = load_default_medias()
from modelseedpy.core.msmedia import MSMedia, MediaCompound
media_core_bet = MSMedia('Bet')
media_core_bet.id = 'Bet'
media_core_bet.name = 'Bet'
media_core_bet.mediacompounds.append(MediaCompound('cpd00540', -1, 1000))
media_core_bet.mediacompounds.append(MediaCompound('cpd00001', -1000, 1000))
media_core_bet.mediacompounds.append(MediaCompound('cpd00067', -1000, 1000))
medias.clear()
medias.append([media_core_bet, 0.01])

# %%
len(medias)
# Out:
# 1

# %%
import os
def conv_atp_results(atp_correction, tests):
    results = {'tests': {}, 'gapfill': {}}
    for x in tests:
        results['tests'][x['media'].id] = {
            'is_max_threshold': x['is_max_threshold'], 
            'threshold': x['threshold'], 
            'objective': x['objective'], 
        }
    for x in atp_correction.media_gapfill_stats:
        gp_stats = atp_correction.media_gapfill_stats[x]
        #print(x.id, gp_stats)
        if gp_stats:
            results['gapfill'][x.id] = {
                'reversed': gp_stats.get('reversed'),
                'new': gp_stats.get('new'),
                'target': gp_stats.get('target'),
                'minobjective': gp_stats.get('minobjective'),
                'binary_check': gp_stats.get('binary_check'),
            }
    return results
#for model_name in models_base:
for model_name in ['Salt_Pond_MetaG_R1_C_D2_MG_DASTool_bins_concoct_out.85.contigs']:
    print(model_name)
    model_base = models_base[model_name]
    if not os.path.exists(f'./atp/{model_base.id}_bet.json'):
        model_gapfill = model_base.copy()
        atp_correction = MSATPCorrection(model_gapfill, template_core, medias,
                    compartment='c0', 
                    atp_hydrolysis_id='ATPM_c0',
                    load_default_medias=False)
        tests = atp_correction.run_atp_correction()
        atp_data = conv_atp_results(atp_correction, tests)
        with open(f'./atp/{model_base.id}_bet.json', 'w') as fh:
            fh.write(json.dumps(atp_data))
    else:
        print(f'skip {model_name}!')
    break
# Out:
# Salt_Pond_MetaG_R1_C_D2_MG_DASTool_bins_concoct_out.85.contigs
# INFO:modelseedpy.core.msmodelutl:Expansion time:empty:0.012155400007031858
# INFO:modelseedpy.core.msmodelutl:Filtered count:0 out of 1089

# %%
for r in atp_data['gapfill']['Bet']['new']:
    if r[:-1] in template_core.reactions:
        print(r, template_core.reactions.get_by_id(r[:-1]).build_reaction_string(True))
    else:
        print('skip', r)
# Out:
# skip EX_cpd01024_e0
# skip EX_cpd00425_e0
# rxn00777_c0 ribose-5-phosphate [c] <=> D-Ribulose5-phosphate [c]
# rxn03127_c0 Methyl CoM [c] + HTP [c] <=> H+ [c] + Methane [c] + CoM-S-S-CoB [c]
# rxn24613_c0 CoM [c] + Methylated-MttC-Proteins [c] <=> H+ [c] + Methyl CoM [c] + MttC-Proteins [c]
# rxn03020_c0 2 Na+ [c] + CoM [c] + 5-Methyl-H4MPT [c] <=> H4MPT [c] + 2 Na+ [e] + Methyl CoM [c]
# rxn10471_c0 Methane [e] <=> Methane [c]
# rxn15962_c0 Acetyl-CoA [c] + H+ [c] + H4MPT [c] <-- CoA [c] + CO [c] + 5-Methyl-H4MPT [c]
# rxn00548_c0 Phosphate [c] + D-fructose-6-phosphate [c] <=> H2O [c] + Acetylphosphate [c] + D-Erythrose4-phosphate [c]
# rxn09318_c0 (CH3)3N [c] <=> (CH3)3N [e]
# rxn24612_c0 H+ [c] + (CH3)3N [c] + MttC-Proteins [c] <=> (CH3)2NH [c] + Methylated-MttC-Proteins [c]
# rxn15961_c0 2 H+ [c] + Methanophenazine [c] + H2 [c] <=> 2 H+ [e] + Dihydromethanophenazine [c]
# rxn03126_c0 H+ [c] + CoM-S-S-CoB [c] + Dihydromethanophenazine [c] <=> CoM [c] + HTP [c] + Methanophenazine [c]
# rxn00173_c0 Phosphate [c] + Acetyl-CoA [c] <=> CoA [c] + Acetylphosphate [c]
# rxn33011_c0 (CH3)2NH [c] <=> (CH3)2NH [e]
# rxn40505_c0 H2O [c] + CO [c] + 2 Oxidizedferredoxin [c] <=> CO2 [c] + 3 H+ [c] + 2 Reducedferredoxin [c]

# %%
from tqdm import tqdm
import json

atp_data = {}
for i in tqdm(target_model_ids):
    with open(f'../cliff_mags/mac/salterns/atp/{i}__.RAST.json', 'r') as fh:
        atp_data[i] = json.load(fh)
genome_core_gf = {}
for genome_id in atp_data:
    genome_core_gf[genome_id] = {}
    _data = atp_data[genome_id]
    for cond_id in _data['gapfill']:
        _gapfill_data = _data['gapfill'][cond_id]
        if _gapfill_data['target']:
            _gap_fill_add = list(filter(lambda x: x[:3] != 'EX_', _gapfill_data['new']))
            genome_core_gf[genome_id][cond_id] = len(_gap_fill_add)
# Out:
# 100%|██████████| 15/15 [00:00<00:00, 970.01it/s]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# Corrected dictionary
d = genome_core_gf

# Convert to DataFrame
df = pd.DataFrame.from_dict(d, orient='index')
stats = {metID: {"max": row.max(), "median": row.median(), "min": row.min(), "total": row.sum()}
         for metID, row in df.T.iterrows()}
stats_df = pd.DataFrame.from_dict(stats, orient='index')
display(stats_df.sort_values(by="total"))
# print("lowest max", )

plt.figure(figsize=(12, 6))
# Plot heatmap
sns.heatmap(df, annot=True, cmap='viridis', annot_kws={"size": 4})
plt.title("Core Gap Filling")
plt.ylabel("Mag")
plt.xlabel("Conditions")
plt.show()
# Out:
#                     max  median   min  total
# Pyr.SO3             2.0     1.0   1.0    5.0
# Pyr                 2.0     1.0   1.0    5.0
# Pyr.TMAO            2.0     1.0   1.0    5.0
# Pyr.DMSO            2.0     1.0   1.0    5.0
# Fum                 5.0     3.0   3.0   17.0
# Glc                 6.0     1.0   1.0   17.0
# Glc.TMAO            7.0     1.0   1.0   18.0
# Glc.DMSO            7.0     1.0   1.0   18.0
# Glyc                5.0     1.0   1.0   25.0
# Dlac                4.0     1.0   1.0   26.0
# LLac.SO4.H2         4.0     1.0   1.0   27.0
# LLac.SO4            4.0     1.0   1.0   27.0
# Llac                4.0     1.0   1.0   27.0
# For.NO2             3.0     2.0   1.0   32.0
# Ac.NO               5.0     2.0   1.0   41.0
# Ac.NO2              6.0     3.0   2.0   54.0
# Etho.O2            10.0     3.5   2.0   56.0
# Glc.O2             12.0     4.0   2.0   67.0
# Dlac.O2             8.0     4.0   1.0   67.0
# Ac.O2               8.0     4.0   1.0   68.0
# Pyr.O2              8.0     4.0   1.0   68.0
# LLac.O2             8.0     4.0   2.0   69.0
# Glyc.O2             9.0     4.0   2.0   72.0
# Ac.NO3              8.0     5.0   3.0   76.0
# Pyr.NO3             9.0     5.0   3.0   78.0
# For.O2             17.0     3.0   1.0   79.0
# Succ                8.0     5.0   4.0   80.0
# Fum.O2              9.0     5.5   4.0   81.0
# Methanol.H2        13.0     7.0   6.0  112.0
# Methanamine.H2     13.0     7.0   7.0  116.0
# Methanol           13.0     7.0   6.0  122.0
# Succ.O2            12.0     9.0   7.0  137.0
# Dimethylamine.H2   15.0     9.0   9.0  146.0
# Pyr.NO             12.0    10.0   6.0  149.0
# H2.CO2             11.0    11.0   7.0  150.0
# For.NO             13.0    11.0   7.0  164.0
# For                12.0    12.0   8.0  169.0
# Pyr.SO4            20.0    11.0   6.0  171.0
# Trimethylamine.H2  17.0    11.0  10.0  174.0
# Pyr.NO2            16.0    12.0   7.0  177.0
# H2.Ac              18.0    12.0   8.0  185.0
# Ac                 18.0    12.0   8.0  185.0
# Akg                17.0    13.0  11.0  196.0
# For.NO3            18.0    14.0   9.0  209.0
# For.SO4.H2         20.0    15.0   8.0  224.0
# H2.SO4             20.0    15.0   9.0  233.0
# Akg.O2             21.0    16.0   8.0  234.0
# For.SO4            21.0    16.0   8.0  236.0

# %%
# Out:
# Salt_Pond_MetaG_R1_B_D2_MG_DASTool_bins_concoct_out.73.contigs
# rxn15395_c0: cpd00084_c0 + cpd00822_c0 --> cpd00036_c0 + cpd19019_c0
# {}
# Salt_Pond_MetaG_R1_A_D1_MG_DASTool_bins.metabat.51.contigs
# Salt_Pond_MetaG_R2_B_D2_MG_DASTool_bins_metabat.52.contigs
# Salt_Pond_MetaG_R1_A_D2_MG_DASTool_bins_metabat.27.contigs
# rxn15395_c0: cpd00084_c0 + cpd00822_c0 --> cpd00036_c0 + cpd19019_c0
# {}
# Salt_Pond_MetaG_R1_A_D1_MG_DASTool_bins.metabat.47.contigs
# Salt_Pond_MetaG_R1_A_D2_MG_DASTool_bins_metabat.45.contigs
# rxn15395_c0: cpd00084_c0 + cpd00822_c0 --> cpd00036_c0 + cpd19019_c0
# {}
# Salt_Pond_MetaG_R1_A_D2_MG_DASTool_bins_metabat.48.contigs
# Salt_Pond_MetaG_R1_A_D2_MG_DASTool_bins_metabat.50.contigs
# Salt_Pond_MetaG_R1_C_D1_MG_DASTool_bins_maxbin.047.contigs
# Salt_Pond_MetaG_R1_C_D2_MG_DASTool_bins_metabat.40.contigs
# Salt_Pond_MetaG_R2_A_D1_MG_DASTool_bins_concoct_out.98.contigs
# Salt_Pond_MetaG_R1_A_D1_MG_DASTool_bins.concoct_out.9.contigs
# rxn15395_c0: cpd00084_c0 + cpd00822_c0 --> cpd00036_c0 + cpd19019_c0
# {}
# Salt_Pond_MetaG_R1_B_D1_MG_DASTool_bins_metabat.58.contigs
# Salt_Pond_MetaG_R1_B_D1_MG_DASTool_bins_concoct_out.59.contigs
# rxn15395_c0: cpd00084_c0 + cpd00822_c0 --> cpd00036_c0 + cpd19019_c0
# {}
# Salt_Pond_MetaG_R1_C_D2_MG_DASTool_bins_concoct_out.85.contigs
# rxn15395_c0: cpd00084_c0 + cpd00822_c0 --> cpd00036_c0 + cpd19019_c0
# {}
# no moar loops!

# %%
template_core.reactions.rxs17220_c.to_reaction(model_base) - template_core.reactions.rxn27318_c.to_reaction(model_base)
# Out:
# <Reaction rxs17220_c0 at 0x1df5cce36d0>

# %%
template_neg.reactions.rxn27318_c.check_mass_balance()
# Out:
# {}

# %%
# Out:
# <MSTemplateReaction rxs17220_c at 0x7b836f122320>

# %%
rxn_net = model.reactions.rxs17220_c0 - model.reactions.rxn27318_c0 - model.reactions.rxn00225_c0 + model.reactions.rxn00161_c0
print(rxn_net.check_mass_balance())
rxn_net
# Out:
# {}
# <Reaction rxs17220_c0 at 0x7b836cff5840>

# %%
for model_id, model in models_base.items():
    if 'cpd00441_c0' in model.metabolites:
        print(model_id, model.metabolites.cpd00441_c0)
        for rxn in model.metabolites.cpd00441_c0.reactions:
            print('\t', rxn.build_reaction_string(True))
# Out:
# Salt_Pond_MetaG_R2_B_D2_MG_DASTool_bins_metabat.52.contigs cpd00441_c0
# 	 H+ [c0] + (CH3)3N [c0] + MttC-Proteins [c0] <=> (CH3)2NH [c0] + Methylated-MttC-Proteins [c0]
# Salt_Pond_MetaG_R1_C_D2_MG_DASTool_bins_metabat.40.contigs cpd00441_c0
# 	 H+ [c0] + (CH3)3N [c0] + MttC-Proteins [c0] <=> (CH3)2NH [c0] + Methylated-MttC-Proteins [c0]
# Salt_Pond_MetaG_R1_A_D1_MG_DASTool_bins.concoct_out.9.contigs cpd00441_c0
# 	 H+ [c0] + (CH3)3NO [c0] + 2-Demethylmenaquinol 8 [c0] <=> H2O [c0] + (CH3)3N [c0] + 2-Demethylmenaquinone 8 [c0]
# Salt_Pond_MetaG_R1_C_D2_MG_DASTool_bins_concoct_out.85.contigs cpd00441_c0
# 	 H+ [c0] + (CH3)3NO [c0] + 2-Demethylmenaquinol 8 [c0] <=> H2O [c0] + (CH3)3N [c0] + 2-Demethylmenaquinone 8 [c0]

# %%
for ex in model.exchanges:
    print(ex.id, list(ex.metabolites)[0].name)
# Out:
# EX_cpd00067_e0 H+ [e0]
# EX_cpd00106_e0 Fumarate [e0]
# EX_cpd00036_e0 Succinate [e0]
# EX_cpd11576_e0 L-methionine R-oxide [e0]
# EX_cpd04097_e0 Pb [e0]
# EX_cpd00154_e0 Xylose [e0]
# EX_cpd11597_e0 ARSENOBETAINE [e0]
# EX_cpd00012_e0 PPi [e0]
# EX_cpd01030_e0 Salicin [e0]
# EX_cpd00129_e0 L-Proline [e0]
# EX_cpd00971_e0 Na+ [e0]
# EX_cpd01012_e0 Cd2+ [e0]
# EX_cpd00276_e0 GLUM [e0]
# EX_cpd00082_e0 D-Fructose [e0]
# EX_cpd00080_e0 Glycerol-3-phosphate [e0]
# EX_cpd00023_e0 L-Glutamate [e0]
# EX_cpd00058_e0 Cu2+ [e0]
# EX_cpd00107_e0 L-Leucine [e0]
# EX_cpd00314_e0 D-Mannitol [e0]
# EX_cpd01017_e0 Cys-Gly [e0]
# EX_cpd00013_e0 NH3 [e0]
# EX_cpd00244_e0 Ni2+ [e0]
# EX_cpd11578_e0 hexanesulfonate [e0]
# EX_cpd00179_e0 Maltose [e0]
# EX_cpd00205_e0 K+ [e0]
# EX_cpd00009_e0 Phosphate [e0]
# EX_cpd00060_e0 L-Methionine [e0]
# EX_cpd00137_e0 Citrate [e0]
# EX_cpd00034_e0 Zn2+ [e0]
# EX_cpd00076_e0 Sucrose [e0]
# EX_cpd11579_e0 ethanesulfonate [e0]
# EX_cpd01171_e0 Dulcose [e0]
# EX_cpd00210_e0 Taurine [e0]
# EX_cpd00264_e0 Spermidine [e0]
# EX_cpd00637_e0 D-Methionine [e0]
# EX_cpd00041_e0 L-Aspartate [e0]
# EX_cpd00122_e0 N-Acetyl-D-glucosamine [e0]
# EX_cpd03696_e0 Ursin [e0]
# EX_cpd00118_e0 Putrescine [e0]
# EX_cpd00220_e0 Riboflavin [e0]
# EX_cpd00224_e0 L-Arabinose [e0]
# EX_cpd00138_e0 D-Mannose [e0]
# EX_cpd03048_e0 Isethionate [e0]
# EX_cpd11596_e0 butanesulfonate [e0]
# EX_cpd00540_e0 BET [e0]
# EX_cpd00065_e0 L-Tryptophan [e0]
# EX_cpd01914_e0 L-Methionine S-oxide [e0]
# EX_cpd00395_e0 L-Cysteate [e0]
# EX_cpd00027_e0 D-Glucose [e0]
# EX_cpd11575_e0 MOPS [e0]
# EX_cpd00794_e0 TRHL [e0]
# EX_cpd00105_e0 D-Ribose [e0]
# EX_cpd09878_e0 Sulfoacetate [e0]
# EX_cpd00254_e0 Mg [e0]
# EX_cpd00322_e0 L-Isoleucine [e0]
# EX_cpd00104_e0 BIOT [e0]
# EX_cpd03424_e0 Vitamin B12 [e0]
# EX_cpd08023_e0 methanesulfonate [e0]
# EX_cpd00092_e0 Uracil [e0]
# EX_cpd00053_e0 L-Glutamine [e0]
# EX_cpd00156_e0 L-Valine [e0]
# EX_cpd00130_e0 L-Malate [e0]
# EX_cpd00158_e0 CELB [e0]
# EX_cpd15574_e0 tungstate [e0]
# EX_cpd00166_e0 Calomide [e0]
# EX_cpd00731_e0 Ala-Ala [e0]
# EX_cpd10515_e0 Fe2+ [e0]
# EX_cpd00635_e0 Cbl [e0]
# EX_cpd00033_e0 Glycine [e0]
# EX_cpd00149_e0 Co2+ [e0]
# EX_cpd00531_e0 Hg2+ [e0]
# EX_cpd00141_e0 Propionate [e0]
# EX_cpd00324_e0 MTTL [e0]
# EX_cpd00020_e0 Pyruvate [e0]
# EX_cpd00001_e0 H2O [e0]
# EX_cpd01414_e0 Tetrathionate [e0]
# EX_cpd00029_e0 Acetate [e0]
# EX_cpd00047_e0 Formate [e0]
# EX_cpd10516_e0 fe3 [e0]
# EX_cpd00116_e0 Methanol [e0]
# EX_cpd00011_e0 CO2 [e0]
# EX_cpd03453_e0 Enterobactin [e0]
# EX_cpd03726_e0 Fe-enterochlin [e0]
# EX_cpd00363_e0 Ethanol [e0]
# EX_cpd03662_e0 n-Butanol [e0]
# EX_cpd00071_e0 Acetaldehyde [e0]
# EX_cpd11640_e0 H2 [e0]
# EX_cpd00221_e0 D-Lactate [e0]
# EX_cpd01861_e0 (R)-1,2-Propanediol [e0]
# EX_cpd00239_e0 H2S [e0]
# EX_cpd00081_e0 Sulfite [e0]
# EX_cpd00268_e0 H2S2O3 [e0]

# %%
model_gf = models_base['Salt_Pond_MetaG_R1_A_D1_MG_DASTool_bins.concoct_out.9.contigs']
min_biomass = 0.02
model.objective = 'bio1'
gapfill = MSGapfill(model_gf, default_gapfill_templates=[template], test_conditions={}, default_target='bio1')
gapfill.gfmodel.reactions.rxn05181_c0.upper_bound = 0

# %%
delete_bounds = [
    'rxn08615_c0',
    'rxn05579_c0',
    'rxn11678_c0',
]
for rxn_id in delete_bounds:
    if rxn_id in gapfill.gfmodel.reactions:
        rxn = gapfill.gfmodel.reactions.get_by_id(rxn_id)
        rxn.lower_bound = 0
        rxn.upper_bound = 0
change_bounds = {
    'rxn08615_c0': [0, 1000],
}
for rxn_id, [lb, ub] in change_bounds.items():
    if rxn_id in gapfill.gfmodel.reactions:
        rxn = gapfill.gfmodel.reactions.get_by_id(rxn_id)
        rxn.lower_bound = lb
        rxn.upper_bound = ub

# %%
disable_lb = [
    'rxn02154_c0',
        'rxn00145_c0', # 
        'rxn00362_c0', # H2O [c0] + CMP [c0] <=> ribose-5-phosphate [c0] + Cytosine [c0] -1000.0 {}'
        'rxn01541_c0', # H2O [c0] + Cytidine [c0] <=> D-Ribose [c0] + Cytosine [c0] 1000.0 {}
        'rxn00797_c0', # H2O [c0] + Uridine [c0] <=> Uracil [c0] + D-Ribose [c0] -1000.0 {}
        'rxn01226_c0', # H2O [c0] + Guanosine [c0] <=> D-Ribose [c0] + Guanine [c0]
        'rxn02314_c0', # ATP [c0] + D-Tagatose 6-phosphate [c0] <=> ADP [c0] + H+ [c0] + D-Tagatose 1,6-biphosphate [c0]
        'rxn00839_c0', # ATP [c0] + dADP [c0] <=> ADP [c0] + dATP [c0] 
        'rxn00216_c0', # ATP [c0] + D-Glucose [c0] -> ADP [c0] + H+ [c0] + D-glucose-6-phosphate [c0]
        'rxn15249_c0', # ATP [c0] + alpha-D-Glucose [c0] -> ADP [c0] + H+ [c0] + alpha-D-Glucose 6-phosphate [c0]
        'rxn00515_c0', # ATP [c0] + IDP [c0] -> ADP [c0] + ITP [c0]
        'rxn01673_c0', # ATP [c0] + dCDP [c0] -> ADP [c0] + dCTP [c0]
        'rxn01353_c0', # ATP [c0] + dGDP [c0] -> ADP [c0] + dGTP [c0] **
        'rxn01128_c0', # dATP [c0] + Cytidine [c0] -> CMP [c0] + H+ [c0] + dADP [c0] ***
        'rxn01678_c0', # ATP [c0] + dUDP [c0] <=> ADP [c0] + dUTP [c0] -1000.0 **
]
for rxn_id in disable_lb:
    if rxn_id in gapfill.gfmodel.reactions:
        rxn = gapfill.gfmodel.reactions.get_by_id(rxn_id)
        rxn.lower_bound = 0

# %%
gapfill.gfmodel.reactions.bio1.lower_bound = min_biomass
gapfill_medium = build_media(gapfill.gfmodel, CONST_MEDIA_BET_O2)
gapfill.gfmodel.medium = gapfill_medium
gapfill_fba = gapfill.gfmodel.optimize()
print(gapfill_fba.fluxes['bio1'])
gapfill_solution = _get_solution(template, gapfill, gapfill_fba, model_gf)
print(len(gapfill_solution))
# Out:
# 0.02
# 0

# %%
_integrate_solution(template, model_gf, gap_fill_solution=gapfill_solution)
_add_dm(model_gf, template)

# %%
model_gf.medium = build_media(model_gf, CONST_MEDIA_BET_O2)
if 'rxn05579_c0' in model_gf.reactions:
    model_gf.reactions.rxn05579_c0.lower_bound = 0
    model_gf.reactions.rxn05579_c0.upper_bound = 0
for rxn_id in disable_lb:
    if rxn_id in model_gf.reactions:
        rxn = model_gf.reactions.get_by_id(rxn_id)
        rxn.lower_bound = 0
for rxn_id in delete_bounds:
    if rxn_id in model_gf.reactions:
        rxn = model_gf.reactions.get_by_id(rxn_id)
        rxn.lower_bound = 0
        rxn.upper_bound = 0
for rxn_id, [lb, ub] in change_bounds.items():
    if rxn_id in model_gf.reactions:
        rxn = model_gf.reactions.get_by_id(rxn_id)
        rxn.lower_bound = lb
        rxn.upper_bound = ub

# %%
model_gf.medium = {'EX_cpd00067_e0': 100.0,
 'EX_cpd00971_e0': 100.0,
 'EX_cpd00058_e0': 100.0,
 'EX_cpd00013_e0': 100.0,
 'EX_cpd00244_e0': 100.0,
 'EX_cpd00205_e0': 100.0,
 'EX_cpd00009_e0': 100.0,
 'EX_cpd00034_e0': 100.0,
 'EX_cpd00540_e0': 1.0,
 'EX_cpd00254_e0': 100.0,
 'EX_cpd10515_e0': 100.0,
 'EX_cpd00149_e0': 100.0,
 'EX_cpd00001_e0': 100.0,
 'EX_cpd10516_e0': 100.0,
 'EX_cpd00063_e0': 100.0,
 'EX_cpd00030_e0': 100.0,
 'EX_cpd00048_e0': 100.0,
 'EX_cpd00099_e0': 100.0,
 'EX_cpd00007_e0': 10.0}

# %%
model_gf.reactions.rxn01128_c0.lower_bound = 0
model_gf.reactions.rxn01128_c0.upper_bound = 1000
model_gf.reactions.rxn01510_c0.lower_bound = 0
model_gf.reactions.rxn01510_c0.upper_bound = 1000

# %%
model_gf.reactions.rxn02154_c0
# Out:
# <Reaction rxn02154_c0 at 0x7b82251264a0>

# %%
model_gf.reactions.rxn05902_c0.lower_bound = 0

# %%
model_gf.objective = 'bio1'

# %%
sol = cobra.flux_analysis.pfba(model_gf)
model_gf.summary(sol)
# Out:
# <h3>Objective</h3><p>1.0 bio1 = 0.5699671612620528</p><h4>Uptake</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>cpd00007_e0</td>
#       <td>EX_cpd00007_e0</td>
#       <td>3.193</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>cpd00009_e0</td>
#       <td>EX_cpd00009_e0</td>
#       <td>0.6641</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>cpd00013_e0</td>
#       <td>EX_cpd00013_e0</td>
#       <td>4.167</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>cpd00030_e0</td>
#       <td>EX_cpd00030_e0</td>
#       <td>0.004351</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>cpd00034_e0</td>
#       <td>EX_cpd00034_e0</td>
#       <td>0.004351</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>cpd00048_e0</td>
#       <td>EX_cpd00048_e0</td>
#       <td>0.1304</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>cpd00058_e0</td>
#       <td>EX_cpd00058_e0</td>
#       <td>0.004351</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>cpd00063_e0</td>
#       <td>EX_cpd00063_e0</td>
#       <td>0.004351</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>cpd00067_e0</td>
#       <td>EX_cpd00067_e0</td>
#       <td>100</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>cpd00099_e0</td>
#       <td>EX_cpd00099_e0</td>
#       <td>0.004351</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>cpd00149_e0</td>
#       <td>EX_cpd00149_e0</td>
#       <td>0.004351</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>cpd00205_e0</td>
#       <td>EX_cpd00205_e0</td>
#       <td>0.004351</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>cpd00254_e0</td>
#       <td>EX_cpd00254_e0</td>
#       <td>0.004351</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>cpd00540_e0</td>
#       <td>EX_cpd00540_e0</td>
#       <td>10</td>
#       <td>5</td>
#       <td>100.00%</td>
#     </tr>
#     <tr>
#       <td>cpd10515_e0</td>
#       <td>EX_cpd10515_e0</td>
#       <td>0.0174</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#   </tbody>
# </table><h4>Secretion</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>cpd00001_e0</td>
#       <td>EX_cpd00001_e0</td>
#       <td>-1.227</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>cpd00047_e0</td>
#       <td>EX_cpd00047_e0</td>
#       <td>-9.759</td>
#       <td>1</td>
#       <td>32.72%</td>
#     </tr>
#     <tr>
#       <td>cpd00425_e0</td>
#       <td>EX_cpd00425_e0</td>
#       <td>-10</td>
#       <td>2</td>
#       <td>67.06%</td>
#     </tr>
#     <tr>
#       <td>cpd11640_e0</td>
#       <td>EX_cpd11640_e0</td>
#       <td>-51.14</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>cpd02701_c0</td>
#       <td>SK_cpd02701_c0</td>
#       <td>-0.004351</td>
#       <td>15</td>
#       <td>0.22%</td>
#     </tr>
#     <tr>
#       <td>cpd11416_c0</td>
#       <td>SK_cpd11416_c0</td>
#       <td>-0.57</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#   </tbody>
# </table>

# %%
for rxn in model_gf.reactions:
    v = sol.fluxes[rxn.id]
    if v != 0:
        print(rxn.id, rxn.build_reaction_string(True), v, gapfill_solution.get(rxn.id), rxn.check_mass_balance())
# Out:
# rxn00545_c0 ATP [c0] + D-fructose-6-phosphate [c0] --> ADP [c0] + H+ [c0] + D-fructose-1,6-bisphosphate [c0] 0.3333333333333294 None {}
# rxn00148_c0 ATP [c0] + Pyruvate [c0] <-- ADP [c0] + Phosphoenolpyruvate [c0] + H+ [c0] -0.33333333333332943 None {}
# rxn00781_c0 NAD [c0] + Phosphate [c0] + Glyceraldehyde3-phosphate [c0] <=> NADH [c0] + H+ [c0] + 1,3-Bisphospho-D-glycerate [c0] 0.33333333333332943 None {}
# rxn00191_c0 2-Oxoglutarate [c0] + L-Alanine [c0] <=> Pyruvate [c0] + L-Glutamate [c0] 0.999999999999988 None {}
# rxn00250_c0 ATP [c0] + Pyruvate [c0] + H2CO3 [c0] <=> ADP [c0] + Phosphate [c0] + Oxaloacetate [c0] + H+ [c0] -0.999999999999988 None {}
# rxn00171_c0 NAD [c0] + CoA [c0] + Acetaldehyde [c0] <=> NADH [c0] + Acetyl-CoA [c0] + H+ [c0] -1.3333333333333144 None {}
# rxn00506_c0 H2O [c0] + NAD [c0] + Acetaldehyde [c0] --> NADH [c0] + Acetate [c0] + 2 H+ [c0] 1.3333333333333144 None {}
# rxn00747_c0 Glyceraldehyde3-phosphate [c0] <=> Glycerone-phosphate [c0] -0.3333333333333294 None {}
# rxn00777_c0 ribose-5-phosphate [c0] <=> D-Ribulose5-phosphate [c0] 0.33333333333334136 None {}
# rxn00422_c0 Pyruvate [c0] + L-Serine [c0] <=> L-Alanine [c0] + Hydroxypyruvate [c0] 0.999999999999988 None {}
# rxn00424_c0 Glyoxalate [c0] + L-Serine [c0] <=> Glycine [c0] + Hydroxypyruvate [c0] -1.0 None {}
# rxn00786_c0 D-fructose-1,6-bisphosphate [c0] <=> Glycerone-phosphate [c0] + Glyceraldehyde3-phosphate [c0] 0.3333333333333294 None {}
# rxn01100_c0 ATP [c0] + 3-Phosphoglycerate [c0] <=> ADP [c0] + 1,3-Bisphospho-D-glycerate [c0] -0.33333333333332943 None {}
# rxn11676_c0 H2O [c0] + NH3 [c0] + Acetylphosphate [c0] + trdox [c0] --> Phosphate [c0] + Glycine [c0] + H+ [c0] + trdrd [c0] 1.0 None {}
# rxn05734_c0 H2O [c0] + NAD [c0] + Glyoxalate [c0] <=> NADH [c0] + 2 H+ [c0] + Oxalate [c0] 0.999999999999988 None {}
# rxn00006_c0 2 H2O2 [c0] <-- 2 H2O [c0] + O2 [c0] -1.1666666666666587 None {}
# rxn01106_c0 2-Phospho-D-glycerate [c0] <=> 3-Phosphoglycerate [c0] -0.33333333333332943 None {}
# rxn00066_c0 NADH [c0] + H2O2 [c0] + H+ [c0] --> 2 H2O [c0] + NAD [c0] 0.3333333333333295 None {}
# rxn09315_c0 H+ [c0] + (CH3)3NO [c0] + 2-Demethylmenaquinol 8 [c0] <=> H2O [c0] + (CH3)3N [c0] + 2-Demethylmenaquinone 8 [c0] -1.0 None {}
# rxn00184_c0 H2O [c0] + NADP [c0] + L-Glutamate [c0] <=> NADPH [c0] + NH3 [c0] + 2-Oxoglutarate [c0] + H+ [c0] 0.999999999999988 None {}
# rxn05559_c0 Formate [e0] + H+ [e0] <=> Formate [c0] + H+ [c0] -2.3333333333333144 None {}
# rxn00459_c0 2-Phospho-D-glycerate [c0] <=> H2O [c0] + Phosphoenolpyruvate [c0] 0.33333333333332943 None {}
# rxn08354_c0 DMSO [c0] + Menaquinol 8 [c0] <=> H2O [c0] + Methyl sulfide [c0] + Menaquinone 8 [c0] -1.0 None {}
# rxn00785_c0 D-fructose-6-phosphate [c0] + Glyceraldehyde3-phosphate [c0] <=> D-Xylulose5-phosphate [c0] + D-Erythrose4-phosphate [c0] 0.3333333333333293 None {}
# rxn01200_c0 Glyceraldehyde3-phosphate [c0] + Sedoheptulose7-phosphate [c0] <=> ribose-5-phosphate [c0] + D-Xylulose5-phosphate [c0] 0.3333333333333293 None {}
# rxn09296_c0 H2O2 [c0] + trdrd [c0] --> 2 H2O [c0] + trdox [c0] 1.999999999999988 None {}
# rxn08356_c0 DMSO [c0] + 2-Demethylmenaquinol 8 [c0] <=> H2O [c0] + Methyl sulfide [c0] + 2-Demethylmenaquinone 8 [c0] 1.0 None {}
# rxn00157_c0 Acetyl-CoA [c0] + Formate [c0] <-- CoA [c0] + Pyruvate [c0] -2.3333333333333144 None {}
# rxn05289_c0 NADPH [c0] + H+ [c0] + trdox [c0] <=> NADP [c0] + trdrd [c0] 0.999999999999988 None {}
# rxn00154_c0 NAD [c0] + CoA [c0] + Pyruvate [c0] <=> NADH [c0] + CO2 [c0] + Acetyl-CoA [c0] -0.999999999999988 None {}
# rxn05759_c0 2 H+ [c0] + 2 Reducedferredoxin [c0] <=> 2 Oxidizedferredoxin [c0] + H2 [c0] 50.83333333333332 None {'charge': 2}
# rxn14048_c0 CO2 [c0] + H+ [c0] + Succinyl-CoA [c0] + 2 Reducedferredoxin [c0] <-- CoA [c0] + 2-Oxoglutarate [c0] + 2 Oxidizedferredoxin [c0] -101.66666666666664 None {'charge': 2}
# rxn08173_c0 ADP [c0] + Phosphate [c0] + 4 H+ [e0] <=> H2O [c0] + ATP [c0] + 3 H+ [c0] 25.666666666666664 None {}
# rxn27318_c0 NADP [c0] + Red-Thioredoxin [c0] <=> NADPH [c0] + Ox-Thioredoxin [c0] -1.0 None {}
# rxn05319_c0 H2O [e0] <=> H2O [c0] 1.0000000000000022 None {}
# rxn05488_c0 Acetate [e0] + H+ [e0] <=> Acetate [c0] + H+ [c0] -0.33333333333333837 None {}
# rxn05468_c0 O2 [e0] --> O2 [c0] 1.1666666666666587 None {}
# rxn08691_c0 H2 [c0] <=> H2 [e0] 50.83333333333332 None {}
# EX_cpd00067_e0 H+ [e0] <=>  -100.0 None {'charge': -1, 'H': -1}
# EX_cpd00540_e0 BET [e0] <=>  -1.0 None {'C': -5, 'H': -11, 'N': -1, 'O': -2}
# EX_cpd00047_e0 Formate [e0] -->  2.3333333333333144 None {'charge': 1, 'C': -1, 'H': -1, 'O': -2}
# EX_cpd00001_e0 H2O [e0] <=>  -1.0000000000000022 None {'H': -2, 'O': -1}
# EX_cpd00029_e0 Acetate [e0] -->  0.33333333333333837 None {'charge': 1, 'C': -2, 'H': -3, 'O': -2}
# EX_cpd00007_e0 O2 [e0] <=>  -1.1666666666666587 None {'O': -2}
# EX_cpd11640_e0 H2 [e0] -->  50.83333333333332 None {'H': -2}
# ATPM_c0 H2O [c0] + ATP [c0] --> ADP [c0] + Phosphate [c0] + H+ [c0] 26.999999999999996 None {}
# rxs17220_c0 Phosphate [c0] + 2 H+ [c0] + BET [e0] + Red-Thioredoxin [c0] --> H2O [c0] + Acetylphosphate [c0] + (CH3)3N [e0] + Ox-Thioredoxin [c0] 1.0 None {}
# rxn01818_c0 H+ [c0] + (CH3)3NO [c0] --> Formaldehyde [c0] + (CH3)2NH [c0] 1.0 None {}
# rxn10614_c0 H+ [e0] + (CH3)3N [e0] --> H+ [c0] + (CH3)3N [c0] 1.0 None {}
# rxn00102_c0 H+ [c0] + H2CO3 [c0] --> H2O [c0] + CO2 [c0] 0.999999999999988 None {}
# rxn01116_c0 D-Ribulose5-phosphate [c0] <-- D-Xylulose5-phosphate [c0] -0.6666666666666586 None {}
# rxn03643_c0 Formaldehyde [c0] + D-Ribulose5-phosphate [c0] --> D-arabino-6-Phospho-hex-3-ulose [c0] 1.0 None {}
# rxn08167_c0 L-Aspartate [c0] + Menaquinone 8 [c0] <-- H+ [c0] + Iminoaspartate [c0] + Menaquinol 8 [c0] -1.0 None {}
# rxn01333_c0 Glyceraldehyde3-phosphate [c0] + Sedoheptulose7-phosphate [c0] <-- D-fructose-6-phosphate [c0] + D-Erythrose4-phosphate [c0] -0.3333333333333293 None {}
# rxn05117_c0 NADP [c0] + L-Aspartate [c0] --> NADPH [c0] + 2 H+ [c0] + Iminoaspartate [c0] 1.0 None {}
# rxn05939_c0 CO2 [c0] + H+ [c0] + Succinyl-CoA [c0] + Reducedferredoxin [c0] --> CoA [c0] + 2-Oxoglutarate [c0] + Oxidizedferredoxin [c0] 101.66666666666664 None {}
# rxn10497_c0 H+ [e0] + (CH3)2NH [e0] <-- H+ [c0] + (CH3)2NH [c0] -1.0 None {}
# rxn00244_c0 H2O [c0] + Oxaloacetate [c0] <-- Acetate [c0] + H+ [c0] + Oxalate [c0] -0.999999999999988 None {}
# rxn03644_c0 D-arabino-6-Phospho-hex-3-ulose [c0] --> D-fructose-6-phosphate [c0] 1.0 None {}
# EX_cpd00425_e0 (CH3)2NH [e0] -->  1.0 None {'charge': -1, 'C': -2, 'H': -8, 'N': -1}

# %%
# %run ~/the_ms_builder.py
def gapfill(model, template):
    from modelseedpy import MSGapfill
    from modelseedpy import MSBuilder
    model_gf = model.copy()
    min_biomass = 0.02
    model.objective = 'bio1'
    gapfill = MSGapfill(model_gf, default_gapfill_templates=[template], test_conditions={}, default_target='bio1')
    gapfill.gfmodel.reactions.rxn05579_c0.lower_bound = 0
    gapfill.gfmodel.reactions.rxn05579_c0.upper_bound = 0
    gapfill.gfmodel.reactions.rxn05181_c0.upper_bound = 0
    gapfill.gfmodel.reactions.rxn11678_c0.upper_bound = 0
    gapfill.gfmodel.reactions.rxn11678_c0.lower_bound = 0
    gapfill.gfmodel.reactions.bio1.lower_bound = min_biomass
    gapfill_medium = build_media(gapfill.gfmodel, CONST_MEDIA_BET_O2)
    gapfill.gfmodel.medium = gapfill_medium
    gapfill_fba = gapfill.gfmodel.optimize()
    print(gapfill_fba.fluxes['bio1'])
    gapfill_solution = _get_solution(template, gapfill, gapfill_fba, model_gf)
    print(len(gapfill_solution))
    _integrate_solution(template, model_gf, gap_fill_solution=gapfill_solution)
    _add_dm(model_gf, template)
    return model_gf

# %%
model_gapfill_bet = {}
for model_id, model in models_base.items():
    model_gapfill_bet[model_id] = gapfill(model, template)
# Out:
# 0.02
# cpd02701_c SK_cpd02701_c0 Sink for S-Adenosyl-4-methylthio-2-oxobutanoate [c] SK_cpd02701_c0: cpd02701_c0 -->
# 0.02
# cpd02701_c SK_cpd02701_c0 Sink for S-Adenosyl-4-methylthio-2-oxobutanoate [c] SK_cpd02701_c0: cpd02701_c0 -->
# 0.02
# cpd02701_c SK_cpd02701_c0 Sink for S-Adenosyl-4-methylthio-2-oxobutanoate [c] SK_cpd02701_c0: cpd02701_c0 -->
# 0.02
# cpd02701_c SK_cpd02701_c0 Sink for S-Adenosyl-4-methylthio-2-oxobutanoate [c] SK_cpd02701_c0: cpd02701_c0 -->
# 0.02
# cpd02701_c SK_cpd02701_c0 Sink for S-Adenosyl-4-methylthio-2-oxobutanoate [c] SK_cpd02701_c0: cpd02701_c0 -->
# 0.02
# cpd02701_c SK_cpd02701_c0 Sink for S-Adenosyl-4-methylthio-2-oxobutanoate [c] SK_cpd02701_c0: cpd02701_c0 -->
# 0.02
# cpd02701_c SK_cpd02701_c0 Sink for S-Adenosyl-4-methylthio-2-oxobutanoate [c] SK_cpd02701_c0: cpd02701_c0 -->
# 0.02
# cpd02701_c SK_cpd02701_c0 Sink for S-Adenosyl-4-methylthio-2-oxobutanoate [c] SK_cpd02701_c0: cpd02701_c0 -->
# 0.02
# cpd02701_c SK_cpd02701_c0 Sink for S-Adenosyl-4-methylthio-2-oxobutanoate [c] SK_cpd02701_c0: cpd02701_c0 -->
# 0.02
# cpd02701_c SK_cpd02701_c0 Sink for S-Adenosyl-4-methylthio-2-oxobutanoate [c] SK_cpd02701_c0: cpd02701_c0 -->
# 0.02
# cpd02701_c SK_cpd02701_c0 Sink for S-Adenosyl-4-methylthio-2-oxobutanoate [c] SK_cpd02701_c0: cpd02701_c0 -->
# 0.02
# cpd02701_c SK_cpd02701_c0 Sink for S-Adenosyl-4-methylthio-2-oxobutanoate [c] SK_cpd02701_c0: cpd02701_c0 -->
# 0.02
# cpd02701_c SK_cpd02701_c0 Sink for S-Adenosyl-4-methylthio-2-oxobutanoate [c] SK_cpd02701_c0: cpd02701_c0 -->
# 0.02
# cpd02701_c SK_cpd02701_c0 Sink for S-Adenosyl-4-methylthio-2-oxobutanoate [c] SK_cpd02701_c0: cpd02701_c0 -->
# 0.02
# cpd02701_c SK_cpd02701_c0 Sink for S-Adenosyl-4-methylthio-2-oxobutanoate [c] SK_cpd02701_c0: cpd02701_c0 -->

# %%
for model_id, model_gf in model_gapfill_bet.items():
    model_gf.medium = build_media(model_gf, CONST_MEDIA_BET_O2)
    if 'rxn05579_c0' in model_gf.reactions:
        model_gf.reactions.rxn05579_c0.lower_bound = 0
        model_gf.reactions.rxn05579_c0.upper_bound = 0
    model_gf.objective = 'bio1'
    sol = cobra.flux_analysis.pfba(model_gf)
    print(sol.fluxes['bio1'], sol.fluxes['EX_cpd00540_e0'], sol.fluxes['EX_cpd00441_e0'])
# Out:
# unable to target: EX_cpd00007_e0
# unable to target: EX_cpd11574_e0
# 1.4079455717359073 -10.0 -5.861977570020827e-14
# unable to target: EX_cpd11574_e0
# unable to target: EX_cpd00244_e0
# 0.7788405813175541 -10.00000000000002 0.0
# 0.8453124349342236 -10.0 0.0
# unable to target: EX_cpd11574_e0
# unable to target: EX_cpd00244_e0
# 0.7810836825186124 -10.0 0.0
# unable to target: EX_cpd11574_e0
# 0.8453124349342249 -10.0 0.0
# unable to target: EX_cpd00007_e0
# unable to target: EX_cpd11574_e0
# 0.7803857498887422 -10.0 0.0
# unable to target: EX_cpd11574_e0
# unable to target: EX_cpd00244_e0
# 1.407945571735912 -10.0 -1.474376176702208e-13
# unable to target: EX_cpd11574_e0
# unable to target: EX_cpd00244_e0
# 0.7779926106542269 -10.000000000000078 0.0
# unable to target: EX_cpd11574_e0
# unable to target: EX_cpd00244_e0
# 0.7779926106542246 -10.000000000000073 0.0
# unable to target: EX_cpd11574_e0
# 1.4079455717359124 -10.0 -1.509903313490213e-13
# unable to target: EX_cpd11574_e0
# 1.0431892279584614 -10.0 -1.9539925233402755e-13
# 0.7900267589991304 -10.0 0.0
# unable to target: EX_cpd00007_e0
# 1.4065773104843962 -10.0 -3.197442310920451e-14
# unable to target: EX_cpd11574_e0
# 0.7802308230970874 -10.0 0.0
# 0.7905829851494092 -10.0 0.0

# %%
model_gf.summary(sol)
# Out:
# <h3>Objective</h3><p>1.0 ATPM_c0 = 1000.0</p><h4>Uptake</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><h4>Secretion</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table>

# %%
for rxn_ex in model_gf.exchanges:
    v = sol.fluxes[rxn_ex.id]
    if v != 0:
        print(rxn_ex, v)
# Out:
# EX_cpd00067_e0: cpd00067_e0 <=>  -3.1124687176569927
# EX_cpd00058_e0: cpd00058_e0 <=>  -0.010747345599691571
# EX_cpd00013_e0: cpd00013_e0 <=>  -0.29281629823965516
# EX_cpd00205_e0: cpd00205_e0 <=>  -0.010747345599691571
# EX_cpd00009_e0: cpd00009_e0 <=>  -1.6404720650078009
# EX_cpd00034_e0: cpd00034_e0 <=>  -0.010747345599691571
# EX_cpd00540_e0: cpd00540_e0 <=>  -10.0
# EX_cpd00254_e0: cpd00254_e0 <=>  -0.010747345599691571
# EX_cpd10515_e0: cpd10515_e0 <=>  -0.042989382398766283
# EX_cpd00149_e0: cpd00149_e0 <=>  -0.010747345599691571
# EX_cpd00001_e0: cpd00001_e0 <=>  6.063643657680451
# EX_cpd11640_e0: cpd11640_e0 -->  11.341816574205701
# EX_cpd00441_e0: cpd00441_e0 -->  -5.684341886080802e-14
# EX_cpd00063_e0: cpd00063_e0 <=>  -0.010747345599691571
# EX_cpd00030_e0: cpd00030_e0 <=>  -0.010747345599691571
# EX_cpd00048_e0: cpd00048_e0 <=>  -0.3222342890391423
# EX_cpd00099_e0: cpd00099_e0 <=>  -0.010747345599691571

# %%
model_gf
# Out:
# 144

# %%
# %run ~/the_ms_builder.py
# Out:
# cpd02701_c SK_cpd02701_c0 Sink for S-Adenosyl-4-methylthio-2-oxobutanoate [c] SK_cpd02701_c0: cpd02701_c0 -->

# %%
model_gf.metabolites.cpd00540_e0.summary(sol)
# Out:
# <h3>cpd00540_e0</h3><p>C5H11NO2</p><h4>Producing Reactions</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Percent</th>
#       <th>Flux</th>
#       <th>Reaction</th>
#       <th>Definition</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>100.00%</td>
#       <td>10</td>
#       <td>EX_cpd00540_e0</td>
#       <td>cpd00540_e0 &lt;=&gt;</td>
#     </tr>
#   </tbody>
# </table><h4>Consuming Reactions</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Percent</th>
#       <th>Flux</th>
#       <th>Reaction</th>
#       <th>Definition</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>100.00%</td>
#       <td>-10</td>
#       <td>rxs17220_c0</td>
#       <td>cpd00009_c0 + 2 cpd00067_c0 + cpd00540_e0 + cpd28060_c0 --&gt; cpd00001_c0 + cpd00196_c0 + cpd00441_e0 + cpd27735_c0</td>
#     </tr>
#   </tbody>
# </table>

# %%
model_gf.metabolites.cpd00441_e0.summary(sol)
# Out:
# <h3>cpd00441_e0</h3><p>C3H10N</p><h4>Producing Reactions</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Percent</th>
#       <th>Flux</th>
#       <th>Reaction</th>
#       <th>Definition</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>100.00%</td>
#       <td>10</td>
#       <td>rxs17220_c0</td>
#       <td>cpd00009_c0 + 2 cpd00067_c0 + cpd00540_e0 + cpd28060_c0 --&gt; cpd00001_c0 + cpd00196_c0 + cpd00441_e0 + cpd27735_c0</td>
#     </tr>
#   </tbody>
# </table><h4>Consuming Reactions</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Percent</th>
#       <th>Flux</th>
#       <th>Reaction</th>
#       <th>Definition</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>100.00%</td>
#       <td>-10</td>
#       <td>rxn10614_c0</td>
#       <td>cpd00067_e0 + cpd00441_e0 --&gt; cpd00067_c0 + cpd00441_c0</td>
#     </tr>
#   </tbody>
# </table>

# %%
model_gf.metabolites.cpd00441_c0.summary(sol)
# Out:
# <h3>cpd00441_c0</h3><p>C3H10N</p><h4>Producing Reactions</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Percent</th>
#       <th>Flux</th>
#       <th>Reaction</th>
#       <th>Definition</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>100.00%</td>
#       <td>10</td>
#       <td>rxn10614_c0</td>
#       <td>cpd00067_e0 + cpd00441_e0 --&gt; cpd00067_c0 + cpd00441_c0</td>
#     </tr>
#   </tbody>
# </table><h4>Consuming Reactions</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Percent</th>
#       <th>Flux</th>
#       <th>Reaction</th>
#       <th>Definition</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>9.74%</td>
#       <td>-0.9738</td>
#       <td>rxn01862_c0</td>
#       <td>cpd00001_c0 + cpd00015_c0 + cpd00441_c0 --&gt; cpd00811_c0 + cpd00982_c0</td>
#     </tr>
#     <tr>
#       <td>90.26%</td>
#       <td>-9.026</td>
#       <td>rxn09315_c0</td>
#       <td>cpd00067_c0 + cpd00811_c0 + cpd15353_c0 &lt;=&gt; cpd00001_c0 + cpd00441_c0 + cpd15352_c0</td>
#     </tr>
#   </tbody>
# </table>

# %%
model_gf.reactions.rxn01862_c0
# Out:
# <Reaction rxn01862_c0 at 0x7b830bca0700>

# %%
model_gf.reactions.rxn09315_c0
# Out:
# <Reaction rxn09315_c0 at 0x7b8319acb9a0>

# %%
model.objective = 'bio1'
model.summary()
# Out:
# <h3>Objective</h3><p>1.0 bio1 = 0.0</p><h4>Uptake</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><h4>Secretion</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table>

# %%
model.objective = 'bio1'
model.medium =

# %%
for r in template_neg.compcompounds.cpd27735_c.reactions:
    print(r.id, r.build_reaction_string(True))
# Out:
# rxn17275_c Adenosine 3-5-bisphosphate [c] + Sulfite [c] + Ox-Thioredoxin [c] <-- 3-phosphoadenylylsulfate [c] + Red-Thioredoxin [c]
# rxn27318_c NADP [c] + Red-Thioredoxin [c] <=> NADPH [c] + Ox-Thioredoxin [c]
# rxn22316_c AMP [c] + Sulfite [c] + Ox-Thioredoxin [c] <-- APS [c] + Red-Thioredoxin [c]
# rxs17220_c Phosphate [c] + 2 H+ [c] + BET [e] + Red-Thioredoxin [c] --> H2O [c] + Acetylphosphate [c] + (CH3)3N [e] + Ox-Thioredoxin [c]

# %%
model.reactions.rxn27318_c0
# Out:
# <Reaction rxn27318_c0 at 0x7b837596b9a0>

# %%
for model_id, model in models_base.items():
    if 'rxn00225_c0' not in model.reactions:
        print('!')
# Out:
# !
# !

# %%
for model_id, model in models_base.items():
    if 'rxn00161_c0' not in model.reactions:
        print('!')

# %%
model.reactions.rxn00225_c0
# Out:
# <Reaction rxn00225_c0 at 0x7621968fba60>

# %%
rxn_net
# Out:
# <Reaction rxs17220_c0 at 0x761867723640>

# %%
from modelseedpy.biochem import from_local
modelseed = from_local('/storage/fliu/data/ModelSEEDDatabase')

# %%
template_core = cobrakbase.io.load_kbase_zip_object('./CoreBacV5.1.json.zip')
# add betaine reductase + thioreduc
rxs00002_c = MSTemplateReaction('rxs00002_c', 'rxs00002_c', 'TMA Transport', '', 0, 1000, gapfill_direction='>')
rxs00002_c.add_metabolites({
    template_core.compcompounds.cpd00441_c: -1,
    template_core.compcompounds.cpd00441_e: 1,
})
print(rxs00002_c.check_mass_balance())
template_core.add_reactions([
    modelseed.reactions.rxn17220.to_template_reaction({0:'c'}),
    modelseed.reactions.rxn27318.to_template_reaction({0:'c'}),
    modelseed.reactions.rxn08639.to_template_reaction({0:'c', 1:'e'}),
    modelseed.reactions.rxn08865.to_template_reaction({0:'c', 1:'e'}),
    rxs00002_c
])
template_core.reactions.rxn17220_c.upper_bound = 0
# Out:
# {}

# %%
manual_bet_gapfill = {
    'rxs00002_c': 'rxs00002_c0',
    'rxn17220_c': 'rxn17220_c0',
    'rxn27318_c': 'rxn27318_c0',
    'rxn08639_c': 'rxn08639_c0',
    'rxn08865_c': 'rxn08865_c0',
}
def manual_add_core_gapfill(model_base, rxn_manual_gap, template):
    rxn_to_add = []
    for rxn_id, rxn_model_id in rxn_manual_gap.items():
        if rxn_model_id not in model_base.reactions:
            print(f'add {rxn_id}')
            template_reaction = template.reactions.get_by_id(rxn_id)
            rxn_to_add.append(template_reaction.to_reaction(model_base))
    model_base.add_reactions(rxn_to_add)
    return MSBuilder.add_exchanges_to_model(model_base)
manual_add_core_gapfill(model, manual_bet_gapfill, template_core)
# Out:
# []

# %%
model.objective = 'ATPM_c0'

# %%
media_core_bet

# %%
model.medium = {
    'EX_cpd00067_e0': 1000,
    'EX_cpd00001_e0': 1000,
    'EX_cpd00540_e0': 1,
}

# %%
sol = cobra.flux_analysis.pfba(model)
model.summary(sol)
# Out:
# <h3>Objective</h3><p>1.0 ATPM_c0 = 1.0</p><h4>Uptake</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>cpd00001_e0</td>
#       <td>EX_cpd00001_e0</td>
#       <td>0.5</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>cpd00067_e0</td>
#       <td>EX_cpd00067_e0</td>
#       <td>0.25</td>
#       <td>0</td>
#       <td>0.00%</td>
#     </tr>
#     <tr>
#       <td>cpd00540_e0</td>
#       <td>EX_cpd00540_e0</td>
#       <td>1</td>
#       <td>5</td>
#       <td>100.00%</td>
#     </tr>
#   </tbody>
# </table><h4>Secretion</h4><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Metabolite</th>
#       <th>Reaction</th>
#       <th>Flux</th>
#       <th>C-Number</th>
#       <th>C-Flux</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>cpd00011_e0</td>
#       <td>EX_cpd00011_e0</td>
#       <td>-0.5</td>
#       <td>1</td>
#       <td>10.00%</td>
#     </tr>
#     <tr>
#       <td>cpd00029_e0</td>
#       <td>EX_cpd00029_e0</td>
#       <td>-0.75</td>
#       <td>2</td>
#       <td>30.00%</td>
#     </tr>
#     <tr>
#       <td>cpd00441_e0</td>
#       <td>EX_cpd00441_e0</td>
#       <td>-1</td>
#       <td>3</td>
#       <td>60.00%</td>
#     </tr>
#   </tbody>
# </table>

# %%
model.reactions.rxn05605_c0.lower_bound = 0
model.reactions.rxn05605_c0.upper_bound = 0

# %%
for r in model.reactions:
    v = sol.fluxes[r.id]
    if v != 0:
        print(r.id, v, r.build_reaction_string(True))
# Out:
# rxn00225_c0 -2.0 ATP [c0] + Acetate [c0] <=> ADP [c0] + Acetylphosphate [c0]
# rxn00173_c0 1.0 Phosphate [c0] + Acetyl-CoA [c0] <=> CoA [c0] + Acetylphosphate [c0]
# rxn00161_c0 1.0 NADP [c0] + L-Malate [c0] --> NADPH [c0] + CO2 [c0] + Pyruvate [c0]
# rxn00157_c0 -1.0 Acetyl-CoA [c0] + Formate [c0] <-- CoA [c0] + Pyruvate [c0]
# rxn08173_c0 0.25 ADP [c0] + Phosphate [c0] + 4 H+ [e0] <=> H2O [c0] + ATP [c0] + 3 H+ [c0]
# rxn27318_c0 -1.0 NADP [c0] + Red-Thioredoxin [c0] <=> NADPH [c0] + Ox-Thioredoxin [c0]
# rxn05319_c0 1.0 H2O [e0] <=> H2O [c0]
# rxn05488_c0 -2.0 Acetate [e0] + H+ [e0] <=> Acetate [c0] + H+ [c0]
# rxn05559_c0 -1.0 Formate [e0] + H+ [e0] <=> Formate [c0] + H+ [c0]
# rxn05467_c0 -1.0 CO2 [e0] <=> CO2 [c0]
# EX_cpd00540_e0 -1.0 BET [e0] <=>
# EX_cpd00130_e0 -1.0 L-Malate [e0] <=>
# EX_cpd00047_e0 1.0 Formate [e0] -->
# EX_cpd00001_e0 -1.0 H2O [e0] <=>
# EX_cpd00029_e0 2.0 Acetate [e0] -->
# EX_cpd00011_e0 1.0 CO2 [e0] -->
# ATPM_c0 2.25 H2O [c0] + ATP [c0] --> ADP [c0] + Phosphate [c0] + H+ [c0]
# rxs17220_c0 1.0 Phosphate [c0] + 2 H+ [c0] + BET [e0] + Red-Thioredoxin [c0] --> H2O [c0] + Acetylphosphate [c0] + (CH3)3N [e0] + Ox-Thioredoxin [c0]
# EX_cpd00441_e0 1.0 (CH3)3N [e0] -->
# rxn08865_c0 1.0 2 H+ [e0] + L-Malate [e0] <=> 2 H+ [c0] + L-Malate [c0]

# %%
media_core_bet.get_media_constraints()
# Out:
# {'cpd00130_e0': (-1, 1000),
#  'cpd00540_e0': (-1, 1000),
#  'cpd00067_e0': (-1000, 1000)}

# %%
rxn_net = model.reactions.rxn17220_c0 - model.reactions.rxs00002_c0 + model.reactions.rxn27318_c0 - \
model.reactions.rxn00161_c0 + model.reactions.rxn00225_c0 + model.reactions.rxn08639_c0 - model.reactions.rxn08865_c0
print(rxn_net.check_mass_balance())
rxn_net
# Out:
# {}
# <Reaction rxn17220_c0 at 0x76165ff3c250>

# %%
rxn_net
# Out:
# <Reaction rxn17220_c0 at 0x761663af5db0>

# %%
model.reactions.rxn00225_c0
# Out:
# <Reaction rxn00225_c0 at 0x7621968fba60>

# %%
from cobra.core import Model
model_core = Model('core')
model_core.add_reactions([x.to_reaction(model_core) for x in template_core.reactions])
MSBuilder.add_exchanges_to_model(model_core)
MSBuilder.add_atpm(model_core)

# %%
model_core.reactions.rxs17220_c0 - model_core.reactions.rxn27318_c0 - model_core.reactions.rxn00225_c0
# Out:
# <Reaction rxs17220_c0 at 0x1dfa2e67c10>

# %%
template_neg

# %%
for r in model_core.metabolites.cpd00441_c0.reactions:
    print(r.id, r.build_reaction_string(True), r.bounds)
# Out:
# rxn09318_c0 (CH3)3N [c0] <=> (CH3)3N [e0] (-1000, 1000)
# rxn24612_c0 H+ [c0] + (CH3)3N [c0] + MttC-Proteins [c0] <=> (CH3)2NH [c0] + Methylated-MttC-Proteins [c0] (-1000, 1000)

# %%
for r in model_core.metabolites.cpd00441_e0.reactions:
    print(r.id, r.build_reaction_string(True), r.bounds)
# Out:
# rxn09318_c0 (CH3)3N [c0] <=> (CH3)3N [e0] (-1000, 1000)
# EX_cpd00441_e0 (CH3)3N [e0] <=>  (-1000, 1000)
# rxs17220_c0 Phosphate [c0] + 2 H+ [c0] + BET [e0] + Red-Thioredoxin [c0] --> H2O [c0] + Acetylphosphate [c0] + (CH3)3N [e0] + Ox-Thioredoxin [c0] (0, 1000)
# rxn09314_c0 H+ [e0] + (CH3)3NO [e0] + Menaquinol 8 [c0] --> H2O [e0] + (CH3)3N [e0] + Menaquinone 8 [c0] (0, 1000)

# %%
for m_id, m in models_base.items():
    print(m_id)
    if 'cpd00441_c0' in m.metabolites:
        for r in m.metabolites.cpd00441_c0.reactions:
            print(r.id, r.build_reaction_string(True), r.bounds)
# Out:
# Salt_Pond_MetaG_R1_B_D1_MG_DASTool_bins_metabat.58.contigs
# Salt_Pond_MetaG_R1_B_D1_MG_DASTool_bins_concoct_out.59.contigs
# Salt_Pond_MetaG_R1_C_D2_MG_DASTool_bins_concoct_out.85.contigs
# rxn09315_c0 H+ [c0] + (CH3)3NO [c0] + 2-Demethylmenaquinol 8 [c0] <=> H2O [c0] + (CH3)3N [c0] + 2-Demethylmenaquinone 8 [c0] (-1000.0, 1000.0)
# Salt_Pond_MetaG_R1_A_D1_MG_DASTool_bins.metabat.47.contigs
# Salt_Pond_MetaG_R1_A_D1_MG_DASTool_bins.concoct_out.9.contigs
# rxn09315_c0 H+ [c0] + (CH3)3NO [c0] + 2-Demethylmenaquinol 8 [c0] <=> H2O [c0] + (CH3)3N [c0] + 2-Demethylmenaquinone 8 [c0] (-1000.0, 1000.0)
# Salt_Pond_MetaG_R2_A_D1_MG_DASTool_bins_concoct_out.98.contigs
# Salt_Pond_MetaG_R1_A_D2_MG_DASTool_bins_metabat.45.contigs
# Salt_Pond_MetaG_R2_B_D2_MG_DASTool_bins_metabat.52.contigs
# rxn24612_c0 H+ [c0] + (CH3)3N [c0] + MttC-Proteins [c0] <=> (CH3)2NH [c0] + Methylated-MttC-Proteins [c0] (-1000.0, 1000.0)
# Salt_Pond_MetaG_R1_C_D1_MG_DASTool_bins_maxbin.047.contigs
# Salt_Pond_MetaG_R1_A_D2_MG_DASTool_bins_metabat.27.contigs
# Salt_Pond_MetaG_R1_B_D2_MG_DASTool_bins_concoct_out.73.contigs
# Salt_Pond_MetaG_R1_A_D2_MG_DASTool_bins_metabat.50.contigs
# Salt_Pond_MetaG_R1_C_D2_MG_DASTool_bins_metabat.40.contigs
# rxn24612_c0 H+ [c0] + (CH3)3N [c0] + MttC-Proteins [c0] <=> (CH3)2NH [c0] + Methylated-MttC-Proteins [c0] (-1000.0, 1000.0)
# Salt_Pond_MetaG_R1_A_D1_MG_DASTool_bins.metabat.51.contigs
# Salt_Pond_MetaG_R1_A_D2_MG_DASTool_bins_metabat.48.contigs

# %%
model_base.metabolites.cpd00441_e0
# Out:
# <Metabolite cpd00441_e0 at 0x1df57bf56d0>

# %%
model_base
# Out:
# 'Salt_Pond_MetaG_R1_A_D2_MG_DASTool_bins_metabat.48.contigs'

# %%
for cpx in template_neg.reactions.rxn09315_c.complexes:
    for role in cpx.roles:
        print(role)
# Out:
# ftr01947:Anaerobic dimethyl sulfoxide reductase chain C (EC 1.8.99.-)
# tftr00356:Anaerobic dimethyl sulfoxide reductase chain C (EC 1.8.5.3)
# tftr00374:Anaerobic dimethyl sulfoxide reductase chain C (EC 1.8.5.3), anchor subunit
# ftr01645:Anaerobic dimethyl sulfoxide reductase chain B (EC 1.8.99.-)
# tftr00539:Anaerobic dimethyl sulfoxide reductase chain B (EC 1.8.5.3), iron-sulfur binding subunit
# tftr00928:Anaerobic dimethyl sulfoxide reductase chain B (EC 1.8.5.3)
# ftr01946:Anaerobic dimethyl sulfoxide reductase chain A (EC 1.8.99.-)
# tftr00733:Anaerobic dimethyl sulfoxide reductase chain A (EC 1.8.5.3)
# tftr00123:Anaerobic dimethyl sulfoxide reductase chain A (EC 1.8.5.3), molybdopterin-binding domain

# %%
for cpx in template_neg.reactions.rxn09314_c.complexes:
    for role in cpx.roles:
        print(role)
# Out:
# tftr00529:Trimethylamine-N-oxide reductase associated c-type cytochrome, TorY
# ftr02201:Trimethylamine-N-oxide reductase (EC 1.6.6.9)
# tftr00463:Trimethylamine-N-oxide reductase associated c-type cytochrome, TorC
# ftr02252:Cytochrome c-type protein TorY
# ftr02200:Cytochrome c-type protein TorC

# %%
for cpx in template_neg.reactions.rxn08355_c.complexes:
    for role in cpx.roles:
        print(role)
# Out:
# tftr00733:Anaerobic dimethyl sulfoxide reductase chain A (EC 1.8.5.3)
# tftr00539:Anaerobic dimethyl sulfoxide reductase chain B (EC 1.8.5.3), iron-sulfur binding subunit
# tftr00928:Anaerobic dimethyl sulfoxide reductase chain B (EC 1.8.5.3)
# tftr00356:Anaerobic dimethyl sulfoxide reductase chain C (EC 1.8.5.3)
# tftr00123:Anaerobic dimethyl sulfoxide reductase chain A (EC 1.8.5.3), molybdopterin-binding domain
# tftr00374:Anaerobic dimethyl sulfoxide reductase chain C (EC 1.8.5.3), anchor subunit
