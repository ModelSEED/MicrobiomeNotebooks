# %%
from json import load, dump

gfResults = load(open("/Users/afreiburger/Downloads/new_gf_phenotype_results.json"))
gapfilledContent = {}
for modelID, content in gfResults.items():
    gapfilledContent[modelID] = {}
    for typ, content2 in content.items():
        gapfilledContent[modelID][typ] = "cpd25960" in content2.keys()

display(gapfilledContent)
dump(gapfilledContent, open("/Users/afreiburger/Documents/microbiome/Cliff/gapfilledContent.json", 'w'), indent=3)
# Out:
# {'R2_C_D2.45.pg.G.D': {'uptake': True, 'excretion': True, 'growth': True},
#  'R2_restored_DShore.17.pg.G.D': {'uptake': True,
#   'excretion': True,
#   'growth': True},
#  'R2A_C_D1.4.pg.G.D': {'uptake': True, 'excretion': True, 'growth': True},
#  'SF2_B_H2O.28.pg.G.D': {'uptake': True, 'excretion': True, 'growth': True},
#  'R1_A_D1.15.pg.G.D': {'uptake': True, 'excretion': True, 'growth': True},
#  'R2_C_D1.88.pg.G.D': {'uptake': True, 'excretion': True, 'growth': True},
#  'R2_restored_C_black.57.pg.G.D': {'uptake': True,
#   'excretion': True,
#   'growth': True},
#  'R2_A_D1.10.pg.G.D': {'uptake': True, 'excretion': True, 'growth': True},
#  'R2_B_H2O.29.pg.G.D': {'uptake': True, 'excretion': True, 'growth': True},
#  'R2_restored_DShore.11.pg.G.D': {'uptake': True,
#   'excretion': True,
#   'growth': True},
#  'R1_A_D1.18.pg.G.D': {'uptake': True, 'excretion': True, 'growth': True},
#  'R2_C_H2O.29.pg.G.D': {'uptake': True, 'excretion': True, 'growth': True},
# ...

# %%
from json import load, dump

gfResults = load(open("/Users/afreiburger/Downloads/gf_phenotype_results.json"))
gapfilledContent = {}
for modelID, content in gfResults.items():
    gapfilledContent[modelID] = {}
    for typ, content2 in content.items():
        gapfilledContent[modelID][typ] = "cpd25960" in content2.keys()

display(gapfilledContent)
dump(gapfilledContent, open("/Users/afreiburger/Documents/microbiome/Cliff/gapfilledContent2.json", 'w'), indent=3)
# Out:
# {'R1_A_D1.18.pg.G.D': {'uptake': True, 'excretion': True, 'growth': True},
#  'R2_C_H2O.29.pg.G.D': {'uptake': True, 'excretion': True, 'growth': True},
#  'SF2_B_D1.44.pg.G.D': {'uptake': True, 'excretion': True, 'growth': True},
#  'R2A_A_D1.51.pg.G.D': {'uptake': True, 'excretion': True, 'growth': True},
#  'R2_A_D1.49.pg.G.D': {'uptake': True, 'excretion': True, 'growth': True},
#  'R2_A_D2.9.pg.G.D': {'uptake': True, 'excretion': True, 'growth': True},
#  'R1_B_D2.78.pg.G.D': {'uptake': True, 'excretion': True, 'growth': True},
#  'R1_C_H2O.67.pg.G.D': {'uptake': True, 'excretion': True, 'growth': True},
#  'R2A_B_H2O.69.pg.G.D': {'uptake': True, 'excretion': True, 'growth': True},
#  'R2A_C_H2O.16.pg.G.D': {'uptake': True, 'excretion': True, 'growth': True},
#  'R2A_A_H2O.62.pg.G.D': {'uptake': True, 'excretion': True, 'growth': True},
#  'R2A_C_D2.42.pg.G.D': {'uptake': True, 'excretion': True, 'growth': True},
# ...

# %%
# from array 
from json import load

abundances = load(open("/Users/afreiburger/Downloads/mag_abundances (1).json", 'r'))
count = 0

for sample, magAbund in abundances.items():
    # print(sample, magAbund["unbinned_reads"])
    if magAbund["unbinned_reads"] > 0.75:
        count += 1
        print(sample)

print(count, len(abundances))
# Out:
# SF2_A_D1
# SF2_A_D2
# SF2_B_D1
# SF2_B_D2
# SF2_C_D1
# SF2_C_D2
# R2A_A_D1
# R2A_A_D2
# R2A_B_D1
# R2A_B_D2
# R2A_C_D1
# R2A_C_D2
# 12 24

# %% [markdown]
# # email contents to Cliff and Susannah
# 1) Ask for Raw Reeds through the KBase pipeline (do their samples assemble/bin, run CheckM and kracken)
# 2)
